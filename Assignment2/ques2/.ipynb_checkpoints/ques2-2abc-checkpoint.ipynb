# %%
#Importing Data from the CSV file
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from cvxopt import matrix as cvxopt_matrix
from cvxopt import solvers as cvxopt_solvers
from sklearn.svm import SVC as svc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
import seaborn as sns
import time
from scipy import spatial
from itertools import combinations 
import pickle

# %% [markdown]
# 28*28 - one row size = 784 - one training data

# %%
def input_read(file, sep, class0=None, class1=None):
    myFile = pd.read_csv(file, sep=sep, header=None, index_col=False)
    if ((class0!=None) and (class1!=None)):
        df_train = myFile[(myFile.get(784) == class0) | (myFile.get(784) == class1)]
    else: df_train = myFile
    train_classes = df_train[784]
    if ((class0!=None) and (class1!=None)):
        train_classes = (train_classes.apply(lambda x: 1 if (x==class1) else -1))*1.
    train_classes.index = np.arange(0, len(df_train))
    df_train = df_train.drop(784, axis=1)
    df_train.index=(np.arange(0, len(df_train)))
    df_train /= 255
    return df_train.to_numpy(), train_classes.to_numpy();

# %%
def calc_accuracy(classes, pred_classes):   
    acc = 0
    for i in range(len(classes)):
        if (classes[i]==pred_classes[i]):
            acc+=1
    acc = (acc/len(classes))*100
    return acc

# %%
def gauss_kernel_cvxopt(X_train, train_classes, c=1):
    sv_pos_ind=[]
    sv_neg_ind=[]
    start =time.time()
    m,n = X_train.shape
    K = np.zeros((m,m))
    gamma = 0.05
    start = time.time()
    pdist = spatial.distance.pdist(X_train, 'sqeuclidean')
    K = np.exp(-1*gamma*spatial.distance.squareform(pdist))
    end = time.time()
    print("Time to Calculate Gaussian Kernel matrix for CVXOPT= {}s".format(end-start))

    P = cvxopt_matrix(np.outer(train_classes, train_classes)*K)
    q = cvxopt_matrix(-1*np.ones((m,1)))
    G1 =-1*np.eye(m)
    G2 =c*np.eye(m)
    G = cvxopt_matrix(np.vstack((G1,G2)))
    h1 = np.zeros(m)
    h2 = np.ones(m)*c
    h = cvxopt_matrix(np.hstack((h1,h2)))
    A = cvxopt_matrix(train_classes.reshape(1,-1)*1.)
    b = cvxopt_matrix(np.zeros(1))
    cvx_solver = cvxopt_solvers.qp(P, q, G, h, A, b)
    print("The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = {}sec".format(time.time()-start))    

    return cvx_solver;

# %%
def train_classifiers(X_train, train_classes, class1, class2):
    
    train_classes = train_classes.reshape(-1,1)
    m,n = X_train.shape
    c=1 #penalty weight
    print("Running CVX Optimizer to classify Class {} and Class {} with Gaussian Kernel".format(class1, class2))
    print("--------------------TRAINING--------------------------------------------")
    
    cvx_solver = gauss_kernel_cvxopt(X_train, train_classes, c)
    return cvx_solver

# %%
def predict(X_train, X_val, X_test, train_classes, val_classes, test_classes, w, b, kernel_shape, supp_vec_ind, alpha):
    if(kernel_shape == 'linear'):
        train_pred = [1.0 if x >=0 else -1. for x in (np.dot(X_train,w) + b) ]
        train_acc = calc_accuracy(train_classes, train_pred)

        val_pred = [1. if x >=0 else -1. for x in (np.dot(X_val,w) + b) ]
        val_acc = calc_accuracy(val_classes, val_pred)

        test_pred = [1. if x >=0 else -1. for x in (np.dot(X_test,w) + b) ]
        test_acc = calc_accuracy(test_classes, test_pred)
        
    elif(kernel_shape == 'gaussian'):
        cdist = spatial.distance.cdist(X_train[supp_vec_ind], X_train, 'sqeuclidean')
        K_train = np.exp(-1*0.05*(cdist))
        w = np.dot(K_train.T, (alpha[supp_vec_ind]*train_classes[supp_vec_ind]))
        train_pred = w + b
        
        cdist = spatial.distance.cdist(X_train[supp_vec_ind], X_val, 'sqeuclidean')
        K_val = np.exp(-1*0.05*(cdist))
        w = np.dot(K_val.T, (alpha[supp_vec_ind]*train_classes[supp_vec_ind]))
        val_pred = w + b
        
        cdist = spatial.distance.cdist(X_train[supp_vec_ind], X_test, 'sqeuclidean')
        K_test = np.exp(-1*0.05*(cdist))
        w = np.dot(K_test.T, (alpha[supp_vec_ind]*train_classes[supp_vec_ind]))
        test_pred = w + b
        
    return train_pred, val_pred, test_pred;

# %% [markdown]
# # 50 mins to train classifiers

# %%
label=range(10)
comb = combinations(label, 2) 
num_classifier=0
for i in list(comb): 
    num_classifier+=1
    
comb = combinations(label, 2) 

cvx_solver = []
print(num_classifier)
start = time.time()
#Training all the classifiers per class pair
for k in list(comb):   
    X_train, train_classes = input_read('fashion_mnist/train.csv', ',', k[0], k[1])
    cvx_solver.append(train_classifiers(X_train, train_classes, k[0], k[1]))
print("Time taken to train all the classifiers (10C2) with CVX OPT = {:2.3f}sec".format(time.time()-start))
# Out:
# 45
# Running CVX Optimizer to classify Class 0 and Class 1 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.133698463439941s
#      pcost       dcost       gap    pres   dres
#  0: -1.6492e+02 -6.6070e+03  3e+04  2e+00  2e-15
#  1: -1.1407e+02 -3.0686e+03  5e+03  2e-01  2e-15
#  2: -1.0459e+02 -7.6952e+02  9e+02  3e-02  2e-15
#  3: -1.2684e+02 -3.0203e+02  2e+02  6e-03  2e-15
#  4: -1.4133e+02 -2.0101e+02  6e+01  1e-03  2e-15
#  5: -1.4945e+02 -1.6809e+02  2e+01  2e-04  2e-15
#  6: -1.5144e+02 -1.6280e+02  1e+01  3e-05  2e-15
#  7: -1.5364e+02 -1.5728e+02  4e+00  7e-06  1e-15
#  8: -1.5443e+02 -1.5550e+02  1e+00  2e-15  2e-15
#  9: -1.5478e+02 -1.5492e+02  1e-01  2e-15  2e-15
# 10: -1.5483e+02 -1.5484e+02  4e-03  5e-15  2e-15
# 11: -1.5483e+02 -1.5483e+02  6e-05  2e-15  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 80.32979035377502sec
# Running CVX Optimizer to classify Class 0 and Class 2 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.517285108566284s
#      pcost       dcost       gap    pres   dres
#  0: -3.7366e+02 -8.4330e+03  4e+04  2e+00  2e-15
#  1: -2.8341e+02 -4.5691e+03  7e+03  2e-01  2e-15
#  2: -2.6181e+02 -1.1549e+03  1e+03  3e-02  2e-15
#  3: -3.1375e+02 -5.8168e+02  3e+02  6e-03  2e-15
#  4: -3.4227e+02 -4.1865e+02  8e+01  1e-03  2e-15
#  5: -3.5409e+02 -3.7849e+02  2e+01  2e-04  2e-15
#  6: -3.5907e+02 -3.6537e+02  6e+00  2e-05  2e-15
#  7: -3.6070e+02 -3.6180e+02  1e+00  2e-06  2e-15
#  8: -3.6105e+02 -3.6113e+02  8e-02  1e-07  2e-15
#  9: -3.6108e+02 -3.6108e+02  2e-03  3e-09  2e-15
# 10: -3.6108e+02 -3.6108e+02  4e-05  4e-11  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 100.81089043617249sec
# Running CVX Optimizer to classify Class 0 and Class 3 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.3566734790802s
#      pcost       dcost       gap    pres   dres
#  0: -5.0649e+02 -8.5038e+03  4e+04  2e+00  2e-15
#  1: -4.0102e+02 -4.7685e+03  7e+03  2e-01  2e-15
#  2: -3.8628e+02 -1.1830e+03  9e+02  2e-02  3e-15
#  3: -4.5117e+02 -7.2740e+02  3e+02  6e-03  2e-15
#  4: -4.8441e+02 -5.8062e+02  1e+02  1e-03  2e-15
#  5: -5.0013e+02 -5.2734e+02  3e+01  2e-05  3e-15
#  6: -5.0580e+02 -5.1293e+02  7e+00  1e-06  3e-15
#  7: -5.0772e+02 -5.0866e+02  9e-01  7e-14  3e-15
#  8: -5.0800e+02 -5.0814e+02  1e-01  1e-13  3e-15
#  9: -5.0805e+02 -5.0806e+02  6e-03  3e-14  3e-15
# 10: -5.0805e+02 -5.0805e+02  2e-04  8e-14  3e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 99.95945310592651sec
# Running CVX Optimizer to classify Class 0 and Class 4 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.265524864196777s
#      pcost       dcost       gap    pres   dres
#  0: -2.6859e+02 -7.0722e+03  3e+04  2e+00  2e-15
#  1: -1.9279e+02 -3.5589e+03  5e+03  2e-01  2e-15
#  2: -1.7237e+02 -8.6876e+02  9e+02  3e-02  2e-15
#  3: -2.1276e+02 -4.3671e+02  3e+02  7e-03  2e-15
#  4: -2.3708e+02 -3.0397e+02  7e+01  1e-03  2e-15
#  5: -2.4834e+02 -2.6677e+02  2e+01  3e-04  2e-15
#  6: -2.5227e+02 -2.5748e+02  5e+00  6e-05  2e-15
#  7: -2.5364e+02 -2.5461e+02  1e+00  5e-14  2e-15
#  8: -2.5398e+02 -2.5404e+02  5e-02  9e-14  2e-15
#  9: -2.5400e+02 -2.5401e+02  1e-03  1e-13  2e-15
# 10: -2.5400e+02 -2.5400e+02  3e-05  1e-13  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 99.05719017982483sec
# Running CVX Optimizer to classify Class 0 and Class 5 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.2144458293914795s
#      pcost       dcost       gap    pres   dres
#  0: -1.9696e+02 -7.3592e+03  3e+04  2e+00  1e-15
#  1: -1.3157e+02 -3.7922e+03  6e+03  2e-01  2e-15
#  2: -1.0046e+02 -9.5864e+02  1e+03  4e-02  2e-15
#  3: -1.3521e+02 -3.4380e+02  2e+02  7e-03  2e-15
#  4: -1.5380e+02 -2.1468e+02  6e+01  8e-04  2e-15
#  5: -1.6312e+02 -1.8376e+02  2e+01  1e-14  2e-15
#  6: -1.6683e+02 -1.7392e+02  7e+00  3e-15  1e-15
#  7: -1.6823e+02 -1.7056e+02  2e+00  6e-15  1e-15
#  8: -1.6889e+02 -1.6928e+02  4e-01  1e-14  1e-15
#  9: -1.6902e+02 -1.6904e+02  2e-02  1e-14  1e-15
# 10: -1.6903e+02 -1.6903e+02  3e-04  2e-14  1e-15
# 11: -1.6903e+02 -1.6903e+02  4e-06  2e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 106.70980262756348sec
# Running CVX Optimizer to classify Class 0 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.117520332336426s
#      pcost       dcost       gap    pres   dres
#  0: -1.0396e+03 -9.5846e+03  4e+04  2e+00  4e-15
#  1: -8.6974e+02 -5.8661e+03  7e+03  2e-01  4e-15
#  2: -8.9358e+02 -1.8092e+03  1e+03  2e-02  4e-15
#  3: -9.9727e+02 -1.2864e+03  3e+02  5e-03  4e-15
#  4: -1.0441e+03 -1.1319e+03  9e+01  8e-04  5e-15
#  5: -1.0607e+03 -1.0851e+03  2e+01  2e-04  5e-15
#  6: -1.0662e+03 -1.0717e+03  6e+00  3e-05  5e-15
#  7: -1.0675e+03 -1.0687e+03  1e+00  4e-06  5e-15
#  8: -1.0679e+03 -1.0679e+03  5e-02  3e-08  5e-15
#  9: -1.0679e+03 -1.0679e+03  1e-03  6e-10  5e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 91.6298360824585sec
# Running CVX Optimizer to classify Class 0 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.136553049087524s
#      pcost       dcost       gap    pres   dres
#  0: -1.0789e+02 -7.4144e+03  4e+04  2e+00  1e-15
#  1: -5.8581e+01 -3.7245e+03  6e+03  3e-01  2e-15
#  2: -1.8417e+01 -8.7407e+02  1e+03  4e-02  3e-15
#  3: -3.8829e+01 -1.9635e+02  2e+02  5e-03  2e-15
#  4: -5.5771e+01 -1.0639e+02  5e+01  1e-03  2e-15
#  5: -6.3792e+01 -8.0947e+01  2e+01  1e-04  1e-15
#  6: -6.7399e+01 -7.2673e+01  5e+00  2e-05  1e-15
#  7: -6.8657e+01 -7.0232e+01  2e+00  1e-06  1e-15
#  8: -6.9169e+01 -6.9365e+01  2e-01  9e-09  1e-15
#  9: -6.9247e+01 -6.9257e+01  1e-02  4e-10  1e-15
# 10: -6.9251e+01 -6.9251e+01  2e-04  6e-12  1e-15
# 11: -6.9251e+01 -6.9251e+01  3e-06  9e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 108.0308609008789sec
# Running CVX Optimizer to classify Class 0 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.1501548290252686s
#      pcost       dcost       gap    pres   dres
#  0: -2.7984e+02 -7.6220e+03  3e+04  2e+00  2e-15
#  1: -2.0299e+02 -4.0371e+03  6e+03  2e-01  2e-15
#  2: -1.7493e+02 -1.2336e+03  1e+03  4e-02  2e-15
#  3: -2.1659e+02 -4.2387e+02  2e+02  6e-03  2e-15
#  4: -2.4162e+02 -2.9524e+02  6e+01  7e-04  2e-15
#  5: -2.5192e+02 -2.6612e+02  1e+01  1e-04  1e-15
#  6: -2.5529e+02 -2.5891e+02  4e+00  2e-05  1e-15
#  7: -2.5634e+02 -2.5681e+02  5e-01  8e-07  1e-15
#  8: -2.5650e+02 -2.5653e+02  3e-02  4e-08  1e-15
#  9: -2.5651e+02 -2.5651e+02  6e-04  7e-10  1e-15
# 10: -2.5651e+02 -2.5651e+02  1e-05  1e-11  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 98.72243142127991sec
# Running CVX Optimizer to classify Class 0 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.1250855922698975s
#      pcost       dcost       gap    pres   dres
#  0: -1.3464e+02 -6.8388e+03  3e+04  2e+00  1e-15
#  1: -7.6690e+01 -3.2910e+03  5e+03  2e-01  2e-15
#  2: -5.4390e+01 -6.8811e+02  8e+02  3e-02  2e-15
#  3: -8.6653e+01 -2.4599e+02  2e+02  5e-03  2e-15
#  4: -1.0255e+02 -1.5246e+02  5e+01  1e-03  1e-15
#  5: -1.0963e+02 -1.2739e+02  2e+01  3e-04  1e-15
#  6: -1.1318e+02 -1.1820e+02  5e+00  4e-05  1e-15
#  7: -1.1445e+02 -1.1556e+02  1e+00  4e-06  1e-15
#  8: -1.1479e+02 -1.1496e+02  2e-01  5e-07  1e-15
#  9: -1.1485e+02 -1.1486e+02  5e-03  9e-09  1e-15
# 10: -1.1485e+02 -1.1485e+02  1e-04  2e-10  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 99.23983669281006sec
# Running CVX Optimizer to classify Class 1 and Class 2 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.132903575897217s
#      pcost       dcost       gap    pres   dres
#  0: -1.3552e+02 -7.1330e+03  3e+04  2e+00  1e-15
#  1: -8.6508e+01 -3.3924e+03  5e+03  2e-01  2e-15
#  2: -7.2456e+01 -7.5584e+02  9e+02  3e-02  2e-15
#  3: -9.8211e+01 -2.9087e+02  2e+02  6e-03  2e-15
#  4: -1.1260e+02 -1.7965e+02  7e+01  2e-03  2e-15
#  5: -1.2011e+02 -1.4295e+02  2e+01  3e-04  1e-15
#  6: -1.2381e+02 -1.3099e+02  7e+00  2e-14  1e-15
#  7: -1.2520e+02 -1.2765e+02  2e+00  1e-14  1e-15
#  8: -1.2579e+02 -1.2645e+02  7e-01  3e-15  1e-15
#  9: -1.2601e+02 -1.2606e+02  5e-02  2e-15  1e-15
# 10: -1.2603e+02 -1.2603e+02  1e-03  2e-14  1e-15
# 11: -1.2603e+02 -1.2603e+02  1e-05  3e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 108.16043543815613sec
# Running CVX Optimizer to classify Class 1 and Class 3 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.142311334609985s
#      pcost       dcost       gap    pres   dres
#  0: -2.2920e+02 -7.6513e+03  4e+04  2e+00  2e-15
#  1: -1.5609e+02 -3.9103e+03  6e+03  2e-01  3e-15
#  2: -1.3600e+02 -9.2629e+02  1e+03  3e-02  3e-15
#  3: -1.7295e+02 -4.3323e+02  3e+02  7e-03  2e-15
#  4: -1.9647e+02 -2.7544e+02  8e+01  1e-03  2e-15
#  5: -2.0746e+02 -2.3515e+02  3e+01  1e-04  2e-15
#  6: -2.1226e+02 -2.2191e+02  1e+01  2e-05  2e-15
#  7: -2.1376e+02 -2.1815e+02  4e+00  5e-15  2e-15
#  8: -2.1495e+02 -2.1581e+02  9e-01  3e-15  2e-15
#  9: -2.1517e+02 -2.1539e+02  2e-01  2e-14  3e-15
# 10: -2.1525e+02 -2.1526e+02  7e-03  3e-14  2e-15
# 11: -2.1526e+02 -2.1526e+02  1e-04  3e-14  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 108.60233068466187sec
# Running CVX Optimizer to classify Class 1 and Class 4 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 5.137632608413696s
#      pcost       dcost       gap    pres   dres
#  0: -1.2784e+02 -6.4239e+03  3e+04  2e+00  2e-15
#  1: -8.0058e+01 -2.9152e+03  4e+03  2e-01  2e-15
#  2: -6.9558e+01 -6.4681e+02  7e+02  3e-02  2e-15
#  3: -9.4376e+01 -2.5073e+02  2e+02  5e-03  2e-15
#  4: -1.0877e+02 -1.5571e+02  5e+01  7e-04  1e-15
#  5: -1.1554e+02 -1.3286e+02  2e+01  1e-04  1e-15
#  6: -1.1887e+02 -1.2384e+02  5e+00  2e-06  1e-15
#  7: -1.2010e+02 -1.2121e+02  1e+00  2e-14  1e-15
#  8: -1.2044e+02 -1.2063e+02  2e-01  2e-14  1e-15
#  9: -1.2051e+02 -1.2052e+02  1e-02  3e-14  1e-15
# 10: -1.2052e+02 -1.2052e+02  2e-04  3e-14  1e-15
# 11: -1.2052e+02 -1.2052e+02  9e-06  7e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 105.26707124710083sec
# Running CVX Optimizer to classify Class 1 and Class 5 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.952662706375122s
#      pcost       dcost       gap    pres   dres
#  0: -9.3956e+01 -6.5185e+03  3e+04  2e+00  1e-15
#  1: -5.0069e+01 -2.9491e+03  5e+03  2e-01  2e-15
#  2: -3.9046e+01 -6.7825e+02  8e+02  3e-02  2e-15
#  3: -6.0172e+01 -2.0557e+02  2e+02  5e-03  2e-15
#  4: -7.2614e+01 -1.1949e+02  5e+01  1e-03  2e-15
#  5: -7.7575e+01 -9.6388e+01  2e+01  1e-04  1e-15
#  6: -7.9825e+01 -8.8992e+01  9e+00  7e-15  1e-15
#  7: -8.1322e+01 -8.4537e+01  3e+00  8e-15  1e-15
#  8: -8.1909e+01 -8.3041e+01  1e+00  2e-15  1e-15
#  9: -8.2190e+01 -8.2488e+01  3e-01  8e-15  1e-15
# 10: -8.2279e+01 -8.2332e+01  5e-02  1e-14  1e-15
# 11: -8.2299e+01 -8.2300e+01  2e-03  5e-15  1e-15
# 12: -8.2299e+01 -8.2299e+01  2e-05  2e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 71.9646143913269sec
# Running CVX Optimizer to classify Class 1 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.93254017829895s
#      pcost       dcost       gap    pres   dres
#  0: -1.6321e+02 -6.5609e+03  3e+04  2e+00  1e-15
#  1: -1.1075e+02 -3.0589e+03  5e+03  2e-01  2e-15
#  2: -1.0167e+02 -7.6887e+02  9e+02  3e-02  2e-15
#  3: -1.2535e+02 -3.1952e+02  2e+02  7e-03  2e-15
#  4: -1.4028e+02 -2.0638e+02  7e+01  2e-03  2e-15
#  5: -1.4794e+02 -1.7118e+02  2e+01  2e-04  1e-15
#  6: -1.5107e+02 -1.6136e+02  1e+01  1e-05  1e-15
#  7: -1.5295e+02 -1.5632e+02  3e+00  3e-06  1e-15
#  8: -1.5376e+02 -1.5442e+02  7e-01  3e-15  1e-15
#  9: -1.5397e+02 -1.5405e+02  8e-02  2e-14  1e-15
# 10: -1.5400e+02 -1.5400e+02  2e-03  5e-15  1e-15
# 11: -1.5400e+02 -1.5400e+02  6e-05  1e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.99083542823792sec
# Running CVX Optimizer to classify Class 1 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.937071084976196s
#      pcost       dcost       gap    pres   dres
#  0: -6.5955e+01 -6.5221e+03  3e+04  2e+00  1e-15
#  1: -3.1834e+01 -2.9574e+03  5e+03  2e-01  2e-15
#  2: -1.0088e+01 -5.1383e+02  7e+02  2e-02  2e-15
#  3: -2.7978e+01 -1.2024e+02  1e+02  3e-03  2e-15
#  4: -3.8190e+01 -7.0454e+01  3e+01  8e-04  1e-15
#  5: -4.2441e+01 -5.6406e+01  1e+01  3e-04  1e-15
#  6: -4.4726e+01 -5.0658e+01  6e+00  5e-05  1e-15
#  7: -4.5554e+01 -4.8795e+01  3e+00  1e-14  1e-15
#  8: -4.6276e+01 -4.7407e+01  1e+00  2e-14  1e-15
#  9: -4.6545e+01 -4.6900e+01  4e-01  3e-14  1e-15
# 10: -4.6685e+01 -4.6706e+01  2e-02  6e-15  1e-15
# 11: -4.6694e+01 -4.6695e+01  4e-04  3e-14  1e-15
# 12: -4.6694e+01 -4.6694e+01  5e-06  5e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 72.06096696853638sec
# Running CVX Optimizer to classify Class 1 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.955540418624878s
#      pcost       dcost       gap    pres   dres
#  0: -1.1469e+02 -6.6612e+03  3e+04  2e+00  2e-15
#  1: -6.4473e+01 -3.0959e+03  5e+03  2e-01  2e-15
#  2: -5.1691e+01 -7.9899e+02  1e+03  3e-02  2e-15
#  3: -7.6800e+01 -2.6329e+02  2e+02  6e-03  2e-15
#  4: -9.2410e+01 -1.4435e+02  5e+01  1e-03  2e-15
#  5: -9.8364e+01 -1.1956e+02  2e+01  3e-04  1e-15
#  6: -1.0088e+02 -1.1105e+02  1e+01  2e-14  1e-15
#  7: -1.0257e+02 -1.0606e+02  3e+00  5e-15  1e-15
#  8: -1.0324e+02 -1.0426e+02  1e+00  6e-15  1e-15
#  9: -1.0355e+02 -1.0367e+02  1e-01  1e-14  1e-15
# 10: -1.0359e+02 -1.0359e+02  5e-03  7e-16  1e-15
# 11: -1.0359e+02 -1.0359e+02  1e-04  8e-15  1e-15
# 12: -1.0359e+02 -1.0359e+02  2e-06  6e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 72.16138052940369sec
# Running CVX Optimizer to classify Class 1 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.948968887329102s
#      pcost       dcost       gap    pres   dres
#  0: -7.7086e+01 -6.2810e+03  3e+04  2e+00  1e-15
#  1: -3.6190e+01 -2.7260e+03  4e+03  2e-01  2e-15
#  2: -2.6916e+01 -5.5124e+02  7e+02  2e-02  2e-15
#  3: -4.8738e+01 -1.5892e+02  1e+02  3e-03  2e-15
#  4: -5.9871e+01 -9.4267e+01  4e+01  8e-04  1e-15
#  5: -6.4611e+01 -7.7166e+01  1e+01  1e-04  1e-15
#  6: -6.6205e+01 -7.3281e+01  7e+00  8e-06  1e-15
#  7: -6.7614e+01 -6.9700e+01  2e+00  2e-06  1e-15
#  8: -6.8024e+01 -6.8779e+01  8e-01  4e-15  1e-15
#  9: -6.8259e+01 -6.8394e+01  1e-01  9e-15  1e-15
# 10: -6.8310e+01 -6.8315e+01  5e-03  6e-15  1e-15
# 11: -6.8312e+01 -6.8312e+01  1e-04  2e-14  1e-15
# 12: -6.8312e+01 -6.8312e+01  2e-06  3e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 72.17790102958679sec
# Running CVX Optimizer to classify Class 2 and Class 3 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.947459697723389s
#      pcost       dcost       gap    pres   dres
#  0: -3.0404e+02 -8.2833e+03  4e+04  2e+00  1e-15
#  1: -2.1981e+02 -4.4663e+03  7e+03  3e-01  2e-15
#  2: -1.8274e+02 -1.0106e+03  1e+03  3e-02  2e-15
#  3: -2.3561e+02 -4.7608e+02  3e+02  6e-03  2e-15
#  4: -2.6244e+02 -3.3488e+02  8e+01  1e-03  2e-15
#  5: -2.7389e+02 -2.9769e+02  2e+01  2e-04  2e-15
#  6: -2.7877e+02 -2.8539e+02  7e+00  4e-05  2e-15
#  7: -2.8041e+02 -2.8192e+02  2e+00  3e-06  2e-15
#  8: -2.8091e+02 -2.8102e+02  1e-01  7e-08  2e-15
#  9: -2.8095e+02 -2.8095e+02  2e-03  9e-10  2e-15
# 10: -2.8095e+02 -2.8095e+02  4e-05  1e-11  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.66486883163452sec
# Running CVX Optimizer to classify Class 2 and Class 4 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.961647987365723s
#      pcost       dcost       gap    pres   dres
#  0: -9.4630e+02 -1.0583e+04  5e+04  3e+00  2e-15
#  1: -7.4464e+02 -6.9192e+03  9e+03  3e-01  3e-15
#  2: -7.6719e+02 -1.7237e+03  1e+03  2e-02  3e-15
#  3: -8.9919e+02 -1.2167e+03  3e+02  4e-03  3e-15
#  4: -9.4723e+02 -1.0952e+03  1e+02  1e-03  3e-15
#  5: -9.7572e+02 -1.0167e+03  4e+01  2e-04  3e-15
#  6: -9.8536e+02 -9.9280e+02  7e+00  1e-05  3e-15
#  7: -9.8745e+02 -9.8827e+02  8e-01  1e-07  3e-15
#  8: -9.8772e+02 -9.8774e+02  3e-02  3e-09  3e-15
#  9: -9.8773e+02 -9.8773e+02  5e-04  5e-11  3e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 56.768481492996216sec
# Running CVX Optimizer to classify Class 2 and Class 5 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.92934775352478s
#      pcost       dcost       gap    pres   dres
#  0: -1.8703e+02 -7.3989e+03  3e+04  2e+00  1e-15
#  1: -1.1528e+02 -3.8473e+03  6e+03  2e-01  2e-15
#  2: -8.4105e+01 -8.9248e+02  1e+03  3e-02  2e-15
#  3: -1.3537e+02 -2.8753e+02  2e+02  4e-03  2e-15
#  4: -1.5511e+02 -2.0703e+02  5e+01  7e-04  1e-15
#  5: -1.6371e+02 -1.8115e+02  2e+01  8e-05  1e-15
#  6: -1.6703e+02 -1.7283e+02  6e+00  3e-06  1e-15
#  7: -1.6834e+02 -1.6982e+02  1e+00  1e-14  1e-15
#  8: -1.6876e+02 -1.6899e+02  2e-01  1e-14  1e-15
#  9: -1.6884e+02 -1.6885e+02  8e-03  4e-15  1e-15
# 10: -1.6885e+02 -1.6885e+02  1e-04  3e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.944693088531494sec
# Running CVX Optimizer to classify Class 2 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.931932210922241s
#      pcost       dcost       gap    pres   dres
#  0: -9.6781e+02 -1.0280e+04  5e+04  3e+00  3e-15
#  1: -7.7941e+02 -6.5268e+03  8e+03  2e-01  3e-15
#  2: -8.3083e+02 -1.8673e+03  1e+03  2e-02  3e-15
#  3: -9.4685e+02 -1.2637e+03  3e+02  5e-03  3e-15
#  4: -9.9989e+02 -1.0807e+03  8e+01  7e-04  3e-15
#  5: -1.0159e+03 -1.0374e+03  2e+01  1e-04  3e-15
#  6: -1.0214e+03 -1.0238e+03  2e+00  8e-06  3e-15
#  7: -1.0221e+03 -1.0223e+03  2e-01  6e-07  3e-15
#  8: -1.0222e+03 -1.0222e+03  7e-03  1e-08  4e-15
#  9: -1.0222e+03 -1.0222e+03  2e-04  2e-10  4e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 56.69216585159302sec
# Running CVX Optimizer to classify Class 2 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.935493230819702s
#      pcost       dcost       gap    pres   dres
#  0: -1.0352e+02 -7.4392e+03  4e+04  2e+00  2e-15
#  1: -5.2259e+01 -3.7516e+03  6e+03  3e-01  2e-15
#  2: -1.0077e+01 -8.8825e+02  1e+03  4e-02  3e-15
#  3: -3.5635e+01 -1.9440e+02  2e+02  5e-03  2e-15
#  4: -5.4188e+01 -1.0235e+02  5e+01  9e-04  2e-15
#  5: -6.2019e+01 -7.9857e+01  2e+01  1e-04  1e-15
#  6: -6.5729e+01 -7.1122e+01  5e+00  5e-06  1e-15
#  7: -6.7167e+01 -6.8294e+01  1e+00  3e-07  1e-15
#  8: -6.7544e+01 -6.7677e+01  1e-01  2e-08  1e-15
#  9: -6.7596e+01 -6.7602e+01  6e-03  2e-14  1e-15
# 10: -6.7599e+01 -6.7599e+01  9e-05  2e-15  1e-15
# 11: -6.7599e+01 -6.7599e+01  3e-06  2e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 67.046706199646sec
# Running CVX Optimizer to classify Class 2 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.921687126159668s
#      pcost       dcost       gap    pres   dres
#  0: -2.7490e+02 -7.4241e+03  3e+04  2e+00  1e-15
#  1: -1.9123e+02 -3.9068e+03  6e+03  2e-01  2e-15
#  2: -1.6914e+02 -1.0114e+03  1e+03  3e-02  2e-15
#  3: -2.2772e+02 -4.2201e+02  2e+02  5e-03  2e-15
#  4: -2.5292e+02 -3.0412e+02  5e+01  8e-04  1e-15
#  5: -2.6267e+02 -2.7651e+02  1e+01  1e-04  1e-15
#  6: -2.6583e+02 -2.6927e+02  3e+00  2e-05  1e-15
#  7: -2.6678e+02 -2.6733e+02  6e-01  3e-06  1e-15
#  8: -2.6696e+02 -2.6699e+02  3e-02  1e-07  1e-15
#  9: -2.6697e+02 -2.6697e+02  6e-04  2e-09  1e-15
# 10: -2.6697e+02 -2.6697e+02  1e-05  2e-11  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.709089517593384sec
# Running CVX Optimizer to classify Class 2 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.950810432434082s
#      pcost       dcost       gap    pres   dres
#  0: -1.3122e+02 -6.8313e+03  3e+04  2e+00  1e-15
#  1: -6.8632e+01 -3.3021e+03  5e+03  2e-01  2e-15
#  2: -4.4226e+01 -5.7527e+02  6e+02  2e-02  2e-15
#  3: -8.9948e+01 -1.9526e+02  1e+02  2e-03  2e-15
#  4: -1.0529e+02 -1.3890e+02  3e+01  6e-04  1e-15
#  5: -1.1181e+02 -1.2245e+02  1e+01  1e-04  1e-15
#  6: -1.1461e+02 -1.1691e+02  2e+00  8e-06  1e-15
#  7: -1.1534e+02 -1.1566e+02  3e-01  3e-07  1e-15
#  8: -1.1546e+02 -1.1548e+02  2e-02  4e-09  1e-15
#  9: -1.1546e+02 -1.1547e+02  5e-04  1e-10  1e-15
# 10: -1.1546e+02 -1.1546e+02  1e-05  2e-12  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.80045938491821sec
# Running CVX Optimizer to classify Class 3 and Class 4 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.933098316192627s
#      pcost       dcost       gap    pres   dres
#  0: -4.2846e+02 -7.6683e+03  3e+04  2e+00  2e-15
#  1: -3.2882e+02 -4.1247e+03  6e+03  2e-01  2e-15
#  2: -3.0989e+02 -9.4797e+02  7e+02  2e-02  3e-15
#  3: -3.7592e+02 -5.6057e+02  2e+02  4e-03  2e-15
#  4: -4.0510e+02 -4.5864e+02  6e+01  7e-04  2e-15
#  5: -4.1586e+02 -4.3199e+02  2e+01  1e-04  2e-15
#  6: -4.1976e+02 -4.2383e+02  4e+00  1e-05  2e-15
#  7: -4.2092e+02 -4.2164e+02  7e-01  5e-14  3e-15
#  8: -4.2117e+02 -4.2123e+02  6e-02  6e-14  2e-15
#  9: -4.2119e+02 -4.2119e+02  1e-03  8e-14  3e-15
# 10: -4.2119e+02 -4.2119e+02  2e-05  8e-14  3e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.79592227935791sec
# Running CVX Optimizer to classify Class 3 and Class 5 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.9417619705200195s
#      pcost       dcost       gap    pres   dres
#  0: -1.5808e+02 -7.8955e+03  4e+04  2e+00  1e-15
#  1: -8.8651e+01 -4.1551e+03  7e+03  3e-01  2e-15
#  2: -4.1501e+01 -1.0107e+03  1e+03  4e-02  2e-15
#  3: -8.5729e+01 -2.6576e+02  2e+02  5e-03  2e-15
#  4: -1.0518e+02 -1.7631e+02  8e+01  2e-03  1e-15
#  5: -1.1475e+02 -1.4040e+02  3e+01  3e-04  1e-15
#  6: -1.1877e+02 -1.2916e+02  1e+01  4e-15  1e-15
#  7: -1.2050e+02 -1.2484e+02  4e+00  9e-15  1e-15
#  8: -1.2142e+02 -1.2270e+02  1e+00  3e-16  1e-15
#  9: -1.2181e+02 -1.2194e+02  1e-01  6e-15  1e-15
# 10: -1.2186e+02 -1.2187e+02  1e-02  8e-15  1e-15
# 11: -1.2186e+02 -1.2186e+02  2e-04  1e-14  1e-15
# 12: -1.2186e+02 -1.2186e+02  3e-06  6e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 72.04822754859924sec
# Running CVX Optimizer to classify Class 3 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.936317443847656s
#      pcost       dcost       gap    pres   dres
#  0: -5.1433e+02 -9.6131e+03  5e+04  3e+00  2e-15
#  1: -3.9419e+02 -5.7409e+03  8e+03  3e-01  2e-15
#  2: -3.6455e+02 -1.3710e+03  1e+03  2e-02  3e-15
#  3: -4.4119e+02 -7.5464e+02  3e+02  5e-03  2e-15
#  4: -4.7842e+02 -5.8509e+02  1e+02  5e-04  2e-15
#  5: -4.9392e+02 -5.2894e+02  4e+01  1e-04  2e-15
#  6: -4.9931e+02 -5.1319e+02  1e+01  3e-05  2e-15
#  7: -5.0143e+02 -5.0716e+02  6e+00  1e-13  2e-15
#  8: -5.0278e+02 -5.0408e+02  1e+00  4e-15  2e-15
#  9: -5.0315e+02 -5.0328e+02  1e-01  3e-14  2e-15
# 10: -5.0319e+02 -5.0320e+02  4e-03  3e-14  2e-15
# 11: -5.0319e+02 -5.0319e+02  7e-05  7e-14  2e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 67.00016903877258sec
# Running CVX Optimizer to classify Class 3 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.931734323501587s
#      pcost       dcost       gap    pres   dres
#  0: -9.2836e+01 -7.1347e+03  3e+04  2e+00  1e-15
#  1: -4.5561e+01 -3.4670e+03  6e+03  2e-01  2e-15
#  2: -6.5966e+00 -7.3664e+02  1e+03  3e-02  3e-15
#  3: -2.9623e+01 -1.6707e+02  2e+02  4e-03  2e-15
#  4: -4.5780e+01 -8.6304e+01  4e+01  9e-04  2e-15
#  5: -5.2466e+01 -6.7231e+01  2e+01  2e-04  1e-15
#  6: -5.5594e+01 -6.0481e+01  5e+00  4e-05  1e-15
#  7: -5.6733e+01 -5.8387e+01  2e+00  6e-06  1e-15
#  8: -5.7241e+01 -5.7533e+01  3e-01  3e-07  1e-15
#  9: -5.7346e+01 -5.7382e+01  4e-02  4e-08  1e-15
# 10: -5.7361e+01 -5.7362e+01  7e-04  3e-10  1e-15
# 11: -5.7361e+01 -5.7361e+01  2e-05  6e-12  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.80130648612976sec
# Running CVX Optimizer to classify Class 3 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.936506748199463s
#      pcost       dcost       gap    pres   dres
#  0: -2.2223e+02 -8.4141e+03  4e+04  2e+00  1e-15
#  1: -1.3588e+02 -4.6583e+03  8e+03  3e-01  2e-15
#  2: -8.2884e+01 -1.3246e+03  2e+03  5e-02  2e-15
#  3: -1.3866e+02 -4.3341e+02  3e+02  8e-03  2e-15
#  4: -1.6992e+02 -2.3917e+02  7e+01  1e-03  2e-15
#  5: -1.8157e+02 -2.0218e+02  2e+01  2e-04  1e-15
#  6: -1.8572e+02 -1.9211e+02  6e+00  5e-05  1e-15
#  7: -1.8735e+02 -1.8861e+02  1e+00  4e-06  1e-15
#  8: -1.8774e+02 -1.8789e+02  1e-01  3e-07  1e-15
#  9: -1.8779e+02 -1.8780e+02  5e-03  8e-09  1e-15
# 10: -1.8779e+02 -1.8779e+02  1e-04  1e-10  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.801103830337524sec
# Running CVX Optimizer to classify Class 3 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.948783874511719s
#      pcost       dcost       gap    pres   dres
#  0: -1.1714e+02 -7.2200e+03  3e+04  2e+00  1e-15
#  1: -5.7504e+01 -3.5569e+03  6e+03  2e-01  2e-15
#  2: -2.3175e+01 -6.8503e+02  8e+02  2e-02  2e-15
#  3: -6.5374e+01 -1.7868e+02  1e+02  3e-03  2e-15
#  4: -8.2099e+01 -1.1645e+02  4e+01  6e-04  1e-15
#  5: -8.8468e+01 -1.0144e+02  1e+01  1e-04  1e-15
#  6: -9.1379e+01 -9.5512e+01  4e+00  1e-05  1e-15
#  7: -9.2466e+01 -9.3422e+01  1e+00  1e-06  1e-15
#  8: -9.2761e+01 -9.2921e+01  2e-01  9e-08  1e-15
#  9: -9.2821e+01 -9.2827e+01  6e-03  2e-09  1e-15
# 10: -9.2823e+01 -9.2823e+01  1e-04  4e-11  1e-15
# 11: -9.2823e+01 -9.2823e+01  3e-06  7e-13  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 67.02585482597351sec
# Running CVX Optimizer to classify Class 4 and Class 5 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.9550018310546875s
#      pcost       dcost       gap    pres   dres
#  0: -1.5598e+02 -6.9927e+03  3e+04  2e+00  1e-15
#  1: -8.8657e+01 -3.4857e+03  6e+03  2e-01  2e-15
#  2: -5.9446e+01 -7.3609e+02  8e+02  2e-02  2e-15
#  3: -1.0523e+02 -2.6151e+02  2e+02  4e-03  2e-15
#  4: -1.2171e+02 -1.8069e+02  6e+01  1e-03  1e-15
#  5: -1.2850e+02 -1.5673e+02  3e+01  3e-14  1e-15
#  6: -1.3314e+02 -1.4204e+02  9e+00  2e-14  1e-15
#  7: -1.3446e+02 -1.3849e+02  4e+00  3e-15  1e-15
#  8: -1.3538e+02 -1.3651e+02  1e+00  1e-14  1e-15
#  9: -1.3573e+02 -1.3581e+02  8e-02  2e-14  1e-15
# 10: -1.3576e+02 -1.3576e+02  2e-03  3e-14  1e-15
# 11: -1.3576e+02 -1.3576e+02  6e-05  2e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 67.3108344078064sec
# Running CVX Optimizer to classify Class 4 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.932546377182007s
#      pcost       dcost       gap    pres   dres
#  0: -8.9772e+02 -9.6565e+03  4e+04  2e+00  3e-15
#  1: -7.1427e+02 -5.9961e+03  8e+03  2e-01  3e-15
#  2: -7.5707e+02 -1.7361e+03  1e+03  3e-02  3e-15
#  3: -8.6971e+02 -1.1390e+03  3e+02  5e-03  3e-15
#  4: -9.1628e+02 -1.0034e+03  9e+01  7e-04  3e-15
#  5: -9.3428e+02 -9.5281e+02  2e+01  8e-05  3e-15
#  6: -9.3898e+02 -9.4171e+02  3e+00  8e-06  4e-15
#  7: -9.3981e+02 -9.3998e+02  2e-01  4e-07  4e-15
#  8: -9.3987e+02 -9.3987e+02  7e-03  1e-08  4e-15
#  9: -9.3987e+02 -9.3987e+02  2e-04  2e-10  4e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 56.60854434967041sec
# Running CVX Optimizer to classify Class 4 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.938223838806152s
#      pcost       dcost       gap    pres   dres
#  0: -9.3076e+01 -7.2188e+03  3e+04  2e+00  1e-15
#  1: -4.4606e+01 -3.5557e+03  6e+03  2e-01  2e-15
#  2: -6.2621e+00 -7.8910e+02  1e+03  4e-02  3e-15
#  3: -3.2395e+01 -1.7430e+02  2e+02  4e-03  2e-15
#  4: -4.9879e+01 -9.0250e+01  4e+01  8e-04  2e-15
#  5: -5.7061e+01 -7.1118e+01  1e+01  1e-04  1e-15
#  6: -6.0160e+01 -6.4483e+01  4e+00  1e-05  1e-15
#  7: -6.1222e+01 -6.2514e+01  1e+00  3e-06  1e-15
#  8: -6.1633e+01 -6.1812e+01  2e-01  2e-14  1e-15
#  9: -6.1706e+01 -6.1711e+01  5e-03  2e-14  1e-15
# 10: -6.1709e+01 -6.1709e+01  9e-05  8e-15  1e-15
# 11: -6.1709e+01 -6.1709e+01  2e-06  6e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.92940187454224sec
# Running CVX Optimizer to classify Class 4 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.921117544174194s
#      pcost       dcost       gap    pres   dres
#  0: -2.2465e+02 -6.8855e+03  3e+04  2e+00  1e-15
#  1: -1.4528e+02 -3.4652e+03  5e+03  2e-01  2e-15
#  2: -1.2473e+02 -7.6671e+02  8e+02  2e-02  2e-15
#  3: -1.7986e+02 -3.1703e+02  1e+02  3e-03  2e-15
#  4: -1.9975e+02 -2.3811e+02  4e+01  6e-04  1e-15
#  5: -2.0764e+02 -2.1714e+02  1e+01  9e-05  1e-15
#  6: -2.1013e+02 -2.1205e+02  2e+00  1e-05  1e-15
#  7: -2.1073e+02 -2.1097e+02  2e-01  7e-07  1e-15
#  8: -2.1081e+02 -2.1082e+02  1e-02  3e-08  1e-15
#  9: -2.1082e+02 -2.1082e+02  3e-04  6e-10  1e-15
# 10: -2.1082e+02 -2.1082e+02  6e-06  7e-12  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.79583764076233sec
# Running CVX Optimizer to classify Class 4 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.945314168930054s
#      pcost       dcost       gap    pres   dres
#  0: -1.1407e+02 -6.5885e+03  3e+04  2e+00  1e-15
#  1: -5.4731e+01 -3.0743e+03  5e+03  2e-01  2e-15
#  2: -3.3614e+01 -5.3901e+02  6e+02  2e-02  2e-15
#  3: -7.3851e+01 -1.8900e+02  1e+02  3e-03  2e-15
#  4: -8.8826e+01 -1.2601e+02  4e+01  7e-04  1e-15
#  5: -9.4967e+01 -1.0838e+02  1e+01  2e-04  1e-15
#  6: -9.7972e+01 -1.0158e+02  4e+00  2e-05  1e-15
#  7: -9.8948e+01 -9.9746e+01  8e-01  2e-06  1e-15
#  8: -9.9202e+01 -9.9319e+01  1e-01  2e-07  1e-15
#  9: -9.9246e+01 -9.9249e+01  3e-03  3e-09  1e-15
# 10: -9.9248e+01 -9.9248e+01  7e-05  7e-11  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.85584998130798sec
# Running CVX Optimizer to classify Class 5 and Class 6 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.910359621047974s
#      pcost       dcost       gap    pres   dres
#  0: -2.0533e+02 -7.5506e+03  3e+04  2e+00  1e-15
#  1: -1.2813e+02 -3.9857e+03  6e+03  2e-01  2e-15
#  2: -9.5987e+01 -7.8644e+02  8e+02  2e-02  2e-15
#  3: -1.4760e+02 -3.3431e+02  2e+02  5e-03  2e-15
#  4: -1.6699e+02 -2.3327e+02  7e+01  1e-03  1e-15
#  5: -1.7565e+02 -2.0037e+02  3e+01  2e-04  1e-15
#  6: -1.7993e+02 -1.8778e+02  8e+00  3e-05  1e-15
#  7: -1.8146e+02 -1.8393e+02  2e+00  4e-14  1e-15
#  8: -1.8213e+02 -1.8255e+02  4e-01  2e-14  1e-15
#  9: -1.8227e+02 -1.8229e+02  3e-02  5e-15  1e-15
# 10: -1.8228e+02 -1.8228e+02  4e-04  1e-15  1e-15
# 11: -1.8228e+02 -1.8228e+02  7e-06  3e-15  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 67.284259557724sec
# Running CVX Optimizer to classify Class 5 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.946295499801636s
#      pcost       dcost       gap    pres   dres
#  0: -3.7910e+02 -8.4574e+03  4e+04  2e+00  3e-15
#  1: -2.7286e+02 -4.7996e+03  8e+03  3e-01  4e-15
#  2: -2.3217e+02 -1.1233e+03  1e+03  2e-02  3e-15
#  3: -3.0157e+02 -5.9118e+02  3e+02  6e-03  3e-15
#  4: -3.3486e+02 -4.4665e+02  1e+02  1e-03  3e-15
#  5: -3.5167e+02 -3.9013e+02  4e+01  3e-04  3e-15
#  6: -3.5933e+02 -3.6849e+02  9e+00  2e-05  3e-15
#  7: -3.6174e+02 -3.6303e+02  1e+00  6e-07  3e-15
#  8: -3.6215e+02 -3.6228e+02  1e-01  5e-08  3e-15
#  9: -3.6219e+02 -3.6220e+02  5e-03  1e-09  3e-15
# 10: -3.6219e+02 -3.6219e+02  9e-05  2e-11  3e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.70482635498047sec
# Running CVX Optimizer to classify Class 5 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.924904823303223s
#      pcost       dcost       gap    pres   dres
#  0: -2.5877e+02 -7.3164e+03  3e+04  2e+00  1e-15
#  1: -1.6844e+02 -3.8401e+03  5e+03  2e-01  2e-15
#  2: -1.7506e+02 -7.0557e+02  6e+02  1e-02  2e-15
#  3: -2.3098e+02 -3.8532e+02  2e+02  3e-03  1e-15
#  4: -2.5075e+02 -3.0061e+02  5e+01  6e-04  1e-15
#  5: -2.5761e+02 -2.7802e+02  2e+01  2e-04  1e-15
#  6: -2.6136e+02 -2.6687e+02  6e+00  1e-05  1e-15
#  7: -2.6251e+02 -2.6379e+02  1e+00  7e-15  1e-15
#  8: -2.6285e+02 -2.6299e+02  1e-01  3e-14  1e-15
#  9: -2.6289e+02 -2.6290e+02  5e-03  3e-14  1e-15
# 10: -2.6290e+02 -2.6290e+02  1e-04  3e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.762580156326294sec
# Running CVX Optimizer to classify Class 5 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.921832323074341s
#      pcost       dcost       gap    pres   dres
#  0: -2.7302e+02 -7.5652e+03  3e+04  2e+00  1e-15
#  1: -1.9616e+02 -4.0285e+03  6e+03  2e-01  2e-15
#  2: -1.7674e+02 -7.9849e+02  7e+02  2e-02  2e-15
#  3: -2.2908e+02 -4.2790e+02  2e+02  4e-03  2e-15
#  4: -2.5164e+02 -3.1447e+02  6e+01  7e-04  2e-15
#  5: -2.6163e+02 -2.8082e+02  2e+01  2e-05  1e-15
#  6: -2.6538e+02 -2.6993e+02  5e+00  7e-07  1e-15
#  7: -2.6630e+02 -2.6772e+02  1e+00  2e-14  1e-15
#  8: -2.6665e+02 -2.6698e+02  3e-01  8e-15  1e-15
#  9: -2.6674e+02 -2.6679e+02  5e-02  2e-14  1e-15
# 10: -2.6676e+02 -2.6676e+02  1e-03  3e-14  1e-15
# 11: -2.6676e+02 -2.6676e+02  1e-05  3e-14  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.95412230491638sec
# Running CVX Optimizer to classify Class 6 and Class 7 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.95189642906189s
#      pcost       dcost       gap    pres   dres
#  0: -1.1028e+02 -7.5103e+03  4e+04  2e+00  2e-15
#  1: -5.6897e+01 -3.8143e+03  7e+03  3e-01  2e-15
#  2: -1.3830e+01 -9.2363e+02  1e+03  4e-02  3e-15
#  3: -3.9528e+01 -1.9616e+02  2e+02  4e-03  2e-15
#  4: -5.5680e+01 -1.2195e+02  7e+01  2e-03  2e-15
#  5: -6.4887e+01 -8.8241e+01  2e+01  1e-04  2e-15
#  6: -6.9418e+01 -7.6829e+01  7e+00  2e-05  1e-15
#  7: -7.1201e+01 -7.3118e+01  2e+00  2e-06  1e-15
#  8: -7.1797e+01 -7.2062e+01  3e-01  1e-07  1e-15
#  9: -7.1900e+01 -7.1908e+01  8e-03  2e-09  1e-15
# 10: -7.1903e+01 -7.1903e+01  1e-04  3e-11  1e-15
# 11: -7.1903e+01 -7.1903e+01  2e-06  3e-13  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 69.19361114501953sec
# Running CVX Optimizer to classify Class 6 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.939972639083862s
#      pcost       dcost       gap    pres   dres
#  0: -3.3801e+02 -8.0319e+03  4e+04  2e+00  1e-15
#  1: -2.4315e+02 -4.4272e+03  7e+03  2e-01  2e-15
#  2: -2.2086e+02 -9.6970e+02  9e+02  2e-02  2e-15
#  3: -2.8364e+02 -5.1393e+02  2e+02  5e-03  2e-15
#  4: -3.1190e+02 -3.6929e+02  6e+01  3e-04  1e-15
#  5: -3.2242e+02 -3.3848e+02  2e+01  4e-05  1e-15
#  6: -3.2587e+02 -3.2978e+02  4e+00  6e-06  1e-15
#  7: -3.2693e+02 -3.2738e+02  4e-01  4e-07  1e-15
#  8: -3.2708e+02 -3.2710e+02  2e-02  1e-08  1e-15
#  9: -3.2708e+02 -3.2709e+02  5e-04  2e-10  1e-15
# 10: -3.2708e+02 -3.2708e+02  1e-05  3e-12  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.96400284767151sec
# Running CVX Optimizer to classify Class 6 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.951002597808838s
#      pcost       dcost       gap    pres   dres
#  0: -1.3972e+02 -6.9017e+03  3e+04  2e+00  1e-15
#  1: -7.4093e+01 -3.3717e+03  5e+03  2e-01  2e-15
#  2: -4.9322e+01 -5.8506e+02  6e+02  2e-02  2e-15
#  3: -9.5462e+01 -2.0704e+02  1e+02  3e-03  2e-15
#  4: -1.1120e+02 -1.4547e+02  4e+01  6e-04  1e-15
#  5: -1.1785e+02 -1.2868e+02  1e+01  6e-05  1e-15
#  6: -1.2042e+02 -1.2319e+02  3e+00  8e-06  1e-15
#  7: -1.2125e+02 -1.2164e+02  4e-01  4e-07  1e-15
#  8: -1.2138e+02 -1.2141e+02  2e-02  7e-09  1e-15
#  9: -1.2139e+02 -1.2139e+02  7e-04  2e-10  1e-15
# 10: -1.2139e+02 -1.2139e+02  1e-05  3e-12  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.814228773117065sec
# Running CVX Optimizer to classify Class 7 and Class 8 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.914960622787476s
#      pcost       dcost       gap    pres   dres
#  0: -1.4021e+02 -7.5807e+03  4e+04  2e+00  2e-15
#  1: -7.7474e+01 -3.9413e+03  7e+03  3e-01  2e-15
#  2: -3.7302e+01 -1.0367e+03  1e+03  4e-02  3e-15
#  3: -7.4177e+01 -2.7628e+02  2e+02  6e-03  2e-15
#  4: -9.3886e+01 -1.5833e+02  7e+01  1e-03  2e-15
#  5: -1.0307e+02 -1.2356e+02  2e+01  3e-04  2e-15
#  6: -1.0675e+02 -1.1333e+02  7e+00  5e-05  1e-15
#  7: -1.0821e+02 -1.0986e+02  2e+00  6e-06  1e-15
#  8: -1.0865e+02 -1.0897e+02  3e-01  7e-07  1e-15
#  9: -1.0875e+02 -1.0879e+02  4e-02  6e-08  1e-15
# 10: -1.0876e+02 -1.0876e+02  1e-03  1e-09  1e-15
# 11: -1.0876e+02 -1.0876e+02  2e-05  2e-11  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.77292013168335sec
# Running CVX Optimizer to classify Class 7 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.935797452926636s
#      pcost       dcost       gap    pres   dres
#  0: -3.8746e+02 -9.5957e+03  5e+04  3e+00  3e-15
#  1: -2.8432e+02 -5.5742e+03  9e+03  3e-01  3e-15
#  2: -2.5152e+02 -1.4261e+03  1e+03  3e-02  3e-15
#  3: -3.0818e+02 -7.0514e+02  4e+02  9e-03  3e-15
#  4: -3.4189e+02 -4.9364e+02  2e+02  2e-03  3e-15
#  5: -3.5935e+02 -4.1679e+02  6e+01  4e-04  3e-15
#  6: -3.6813e+02 -3.8647e+02  2e+01  6e-15  3e-15
#  7: -3.7153e+02 -3.7782e+02  6e+00  2e-14  3e-15
#  8: -3.7293e+02 -3.7451e+02  2e+00  2e-14  3e-15
#  9: -3.7345e+02 -3.7358e+02  1e-01  4e-14  3e-15
# 10: -3.7350e+02 -3.7350e+02  4e-03  5e-14  3e-15
# 11: -3.7350e+02 -3.7350e+02  8e-05  1e-14  3e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 66.94181180000305sec
# Running CVX Optimizer to classify Class 8 and Class 9 with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# Time to Calculate Gaussian Kernel matrix for CVXOPT= 4.9260170459747314s
#      pcost       dcost       gap    pres   dres
#  0: -1.5990e+02 -7.2285e+03  3e+04  2e+00  1e-15
#  1: -7.8001e+01 -3.7404e+03  6e+03  2e-01  2e-15
#  2: -5.8062e+01 -7.5437e+02  8e+02  2e-02  2e-15
#  3: -1.2171e+02 -2.6113e+02  1e+02  3e-03  2e-15
#  4: -1.4164e+02 -1.8153e+02  4e+01  6e-04  1e-15
#  5: -1.4951e+02 -1.6040e+02  1e+01  6e-05  1e-15
#  6: -1.5210e+02 -1.5479e+02  3e+00  8e-06  1e-15
#  7: -1.5284e+02 -1.5330e+02  5e-01  9e-07  1e-15
#  8: -1.5299e+02 -1.5303e+02  4e-02  5e-08  1e-15
#  9: -1.5300e+02 -1.5301e+02  7e-04  8e-10  1e-15
# 10: -1.5300e+02 -1.5300e+02  1e-05  1e-11  1e-15
# Optimal solution found.
# The time taken to optimize SVM model using CVXOPT and Gaussian Kernel = 61.66853952407837sec

# %% [raw]
# import pickle
# with open('fashion_MNIST_SVM.pickle','wb') as f:
#     pickle.dump(cvx_solver, f)

# %%
cvx_solver = pickle.load(open("fashion_MNIST_SVM.pickle", "rb"))

# %%
X_val, val_classes = input_read('fashion_mnist/val.csv', ',')
X_test, test_classes = input_read('fashion_mnist/test.csv', ',')

# %%
label=range(10)
classifiers = list(combinations(label, 2) )
#train_label_score = np.zeros((len(X_train), len(label)))
val_label_score = np.zeros((len(X_val), len(label)))
test_label_score = np.zeros((len(X_test), len(label)))

start = time.time()
for i in range(len(classifiers)):
    k = classifiers[i] # Stores class pair for the current classifier
    X_train, train_classes = input_read('fashion_mnist/train.csv', ',', k[0], k[1])
    #print(k[0], k[1])
    train_classes = train_classes.reshape(-1,1)
    alpha = np.array(cvx_solver[i]['x'])
    S = (alpha > 1e-3)
    supp_vec_ind = np.where(S == True)[0]
    S = S.flatten()
    pdist = spatial.distance.pdist(X_train[supp_vec_ind], 'sqeuclidean')
    K_train = np.exp(-1*0.05*spatial.distance.squareform(pdist))
    w_train = np.dot(K_train.T, (alpha[S]*train_classes[S]))
    bias = train_classes[S] - w_train
    b = np.mean(bias)
    train_pred, val_pred, test_pred= predict(X_train, X_val, X_test, train_classes, val_classes, test_classes, w_train, b, 'gaussian', supp_vec_ind, alpha)    
    #train_pred = [k[1] if x >=0 else k[0] for x in train_pred ]
    
    class1=np.where(val_pred >=0)[0]
    class0=np.where(val_pred <0)[0]
    val_pred[class1] = 1/(1 + np.exp(-np.abs(val_pred[class1])))
    val_pred[class0] = 1/(1 + np.exp(-np.abs(val_pred[class0])))
    val_label_score[class1,k[1]]+=val_pred[class1,0]
    val_label_score[class0,k[0]]+=val_pred[class0,0]
    
    class1=np.where(test_pred >=0)[0]
    class0=np.where(test_pred <0)[0]
    test_pred[class1] = 1/(1 + np.exp(-np.abs(test_pred[class1])))
    test_pred[class0] = 1/(1 + np.exp(-np.abs(test_pred[class0])))
    test_label_score[class1,k[1]]+=test_pred[class1,0]
    test_label_score[class0,k[0]]+=test_pred[class0,0]

print("The time taken to predict the scores is {:2.3f}sec".format(time.time()-start))
# Out:
# The time taken to predict the scores is 457.70838236808777sec

# %%
val_label_pred = [np.where(x == max(x))[0][0] for x in val_label_score[:,:]]
test_label_pred  = [np.where(x == max(x))[0][0] for x in test_label_score[:,:]]
val_acc = calc_accuracy(val_classes, val_label_pred)
test_acc = calc_accuracy(test_classes, test_label_pred)
#print(val_acc, test_acc)

# %% [markdown]
# [supp_vec_ind]#Implementation using SVM Classifier

# %%
print("\n-----------GAUSSIAN KERNEL(Multi-class)----------------")
print("---------------CVXOPT------------------------------------")

print("The Validation accuracy of the model with 10C2 classifiers is= {:2.3f}%".format(val_acc))
print("The test accuracy of the model with 10C2 classifiers is = {:2.3f}%".format(test_acc))
# Out:
# -----------GAUSSIAN KERNEL(Multi-class)----------------
# ---------------CVXOPT------------------------------------
# The Validation accuracy of the model with 10C2 classifiers is= 87.600%
# The test accuracy of the model with 10C2 classifiers is = 87.800%

# %% [markdown]
# # Read whole input training set for SVM classifier

# %%
X_train, train_classes = input_read('fashion_mnist/train.csv', ',')

# %%
def sklearn_svm(X_train, train_classes, shape, gamma='scale'):
    start = time.time()
    svc_classifier = svc(kernel=shape, gamma=gamma, decision_function_shape='ovo', probability=True)
    svc_classifier.fit(X_train, train_classes)
    train_pred_svc = svc_classifier.predict_proba(X_train)
    val_pred_svc = svc_classifier.predict_proba(X_val)
    test_pred_svc = svc_classifier.predict_proba(X_test)
    train_acc_svc = svc_classifier.score(X_train, train_classes)
    val_acc_svc = svc_classifier.score(X_val, val_classes)
    test_acc_svc = svc_classifier.score(X_test, test_classes)
    print("The time taken to train SVM model using SVM classifier SKLEARN and {} Kernel = {}sec"
          .format(shape, time.time()-start))    
    print("The number of support vectors in SVM classifier trained model with {} kernel = {}"
          .format(shape, svc_classifier.n_support_))
    return train_pred_svc, val_pred_svc, test_pred_svc, train_acc_svc, val_acc_svc, test_acc_svc;

# %%
print("\n\nRunning SVM Classifier from SKLEARN to classify with Gaussian Kernel")
print("--------------------TRAINING--------------------------------------------")
train_pred_svc, val_pred_svc, test_pred_svc, train_acc_svc, val_acc_svc, test_acc_svc= sklearn_svm(X_train, train_classes, 'rbf', 0.05)

val_label_pred_svc = [np.where(x == max(x))[0][0] for x in val_pred_svc[:,:]]
test_label_pred_svc  = [np.where(x == max(x))[0][0] for x in test_pred_svc[:,:]]
val_acc = calc_accuracy(val_classes, val_label_pred_svc)
test_acc = calc_accuracy(test_classes, test_label_pred_svc)

print("-----------SVM classifier--------------")

#print("The number of support vectors are = {}".format())
print("The training accuracy of the SVM model is = {:2.3f}%".format(train_acc_svc*100))
print("The Validation accuracy of the SVM model is= {:2.3f}%".format(val_acc))
print("The test accuracy of the SVM model is = {:2.3f}%".format(test_acc))
# Out:
# Running SVM Classifier from SKLEARN to classify with Gaussian Kernel
# --------------------TRAINING--------------------------------------------
# The time taken to train SVM model using SVM classifier SKLEARN and rbf Kernel = 1768.8962709903717sec
# The number of support vectors in SVM classifier trained model with rbf kernel = [1291  368 1543 1144 1541 1282 1832  770 1078  816]
# -----------SVM classifier--------------
# The training accuracy of the SVM model is = 96.920%
# The Validation accuracy of the SVM model is= 88.000%
# The test accuracy of the SVM model is = 88.100%

# %%
def plot_conf_matrix(kernel_shape, test_classes, test_pred, test_pred_svc ):
    print("\nPlotting Confusion Matrix for {} Kernel - CVXOPT vs. SVMC-library".format(kernel_shape))

    conf_matrix_cvxopt = confusion_matrix(test_classes, test_pred)
    conf_matrix_svmC = confusion_matrix(test_classes, test_pred_svc)
    fig = plt.figure(1)
    ax= fig.add_subplot(111)
    sns.heatmap(conf_matrix_cvxopt, annot=True, ax = ax, fmt="d",linewidths=1, cmap="YlGnBu"); #annot=True to annotate cells
    #ax.set_ylim([0,2]) # Workaround to display values in the center, to avoid downgrade to matplotlib3.1.1
    ax.set_ylabel('Actual labels');
    ax.set_xlabel('Predicted labels'); 
    ax.set_title('Confusion Matrix with CVX '); 
    #ax.xaxis.set_ticklabels(['y=0', 'y=1']); ax.yaxis.set_ticklabels(['y=0', 'y=1']);
    fig.savefig('cm_cvxopt_test_multiclass.png', dpi=1000, bbox_inches='tight')

    fig1 = plt.figure(2)
    ax1 = fig1.add_subplot(111)
    sns.heatmap(conf_matrix_svmC, annot=True, ax = ax1, fmt="d",linewidths=1, cmap="YlGnBu"); #annot=True to annotate cells
    #ax1.set_ylim([0,2]) # Workaround to display values in the center, to avoid downgrade to matplotlib3.1.1
    ax1.set_ylabel('Actual labels');
    ax1.set_xlabel('Predicted labels'); 
    ax1.set_title('Confusion Matrix with SVM-C'); 
    #ax1.xaxis.set_ticklabels(['y=0', 'y=1']); ax1.yaxis.set_ticklabels(['y=0', 'y=1']);

    fig.tight_layout(pad=3.0)
    fig1.savefig('cm_svm_test_multiclass.png', dpi=1000, bbox_inches='tight')
    
    plt.show()

# %%
plot_conf_matrix('gaussian', val_classes, val_label_pred, val_label_pred_svc)
# Out:
# Plotting Confusion Matrix for gaussian Kernel - CVXOPT vs. SVMC-library
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
plot_conf_matrix('gaussian', test_classes, test_label_pred, test_label_pred_svc)
# Out:
# Plotting Confusion Matrix for gaussian Kernel - CVXOPT vs. SVMC-library
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
