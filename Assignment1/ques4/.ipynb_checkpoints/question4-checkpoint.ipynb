# %%
#Importing Data from the CSV file
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import numpy as np

os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q4")
print("Path has been changed to:\n", os.getcwd())

#Importing Data X from the CSV file
#X = np.genfromtxt('q4x.dat', delimiter=[3,5])
#Importing Data Y from the CSV file
#Y = np.genfromtxt('q4y.dat', delimiter=6, dtype=str)


#More SOPHISTICATED METHOD FOR DAT FILE
X = np.loadtxt('q4x.dat')
print(X[1:4])
Y = np.loadtxt('q4y.dat', dtype=str).reshape(-1,1)
#print(Y)

m=X.shape[0]

os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques4")
print("Path changed back to python file directory:\n", os.getcwd())
# Out:
# Path has been changed to:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q4
# [[131. 355.]
#  [105. 469.]
#  [ 86. 506.]]
# Path changed back to python file directory:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques4

# %%
#GDA theta parameters
Y[Y=='Alaska']=1
Y[Y=='Canada']=0
#print(Y)
phi = np.sum([Y=='1'])/m

index_x0=[i for i in range(len(Y)) if Y[i]=='0']
index_x1=[i for i in range(len(Y)) if Y[i]=='1']
#print(index_x0)
mean_x0 = (np.sum(X[index_x0], axis=0)/len(index_x0)).reshape(1,-1)
mean_x1 = (np.sum(X[index_x1], axis=0)/len(index_x1)).reshape(1,-1)
#print(X[index_x0])
cov=np.zeros((2,2))
for i in range(m):
    if(Y[i]=='1'):
        cov+=np.dot((X[i:i+1]-mean_x1).T, (X[i:i+1]-mean_x1))
    else:
        cov+=np.dot((X[i:i+1]-mean_x0).T, (X[i:i+1]-mean_x0))
cov/=m

# %%
print("Mean of the Distribution for label='Alaska' is={}".format(mean_x1))
print("Mean of the Distribution for label='Canada' is={}".format(mean_x0))
print("The value of the covariance matrxi is = \n{}".format(cov))
# Out:
# Mean of the Distribution for label='Alaska' is=[[ 98.38 429.66]]
# Mean of the Distribution for label='Canada' is=[[137.46 366.62]]
# The value of the covariance matrxi is =
# [[ 287.482  -26.748]
#  [ -26.748 1123.25 ]]

# %%
X[index_x0][:,0]
# Out:
# array([129., 148., 179., 152., 166., 124., 156., 131., 140., 144., 149.,
#        108., 135., 170., 152., 153., 152., 136., 122., 148.,  90., 145.,
#        123., 145., 115., 134., 117., 126., 118., 120., 153., 150., 154.,
#        155., 109., 117., 128., 144., 163., 145., 133., 128., 123., 144.,
#        140., 150., 124., 125., 153., 108.])

# %%
#Part (b)
#Plot the training data with class labels

plt.scatter(X[index_x0][:,0], X[index_x0][:,1], s = 5, marker='*', c='r',label='Label=Canada')
plt.scatter(X[index_x1][:,0], X[index_x1][:,1], s = 5, marker='o', c='b',label='Label=Alaska')
plt.legend()
plt.title('(b) Data with labels')
plt.xlabel('Feature -> X1')
plt.ylabel('Feauture -> X2')
#plt.show()
plt.savefig('data.png', dpi=1000, bbox_inches='tight')

# %%
import math
cov_inv = np.linalg.inv(cov)
mean_x1_sq = mean_x1*mean_x1
mean_x0_sq = mean_x0*mean_x0
temp = math.log(phi/(1-phi))
c = (((1/2)*np.dot(cov_inv, (mean_x1_sq-mean_x0_sq).T)) - temp) / (np.dot(cov_inv, (mean_x1-mean_x0).T))
print(c.shape)
print(X.shape)
y = X.T-c
y.shape
print(y)
# Out:
# (2, 1)
# (100, 2)
# [[   1.27404413   24.27404413   -1.72595587  -20.72595587   -7.72595587
#    -19.72595587  -12.72595587   10.27404413  -27.72595587   -7.72595587
#      7.27404413   16.27404413   16.27404413    2.27404413    5.27404413
#     -2.72595587    4.27404413   19.27404413   -1.72595587   12.27404413
#      7.27404413   -6.72595587  -22.72595587   -4.72595587   -5.72595587
#    -21.72595587    2.27404413   -0.72595587  -24.72595587   11.27404413
#     -1.72595587   14.27404413  -21.72595587  -23.72595587  -53.72595587
#    -11.72595587  -30.72595587  -11.72595587  -19.72595587  -36.72595587
#    -22.72595587  -15.72595587  -32.72595587   -5.72595587  -26.72595587
#    -11.72595587  -14.72595587   -7.72595587  -12.72595587  -19.72595587
#     22.27404413   41.27404413   72.27404413   45.27404413   59.27404413
#     17.27404413   49.27404413   24.27404413   33.27404413   37.27404413
#     42.27404413    1.27404413   28.27404413   63.27404413   45.27404413
#     46.27404413   45.27404413   29.27404413   15.27404413   41.27404413
#    -16.72595587   38.27404413   16.27404413   38.27404413    8.27404413
#     27.27404413   10.27404413   19.27404413   11.27404413   13.27404413
#     46.27404413   43.27404413   47.27404413   48.27404413    2.27404413
#     10.27404413   21.27404413   37.27404413   56.27404413   38.27404413
#     26.27404413   21.27404413   16.27404413   37.27404413   33.27404413
#     43.27404413   17.27404413   18.27404413   46.27404413    1.27404413]
#  [ -47.29218078  -60.29218078   53.70781922   90.70781922  -13.29218078
#      7.70781922   24.70781922   73.70781922   16.70781922  -12.29218078
#     12.70781922  -43.29218078  -43.29218078    4.70781922  -21.29218078
#     -8.29218078    6.70781922    7.70781922   18.70781922   58.70781922
#    -19.29218078   54.70781922  -16.29218078   13.70781922   53.70781922
#     28.70781922  -18.29218078   26.70781922   15.70781922  -34.29218078
#    -27.29218078  -12.29218078   35.70781922   37.70781922   11.70781922
#     -4.29218078   26.70781922   10.70781922  -13.29218078  -18.29218078
#     95.70781922   53.70781922   35.70781922   58.70781922  -17.29218078
#     17.70781922  -11.29218078   65.70781922   75.70781922   64.70781922
#      4.70781922  -44.29218078   -8.29218078  -34.29218078  -38.29218078
#    -26.29218078    3.70781922  -70.29218078  -53.29218078  -70.29218078
#    -22.29218078  -85.29218078  -60.29218078  -29.29218078 -114.29218078
#    -18.29218078 -114.29218078   22.70781922 -109.29218078  -32.29218078
#    -30.29218078  -78.29218078  -51.29218078  -39.29218078  -61.29218078
#    -32.29218078  -60.29218078  -70.29218078  -36.29218078  -46.29218078
#    -12.29218078  -61.29218078  -25.29218078  -66.29218078  -90.29218078
#    -71.29218078  -15.29218078  -12.29218078  -45.29218078  -60.29218078
#    -40.29218078  -32.29218078  -66.29218078  -42.29218078  -27.29218078
#    -76.29218078  -74.29218078  -69.29218078  -63.29218078  -76.29218078]]

# %%
#visualize Gaussian

import numpy as np

from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D
#Create grid and multivariate normal
x = np.linspace(50,350,500)
y = np.linspace(50,350,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal(mean_x1.ravel(), cov)

#Make a 3D plot
fig = plt.figure()

ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
#plt.show()
plt.savefig('temp.png', dpi=1000, bbox_inches='tight')
