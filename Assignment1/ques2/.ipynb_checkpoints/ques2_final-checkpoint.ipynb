# %%
#Importing Data from the CSV file
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import sys

os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q2")
print("Path has been changed to:\n", os.getcwd())

#Importing Data X from the CSV file
temp = np.genfromtxt('q2test.csv', delimiter=',')
#print(temp[1:])

X1_test = temp[1:, 0].reshape(-1,1)
X2_test = temp[1:, 1].reshape(-1,1)
Y_test = temp[1:, 2].reshape(-1,1)
X0_test = np.ones((X1_test.shape))
X_test = np.append(X0_test, X1_test, axis=1)
X_test = np.append(X_test, X2_test, axis=1)

num_test = X_test.shape[0]
os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques2")
print("Path changed back to python file directory:\n", os.getcwd())
# Out:
# Path has been changed to:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q2
# Path changed back to python file directory:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques2

# %%
#given as input
m = 1000000
x0 = np.ones((m,1)) #Intercept term

#Sample X1 ~ N(3,4) and sample X2 ~ N(-1, 4)
x1 = np.random.normal(3, 2, m).reshape(-1,1)
x2 = np.random.normal(-1, 2, m).reshape(-1,1)

#Make a 1Mx3 matrix
X = np.append(x0,x1,axis=1)
X = np.append(X, x2, axis=1)
print("The number of training samples to be generated is {}".format(m))
# Out:
# The number of training samples to be generated is 1000000

# %%
#Sample epsilon error in the data from N(0, 2)
epsilon = np.random.normal(0, np.sqrt(2), m).reshape(-1,1)

#Theta is fixed with values 3, 1, 2 for generating the data. 
#We will later use these parameters to verify our hypothesis from SGD. 
theta = np.array([[3], [1], [2]])

# %%
#Generate the value of Y (given X, parameterized by given Theta)
Y = np.dot(X,theta) + epsilon

# %%
#Data is (X, Y)
#Randomly shuffle the data
temp = np.append(X, Y, axis=1)
#We use random shuffle from numpy to shuffle all the rows of the data
np.random.shuffle(temp)
X = temp[:,0:3]
Y = temp[:,-1:]

# %%
#Applying SGD on X, Y to learn hypothesis with parameters theta

#Model Initial Parameters initialized to zeros
theta = np.zeros((3,1))
#Learning Rate (has to be fixed)
alpha = 0.001 

#Batch Size r options stored in an array 
batch_size = np.array([1, 100, 10000, 1000000])

print("The model's initial theta is = {} and the learning rate is = {}".format(theta.T, alpha))
# Out:
# The model's initial theta is = [[0. 0. 0.]] and the learning rate is = 0.001

# %%
#define the hypothesis function
def hypothesis(X, theta):
    return np.dot(X, theta)

#Define the cost function over the entire sample/batch
def cost_total(X, theta, Y, m):
    h_x= hypothesis(X, theta)
    cost = (1/(2*m)) * np.sum((Y-h_x)**2) # Average Cost Function
    return cost

#function for calculating the cost function gradient
def cost_grad(X, theta, Y, m):
    temp = np.dot(X, theta)-Y
    theta_grad = np.zeros((3,1))
    theta_grad += np.dot(X.transpose(), temp)
    return theta_grad/m #average Gradient 
    
cost_start = cost_total(X, theta, Y, m)
print("Initial Cost value for the hypothesis with zero parameters={}".format(cost_start))
# Out:
# Initial Cost value for the hypothesis with zero parameters=19.02304717410501

# %%
#r is the current batch size (choose between 1, 100, 10000, 1000000 - defined in batch_size array)
r = batch_size[1] 

#number of batches (sub batches stored in an array mini_batch)
mini_batch = [(X[i:i+r,:], Y[i:i+r]) for i in range(0, m, r)]
print("The size of one batch is = {} and the number of batches = {}".format(r, len(mini_batch)))
# Out:
# The size of one batch is = 100 and the number of batches = 10000

# %%
import time
start = time.time()

i=0   #Variable for outer loop
J_curr=0.0; #Store the current cost at one (r=1) data point/over r data points
theta_all = theta

J_avg = np.array([cost_total(X[0], theta, Y[0], 1)])
print(J_avg)

#We change the while condition to while(1) for r=1 since only one epoch is enough.
while(True):
    i+=1
    count = 0
    cost_initial = cost_total(X, theta, Y, m) # Cost at the starting of the epoch
    for b in mini_batch:
        X_b = b[0]
        Y_b = b[1]
        J_curr += cost_total(X_b, theta, Y_b, r)
        #Change this value for different batch sizes. 
        # When r = 1, then we check convergence at every 10000 samples. 
        # When r = 100, #batches= 10000, then we chech the average cost of every 100 samples. 
        # When r = 10000, #batches = 100, then we check the average cost after every 10 samples. 
        # When r = 1000000, #batches = 1, count is always 1 so this doesnt matter. 
        if(count%100 == 0 and count!=0):
            J_curr /= 100; #gives the average cost over 1000 iterations. 
            J_avg = np.append(J_avg, J_curr)
            print("Current average cost = {}".format(J_curr)) 
            J_curr=0.0;  
        theta -= alpha * cost_grad(X_b, theta, Y_b, r)
        theta_all = np.append(theta_all,theta,axis=1)
        count +=1
    cost_final = cost_total(X, theta, Y, m)
    print("Cost is = {} in iterations = {}".format(cost_final, i)) 
    if (abs(cost_final - cost_initial) < 0.00000001):
        print(cost_final, cost_initial, cost_final-cost_initial)
        break
end = time.time()

print("Cost is = {} in iterations = {} in time = {} sec".format(cost_final, i, end-start))
# Out:
# [39.47549641]
# Current average cost = 11.198583357320793
# Current average cost = 5.100784078746458
# Current average cost = 3.3883416871814798
# Current average cost = 2.501118099109486
# Current average cost = 2.120811264511469
# Current average cost = 1.9134390876035783
# Current average cost = 1.8342023681868238
# Current average cost = 1.7858509648881844
# Current average cost = 1.6890405766127068
# Current average cost = 1.6152868243866538
# Current average cost = 1.6428472591533976
# Current average cost = 1.5904929278615407
# Current average cost = 1.5756211382248169
# Current average cost = 1.5159648347484203
# Current average cost = 1.4946106665995484
# Current average cost = 1.4970400801184667
# Current average cost = 1.4681638219175743
# Current average cost = 1.4549749928360296
# Current average cost = 1.3870409404334219
# Current average cost = 1.3694481806490417
# Current average cost = 1.3635219622248587
# Current average cost = 1.3693392035321637
# Current average cost = 1.306341118931411
# Current average cost = 1.3077681735928666
# Current average cost = 1.3082721279377985
# Current average cost = 1.2641572323991954
# Current average cost = 1.2416793128896744
# Current average cost = 1.27102066859248
# Current average cost = 1.212358224671199
# Current average cost = 1.237123244073121
# Current average cost = 1.197453666521067
# Current average cost = 1.2061147517677226
# Current average cost = 1.1817934338509934
# Current average cost = 1.1864146681439185
# Current average cost = 1.1581489777804013
# Current average cost = 1.1717273220025717
# Current average cost = 1.1502691088693813
# Current average cost = 1.144284617648612
# Current average cost = 1.1184107766561135
# Current average cost = 1.1031768315123904
# Current average cost = 1.1371207638835286
# Current average cost = 1.0846393671493708
# Current average cost = 1.1172129504857953
# Current average cost = 1.083605159023065
# Current average cost = 1.1153362103487765
# Current average cost = 1.1144225922731479
# Current average cost = 1.0757741815287476
# Current average cost = 1.093893991908689
# Current average cost = 1.0765455557558479
# Current average cost = 1.0693013192877219
# Current average cost = 1.0817920409518973
# Current average cost = 1.062822375579602
# Current average cost = 1.0803920369044306
# Current average cost = 1.062777576641874
# Current average cost = 1.0623396606064075
# Current average cost = 1.0579525608001674
# Current average cost = 1.039020623146021
# Current average cost = 1.0467449206659851
# Current average cost = 1.0447911982429998
# Current average cost = 1.0539476354802044
# Current average cost = 1.0407690381691508
# Current average cost = 1.035698451076778
# Current average cost = 1.029244955062324
# Current average cost = 1.033968542546061
# Current average cost = 1.0325967263852407
# Current average cost = 1.0347607498929592
# Current average cost = 1.050803996075487
# Current average cost = 0.9994472173091447
# Current average cost = 1.0381709160461838
# Current average cost = 1.0160481770582452
# Current average cost = 1.0257976333575543
# Current average cost = 1.0094704989714705
# Current average cost = 1.0100860053092122
# Current average cost = 1.006602607787419
# Current average cost = 1.0049928373557278
# Current average cost = 1.0131749029629211
# Current average cost = 0.9914953503420578
# Current average cost = 1.0214200209071878
# Current average cost = 1.0185830473935933
# Current average cost = 1.0169370078487525
# Current average cost = 1.0200870190329758
# Current average cost = 1.0081125386924874
# Current average cost = 1.0161568972124477
# Current average cost = 1.022495412743113
# Current average cost = 1.0001713901945093
# Current average cost = 1.0114832985391233
# Current average cost = 1.0089811519998153
# Current average cost = 0.9932986394116887
# Current average cost = 1.0248773596811391
# Current average cost = 1.0313897790827444
# Current average cost = 0.9879529861627873
# Current average cost = 1.0276841764644693
# Current average cost = 1.0110034253527007
# Current average cost = 1.0169714441926718
# Current average cost = 1.0046843222864177
# Current average cost = 1.0168433406776662
# Current average cost = 1.0184436714167406
# Current average cost = 1.0299299121681569
# Current average cost = 0.999231250086667
# Cost is = 1.0033557977863863 in iterations = 1
# Current average cost = 1.9832047880553452
# Current average cost = 1.004249311596785
# Current average cost = 1.0132904457137086
# Current average cost = 0.9922011134732343
# Current average cost = 0.9868012136509102
# Current average cost = 0.981584579073451
# Current average cost = 0.9947912069500581
# Current average cost = 1.0108281835660025
# Current average cost = 1.0023856140500427
# Current average cost = 0.975759217189847
# Current average cost = 1.0119201218077318
# Current average cost = 0.9902473164931918
# Current average cost = 1.0026763141507131
# Current average cost = 0.9850735569748948
# Current average cost = 0.9935285208142343
# Current average cost = 1.0116030814330774
# Current average cost = 1.0103751289813954
# Current average cost = 1.0166854880703902
# Current average cost = 1.0066756542186608
# Current average cost = 0.9870469691403018
# Current average cost = 1.002799332659454
# Current average cost = 1.0124758476718583
# Current average cost = 0.9806540475089605
# Current average cost = 0.9943280415241328
# Current average cost = 1.0152889661336923
# Current average cost = 0.9983320185188614
# Current average cost = 0.9790087018570834
# Current average cost = 1.0112918650505482
# Current average cost = 0.9883506259670137
# Current average cost = 1.012660099580493
# Current average cost = 0.9903417094583523
# Current average cost = 1.0104483614748063
# Current average cost = 0.9920730350285762
# Current average cost = 0.9995302051290598
# Current average cost = 0.9837380452273521
# Current average cost = 1.0184446259498456
# Current average cost = 0.9986134504949091
# Current average cost = 0.9997515400415528
# Current average cost = 0.9848280049079925
# Current average cost = 0.9767757677383802
# Current average cost = 1.0160668072862686
# Current average cost = 0.9802309522050914
# Current average cost = 1.00459538467618
# Current average cost = 0.9798594743206779
# Current average cost = 1.0082022485032838
# Current average cost = 1.0150624178334011
# Current average cost = 0.9895706003295954
# Current average cost = 1.0041593065659766
# Current average cost = 1.001832606663262
# Current average cost = 0.9996456504858522
# Current average cost = 1.0072044342871
# Current average cost = 0.9998322295023974
# Current average cost = 1.0062833914597633
# Current average cost = 0.9983435183714967
# Current average cost = 1.0073321847241963
# Current average cost = 1.012072050566615
# Current average cost = 0.9857601428052253
# Current average cost = 1.0030786147032005
# Current average cost = 0.9955951752128331
# Current average cost = 1.0066679646259498
# Current average cost = 1.0032730939927164
# Current average cost = 0.9985236934082251
# Current average cost = 0.9995493345490598
# Current average cost = 0.9972468685305301
# Current average cost = 1.0042026308754748
# Current average cost = 1.0101690145712217
# Current average cost = 1.0284103960457143
# Current average cost = 0.9748851447584167
# Current average cost = 1.0093944190462776
# Current average cost = 0.9898461809204484
# Current average cost = 0.9990709640018939
# Current average cost = 0.9906484531842119
# Current average cost = 0.9875184381568144
# Current average cost = 0.9825920072654365
# Current average cost = 0.9849181157649032
# Current average cost = 0.9972911487013821
# Current average cost = 0.9783153473992247
# Current average cost = 1.007715687063769
# Current average cost = 0.9988997785977332
# Current average cost = 0.9997944605730601
# Current average cost = 1.0045936469478687
# Current average cost = 0.9923803779389644
# Current average cost = 1.0045751427394607
# Current average cost = 1.0124810409204854
# Current average cost = 0.987501995499982
# Current average cost = 0.999762198823271
# Current average cost = 0.9982609270166632
# Current average cost = 0.9818673461921154
# Current average cost = 1.015689539301285
# Current average cost = 1.0233232763001003
# Current average cost = 0.9788882445555389
# Current average cost = 1.0196186244888314
# Current average cost = 1.0007674779917632
# Current average cost = 1.0076207163559447
# Current average cost = 0.9984506410163857
# Current average cost = 1.013199237761626
# Current average cost = 1.0135598841897966
# Current average cost = 1.022113930706375
# Current average cost = 0.9954242417680979
# Cost is = 0.9984883157627132 in iterations = 2
# Current average cost = 1.9762472745143722
# Current average cost = 1.000633395536079
# Current average cost = 1.0094459438949996
# Current average cost = 0.9874777536127562
# Current average cost = 0.9824679383071268
# Current average cost = 0.9786159860681587
# Current average cost = 0.9912243342546708
# Current average cost = 1.0065301360481893
# Current average cost = 0.9994669005548871
# Current average cost = 0.9740843804346361
# Current average cost = 1.0076490178808837
# Current average cost = 0.9871310046590572
# Current average cost = 0.9991522304759255
# Current average cost = 0.9821373657664051
# Current average cost = 0.991229986635175
# Current average cost = 1.0095274220869457
# Current average cost = 1.0081201681872367
# Current average cost = 1.0137359177160692
# Current average cost = 1.0064545092093093
# Current average cost = 0.9854722952261896
# Current average cost = 1.001097181046345
# Current average cost = 1.010009109839926
# Current average cost = 0.9791514778075754
# Current average cost = 0.9924665680909964
# Current average cost = 1.013569703116327
# Current average cost = 0.9976153359710874
# Current average cost = 0.9778866707699082
# Current average cost = 1.0092542507923015
# Current average cost = 0.9878286362396932
# Current average cost = 1.011434777967623
# Current average cost = 0.9895255044043896
# Current average cost = 1.009917796140611
# Current average cost = 0.9917064901596803
# Current average cost = 0.9984191262047942
# Current average cost = 0.9827288990875478
# Current average cost = 1.01794482687341
# Current average cost = 0.9980224708827117
# Current average cost = 0.9991169248437854
# Current average cost = 0.9843759090965618
# Current average cost = 0.9764956681541911
# Current average cost = 1.0155423445375087
# Current average cost = 0.9804384083148505
# Current average cost = 1.0041156257671962
# Current average cost = 0.9791913220219048
# Current average cost = 1.0072641317153508
# Current average cost = 1.0143124047087322
# Current average cost = 0.9893485332327316
# Current average cost = 1.0033793241370998
# Current average cost = 1.001883301480875
# Current average cost = 0.9996465228547406
# Current average cost = 1.0065961930700242
# Current average cost = 0.99989006548155
# Current average cost = 1.0054191051018602
# Current average cost = 0.9977728869538309
# Current average cost = 1.0072224908100136
# Current average cost = 1.012391621585706
# Current average cost = 0.985401689994912
# Current average cost = 1.0032210459207611
# Current average cost = 0.9952300478298892
# Current average cost = 1.0061929197703272
# Current average cost = 1.0032845257877023
# Current average cost = 0.9984680610575717
# Current average cost = 0.9998883916023703
# Current average cost = 0.9969637065938203
# Current average cost = 1.004352316010058
# Current average cost = 1.0105084400594508
# Current average cost = 1.0287591991279001
# Current average cost = 0.975014801757484
# Current average cost = 1.0091348404960516
# Current average cost = 0.9896924573568375
# Current average cost = 0.998802105995925
# Current average cost = 0.9907999122684678
# Current average cost = 0.9873706545967573
# Current average cost = 0.9822476860411921
# Current average cost = 0.9847869957699737
# Current average cost = 0.997357529507618
# Current average cost = 0.9785017103538659
# Current average cost = 1.007818100017432
# Current average cost = 0.998562335591075
# Current average cost = 0.9995873827889732
# Current average cost = 1.0044354641724618
# Current average cost = 0.9921414796694306
# Current average cost = 1.004576681499015
# Current average cost = 1.0125421053225272
# Current average cost = 0.9873538154559048
# Current average cost = 0.9996401130794159
# Current average cost = 0.9981776117412656
# Current average cost = 0.9816890835551507
# Current average cost = 1.0156384643247791
# Current average cost = 1.023333004769458
# Current average cost = 0.978788329446001
# Current average cost = 1.0195494211066627
# Current average cost = 1.0005346384515317
# Current average cost = 1.0074240816778677
# Current average cost = 0.9984343169236328
# Current average cost = 1.0133278552819034
# Current average cost = 1.0135902306122322
# Current average cost = 1.0219443203413998
# Current average cost = 0.9954951201269937
# Cost is = 0.9984658373605885 in iterations = 3
# Current average cost = 1.9763906240938482
# Current average cost = 1.0006691844910487
# Current average cost = 1.009456850307756
# Current average cost = 0.987409391716708
# Current average cost = 0.9824215272880521
# Current average cost = 0.9786464818223845
# Current average cost = 0.9912000129925912
# Current average cost = 1.0064461352890137
# Current average cost = 0.9994584672245158
# Current average cost = 0.974150980627393
# Current average cost = 1.0075304684061168
# Current average cost = 0.9870854067810132
# Current average cost = 0.9990702936671879
# Current average cost = 0.9820847132061936
# Current average cost = 0.9912139554687741
# Current average cost = 1.0095224375607617
# Current average cost = 1.0080945045617724
# Current average cost = 1.0136553052097947
# Current average cost = 1.006550128652692
# Current average cost = 0.985472694596419
# Current average cost = 1.0010822220932347
# Current average cost = 1.0099388830040212
# Current average cost = 0.9791403848496385
# Current average cost = 0.9924264868588576
# Current average cost = 1.013533705622092
# Current average cost = 0.9976423672242786
# Current average cost = 0.9778840829569491
# Current average cost = 1.0091859891332498
# Current average cost = 0.9878572160751699
# Current average cost = 1.0114137019153928
# Current average cost = 0.9895283137733903
# Current average cost = 1.0099374779471084
# Current average cost = 0.9917360437621086
# Current average cost = 0.9983951439010543
# Current average cost = 0.9827084836257353
# Current average cost = 1.0179542875997645
# Current average cost = 0.9980250009020183
# Current average cost = 0.9991142821719893
# Current average cost = 0.984382983688775
# Current average cost = 0.9765128175520397
# Current average cost = 1.0155406309797415
# Current average cost = 0.9804836384001492
# Current average cost = 1.004114608816263
# Current average cost = 0.9791743731151292
# Current average cost = 1.0072290629962255
# Current average cost = 1.014288377843212
# Current average cost = 0.9893580312612837
# Current average cost = 1.0033503598360909
# Current average cost = 1.0019087470552308
# Current average cost = 0.9996669619744505
# Current average cost = 1.0065749552949759
# Current average cost = 0.9999125871468432
# Current average cost = 1.0053796015410623
# Current average cost = 0.9977513412486891
# Current average cost = 1.0072308175976974
# Current average cost = 1.012427666387307
# Current average cost = 0.9853918958406211
# Current average cost = 1.0032439030820184
# Current average cost = 0.9952185921429995
# Current average cost = 1.0061731223078068
# Current average cost = 1.0032963042769578
# Current average cost = 0.9984749980537014
# Current average cost = 0.999921081041968
# Current average cost = 0.9969544040166021
# Current average cost = 1.0043712188856626
# Current average cost = 1.0105396624687315
# Current average cost = 1.0287904423337924
# Current average cost = 0.9750311657869568
# Current average cost = 1.009124883092526
# Current average cost = 0.989689240368722
# Current average cost = 0.9987908920260391
# Current average cost = 0.9908161404756752
# Current average cost = 0.9873667948756686
# Current average cost = 0.9822303353911863
# Current average cost = 0.9847835864102319
# Current average cost = 0.9973668753659141
# Current average cost = 0.9785187588907287
# Current average cost = 1.0078293590473497
# Current average cost = 0.9985442059204227
# Current average cost = 0.9995777385175769
# Current average cost = 1.004428798766517
# Current average cost = 0.9921291701964903
# Current average cost = 1.0045801786046384
# Current average cost = 1.012549357773774
# Current average cost = 0.9873470320141183
# Current average cost = 0.9996348994586519
# Current average cost = 0.9981748499170987
# Current average cost = 0.9816798083398112
# Current average cost = 1.0156375365245707
# Current average cost = 1.0233360532654925
# Current average cost = 0.9787839082023696
# Current average cost = 1.0195468816669828
# Current average cost = 1.0005211499960391
# Current average cost = 1.0074128972316319
# Current average cost = 0.9984349849537429
# Current average cost = 1.0133380262944223
# Current average cost = 1.0135938075868471
# Current average cost = 1.021934599989673
# Current average cost = 0.995501251388799
# Cost is = 0.9984656700478349 in iterations = 4
# Current average cost = 1.9764028073213953
# Current average cost = 1.0006727758390987
# Current average cost = 1.009458747069456
# Current average cost = 0.9874059341075813
# Current average cost = 0.9824195094844963
# Current average cost = 0.9786495090893154
# Current average cost = 0.9911993347363519
# Current average cost = 1.0064414461678701
# Current average cost = 0.9994587240741784
# Current average cost = 0.97415618527944
# Current average cost = 1.0075233256677825
# Current average cost = 0.9870830905247969
# Current average cost = 0.9990655242363171
# Current average cost = 0.9820818448493626
# Current average cost = 0.9912134930308341
# Current average cost = 1.0095226919237827
# Current average cost = 1.008093347486152
# Current average cost = 1.0136504614569433
# Current average cost = 1.0065569623347528
# Current average cost = 0.9854731835299679
# Current average cost = 1.0010816610899709
# Current average cost = 1.0099346332123538
# Current average cost = 0.9791400391371516
# Current average cost = 0.9924241940352907
# Current average cost = 1.0135316602872095
# Current average cost = 0.9976444904526207
# Current average cost = 0.977884228007036
# Current average cost = 1.0091817529206122
# Current average cost = 0.9878593919727995
# Current average cost = 1.0114125683832527
# Current average cost = 0.9895287514272559
# Current average cost = 1.0099390264539188
# Current average cost = 0.9917382431190905
# Current average cost = 0.9983937712116875
# Current average cost = 0.9827073336165051
# Current average cost = 1.0179551035465237
# Current average cost = 0.9980253528920607
# Current average cost = 0.9991142807478635
# Current average cost = 0.984383616763613
# Current average cost = 0.9765141135150281
# Current average cost = 1.0155406631039794
# Current average cost = 0.9804867795889382
# Current average cost = 1.0041146771760823
# Current average cost = 0.9791733687507025
# Current average cost = 1.0072268548903556
# Current average cost = 1.0142868963715603
# Current average cost = 0.9893587685998111
# Current average cost = 1.0033485376062374
# Current average cost = 1.0019105335401057
# Current average cost = 0.9996684086231167
# Current average cost = 1.0065736297910224
# Current average cost = 0.9999141645564312
# Current average cost = 1.0053770578900505
# Current average cost = 0.9977499829435545
# Current average cost = 1.0072314391488923
# Current average cost = 1.0124301245429381
# Current average cost = 0.9853913073668319
# Current average cost = 1.0032454794938215
# Current average cost = 0.9952178880004142
# Current average cost = 1.0061718597990603
# Current average cost = 1.0032971347426187
# Current average cost = 0.9984755054048898
# Current average cost = 0.9999232959679447
# Current average cost = 0.9969538283160907
# Current average cost = 1.0043725132478978
# Current average cost = 1.0105417734345143
# Current average cost = 1.028792552028425
# Current average cost = 0.9750322862810802
# Current average cost = 1.0091242541370808
# Current average cost = 0.9896890576061483
# Current average cost = 0.9987901768317698
# Current average cost = 0.9908172449767427
# Current average cost = 0.9873665648757296
# Current average cost = 0.982229207852079
# Current average cost = 0.984783383416953
# Current average cost = 0.9973675175484013
# Current average cost = 0.9785199112527517
# Current average cost = 1.0078301261239992
# Current average cost = 0.9985430212215521
# Current average cost = 0.9995771163702442
# Current average cost = 1.004428373191825
# Current average cost = 0.9921283686860153
# Current average cost = 1.0045804257177715
# Current average cost = 1.0125498533173558
# Current average cost = 0.9873465951573215
# Current average cost = 0.9996345660971757
# Current average cost = 0.9981746787784574
# Current average cost = 0.9816792038885873
# Current average cost = 1.0156374857864399
# Current average cost = 1.0233362662252912
# Current average cost = 0.9787836244481
# Current average cost = 1.0195467221427887
# Current average cost = 1.00052026325187
# Current average cost = 1.0074121629988506
# Current average cost = 0.9984350370197208
# Current average cost = 1.013338708683336
# Current average cost = 1.0135940519264635
# Current average cost = 1.0219339614956664
# Current average cost = 0.9955016646913444
# Cost is = 0.99846566477954 in iterations = 5
# 0.99846566477954 0.9984656700478349 -5.268294911431326e-09
# Cost is = 0.99846566477954 in iterations = 5 in time = 3.7979423999786377 sec

# %%
print("Final theta learned = \n", theta)
# Out:
# Final theta learned =
#  [[3.00297147]
#  [0.99637633]
#  [1.9962794 ]]

# %%
test_err_original = cost_total(X_test, np.array([[3],[1],[2]]), Y_test, num_test)
print("The Test error on Original Hypothesis with theta = 0 is = {}".format(test_err_original))

test_err_learned = cost_total(X_test, theta, Y_test, num_test)
print("The Test error on Learned Hypothesis = {}".format(test_err_learned))

print("The difference in the test error of original and learned hypothesis is = {}".format(test_err_learned-test_err_original))
# Out:
# The Test error on Original Hypothesis with theta = 0 is = 0.9829469215
# The Test error on Learned Hypothesis = 0.9850172360676815
# The difference in the test error of original and learned hypothesis is = 0.002070314567681586

# %%
#For r =1
#theta_all_new = theta_all.T[0:40000:5,:]
#For r = 100
theta_all_new = theta_all.T[0::15,:]
#For r = 10000
#theta_all_new = theta_all.T[0::15,:]
#For r = 1000000
#theta_all_new = theta_all.T[0::30,:]
print(theta_all_new.shape)
# Out:
# (3334, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Theta Movement", fontsize=15)
ax.set_xlabel('theta0', fontsize=15)
ax.set_ylabel('theta1', fontsize=15)
ax.set_zlabel('theta2', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=15)

graph = ax.scatter([], [], [], marker='o', c='r', s=15)
ax.set_xlim(np.amin(theta_all_new[:,0]), np.amax(theta_all_new[:,0]))
ax.set_ylim(np.amin(theta_all_new[:,1]), np.amax(theta_all_new[:,1]))
ax.set_zlim(np.amin(theta_all_new[:,2]), np.amax(theta_all_new[:,2]))
graph.set_alpha(1)
xdata, ydata, zdata = [], [], []

def animate(i):
    xdata.append(theta_all_new[i,0])
    ydata.append(theta_all_new[i,1])
    zdata.append(theta_all_new[i,2])
    graph._offsets3d = (xdata, ydata, zdata)
    return graph

#for r =1
#anim = FuncAnimation(fig, animate, frames=np.arange(0, theta_all_new.shape[0], 1000), interval=200, repeat_delay=3000, blit=False)

#for r =100
anim = FuncAnimation(fig, animate, frames=np.arange(0, theta_all_new.shape[0], 20), interval=200, repeat_delay=3000, blit=False)

#for r =10000
#anim = FuncAnimation(fig, animate, frames=np.arange(0, theta_all_new.shape[0], 10), interval=200, repeat_delay=3000, blit=False)

#for r =1000000
#anim = FuncAnimation(fig, animate, frames=np.arange(0, theta_all_new.shape[0], 10), interval=200, repeat_delay=3000, blit=False)

plt.show()
#anim.save('plot_r_100.gif', writer='imagemagick')
