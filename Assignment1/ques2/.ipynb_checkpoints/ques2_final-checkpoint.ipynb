# %%
#Importing Data from the CSV file
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import sys

os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q2")
print("Path has been changed to:\n", os.getcwd())

#Importing Data X from the CSV file
temp = np.genfromtxt('q2test.csv', delimiter=',')
#print(temp[1:])

X1_test = temp[1:, 0].reshape(-1,1)
X2_test = temp[1:, 1].reshape(-1,1)
Y_test = temp[1:, 2].reshape(-1,1)
X0_test = np.ones((X1_test.shape))
X_test = np.append(X0_test, X1_test, axis=1)
X_test = np.append(X_test, X2_test, axis=1)

num_test = X_test.shape[0]
os.chdir("/home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques2")
print("Path changed back to python file directory:\n", os.getcwd())
# Out:
# Path has been changed to:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/data/q2
# Path changed back to python file directory:
#  /home/ayushi/coursework/col774/Machine-Learning-Assignments/Assignment1/ques2

# %%
#given as input
m = 1000000
x0 = np.ones((m,1)) #Intercept term

#Sample X1 ~ N(3,4) and sample X2 ~ N(-1, 4)
x1 = np.random.normal(3, 2, m).reshape(-1,1)
x2 = np.random.normal(-1, 2, m).reshape(-1,1)

#Make a 1Mx3 matrix
X = np.append(x0,x1,axis=1)
X = np.append(X, x2, axis=1)
print("The number of training samples to be generated is {}".format(m))
# Out:
# The number of training samples to be generated is 1000000

# %%
#Sample epsilon error in the data from N(0, 2)
epsilon = np.random.normal(0, np.sqrt(2), m).reshape(-1,1)

#Theta is fixed with values 3, 1, 2 for generating the data. 
#We will later use these parameters to vr=erify our hypothesis from SGD. 
theta = np.array([[3], [1], [2]])

# %%
#Generate the value of Y (given X, parameterized by given Theta)
Y = np.dot(X,theta) + epsilon

# %%
#Data is (X, Y)
#Randomly shuffle the data
temp = np.append(X, Y, axis=1)
#We use random shuffle from numpy to shuffle all the rows of the data
np.random.shuffle(temp)
X = temp[:,0:3]
Y = temp[:,-1:]

# %%
#Applying SGD on X, Y to learn hypothesis with parameters theta

#Model Initial Parameters initialized to zeros
theta = np.zeros((3,1))
#Learning Rate (has to be fixed)
alpha = 0.001 

#Batch Size r options stored in an array 
batch_size = np.array([1, 100, 10000, 1000000])

print("The model's initial theta is = {} and the learning rate is = {}".format(theta.T, alpha))
# Out:
# The model's initial theta is = [[0. 0. 0.]] and the learning rate is = 0.001

# %%
#define the hypothesis function
def hypothesis(X, theta):
    return np.dot(X, theta)

#Define the cost function over the entire sample/batch
def cost_total(X, theta, Y, m):
    h_x= hypothesis(X, theta)
    cost = (1/(2*m)) * np.sum((Y-h_x)**2) # Average Cost Function
    return cost

#function for calculating the cost function gradient
def cost_grad(X, theta, Y, m):
    temp = np.dot(X, theta)-Y
    theta_grad = np.zeros((3,1))
    theta_grad += np.dot(X.transpose(), temp)
    return theta_grad/m #average Gradient 
    
cost_start = cost_total(X, theta, Y, m)
print("Initial Cost value for the hypothesis with zero parameters={}".format(cost_start))
# Out:
# Initial Cost value for the hypothesis with zero parameters=18.93045800596544

# %%
#r is the current batch size (choose between 1, 100, 10000, 1000000 - defined in batch_size array)
r = batch_size[3]
#r = sys.argv[0]

#number of batches (sub batches stored in an array mini_batch)
mini_batch = [(X[i:i+r,:], Y[i:i+r]) for i in range(0, m, r)]
print("The size of one batch is = {} and the number of batches = {}".format(r, len(mini_batch)))
#for b in mini_batch: print(b[1])
# Out:
# The size of one batch is = 1000000 and the number of batches = 1

# %%
import time
start = time.time()

i=0   #Variable for outer loop
J_curr=0.0; #Store the current cost at one (r=1) data point/over r data points
theta_all = theta
#print(theta_all)

J_avg = np.array([cost_total(X[0], theta, Y[0], 1)])
print(J_avg)

#while(np.amax(abs(cost_grad(X, theta, Y, m))) >= 0.0000001):
while(True):
    i+=1
    count = 0
    cost_initial = cost_total(X, theta, Y, m)
    for b in mini_batch:
        X_b = b[0]
        Y_b = b[1]
        J_curr += cost_total(X_b, theta, Y_b, r)
        if(count%1 == 0 and count!=0):
            J_curr /= 1; #gives the average cost over 1000 iterations. 
            J_avg = np.append(J_avg, J_curr)
            print("Current average cost = {}".format(J_curr)) 
            J_curr=0.0;  
        theta -= alpha * cost_grad(X_b, theta, Y_b, r)
        theta_all = np.append(theta_all,theta,axis=1)
        count +=1

    cost_final = cost_total(X, theta, Y, m)
    print("Cost is = {} in iterations = {}".format(cost_final, i)) 
    if (abs(cost_final - cost_initial) < 0.00000001):
        print(cost_final, cost_initial, cost_final-cost_initial)
        break
end = time.time()

print("Cost is = {} in iterations = {} in time = {} sec".format(cost_final, i, end-start))
# Out:
# [77.45425759]
# Cost is = 18.646269169512443 in iterations = 1
# Cost is = 18.368707144091474 in iterations = 2
# Cost is = 18.097591511825318 in iterations = 3
# Cost is = 17.832747022393967 in iterations = 4
# Cost is = 17.574003442836606 in iterations = 5
# Cost is = 17.32119541173695 in iterations = 6
# Cost is = 17.07416229766408 in iterations = 7
# Cost is = 16.83274806174416 in iterations = 8
# Cost is = 16.596801124242567 in iterations = 9
# Cost is = 16.366174235039036 in iterations = 10
# Cost is = 16.140724347882458 in iterations = 11
# Cost is = 15.92031249831436 in iterations = 12
# Cost is = 15.704803685154499 in iterations = 13
# Cost is = 15.494066755443988 in iterations = 14
# Cost is = 15.287974292745274 in iterations = 15
# Cost is = 15.08640250870067 in iterations = 16
# Cost is = 14.88923113775457 in iterations = 17
# Cost is = 14.696343334946416 in iterations = 18
# Cost is = 14.507625576685255 in iterations = 19
# Cost is = 14.322967564418429 in iterations = 20
# Cost is = 14.142262131109984 in iterations = 21
# Cost is = 13.965405150446712 in iterations = 22
# Cost is = 13.792295448692085 in iterations = 23
# Cost is = 13.622834719110838 in iterations = 24
# Cost is = 13.456927438889037 in iterations = 25
# Cost is = 13.294480788476728 in iterations = 26
# Cost is = 13.135404573282468 in iterations = 27
# Cost is = 12.979611147650958 in iterations = 28
# Cost is = 12.827015341057189 in iterations = 29
# Cost is = 12.677534386452221 in iterations = 30
# Cost is = 12.531087850697912 in iterations = 31
# Cost is = 12.387597567029486 in iterations = 32
# Cost is = 12.246987569486638 in iterations = 33
# Cost is = 12.109184029255934 in iterations = 34
# Cost is = 11.974115192868357 in iterations = 35
# Cost is = 11.841711322198087 in iterations = 36
# Cost is = 11.711904636209754 in iterations = 37
# Cost is = 11.58462925440318 in iterations = 38
# Cost is = 11.45982114190593 in iterations = 39
# Cost is = 11.337418056165752 in iterations = 40
# Cost is = 11.21735949519592 in iterations = 41
# Cost is = 11.099586647328364 in iterations = 42
# Cost is = 10.984042342430369 in iterations = 43
# Cost is = 10.870671004542299 in iterations = 44
# Cost is = 10.759418605894625 in iterations = 45
# Cost is = 10.650232622264234 in iterations = 46
# Cost is = 10.543061989630628 in iterations = 47
# Cost is = 10.437857062094313 in iterations = 48
# Cost is = 10.334569571020397 in iterations = 49
# Cost is = 10.233152585371617 in iterations = 50
# Cost is = 10.13356047319613 in iterations = 51
# Cost is = 10.03574886423625 in iterations = 52
# Cost is = 9.939674613625565 in iterations = 53
# Cost is = 9.845295766642488 in iterations = 54
# Cost is = 9.752571524489522 in iterations = 55
# Cost is = 9.661462211068196 in iterations = 56
# Cost is = 9.571929240720744 in iterations = 57
# Cost is = 9.483935086910083 in iterations = 58
# Cost is = 9.397443251811037 in iterations = 59
# Cost is = 9.31241823678578 in iterations = 60
# Cost is = 9.228825513718087 in iterations = 61
# Cost is = 9.146631497181076 in iterations = 62
# Cost is = 9.065803517414206 in iterations = 63
# Cost is = 8.986309794085898 in iterations = 64
# Cost is = 8.908119410818854 in iterations = 65
# Cost is = 8.831202290455774 in iterations = 66
# Cost is = 8.755529171043955 in iterations = 67
# Cost is = 8.681071582517674 in iterations = 68
# Cost is = 8.6078018240581 in iterations = 69
# Cost is = 8.535692942110911 in iterations = 70
# Cost is = 8.464718709042378 in iterations = 71
# Cost is = 8.394853602415424 in iterations = 72
# Cost is = 8.32607278486739 in iterations = 73
# Cost is = 8.258352084572147 in iterations = 74
# Cost is = 8.191667976269295 in iterations = 75
# Cost is = 8.125997562844109 in iterations = 76
# Cost is = 8.06131855744199 in iterations = 77
# Cost is = 7.997609266101976 in iterations = 78
# Cost is = 7.934848570894021 in iterations = 79
# Cost is = 7.873015913545533 in iterations = 80
# Cost is = 7.8120912795426944 in iterations = 81
# Cost is = 7.752055182692891 in iterations = 82
# Cost is = 7.692888650134683 in iterations = 83
# Cost is = 7.63457320778234 in iterations = 84
# Cost is = 7.577090866192215 in iterations = 85
# Cost is = 7.520424106838693 in iterations = 86
# Cost is = 7.46455586878777 in iterations = 87
# Cost is = 7.409469535756621 in iterations = 88
# Cost is = 7.355148923547968 in iterations = 89
# Cost is = 7.3015782678482655 in iterations = 90
# Cost is = 7.24874221237916 in iterations = 91
# Cost is = 7.19662579739182 in iterations = 92
# Cost is = 7.145214448494273 in iterations = 93
# Cost is = 7.094493965801955 in iterations = 94
# Cost is = 7.044450513402056 in iterations = 95
# Cost is = 6.995070609122547 in iterations = 96
# Cost is = 6.946341114597022 in iterations = 97
# Cost is = 6.898249225616655 in iterations = 98
# Cost is = 6.8507824627610105 in iterations = 99
# Cost is = 6.803928662299508 in iterations = 100
# Cost is = 6.757675967355666 in iterations = 101
# Cost is = 6.712012819326512 in iterations = 102
# Cost is = 6.666927949549692 in iterations = 103
# Cost is = 6.6224103712110205 in iterations = 104
# Cost is = 6.5784493714855765 in iterations = 105
# Cost is = 6.5350345039054485 in iterations = 106
# Cost is = 6.492155580947575 in iterations = 107
# Cost is = 6.449802666835233 in iterations = 108
# Cost is = 6.407966070547011 in iterations = 109
# Cost is = 6.366636339027177 in iterations = 110
# Cost is = 6.325804250591579 in iterations = 111
# Cost is = 6.2854608085234265 in iterations = 112
# Cost is = 6.245597234853386 in iterations = 113
# Cost is = 6.206204964318648 in iterations = 114
# Cost is = 6.16727563849573 in iterations = 115
# Cost is = 6.128801100101994 in iterations = 116
# Cost is = 6.0907733874609855 in iterations = 117
# Cost is = 6.053184729126712 in iterations = 118
# Cost is = 6.016027538662425 in iterations = 119
# Cost is = 5.979294409569196 in iterations = 120
# Cost is = 5.942978110360191 in iterations = 121
# Cost is = 5.907071579776075 in iterations = 122
# Cost is = 5.871567922137779 in iterations = 123
# Cost is = 5.8364604028324125 in iterations = 124
# Cost is = 5.801742443928511 in iterations = 125
# Cost is = 5.767407619916887 in iterations = 126
# Cost is = 5.73344965357345 in iterations = 127
# Cost is = 5.699862411940318 in iterations = 128
# Cost is = 5.666639902421984 in iterations = 129
# Cost is = 5.633776268993035 in iterations = 130
# Cost is = 5.601265788514248 in iterations = 131
# Cost is = 5.569102867153908 in iterations = 132
# Cost is = 5.537282036911281 in iterations = 133
# Cost is = 5.505797952239337 in iterations = 134
# Cost is = 5.474645386763683 in iterations = 135
# Cost is = 5.44381923009513 in iterations = 136
# Cost is = 5.413314484732988 in iterations = 137
# Cost is = 5.383126263056587 in iterations = 138
# Cost is = 5.353249784402366 in iterations = 139
# Cost is = 5.323680372224106 in iterations = 140
# Cost is = 5.294413451333906 in iterations = 141
# Cost is = 5.265444545221481 in iterations = 142
# Cost is = 5.236769273449633 in iterations = 143
# Cost is = 5.208383349123555 in iterations = 144
# Cost is = 5.180282576431918 in iterations = 145
# Cost is = 5.152462848257642 in iterations = 146
# Cost is = 5.1249201438563174 in iterations = 147
# Cost is = 5.097650526600304 in iterations = 148
# Cost is = 5.070650141786634 in iterations = 149
# Cost is = 5.043915214506895 in iterations = 150
# Cost is = 5.017442047577189 in iterations = 151
# Cost is = 4.991227019526583 in iterations = 152
# Cost is = 4.9652665826422355 in iterations = 153
# Cost is = 4.939557261069597 in iterations = 154
# Cost is = 4.914095648966113 in iterations = 155
# Cost is = 4.888878408706878 in iterations = 156
# Cost is = 4.86390226914068 in iterations = 157
# Cost is = 4.83916402389509 in iterations = 158
# Cost is = 4.814660529729033 in iterations = 159
# Cost is = 4.790388704931616 in iterations = 160
# Cost is = 4.766345527765787 in iterations = 161
# Cost is = 4.742528034955524 in iterations = 162
# Cost is = 4.718933320215385 in iterations = 163
# Cost is = 4.695558532821073 in iterations = 164
# Cost is = 4.672400876219933 in iterations = 165
# Cost is = 4.649457606680185 in iterations = 166
# Cost is = 4.626726031977785 in iterations = 167
# Cost is = 4.604203510119803 in iterations = 168
# Cost is = 4.581887448103327 in iterations = 169
# Cost is = 4.559775300708799 in iterations = 170
# Cost is = 4.537864569326843 in iterations = 171
# Cost is = 4.516152800817581 in iterations = 172
# Cost is = 4.494637586401535 in iterations = 173
# Cost is = 4.4733165605811935 in iterations = 174
# Cost is = 4.452187400092358 in iterations = 175
# Cost is = 4.431247822884385 in iterations = 176
# Cost is = 4.41049558712858 in iterations = 177
# Cost is = 4.389928490253805 in iterations = 178
# Cost is = 4.369544368008649 in iterations = 179
# Cost is = 4.349341093549307 in iterations = 180
# Cost is = 4.3293165765524515 in iterations = 181
# Cost is = 4.309468762352418 in iterations = 182
# Cost is = 4.289795631101957 in iterations = 183
# Cost is = 4.27029519695589 in iterations = 184
# Cost is = 4.25096550727704 in iterations = 185
# Cost is = 4.231804641863752 in iterations = 186
# Cost is = 4.212810712198463 in iterations = 187
# Cost is = 4.193981860716569 in iterations = 188
# Cost is = 4.175316260095225 in iterations = 189
# Cost is = 4.156812112561297 in iterations = 190
# Cost is = 4.1384676492180485 in iterations = 191
# Cost is = 4.120281129389993 in iterations = 192
# Cost is = 4.102250839985362 in iterations = 193
# Cost is = 4.084375094875747 in iterations = 194
# Cost is = 4.066652234292356 in iterations = 195
# Cost is = 4.049080624238479 in iterations = 196
# Cost is = 4.031658655917625 in iterations = 197
# Cost is = 4.014384745176976 in iterations = 198
# Cost is = 3.997257331965635 in iterations = 199
# Cost is = 3.980274879807284 in iterations = 200
# Cost is = 3.963435875286879 in iterations = 201
# Cost is = 3.946738827550903 in iterations = 202
# Cost is = 3.930182267820841 in iterations = 203
# Cost is = 3.9137647489195326 in iterations = 204
# Cost is = 3.897484844809963 in iterations = 205
# Cost is = 3.8813411501461754 in iterations = 206
# Cost is = 3.8653322798359895 in iterations = 207
# Cost is = 3.8494568686151474 in iterations = 208
# Cost is = 3.8337135706325745 in iterations = 209
# Cost is = 3.81810105904647 in iterations = 210
# Cost is = 3.8026180256308617 in iterations = 211
# Cost is = 3.787263180392423 in iterations = 212
# Cost is = 3.7720352511971385 in iterations = 213
# Cost is = 3.756932983406661 in iterations = 214
# Cost is = 3.7419551395240074 in iterations = 215
# Cost is = 3.727100498848374 in iterations = 216
# Cost is = 3.7123678571387666 in iterations = 217
# Cost is = 3.697756026286273 in iterations = 218
# Cost is = 3.683263833994653 in iterations = 219
# Cost is = 3.6688901234690663 in iterations = 220
# Cost is = 3.6546337531127033 in iterations = 221
# Cost is = 3.640493596231062 in iterations = 222
# Cost is = 3.6264685407437103 in iterations = 223
# Cost is = 3.612557488903284 in iterations = 224
# Cost is = 3.598759357021535 in iterations = 225
# Cost is = 3.585073075202218 in iterations = 226
# Cost is = 3.5714975870806738 in iterations = 227
# Cost is = 3.5580318495698284 in iterations = 228
# Cost is = 3.5446748326125443 in iterations = 229
# Cost is = 3.531425518940041 in iterations = 230
# Cost is = 3.518282903836304 in iterations = 231
# Cost is = 3.505245994908255 in iterations = 232
# Cost is = 3.492313811861557 in iterations = 233
# Cost is = 3.479485386281861 in iterations = 234
# Cost is = 3.4667597614214234 in iterations = 235
# Cost is = 3.454135991990828 in iterations = 236
# Cost is = 3.441613143955791 in iterations = 237
# Cost is = 3.42919029433882 in iterations = 238
# Cost is = 3.4168665310256374 in iterations = 239
# Cost is = 3.4046409525762367 in iterations = 240
# Cost is = 3.392512668040423 in iterations = 241
# Cost is = 3.3804807967777335 in iterations = 242
# Cost is = 3.3685444682816117 in iterations = 243
# Cost is = 3.3567028220077053 in iterations = 244
# Cost is = 3.3449550072062264 in iterations = 245
# Cost is = 3.3333001827581734 in iterations = 246
# Cost is = 3.3217375170154164 in iterations = 247
# Cost is = 3.310266187644436 in iterations = 248
# Cost is = 3.298885381473706 in iterations = 249
# Cost is = 3.287594294344563 in iterations = 250
# Cost is = 3.276392130965494 in iterations = 251
# Cost is = 3.265278104769736 in iterations = 252
# Cost is = 3.254251437776124 in iterations = 253
# Cost is = 3.243311360453053 in iterations = 254
# Cost is = 3.232457111585534 in iterations = 255
# Cost is = 3.221687938145189 in iterations = 256
# Cost is = 3.2110030951631785 in iterations = 257
# Cost is = 3.20040184560592 in iterations = 258
# Cost is = 3.1898834602535677 in iterations = 259
# Cost is = 3.179447217581153 in iterations = 260
# Cost is = 3.1690924036423356 in iterations = 261
# Cost is = 3.158818311955673 in iterations = 262
# Cost is = 3.1486242433933667 in iterations = 263
# Cost is = 3.1385095060723924 in iterations = 264
# Cost is = 3.1284734152479823 in iterations = 265
# Cost is = 3.1185152932093625 in iterations = 266
# Cost is = 3.1086344691777246 in iterations = 267
# Cost is = 3.098830279206339 in iterations = 268
# Cost is = 3.0891020660827717 in iterations = 269
# Cost is = 3.0794491792331478 in iterations = 270
# Cost is = 3.0698709746284063 in iterations = 271
# Cost is = 3.060366814692485 in iterations = 272
# Cost is = 3.0509360682124154 in iterations = 273
# Cost is = 3.0415781102502413 in iterations = 274
# Cost is = 3.03229232205673 in iterations = 275
# Cost is = 3.0230780909868478 in iterations = 276
# Cost is = 3.0139348104169055 in iterations = 277
# Cost is = 3.0048618796634075 in iterations = 278
# Cost is = 2.995858703903466 in iterations = 279
# Cost is = 2.9869246940968366 in iterations = 280
# Cost is = 2.978059266909452 in iterations = 281
# Cost is = 2.9692618446384733 in iterations = 282
# Cost is = 2.9605318551387985 in iterations = 283
# Cost is = 2.9518687317509804 in iterations = 284
# Cost is = 2.943271913230526 in iterations = 285
# Cost is = 2.934740843678583 in iterations = 286
# Cost is = 2.926274972473894 in iterations = 287
# Cost is = 2.917873754206069 in iterations = 288
# Cost is = 2.909536648610096 in iterations = 289
# Cost is = 2.9012631205020787 in iterations = 290
# Cost is = 2.8930526397161627 in iterations = 291
# Cost is = 2.884904681042616 in iterations = 292
# Cost is = 2.876818724167059 in iterations = 293
# Cost is = 2.8687942536107944 in iterations = 294
# Cost is = 2.8608307586721966 in iterations = 295
# Cost is = 2.8529277333691865 in iterations = 296
# Cost is = 2.845084676382703 in iterations = 297
# Cost is = 2.8373010910011964 in iterations = 298
# Cost is = 2.829576485066092 in iterations = 299
# Cost is = 2.821910370918205 in iterations = 300
# Cost is = 2.814302265345097 in iterations = 301
# Cost is = 2.806751689529329 in iterations = 302
# Cost is = 2.7992581689976186 in iterations = 303
# Cost is = 2.7918212335708414 in iterations = 304
# Cost is = 2.7844404173149093 in iterations = 305
# Cost is = 2.7771152584924446 in iterations = 306
# Cost is = 2.7698452995152865 in iterations = 307
# Cost is = 2.762630086897766 in iterations = 308
# Cost is = 2.7554691712107706 in iterations = 309
# Cost is = 2.7483621070365385 in iterations = 310
# Cost is = 2.741308452924222 in iterations = 311
# Cost is = 2.734307771346128 in iterations = 312
# Cost is = 2.727359628654693 in iterations = 313
# Cost is = 2.7204635950401332 in iterations = 314
# Cost is = 2.713619244488755 in iterations = 315
# Cost is = 2.7068261547419525 in iterations = 316
# Cost is = 2.7000839072558005 in iterations = 317
# Cost is = 2.693392087161308 in iterations = 318
# Cost is = 2.6867502832252854 in iterations = 319
# Cost is = 2.6801580878117877 in iterations = 320
# Cost is = 2.6736150968441557 in iterations = 321
# Cost is = 2.6671209097676445 in iterations = 322
# Cost is = 2.660675129512587 in iterations = 323
# Cost is = 2.6542773624581297 in iterations = 324
# Cost is = 2.6479272183964793 in iterations = 325
# Cost is = 2.6416243104977095 in iterations = 326
# Cost is = 2.6353682552750426 in iterations = 327
# Cost is = 2.629158672550677 in iterations = 328
# Cost is = 2.622995185422059 in iterations = 329
# Cost is = 2.616877420228678 in iterations = 330
# Cost is = 2.61080500651932 in iterations = 331
# Cost is = 2.6047775770197705 in iterations = 332
# Cost is = 2.5987947676009866 in iterations = 333
# Cost is = 2.5928562172477068 in iterations = 334
# Cost is = 2.5869615680274967 in iterations = 335
# Cost is = 2.5811104650602212 in iterations = 336
# Cost is = 2.5753025564879195 in iterations = 337
# Cost is = 2.5695374934451185 in iterations = 338
# Cost is = 2.5638149300295097 in iterations = 339
# Cost is = 2.558134523273055 in iterations = 340
# Cost is = 2.552495933113446 in iterations = 341
# Cost is = 2.546898822365958 in iterations = 342
# Cost is = 2.5413428566956746 in iterations = 343
# Cost is = 2.5358277045900577 in iterations = 344
# Cost is = 2.5303530373319023 in iterations = 345
# Cost is = 2.5249185289726066 in iterations = 346
# Cost is = 2.5195238563058027 in iterations = 347
# Cost is = 2.514168698841331 in iterations = 348
# Cost is = 2.508852738779523 in iterations = 349
# Cost is = 2.5035756609858106 in iterations = 350
# Cost is = 2.4983371529656826 in iterations = 351
# Cost is = 2.493136904839901 in iterations = 352
# Cost is = 2.487974609320068 in iterations = 353
# Cost is = 2.4828499616844675 in iterations = 354
# Cost is = 2.4777626597542093 in iterations = 355
# Cost is = 2.4727124038696604 in iterations = 356
# Cost is = 2.4676988968671663 in iterations = 357
# Cost is = 2.4627218440560386 in iterations = 358
# Cost is = 2.4577809531958255 in iterations = 359
# Cost is = 2.4528759344738535 in iterations = 360
# Cost is = 2.448006500483028 in iterations = 361
# Cost is = 2.4431723661998883 in iterations = 362
# Cost is = 2.438373248962929 in iterations = 363
# Cost is = 2.4336088684511736 in iterations = 364
# Cost is = 2.4288789466629783 in iterations = 365
# Cost is = 2.4241832078950893 in iterations = 366
# Cost is = 2.4195213787219454 in iterations = 367
# Cost is = 2.4148931879752054 in iterations = 368
# Cost is = 2.4102983667234974 in iterations = 369
# Cost is = 2.405736648252422 in iterations = 370
# Cost is = 2.4012077680447392 in iterations = 371
# Cost is = 2.39671146376082 in iterations = 372
# Cost is = 2.392247475219276 in iterations = 373
# Cost is = 2.387815544377817 in iterations = 374
# Cost is = 2.3834154153143237 in iterations = 375
# Cost is = 2.3790468342081104 in iterations = 376
# Cost is = 2.3747095493214014 in iterations = 377
# Cost is = 2.3704033109810045 in iterations = 378
# Cost is = 2.3661278715601806 in iterations = 379
# Cost is = 2.3618829854606993 in iterations = 380
# Cost is = 2.357668409095097 in iterations = 381
# Cost is = 2.353483900869111 in iterations = 382
# Cost is = 2.3493292211643126 in iterations = 383
# Cost is = 2.345204132320894 in iterations = 384
# Cost is = 2.341108398620674 in iterations = 385
# Cost is = 2.337041786270241 in iterations = 386
# Cost is = 2.333004063384296 in iterations = 387
# Cost is = 2.328994999969152 in iterations = 388
# Cost is = 2.325014367906421 in iterations = 389
# Cost is = 2.32106194093683 in iterations = 390
# Cost is = 2.317137494644252 in iterations = 391
# Cost is = 2.313240806439853 in iterations = 392
# Cost is = 2.309371655546423 in iterations = 393
# Cost is = 2.305529822982858 in iterations = 394
# Cost is = 2.3017150915487985 in iterations = 395
# Cost is = 2.2979272458094155 in iterations = 396
# Cost is = 2.2941660720803494 in iterations = 397
# Cost is = 2.290431358412805 in iterations = 398
# Cost is = 2.2867228945787805 in iterations = 399
# Cost is = 2.283040472056448 in iterations = 400
# Cost is = 2.279383884015681 in iterations = 401
# Cost is = 2.275752925303709 in iterations = 402
# Cost is = 2.2721473924309317 in iterations = 403
# Cost is = 2.2685670835568406 in iterations = 404
# Cost is = 2.26501179847611 in iterations = 405
# Cost is = 2.261481338604796 in iterations = 406
# Cost is = 2.2579755069666803 in iterations = 407
# Cost is = 2.2544941081797316 in iterations = 408
# Cost is = 2.25103694844271 in iterations = 409
# Cost is = 2.2476038355219035 in iterations = 410
# Cost is = 2.2441945787379494 in iterations = 411
# Cost is = 2.2408089889528378 in iterations = 412
# Cost is = 2.2374468785569874 in iterations = 413
# Cost is = 2.2341080614564723 in iterations = 414
# Cost is = 2.230792353060354 in iterations = 415
# Cost is = 2.227499570268139 in iterations = 416
# Cost is = 2.224229531457341 in iterations = 417
# Cost is = 2.22098205647117 in iterations = 418
# Cost is = 2.2177569666063337 in iterations = 419
# Cost is = 2.2145540846009455 in iterations = 420
# Cost is = 2.211373234622535 in iterations = 421
# Cost is = 2.208214242256199 in iterations = 422
# Cost is = 2.205076934492825 in iterations = 423
# Cost is = 2.2019611397174383 in iterations = 424
# Cost is = 2.1988666876976604 in iterations = 425
# Cost is = 2.1957934095722607 in iterations = 426
# Cost is = 2.1927411378398163 in iterations = 427
# Cost is = 2.1897097063474735 in iterations = 428
# Cost is = 2.186698950279812 in iterations = 429
# Cost is = 2.183708706147801 in iterations = 430
# Cost is = 2.180738811777874 in iterations = 431
# Cost is = 2.177789106301071 in iterations = 432
# Cost is = 2.1748594301423054 in iterations = 433
# Cost is = 2.1719496250097126 in iterations = 434
# Cost is = 2.1690595338840892 in iterations = 435
# Cost is = 2.16618900100844 in iterations = 436
# Cost is = 2.163337871877611 in iterations = 437
# Cost is = 2.160505993227995 in iterations = 438
# Cost is = 2.157693213027366 in iterations = 439
# Cost is = 2.1548993804647667 in iterations = 440
# Cost is = 2.1521243459405084 in iterations = 441
# Cost is = 2.149367961056241 in iterations = 442
# Cost is = 2.14663007860513 in iterations = 443
# Cost is = 2.1439105525620943 in iterations = 444
# Cost is = 2.1412092380741528 in iterations = 445
# Cost is = 2.1385259914508334 in iterations = 446
# Cost is = 2.135860670154691 in iterations = 447
# Cost is = 2.133213132791872 in iterations = 448
# Cost is = 2.1305832391028012 in iterations = 449
# Cost is = 2.127970849952915 in iterations = 450
# Cost is = 2.1253758273234964 in iterations = 451
# Cost is = 2.1227980343025696 in iterations = 452
# Cost is = 2.120237335075901 in iterations = 453
# Cost is = 2.117693594918043 in iterations = 454
# Cost is = 2.115166680183481 in iterations = 455
# Cost is = 2.112656458297847 in iterations = 456
# Cost is = 2.1101627977492017 in iterations = 457
# Cost is = 2.107685568079405 in iterations = 458
# Cost is = 2.1052246398755488 in iterations = 459
# Cost is = 2.1027798847614636 in iterations = 460
# Cost is = 2.1003511753893065 in iterations = 461
# Cost is = 2.0979383854312075 in iterations = 462
# Cost is = 2.095541389570997 in iterations = 463
# Cost is = 2.093160063495998 in iterations = 464
# Cost is = 2.0907942838888878 in iterations = 465
# Cost is = 2.0884439284196348 in iterations = 466
# Cost is = 2.086108875737489 in iterations = 467
# Cost is = 2.0837890054630597 in iterations = 468
# Cost is = 2.0814841981804424 in iterations = 469
# Cost is = 2.0791943354294213 in iterations = 470
# Cost is = 2.076919299697735 in iterations = 471
# Cost is = 2.074658974413404 in iterations = 472
# Cost is = 2.0724132439371323 in iterations = 473
# Cost is = 2.070181993554758 in iterations = 474
# Cost is = 2.067965109469774 in iterations = 475
# Cost is = 2.0657624787959246 in iterations = 476
# Cost is = 2.0635739895498406 in iterations = 477
# Cost is = 2.0613995306437416 in iterations = 478
# Cost is = 2.059238991878218 in iterations = 479
# Cost is = 2.0570922639350493 in iterations = 480
# Cost is = 2.0549592383700963 in iterations = 481
# Cost is = 2.0528398076062455 in iterations = 482
# Cost is = 2.0507338649264137 in iterations = 483
# Cost is = 2.0486413044666176 in iterations = 484
# Cost is = 2.0465620212090823 in iterations = 485
# Cost is = 2.044495910975438 in iterations = 486
# Cost is = 2.0424428704199364 in iterations = 487
# Cost is = 2.040402797022752 in iterations = 488
# Cost is = 2.038375589083324 in iterations = 489
# Cost is = 2.0363611457137556 in iterations = 490
# Cost is = 2.034359366832277 in iterations = 491
# Cost is = 2.0323701531567413 in iterations = 492
# Cost is = 2.030393406198201 in iterations = 493
# Cost is = 2.028429028254515 in iterations = 494
# Cost is = 2.0264769224040253 in iterations = 495
# Cost is = 2.024536992499261 in iterations = 496
# Cost is = 2.022609143160734 in iterations = 497
# Cost is = 2.02069327977074 in iterations = 498
# Cost is = 2.018789308467244 in iterations = 499
# Cost is = 2.016897136137806 in iterations = 500
# Cost is = 2.0150166704135475 in iterations = 501
# Cost is = 2.0131478196631774 in iterations = 502
# Cost is = 2.011290492987073 in iterations = 503
# Cost is = 2.0094446002113853 in iterations = 504
# Cost is = 2.0076100518822177 in iterations = 505
# Cost is = 2.005786759259846 in iterations = 506
# Cost is = 2.003974634312972 in iterations = 507
# Cost is = 2.002173589713042 in iterations = 508
# Cost is = 2.000383538828601 in iterations = 509
# Cost is = 1.998604395719699 in iterations = 510
# Cost is = 1.996836075132336 in iterations = 511
# Cost is = 1.9950784924929534 in iterations = 512
# Cost is = 1.993331563902987 in iterations = 513
# Cost is = 1.9915952061334352 in iterations = 514
# Cost is = 1.9898693366194924 in iterations = 515
# Cost is = 1.9881538734552224 in iterations = 516
# Cost is = 1.9864487353882723 in iterations = 517
# Cost is = 1.9847538418146278 in iterations = 518
# Cost is = 1.983069112773417 in iterations = 519
# Cost is = 1.9813944689417495 in iterations = 520
# Cost is = 1.9797298316296017 in iterations = 521
# Cost is = 1.9780751227747477 in iterations = 522
# Cost is = 1.976430264937721 in iterations = 523
# Cost is = 1.9747951812968243 in iterations = 524
# Cost is = 1.9731697956431768 in iterations = 525
# Cost is = 1.9715540323758092 in iterations = 526
# Cost is = 1.9699478164967796 in iterations = 527
# Cost is = 1.968351073606357 in iterations = 528
# Cost is = 1.9667637298982152 in iterations = 529
# Cost is = 1.9651857121546892 in iterations = 530
# Cost is = 1.9636169477420533 in iterations = 531
# Cost is = 1.962057364605841 in iterations = 532
# Cost is = 1.9605068912662182 in iterations = 533
# Cost is = 1.9589654568133654 in iterations = 534
# Cost is = 1.957432990902925 in iterations = 535
# Cost is = 1.9559094237514676 in iterations = 536
# Cost is = 1.954394686132 in iterations = 537
# Cost is = 1.9528887093695169 in iterations = 538
# Cost is = 1.9513914253365723 in iterations = 539
# Cost is = 1.9499027664489055 in iterations = 540
# Cost is = 1.9484226656610864 in iterations = 541
# Cost is = 1.9469510564622041 in iterations = 542
# Cost is = 1.9454878728715923 in iterations = 543
# Cost is = 1.9440330494345812 in iterations = 544
# Cost is = 1.942586521218295 in iterations = 545
# Cost is = 1.9411482238074662 in iterations = 546
# Cost is = 1.939718093300303 in iterations = 547
# Cost is = 1.9382960663043778 in iterations = 548
# Cost is = 1.9368820799325486 in iterations = 549
# Cost is = 1.9354760717989243 in iterations = 550
# Cost is = 1.9340779800148502 in iterations = 551
# Cost is = 1.9326877431849305 in iterations = 552
# Cost is = 1.9313053004030796 in iterations = 553
# Cost is = 1.929930591248616 in iterations = 554
# Cost is = 1.9285635557823766 in iterations = 555
# Cost is = 1.9272041345428632 in iterations = 556
# Cost is = 1.9258522685424244 in iterations = 557
# Cost is = 1.9245078992634705 in iterations = 558
# Cost is = 1.9231709686547074 in iterations = 559
# Cost is = 1.9218414191274122 in iterations = 560
# Cost is = 1.9205191935517343 in iterations = 561
# Cost is = 1.919204235253026 in iterations = 562
# Cost is = 1.917896488008207 in iterations = 563
# Cost is = 1.9165958960421434 in iterations = 564
# Cost is = 1.9153024040240807 in iterations = 565
# Cost is = 1.9140159570640847 in iterations = 566
# Cost is = 1.9127365007095138 in iterations = 567
# Cost is = 1.9114639809415297 in iterations = 568
# Cost is = 1.9101983441716326 in iterations = 569
# Cost is = 1.9089395372382074 in iterations = 570
# Cost is = 1.907687507403131 in iterations = 571
# Cost is = 1.9064422023483738 in iterations = 572
# Cost is = 1.9052035701726455 in iterations = 573
# Cost is = 1.9039715593880717 in iterations = 574
# Cost is = 1.9027461189168797 in iterations = 575
# Cost is = 1.9015271980881288 in iterations = 576
# Cost is = 1.9003147466344528 in iterations = 577
# Cost is = 1.8991087146888446 in iterations = 578
# Cost is = 1.8979090527814506 in iterations = 579
# Cost is = 1.8967157118363978 in iterations = 580
# Cost is = 1.8955286431686447 in iterations = 581
# Cost is = 1.8943477984808634 in iterations = 582
# Cost is = 1.893173129860344 in iterations = 583
# Cost is = 1.8920045897759081 in iterations = 584
# Cost is = 1.890842131074878 in iterations = 585
# Cost is = 1.8896857069800426 in iterations = 586
# Cost is = 1.8885352710866594 in iterations = 587
# Cost is = 1.887390777359484 in iterations = 588
# Cost is = 1.8862521801298093 in iterations = 589
# Cost is = 1.8851194340925477 in iterations = 590
# Cost is = 1.8839924943033248 in iterations = 591
# Cost is = 1.8828713161755855 in iterations = 592
# Cost is = 1.8817558554777587 in iterations = 593
# Cost is = 1.8806460683303996 in iterations = 594
# Cost is = 1.8795419112033929 in iterations = 595
# Cost is = 1.8784433409131551 in iterations = 596
# Cost is = 1.877350314619868 in iterations = 597
# Cost is = 1.8762627898247386 in iterations = 598
# Cost is = 1.8751807243672656 in iterations = 599
# Cost is = 1.8741040764225472 in iterations = 600
# Cost is = 1.8730328044985958 in iterations = 601
# Cost is = 1.871966867433681 in iterations = 602
# Cost is = 1.8709062243936918 in iterations = 603
# Cost is = 1.869850834869525 in iterations = 604
# Cost is = 1.868800658674478 in iterations = 605
# Cost is = 1.8677556559416897 in iterations = 606
# Cost is = 1.8667157871215745 in iterations = 607
# Cost is = 1.8656810129792962 in iterations = 608
# Cost is = 1.8646512945922507 in iterations = 609
# Cost is = 1.8636265933475735 in iterations = 610
# Cost is = 1.8626068709396704 in iterations = 611
# Cost is = 1.8615920893677582 in iterations = 612
# Cost is = 1.8605822109334385 in iterations = 613
# Cost is = 1.859577198238273 in iterations = 614
# Cost is = 1.8585770141813973 in iterations = 615
# Cost is = 1.857581621957147 in iterations = 616
# Cost is = 1.8565909850526878 in iterations = 617
# Cost is = 1.8556050672456956 in iterations = 618
# Cost is = 1.8546238326020212 in iterations = 619
# Cost is = 1.8536472454733988 in iterations = 620
# Cost is = 1.8526752704951621 in iterations = 621
# Cost is = 1.8517078725839793 in iterations = 622
# Cost is = 1.850745016935604 in iterations = 623
# Cost is = 1.8497866690226585 in iterations = 624
# Cost is = 1.8488327945924095 in iterations = 625
# Cost is = 1.847883359664583 in iterations = 626
# Cost is = 1.8469383305291918 in iterations = 627
# Cost is = 1.8459976737443706 in iterations = 628
# Cost is = 1.8450613561342408 in iterations = 629
# Cost is = 1.8441293447867884 in iterations = 630
# Cost is = 1.8432016070517534 in iterations = 631
# Cost is = 1.842278110538543 in iterations = 632
# Cost is = 1.8413588231141618 in iterations = 633
# Cost is = 1.8404437129011473 in iterations = 634
# Cost is = 1.839532748275537 in iterations = 635
# Cost is = 1.8386258978648493 in iterations = 636
# Cost is = 1.8377231305460602 in iterations = 637
# Cost is = 1.8368244154436295 in iterations = 638
# Cost is = 1.835929721927517 in iterations = 639
# Cost is = 1.8350390196112247 in iterations = 640
# Cost is = 1.834152278349851 in iterations = 641
# Cost is = 1.833269468238167 in iterations = 642
# Cost is = 1.832390559608699 in iterations = 643
# Cost is = 1.8315155230298341 in iterations = 644
# Cost is = 1.8306443293039332 in iterations = 645
# Cost is = 1.8297769494654725 in iterations = 646
# Cost is = 1.8289133547791796 in iterations = 647
# Cost is = 1.8280535167382064 in iterations = 648
# Cost is = 1.8271974070623003 in iterations = 649
# Cost is = 1.8263449976959931 in iterations = 650
# Cost is = 1.8254962608068157 in iterations = 651
# Cost is = 1.8246511687835116 in iterations = 652
# Cost is = 1.8238096942342743 in iterations = 653
# Cost is = 1.8229718099849945 in iterations = 654
# Cost is = 1.8221374890775233 in iterations = 655
# Cost is = 1.8213067047679512 in iterations = 656
# Cost is = 1.82047943052489 in iterations = 657
# Cost is = 1.8196556400277923 in iterations = 658
# Cost is = 1.818835307165252 in iterations = 659
# Cost is = 1.818018406033348 in iterations = 660
# Cost is = 1.8172049109339783 in iterations = 661
# Cost is = 1.8163947963732274 in iterations = 662
# Cost is = 1.8155880370597337 in iterations = 663
# Cost is = 1.8147846079030627 in iterations = 664
# Cost is = 1.8139844840121215 in iterations = 665
# Cost is = 1.8131876406935572 in iterations = 666
# Cost is = 1.812394053450177 in iterations = 667
# Cost is = 1.8116036979793937 in iterations = 668
# Cost is = 1.81081655017166 in iterations = 669
# Cost is = 1.8100325861089364 in iterations = 670
# Cost is = 1.8092517820631622 in iterations = 671
# Cost is = 1.8084741144947376 in iterations = 672
# Cost is = 1.8076995600510184 in iterations = 673
# Cost is = 1.806928095564828 in iterations = 674
# Cost is = 1.806159698052976 in iterations = 675
# Cost is = 1.8053943447147924 in iterations = 676
# Cost is = 1.804632012930661 in iterations = 677
# Cost is = 1.8038726802605924 in iterations = 678
# Cost is = 1.8031163244427726 in iterations = 679
# Cost is = 1.8023629233921563 in iterations = 680
# Cost is = 1.8016124551990458 in iterations = 681
# Cost is = 1.8008648981276967 in iterations = 682
# Cost is = 1.8001202306149284 in iterations = 683
# Cost is = 1.7993784312687486 in iterations = 684
# Cost is = 1.7986394788669906 in iterations = 685
# Cost is = 1.7979033523559456 in iterations = 686
# Cost is = 1.7971700308490388 in iterations = 687
# Cost is = 1.7964394936254726 in iterations = 688
# Cost is = 1.7957117201289285 in iterations = 689
# Cost is = 1.7949866899662306 in iterations = 690
# Cost is = 1.7942643829060618 in iterations = 691
# Cost is = 1.793544778877668 in iterations = 692
# Cost is = 1.7928278579695687 in iterations = 693
# Cost is = 1.7921136004282978 in iterations = 694
# Cost is = 1.7914019866571387 in iterations = 695
# Cost is = 1.7906929972148689 in iterations = 696
# Cost is = 1.789986612814523 in iterations = 697
# Cost is = 1.7892828143221693 in iterations = 698
# Cost is = 1.7885815827556746 in iterations = 699
# Cost is = 1.7878828992835039 in iterations = 700
# Cost is = 1.7871867452235144 in iterations = 701
# Cost is = 1.7864931020417654 in iterations = 702
# Cost is = 1.7858019513513361 in iterations = 703
# Cost is = 1.7851132749111505 in iterations = 704
# Cost is = 1.7844270546248144 in iterations = 705
# Cost is = 1.7837432725394646 in iterations = 706
# Cost is = 1.7830619108446184 in iterations = 707
# Cost is = 1.7823829518710441 in iterations = 708
# Cost is = 1.7817063780896267 in iterations = 709
# Cost is = 1.7810321721102542 in iterations = 710
# Cost is = 1.780360316680712 in iterations = 711
# Cost is = 1.7796907946855742 in iterations = 712
# Cost is = 1.7790235891451243 in iterations = 713
# Cost is = 1.778358683214256 in iterations = 714
# Cost is = 1.7776960601814171 in iterations = 715
# Cost is = 1.777035703467533 in iterations = 716
# Cost is = 1.7763775966249504 in iterations = 717
# Cost is = 1.7757217233363956 in iterations = 718
# Cost is = 1.775068067413928 in iterations = 719
# Cost is = 1.774416612797909 in iterations = 720
# Cost is = 1.7737673435559829 in iterations = 721
# Cost is = 1.7731202438820526 in iterations = 722
# Cost is = 1.7724752980952891 in iterations = 723
# Cost is = 1.7718324906391087 in iterations = 724
# Cost is = 1.7711918060802059 in iterations = 725
# Cost is = 1.770553229107551 in iterations = 726
# Cost is = 1.7699167445314268 in iterations = 727
# Cost is = 1.7692823372824524 in iterations = 728
# Cost is = 1.7686499924106314 in iterations = 729
# Cost is = 1.7680196950843914 in iterations = 730
# Cost is = 1.767391430589651 in iterations = 731
# Cost is = 1.7667651843288648 in iterations = 732
# Cost is = 1.7661409418201108 in iterations = 733
# Cost is = 1.7655186886961627 in iterations = 734
# Cost is = 1.7648984107035652 in iterations = 735
# Cost is = 1.764280093701746 in iterations = 736
# Cost is = 1.7636637236620945 in iterations = 737
# Cost is = 1.7630492866670837 in iterations = 738
# Cost is = 1.762436768909381 in iterations = 739
# Cost is = 1.7618261566909605 in iterations = 740
# Cost is = 1.7612174364222433 in iterations = 741
# Cost is = 1.7606105946212243 in iterations = 742
# Cost is = 1.7600056179126173 in iterations = 743
# Cost is = 1.7594024930270054 in iterations = 744
# Cost is = 1.758801206799991 in iterations = 745
# Cost is = 1.758201746171362 in iterations = 746
# Cost is = 1.7576040981842656 in iterations = 747
# Cost is = 1.7570082499843687 in iterations = 748
# Cost is = 1.7564141888190579 in iterations = 749
# Cost is = 1.7558219020366206 in iterations = 750
# Cost is = 1.7552313770854333 in iterations = 751
# Cost is = 1.7546426015131775 in iterations = 752
# Cost is = 1.7540555629660348 in iterations = 753
# Cost is = 1.753470249187909 in iterations = 754
# Cost is = 1.7528866480196432 in iterations = 755
# Cost is = 1.7523047473982465 in iterations = 756
# Cost is = 1.751724535356133 in iterations = 757
# Cost is = 1.7511460000203478 in iterations = 758
# Cost is = 1.7505691296118286 in iterations = 759
# Cost is = 1.7499939124446433 in iterations = 760
# Cost is = 1.7494203369252543 in iterations = 761
# Cost is = 1.7488483915517814 in iterations = 762
# Cost is = 1.7482780649132648 in iterations = 763
# Cost is = 1.7477093456889494 in iterations = 764
# Cost is = 1.7471422226475581 in iterations = 765
# Cost is = 1.7465766846465791 in iterations = 766
# Cost is = 1.7460127206315588 in iterations = 767
# Cost is = 1.7454503196354056 in iterations = 768
# Cost is = 1.7448894707776799 in iterations = 769
# Cost is = 1.7443301632639172 in iterations = 770
# Cost is = 1.7437723863849302 in iterations = 771
# Cost is = 1.7432161295161386 in iterations = 772
# Cost is = 1.742661382116889 in iterations = 773
# Cost is = 1.7421081337297832 in iterations = 774
# Cost is = 1.7415563739800228 in iterations = 775
# Cost is = 1.7410060925747437 in iterations = 776
# Cost is = 1.7404572793023625 in iterations = 777
# Cost is = 1.739909924031931 in iterations = 778
# Cost is = 1.7393640167124915 in iterations = 779
# Cost is = 1.7388195473724444 in iterations = 780
# Cost is = 1.7382765061189018 in iterations = 781
# Cost is = 1.7377348831370787 in iterations = 782
# Cost is = 1.737194668689651 in iterations = 783
# Cost is = 1.7366558531161504 in iterations = 784
# Cost is = 1.736118426832351 in iterations = 785
# Cost is = 1.7355823803296526 in iterations = 786
# Cost is = 1.7350477041744852 in iterations = 787
# Cost is = 1.7345143890077113 in iterations = 788
# Cost is = 1.7339824255440277 in iterations = 789
# Cost is = 1.7334518045713756 in iterations = 790
# Cost is = 1.732922516950366 in iterations = 791
# Cost is = 1.732394553613687 in iterations = 792
# Cost is = 1.7318679055655424 in iterations = 793
# Cost is = 1.7313425638810696 in iterations = 794
# Cost is = 1.7308185197057815 in iterations = 795
# Cost is = 1.7302957642550048 in iterations = 796
# Cost is = 1.7297742888133185 in iterations = 797
# Cost is = 1.7292540847340043 in iterations = 798
# Cost is = 1.7287351434385039 in iterations = 799
# Cost is = 1.728217456415867 in iterations = 800
# Cost is = 1.727701015222215 in iterations = 801
# Cost is = 1.7271858114802103 in iterations = 802
# Cost is = 1.7266718368785232 in iterations = 803
# Cost is = 1.7261590831712992 in iterations = 804
# Cost is = 1.7256475421776498 in iterations = 805
# Cost is = 1.7251372057811236 in iterations = 806
# Cost is = 1.724628065929197 in iterations = 807
# Cost is = 1.7241201146327632 in iterations = 808
# Cost is = 1.723613343965628 in iterations = 809
# Cost is = 1.7231077460640079 in iterations = 810
# Cost is = 1.7226033131260292 in iterations = 811
# Cost is = 1.7221000374112412 in iterations = 812
# Cost is = 1.7215979112401183 in iterations = 813
# Cost is = 1.7210969269935807 in iterations = 814
# Cost is = 1.7205970771125116 in iterations = 815
# Cost is = 1.720098354097271 in iterations = 816
# Cost is = 1.7196007505072357 in iterations = 817
# Cost is = 1.7191042589603167 in iterations = 818
# Cost is = 1.718608872132498 in iterations = 819
# Cost is = 1.718114582757374 in iterations = 820
# Cost is = 1.7176213836256848 in iterations = 821
# Cost is = 1.7171292675848688 in iterations = 822
# Cost is = 1.7166382275386038 in iterations = 823
# Cost is = 1.7161482564463633 in iterations = 824
# Cost is = 1.7156593473229667 in iterations = 825
# Cost is = 1.715171493238143 in iterations = 826
# Cost is = 1.714684687316091 in iterations = 827
# Cost is = 1.714198922735044 in iterations = 828
# Cost is = 1.71371419272684 in iterations = 829
# Cost is = 1.7132304905764968 in iterations = 830
# Cost is = 1.7127478096217803 in iterations = 831
# Cost is = 1.7122661432527977 in iterations = 832
# Cost is = 1.7117854849115641 in iterations = 833
# Cost is = 1.7113058280915996 in iterations = 834
# Cost is = 1.7108271663375163 in iterations = 835
# Cost is = 1.7103494932446068 in iterations = 836
# Cost is = 1.7098728024584484 in iterations = 837
# Cost is = 1.709397087674498 in iterations = 838
# Cost is = 1.708922342637688 in iterations = 839
# Cost is = 1.7084485611420401 in iterations = 840
# Cost is = 1.707975737030276 in iterations = 841
# Cost is = 1.7075038641934224 in iterations = 842
# Cost is = 1.7070329365704267 in iterations = 843
# Cost is = 1.706562948147778 in iterations = 844
# Cost is = 1.7060938929591278 in iterations = 845
# Cost is = 1.705625765084913 in iterations = 846
# Cost is = 1.7051585586519846 in iterations = 847
# Cost is = 1.7046922678332332 in iterations = 848
# Cost is = 1.704226886847228 in iterations = 849
# Cost is = 1.7037624099578452 in iterations = 850
# Cost is = 1.7032988314739201 in iterations = 851
# Cost is = 1.7028361457488737 in iterations = 852
# Cost is = 1.7023743471803643 in iterations = 853
# Cost is = 1.7019134302099355 in iterations = 854
# Cost is = 1.701453389322667 in iterations = 855
# Cost is = 1.7009942190468252 in iterations = 856
# Cost is = 1.700535913953516 in iterations = 857
# Cost is = 1.7000784686563524 in iterations = 858
# Cost is = 1.6996218778111085 in iterations = 859
# Cost is = 1.6991661361153838 in iterations = 860
# Cost is = 1.6987112383082736 in iterations = 861
# Cost is = 1.6982571791700338 in iterations = 862
# Cost is = 1.6978039535217606 in iterations = 863
# Cost is = 1.6973515562250525 in iterations = 864
# Cost is = 1.6968999821817 in iterations = 865
# Cost is = 1.6964492263333548 in iterations = 866
# Cost is = 1.6959992836612254 in iterations = 867
# Cost is = 1.6955501491857463 in iterations = 868
# Cost is = 1.6951018179662727 in iterations = 869
# Cost is = 1.6946542851007773 in iterations = 870
# Cost is = 1.6942075457255312 in iterations = 871
# Cost is = 1.6937615950147984 in iterations = 872
# Cost is = 1.6933164281805493 in iterations = 873
# Cost is = 1.6928720404721398 in iterations = 874
# Cost is = 1.692428427176023 in iterations = 875
# Cost is = 1.6919855836154574 in iterations = 876
# Cost is = 1.6915435051502077 in iterations = 877
# Cost is = 1.6911021871762497 in iterations = 878
# Cost is = 1.6906616251254964 in iterations = 879
# Cost is = 1.690221814465497 in iterations = 880
# Cost is = 1.689782750699159 in iterations = 881
# Cost is = 1.6893444293644682 in iterations = 882
# Cost is = 1.6889068460342043 in iterations = 883
# Cost is = 1.6884699963156697 in iterations = 884
# Cost is = 1.6880338758504085 in iterations = 885
# Cost is = 1.6875984803139352 in iterations = 886
# Cost is = 1.68716380541547 in iterations = 887
# Cost is = 1.6867298468976624 in iterations = 888
# Cost is = 1.6862966005363271 in iterations = 889
# Cost is = 1.6858640621401804 in iterations = 890
# Cost is = 1.6854322275505804 in iterations = 891
# Cost is = 1.6850010926412633 in iterations = 892
# Cost is = 1.6845706533180862 in iterations = 893
# Cost is = 1.6841409055187757 in iterations = 894
# Cost is = 1.6837118452126634 in iterations = 895
# Cost is = 1.6832834684004452 in iterations = 896
# Cost is = 1.6828557711139298 in iterations = 897
# Cost is = 1.6824287494157815 in iterations = 898
# Cost is = 1.682002399399287 in iterations = 899
# Cost is = 1.6815767171881 in iterations = 900
# Cost is = 1.68115169893601 in iterations = 901
# Cost is = 1.6807273408266923 in iterations = 902
# Cost is = 1.68030363907348 in iterations = 903
# Cost is = 1.6798805899191194 in iterations = 904
# Cost is = 1.6794581896355354 in iterations = 905
# Cost is = 1.6790364345236077 in iterations = 906
# Cost is = 1.6786153209129318 in iterations = 907
# Cost is = 1.6781948451615973 in iterations = 908
# Cost is = 1.6777750036559504 in iterations = 909
# Cost is = 1.6773557928103804 in iterations = 910
# Cost is = 1.6769372090670909 in iterations = 911
# Cost is = 1.6765192488958744 in iterations = 912
# Cost is = 1.676101908793902 in iterations = 913
# Cost is = 1.6756851852854981 in iterations = 914
# Cost is = 1.6752690749219261 in iterations = 915
# Cost is = 1.6748535742811728 in iterations = 916
# Cost is = 1.6744386799677389 in iterations = 917
# Cost is = 1.6740243886124246 in iterations = 918
# Cost is = 1.6736106968721205 in iterations = 919
# Cost is = 1.673197601429601 in iterations = 920
# Cost is = 1.672785098993319 in iterations = 921
# Cost is = 1.6723731862971978 in iterations = 922
# Cost is = 1.671961860100431 in iterations = 923
# Cost is = 1.671551117187281 in iterations = 924
# Cost is = 1.6711409543668825 in iterations = 925
# Cost is = 1.670731368473034 in iterations = 926
# Cost is = 1.670322356364015 in iterations = 927
# Cost is = 1.6699139149223814 in iterations = 928
# Cost is = 1.6695060410547766 in iterations = 929
# Cost is = 1.669098731691736 in iterations = 930
# Cost is = 1.668691983787502 in iterations = 931
# Cost is = 1.6682857943198324 in iterations = 932
# Cost is = 1.6678801602898092 in iterations = 933
# Cost is = 1.6674750787216623 in iterations = 934
# Cost is = 1.6670705466625773 in iterations = 935
# Cost is = 1.6666665611825127 in iterations = 936
# Cost is = 1.6662631193740263 in iterations = 937
# Cost is = 1.6658602183520865 in iterations = 938
# Cost is = 1.6654578552538974 in iterations = 939
# Cost is = 1.6650560272387234 in iterations = 940
# Cost is = 1.6646547314877098 in iterations = 941
# Cost is = 1.6642539652037138 in iterations = 942
# Cost is = 1.663853725611125 in iterations = 943
# Cost is = 1.6634540099557016 in iterations = 944
# Cost is = 1.663054815504392 in iterations = 945
# Cost is = 1.6626561395451764 in iterations = 946
# Cost is = 1.6622579793868861 in iterations = 947
# Cost is = 1.661860332359049 in iterations = 948
# Cost is = 1.6614631958117223 in iterations = 949
# Cost is = 1.661066567115323 in iterations = 950
# Cost is = 1.6606704436604747 in iterations = 951
# Cost is = 1.660274822857838 in iterations = 952
# Cost is = 1.6598797021379585 in iterations = 953
# Cost is = 1.659485078951105 in iterations = 954
# Cost is = 1.659090950767112 in iterations = 955
# Cost is = 1.6586973150752253 in iterations = 956
# Cost is = 1.6583041693839484 in iterations = 957
# Cost is = 1.657911511220886 in iterations = 958
# Cost is = 1.6575193381325954 in iterations = 959
# Cost is = 1.6571276476844334 in iterations = 960
# Cost is = 1.6567364374604068 in iterations = 961
# Cost is = 1.6563457050630273 in iterations = 962
# Cost is = 1.6559554481131586 in iterations = 963
# Cost is = 1.655565664249875 in iterations = 964
# Cost is = 1.6551763511303155 in iterations = 965
# Cost is = 1.654787506429538 in iterations = 966
# Cost is = 1.6543991278403807 in iterations = 967
# Cost is = 1.6540112130733127 in iterations = 968
# Cost is = 1.6536237598563055 in iterations = 969
# Cost is = 1.6532367659346823 in iterations = 970
# Cost is = 1.6528502290709897 in iterations = 971
# Cost is = 1.6524641470448522 in iterations = 972
# Cost is = 1.6520785176528419 in iterations = 973
# Cost is = 1.6516933387083401 in iterations = 974
# Cost is = 1.6513086080414086 in iterations = 975
# Cost is = 1.6509243234986481 in iterations = 976
# Cost is = 1.6505404829430799 in iterations = 977
# Cost is = 1.6501570842539994 in iterations = 978
# Cost is = 1.6497741253268632 in iterations = 979
# Cost is = 1.6493916040731453 in iterations = 980
# Cost is = 1.649009518420221 in iterations = 981
# Cost is = 1.648627866311234 in iterations = 982
# Cost is = 1.6482466457049723 in iterations = 983
# Cost is = 1.6478658545757472 in iterations = 984
# Cost is = 1.6474854909132646 in iterations = 985
# Cost is = 1.647105552722504 in iterations = 986
# Cost is = 1.6467260380236033 in iterations = 987
# Cost is = 1.646346944851729 in iterations = 988
# Cost is = 1.64596827125696 in iterations = 989
# Cost is = 1.6455900153041736 in iterations = 990
# ...
# Cost is = 1.0023269114779927 in iterations = 9907
# Cost is = 1.0023241396576164 in iterations = 9908
# Cost is = 1.0023213693406263 in iterations = 9909
# Cost is = 1.0023186005262081 in iterations = 9910
# Cost is = 1.002315833213547 in iterations = 9911
# Cost is = 1.0023130674018275 in iterations = 9912
# Cost is = 1.0023103030902352 in iterations = 9913
# Cost is = 1.0023075402779578 in iterations = 9914
# Cost is = 1.002304778964182 in iterations = 9915
# Cost is = 1.0023020191480947 in iterations = 9916
# Cost is = 1.0022992608288823 in iterations = 9917
# Cost is = 1.0022965040057348 in iterations = 9918
# Cost is = 1.0022937486778398 in iterations = 9919
# Cost is = 1.0022909948443859 in iterations = 9920
# Cost is = 1.0022882425045636 in iterations = 9921
# Cost is = 1.0022854916575628 in iterations = 9922
# Cost is = 1.0022827423025726 in iterations = 9923
# Cost is = 1.0022799944387852 in iterations = 9924
# Cost is = 1.0022772480653905 in iterations = 9925
# Cost is = 1.002274503181581 in iterations = 9926
# Cost is = 1.0022717597865483 in iterations = 9927
# Cost is = 1.0022690178794857 in iterations = 9928
# Cost is = 1.0022662774595843 in iterations = 9929
# Cost is = 1.0022635385260403 in iterations = 9930
# Cost is = 1.0022608010780452 in iterations = 9931
# Cost is = 1.0022580651147937 in iterations = 9932
# Cost is = 1.0022553306354811 in iterations = 9933
# Cost is = 1.0022525976393024 in iterations = 9934
# Cost is = 1.0022498661254533 in iterations = 9935
# Cost is = 1.0022471360931295 in iterations = 9936
# Cost is = 1.0022444075415275 in iterations = 9937
# Cost is = 1.0022416804698435 in iterations = 9938
# Cost is = 1.0022389548772763 in iterations = 9939
# Cost is = 1.002236230763023 in iterations = 9940
# Cost is = 1.0022335081262812 in iterations = 9941
# Cost is = 1.0022307869662501 in iterations = 9942
# Cost is = 1.0022280672821282 in iterations = 9943
# Cost is = 1.0022253490731161 in iterations = 9944
# Cost is = 1.0022226323384134 in iterations = 9945
# Cost is = 1.0022199170772184 in iterations = 9946
# Cost is = 1.0022172032887358 in iterations = 9947
# Cost is = 1.0022144909721633 in iterations = 9948
# Cost is = 1.0022117801267039 in iterations = 9949
# Cost is = 1.0022090707515607 in iterations = 9950
# Cost is = 1.0022063628459343 in iterations = 9951
# Cost is = 1.0022036564090282 in iterations = 9952
# Cost is = 1.0022009514400472 in iterations = 9953
# Cost is = 1.0021982479381937 in iterations = 9954
# Cost is = 1.0021955459026723 in iterations = 9955
# Cost is = 1.0021928453326878 in iterations = 9956
# Cost is = 1.0021901462274456 in iterations = 9957
# Cost is = 1.0021874485861497 in iterations = 9958
# Cost is = 1.0021847524080087 in iterations = 9959
# Cost is = 1.0021820576922265 in iterations = 9960
# Cost is = 1.0021793644380117 in iterations = 9961
# Cost is = 1.0021766726445713 in iterations = 9962
# Cost is = 1.0021739823111118 in iterations = 9963
# Cost is = 1.0021712934368423 in iterations = 9964
# Cost is = 1.0021686060209714 in iterations = 9965
# Cost is = 1.0021659200627082 in iterations = 9966
# Cost is = 1.002163235561261 in iterations = 9967
# Cost is = 1.0021605525158412 in iterations = 9968
# Cost is = 1.0021578709256573 in iterations = 9969
# Cost is = 1.0021551907899218 in iterations = 9970
# Cost is = 1.0021525121078454 in iterations = 9971
# Cost is = 1.0021498348786393 in iterations = 9972
# Cost is = 1.0021471591015154 in iterations = 9973
# Cost is = 1.002144484775686 in iterations = 9974
# Cost is = 1.002141811900364 in iterations = 9975
# Cost is = 1.0021391404747633 in iterations = 9976
# Cost is = 1.0021364704980973 in iterations = 9977
# Cost is = 1.0021338019695794 in iterations = 9978
# Cost is = 1.0021311348884248 in iterations = 9979
# Cost is = 1.0021284692538488 in iterations = 9980
# Cost is = 1.0021258050650663 in iterations = 9981
# Cost is = 1.0021231423212933 in iterations = 9982
# Cost is = 1.002120481021746 in iterations = 9983
# Cost is = 1.0021178211656403 in iterations = 9984
# Cost is = 1.0021151627521947 in iterations = 9985
# Cost is = 1.0021125057806257 in iterations = 9986
# Cost is = 1.0021098502501524 in iterations = 9987
# Cost is = 1.0021071961599914 in iterations = 9988
# Cost is = 1.0021045435093634 in iterations = 9989
# Cost is = 1.0021018922974863 in iterations = 9990
# Cost is = 1.0020992425235806 in iterations = 9991
# Cost is = 1.0020965941868656 in iterations = 9992
# Cost is = 1.0020939472865622 in iterations = 9993
# Cost is = 1.0020913018218913 in iterations = 9994
# Cost is = 1.0020886577920738 in iterations = 9995
# Cost is = 1.0020860151963331 in iterations = 9996
# Cost is = 1.0020833740338888 in iterations = 9997
# Cost is = 1.0020807343039657 in iterations = 9998
# Cost is = 1.0020780960057856 in iterations = 9999
# Cost is = 1.002075459138572 in iterations = 10000
# Cost is = 1.0020728237015495 in iterations = 10001
# Cost is = 1.002070189693942 in iterations = 10002
# Cost is = 1.0020675571149738 in iterations = 10003
# Cost is = 1.002064925963871 in iterations = 10004
# Cost is = 1.0020622962398584 in iterations = 10005
# Cost is = 1.0020596679421616 in iterations = 10006
# Cost is = 1.0020570410700078 in iterations = 10007
# Cost is = 1.0020544156226243 in iterations = 10008
# Cost is = 1.0020517915992364 in iterations = 10009
# Cost is = 1.0020491689990736 in iterations = 10010
# Cost is = 1.0020465478213636 in iterations = 10011
# Cost is = 1.0020439280653335 in iterations = 10012
# Cost is = 1.0020413097302139 in iterations = 10013
# Cost is = 1.0020386928152338 in iterations = 10014
# Cost is = 1.0020360773196226 in iterations = 10015
# Cost is = 1.0020334632426098 in iterations = 10016
# Cost is = 1.0020308505834274 in iterations = 10017
# Cost is = 1.0020282393413054 in iterations = 10018
# Cost is = 1.002025629515475 in iterations = 10019
# Cost is = 1.0020230211051695 in iterations = 10020
# Cost is = 1.00202041410962 in iterations = 10021
# Cost is = 1.0020178085280584 in iterations = 10022
# Cost is = 1.00201520435972 in iterations = 10023
# Cost is = 1.0020126016038362 in iterations = 10024
# Cost is = 1.0020100002596415 in iterations = 10025
# Cost is = 1.0020074003263713 in iterations = 10026
# Cost is = 1.0020048018032583 in iterations = 10027
# Cost is = 1.0020022046895392 in iterations = 10028
# Cost is = 1.0019996089844496 in iterations = 10029
# Cost is = 1.0019970146872252 in iterations = 10030
# Cost is = 1.001994421797102 in iterations = 10031
# Cost is = 1.0019918303133168 in iterations = 10032
# Cost is = 1.001989240235107 in iterations = 10033
# Cost is = 1.0019866515617109 in iterations = 10034
# Cost is = 1.0019840642923659 in iterations = 10035
# Cost is = 1.0019814784263104 in iterations = 10036
# Cost is = 1.0019788939627834 in iterations = 10037
# Cost is = 1.001976310901025 in iterations = 10038
# Cost is = 1.0019737292402733 in iterations = 10039
# Cost is = 1.001971148979769 in iterations = 10040
# Cost is = 1.001968570118754 in iterations = 10041
# Cost is = 1.001965992656467 in iterations = 10042
# Cost is = 1.0019634165921505 in iterations = 10043
# Cost is = 1.001960841925047 in iterations = 10044
# Cost is = 1.001958268654398 in iterations = 10045
# Cost is = 1.0019556967794458 in iterations = 10046
# Cost is = 1.0019531262994334 in iterations = 10047
# Cost is = 1.001950557213605 in iterations = 10048
# Cost is = 1.0019479895212036 in iterations = 10049
# Cost is = 1.0019454232214733 in iterations = 10050
# Cost is = 1.0019428583136587 in iterations = 10051
# Cost is = 1.0019402947970062 in iterations = 10052
# Cost is = 1.0019377326707601 in iterations = 10053
# Cost is = 1.0019351719341667 in iterations = 10054
# Cost is = 1.0019326125864711 in iterations = 10055
# Cost is = 1.0019300546269216 in iterations = 10056
# Cost is = 1.001927498054765 in iterations = 10057
# Cost is = 1.001924942869249 in iterations = 10058
# Cost is = 1.0019223890696194 in iterations = 10059
# Cost is = 1.0019198366551272 in iterations = 10060
# Cost is = 1.0019172856250194 in iterations = 10061
# Cost is = 1.0019147359785459 in iterations = 10062
# Cost is = 1.0019121877149564 in iterations = 10063
# Cost is = 1.0019096408335004 in iterations = 10064
# Cost is = 1.0019070953334281 in iterations = 10065
# Cost is = 1.0019045512139908 in iterations = 10066
# Cost is = 1.0019020084744394 in iterations = 10067
# Cost is = 1.001899467114025 in iterations = 10068
# Cost is = 1.0018969271320006 in iterations = 10069
# Cost is = 1.0018943885276181 in iterations = 10070
# Cost is = 1.0018918513001296 in iterations = 10071
# Cost is = 1.00188931544879 in iterations = 10072
# Cost is = 1.0018867809728504 in iterations = 10073
# Cost is = 1.0018842478715675 in iterations = 10074
# Cost is = 1.0018817161441944 in iterations = 10075
# Cost is = 1.0018791857899851 in iterations = 10076
# Cost is = 1.001876656808197 in iterations = 10077
# Cost is = 1.0018741291980835 in iterations = 10078
# Cost is = 1.0018716029589017 in iterations = 10079
# Cost is = 1.0018690780899073 in iterations = 10080
# Cost is = 1.001866554590359 in iterations = 10081
# Cost is = 1.0018640324595125 in iterations = 10082
# Cost is = 1.0018615116966245 in iterations = 10083
# Cost is = 1.001858992300955 in iterations = 10084
# Cost is = 1.0018564742717617 in iterations = 10085
# Cost is = 1.0018539576083034 in iterations = 10086
# Cost is = 1.0018514423098397 in iterations = 10087
# Cost is = 1.0018489283756293 in iterations = 10088
# Cost is = 1.001846415804933 in iterations = 10089
# Cost is = 1.0018439045970113 in iterations = 10090
# Cost is = 1.0018413947511244 in iterations = 10091
# Cost is = 1.0018388862665348 in iterations = 10092
# Cost is = 1.0018363791425033 in iterations = 10093
# Cost is = 1.0018338733782914 in iterations = 10094
# Cost is = 1.0018313689731633 in iterations = 10095
# Cost is = 1.0018288659263805 in iterations = 10096
# Cost is = 1.0018263642372056 in iterations = 10097
# Cost is = 1.0018238639049037 in iterations = 10098
# Cost is = 1.0018213649287389 in iterations = 10099
# Cost is = 1.0018188673079742 in iterations = 10100
# Cost is = 1.0018163710418762 in iterations = 10101
# Cost is = 1.001813876129709 in iterations = 10102
# Cost is = 1.0018113825707378 in iterations = 10103
# Cost is = 1.0018088903642297 in iterations = 10104
# Cost is = 1.0018063995094513 in iterations = 10105
# Cost is = 1.00180391000567 in iterations = 10106
# Cost is = 1.00180142185215 in iterations = 10107
# Cost is = 1.0017989350481624 in iterations = 10108
# Cost is = 1.001796449592973 in iterations = 10109
# Cost is = 1.0017939654858514 in iterations = 10110
# Cost is = 1.0017914827260654 in iterations = 10111
# Cost is = 1.001789001312886 in iterations = 10112
# Cost is = 1.0017865212455812 in iterations = 10113
# Cost is = 1.0017840425234212 in iterations = 10114
# Cost is = 1.0017815651456778 in iterations = 10115
# Cost is = 1.00177908911162 in iterations = 10116
# Cost is = 1.0017766144205196 in iterations = 10117
# Cost is = 1.0017741410716494 in iterations = 10118
# Cost is = 1.0017716690642793 in iterations = 10119
# Cost is = 1.001769198397684 in iterations = 10120
# Cost is = 1.0017667290711338 in iterations = 10121
# Cost is = 1.0017642610839037 in iterations = 10122
# Cost is = 1.0017617944352672 in iterations = 10123
# Cost is = 1.0017593291244968 in iterations = 10124
# Cost is = 1.0017568651508684 in iterations = 10125
# Cost is = 1.0017544025136564 in iterations = 10126
# Cost is = 1.0017519412121358 in iterations = 10127
# Cost is = 1.001749481245582 in iterations = 10128
# Cost is = 1.0017470226132708 in iterations = 10129
# Cost is = 1.0017445653144792 in iterations = 10130
# Cost is = 1.001742109348483 in iterations = 10131
# Cost is = 1.001739654714561 in iterations = 10132
# Cost is = 1.001737201411988 in iterations = 10133
# Cost is = 1.001734749440044 in iterations = 10134
# Cost is = 1.0017322987980068 in iterations = 10135
# Cost is = 1.0017298494851556 in iterations = 10136
# Cost is = 1.0017274015007678 in iterations = 10137
# Cost is = 1.0017249548441245 in iterations = 10138
# Cost is = 1.0017225095145055 in iterations = 10139
# Cost is = 1.00172006551119 in iterations = 10140
# Cost is = 1.0017176228334594 in iterations = 10141
# Cost is = 1.0017151814805945 in iterations = 10142
# Cost is = 1.001712741451876 in iterations = 10143
# Cost is = 1.0017103027465872 in iterations = 10144
# Cost is = 1.0017078653640088 in iterations = 10145
# Cost is = 1.001705429303425 in iterations = 10146
# Cost is = 1.0017029945641183 in iterations = 10147
# Cost is = 1.00170056114537 in iterations = 10148
# Cost is = 1.001698129046467 in iterations = 10149
# Cost is = 1.0016956982666907 in iterations = 10150
# Cost is = 1.0016932688053273 in iterations = 10151
# Cost is = 1.0016908406616618 in iterations = 10152
# Cost is = 1.0016884138349782 in iterations = 10153
# Cost is = 1.0016859883245643 in iterations = 10154
# Cost is = 1.0016835641297035 in iterations = 10155
# Cost is = 1.0016811412496842 in iterations = 10156
# Cost is = 1.001678719683792 in iterations = 10157
# Cost is = 1.001676299431316 in iterations = 10158
# Cost is = 1.0016738804915415 in iterations = 10159
# Cost is = 1.0016714628637586 in iterations = 10160
# Cost is = 1.0016690465472542 in iterations = 10161
# Cost is = 1.0016666315413179 in iterations = 10162
# Cost is = 1.0016642178452386 in iterations = 10163
# Cost is = 1.0016618054583057 in iterations = 10164
# Cost is = 1.001659394379809 in iterations = 10165
# Cost is = 1.0016569846090395 in iterations = 10166
# Cost is = 1.0016545761452873 in iterations = 10167
# Cost is = 1.001652168987844 in iterations = 10168
# Cost is = 1.0016497631360002 in iterations = 10169
# Cost is = 1.0016473585890497 in iterations = 10170
# Cost is = 1.0016449553462827 in iterations = 10171
# Cost is = 1.001642553406992 in iterations = 10172
# Cost is = 1.0016401527704726 in iterations = 10173
# Cost is = 1.0016377534360152 in iterations = 10174
# Cost is = 1.0016353554029158 in iterations = 10175
# Cost is = 1.0016329586704669 in iterations = 10176
# Cost is = 1.001630563237964 in iterations = 10177
# Cost is = 1.001628169104702 in iterations = 10178
# Cost is = 1.001625776269975 in iterations = 10179
# Cost is = 1.001623384733081 in iterations = 10180
# Cost is = 1.0016209944933148 in iterations = 10181
# Cost is = 1.0016186055499723 in iterations = 10182
# Cost is = 1.0016162179023518 in iterations = 10183
# Cost is = 1.001613831549749 in iterations = 10184
# Cost is = 1.0016114464914618 in iterations = 10185
# Cost is = 1.001609062726789 in iterations = 10186
# Cost is = 1.001606680255028 in iterations = 10187
# Cost is = 1.0016042990754788 in iterations = 10188
# Cost is = 1.0016019191874392 in iterations = 10189
# Cost is = 1.0015995405902092 in iterations = 10190
# Cost is = 1.0015971632830891 in iterations = 10191
# Cost is = 1.0015947872653783 in iterations = 10192
# Cost is = 1.001592412536379 in iterations = 10193
# Cost is = 1.0015900390953905 in iterations = 10194
# Cost is = 1.0015876669417152 in iterations = 10195
# Cost is = 1.0015852960746539 in iterations = 10196
# Cost is = 1.0015829264935103 in iterations = 10197
# Cost is = 1.0015805581975856 in iterations = 10198
# Cost is = 1.0015781911861836 in iterations = 10199
# Cost is = 1.0015758254586076 in iterations = 10200
# Cost is = 1.0015734610141598 in iterations = 10201
# Cost is = 1.0015710978521457 in iterations = 10202
# Cost is = 1.0015687359718692 in iterations = 10203
# Cost is = 1.0015663753726363 in iterations = 10204
# Cost is = 1.0015640160537502 in iterations = 10205
# Cost is = 1.0015616580145177 in iterations = 10206
# Cost is = 1.0015593012542443 in iterations = 10207
# Cost is = 1.0015569457722364 in iterations = 10208
# Cost is = 1.0015545915678015 in iterations = 10209
# Cost is = 1.001552238640245 in iterations = 10210
# Cost is = 1.0015498869888755 in iterations = 10211
# Cost is = 1.0015475366130013 in iterations = 10212
# Cost is = 1.0015451875119292 in iterations = 10213
# Cost is = 1.0015428396849688 in iterations = 10214
# Cost is = 1.0015404931314285 in iterations = 10215
# Cost is = 1.0015381478506178 in iterations = 10216
# Cost is = 1.0015358038418467 in iterations = 10217
# Cost is = 1.0015334611044246 in iterations = 10218
# Cost is = 1.0015311196376628 in iterations = 10219
# Cost is = 1.0015287794408712 in iterations = 10220
# Cost is = 1.0015264405133617 in iterations = 10221
# Cost is = 1.0015241028544455 in iterations = 10222

# %%
theta
# Out:
# array([[2.99799309],
#        [0.99888929],
#        [2.0025575 ]])

# %%
test_err_original = cost_total(X_test, np.array([[3],[1],[2]]), Y_test, num_test)
print("The Test error on Original Hypothesis with theta = 0 is = {}".format(test_err_original))

test_err_learned = cost_total(X_test, theta, Y_test, num_test)
print("The Test error on Learned Hypothesis = {}".format(test_err_learned))

print("The difference in the test error of original and learned hypothesis is = {}".format(test_err_learned-test_err_original))
# Out:
# The Test error on Original Hypothesis with theta = 0 is = 0.9829469215
# The Test error on Learned Hypothesis = 0.9830876293940337
# The difference in the test error of original and learned hypothesis is = 0.0001407078940337536

# %%
theta_all_new = theta_all.T[0::15,:]
print(theta_all_new.shape)
print(theta_all_new[4000][2])
print(theta_all_new)
# Out:
# (4001, 3)
# 2.0025575046864357
# [[0.00357338 0.0158335  0.00389086]
#  [0.05494193 0.22183665 0.06598359]
#  [0.09989585 0.39407922 0.14137526]
#  ...
#  [2.9975507  0.99728782 2.00315705]
#  [2.9976966  0.99867296 2.00299153]
#  [2.99799309 0.99888929 2.0025575 ]]

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Theta Movement", fontsize=15)
ax.set_xlabel('theta0', fontsize=15)
ax.set_ylabel('theta1', fontsize=15)
ax.set_zlabel('theta2', fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=15)

graph = ax.scatter([], [], [], marker='o', c='r', s=15)
ax.set_xlim(np.amin(theta_all_new[:,0]), np.amax(theta_all_new[:,0]))
ax.set_ylim(np.amin(theta_all_new[:,1]), np.amax(theta_all_new[:,1]))
ax.set_zlim(np.amin(theta_all_new[:,2]), np.amax(theta_all_new[:,2]))
graph.set_alpha(1)
xdata, ydata, zdata = [], [], []

def animate(i):
    xdata.append(theta_all_new[i,0])
    ydata.append(theta_all_new[i,1])
    zdata.append(theta_all_new[i,2])
    graph._offsets3d = (xdata, ydata, zdata)
    return graph

anim = FuncAnimation(fig, animate, frames=np.arange(0, theta_all_new.shape[0], 20), interval=200, repeat_delay=3000, blit=False)
anim.save('plot_r_100.gif', writer='imagemagick')

# plt.ion()

# for i in range(theta_all_new.shape[0]):
#     ax.scatter(theta_all_new[i,0], theta_all_new[i,1], theta_all_new[i,2], c='r', marker='o', s=50)
#     plt.pause(0.02)
#     plt.draw()

# %% [markdown]
# # def calc_y(x1, x2, theta, epsilon, points)
# #     h_x = theta[0] +  points.x1*theta[1] + points.x2*theta[2]
# #     points.y = h_x + epsilon
# #     return

# %% [markdown]
# # X1, X2 = np.meshgrid(x1, x2)
# # Point = collections.namedtuple('Point', ['x1', 'x2', 'y'])
# # points = [Point(x1, x2, y)]
#
# # fig = plt.figure(figsize=(15,10))
# # ax = fig.add_subplot(111, projection='3d')
# # ax.set_title("Y function", fontsize=15)
#
# # cost_error = np.array([calc_y(x1, x2, theta, points)
# #                for x0, x1 in zip(np.ravel(X1), np.ravel(X2))])
# # cost_plot = cost_error.reshape(theta0.shape)
#
#
# # Y_data = calc_y(X1, X2, )
