# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)
np.random.shuffle(X_train.to_numpy())
train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

X_train = X_train/255
X_test = X_test/255
m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# The total number of training samples = 13000
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
# Out:
# --------Perform 1-hot encoding of class labels------------

# %%
#Add the intercept term to the data samples both in training and test dataset
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))

# %%
lr = 0.1
arch_test = [1,5,10,50,100] # Only for single layer
arch = [arch_test[3]] #means one hidden layer with #perceptrons 
batch_size = 100 # Mini-Batch Size
r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
#Mini-Batch formation
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# The number of mini-batches formed is = 130

# %%
#Theta Initialization 
#np.random.seed(1)
def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]

        theta.append((2*np.random.random((dim0, dim1))-1))
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
def activation(x):
    return 1/(1+np.exp(-x))

# %%
def forward_prop(data, theta):
    fm = []
    fm.append(data)
    for l in range(len(theta)):
        fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
def cost_total(X, theta, Y, m):
    fm = forward_prop(X, theta)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    #print("The Test Accuracy of the model = {}%".format(test_acc*100))
    return (test_acc*100)

# %%
epochs = []
train_accuracy = []
test_accuracy = []
train_time = []
costs=[]

# %%
lr = 0.1

# %%
arch_test=[100]
for i in range(len(arch_test)):
    theta = theta_init([arch_test[i], arch_test[i]])
    print(theta[0].shape, theta[1].shape, theta[2].shape)
    fm = forward_prop(X_train, theta)
    
    epoch = 0
    start = time.time()
    cost_init = cost_total(X_train, theta, train_class_enc, m)

    while(True):
        count = 0

        print("Initial Cost for this epoch {} = {}".format(epoch, cost_init))
        
        for b in mini_batch:
            X_b = b[0]
            Y_b = b[1]
            fm = forward_prop(X_b, theta)
            delta = [None]*len(fm)

            if (count % 60 == 0):
                print("Error = "+str(cost_total(X_b, theta, Y_b, batch_size)))
            #Backward Propagation

            for l in range(len(fm)-1, 0, -1):
                if (l == len(fm)-1):
                    delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
                else:
                    delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))

            #delta_l1 = np.dot(delta_l2, theta2.T)*l1*(1-l1)

            for t in range(len(theta)):
                theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

            count+=1
            
        if epoch %10 == 0:
            costs.append(cost_init)
        epoch+=1 #Number of epochs
        
        cost_final = cost_total(X_train, theta, train_class_enc, m)
        
        print("Cost after {} epochs is = {}".format(epoch, cost_final))
        if (abs(cost_final-cost_init) < 1e-06):
            print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
            break
        cost_init = cost_final
    epochs.append(epoch)
    train_time.append(time.time()-start)
    train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
    test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
    print("\n------------------------------------------------------------------------------")
    print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
    print("------------------------------------------------------------------------------")
    print("The number of epochs = {}".format(epochs[-1]))
    print("The training time = {}sec".format(train_time[-1]))
    print("The training accuracy is = {}%".format(train_accuracy[-1]))
    print("The test accuracy is = {}%".format(test_accuracy[-1]))
    print("------------------------------------------------------------------------------\n")
# Out:
# (785, 100) (100, 100) (100, 26)
# Initial Cost for this epoch 0 = 4.907509036422232
# Error = 4.929768060968566
# Error = 1.909973083711403
# Error = 1.8719101530381232
# Cost after 1 epochs is = 1.819762811576304
# Initial Cost for this epoch 1 = 1.819762811576304
# Error = 1.8158952744639145
# Error = 0.9671337138337412
# Error = 0.49826478979325717
# Cost after 2 epochs is = 0.4965906484809551
# Initial Cost for this epoch 2 = 0.4965906484809551
# Error = 0.49661686537226957
# Error = 0.4968075526395006
# Error = 0.48963428591897673
# Cost after 3 epochs is = 0.4907493098157923
# Initial Cost for this epoch 3 = 0.4907493098157923
# Error = 0.49208493252361724
# Error = 0.4941793960647315
# Error = 0.48766100401298035
# Cost after 4 epochs is = 0.48904085292325367
# Initial Cost for this epoch 4 = 0.48904085292325367
# Error = 0.4908077901229025
# Error = 0.4928541018456798
# Error = 0.4859190504145806
# Cost after 5 epochs is = 0.48755214997250396
# Initial Cost for this epoch 5 = 0.48755214997250396
# Error = 0.4897313868851457
# Error = 0.49163539615687163
# Error = 0.484026368749289
# Cost after 6 epochs is = 0.4859536964082994
# Initial Cost for this epoch 6 = 0.4859536964082994
# Error = 0.48855026207560515
# Error = 0.49023876100081426
# Error = 0.48182814161072274
# Cost after 7 epochs is = 0.4841334818130023
# Initial Cost for this epoch 7 = 0.4841334818130023
# Error = 0.48710867164063615
# Error = 0.4885171263280785
# Error = 0.47921726968808515
# Cost after 8 epochs is = 0.4820210421176477
# Initial Cost for this epoch 8 = 0.4820210421176477
# Error = 0.4852622542369469
# Error = 0.4863695007896226
# Error = 0.4761084215023958
# Cost after 9 epochs is = 0.4795525258081344
# Initial Cost for this epoch 9 = 0.4795525258081344
# Error = 0.48286898235944753
# Error = 0.48372243134024767
# Error = 0.47243664374801947
# Cost after 10 epochs is = 0.47666043862455
# Initial Cost for this epoch 10 = 0.47666043862455
# Error = 0.4798133771023677
# Error = 0.48053246187210674
# Error = 0.4681574258006019
# Cost after 11 epochs is = 0.4732772297914093
# Initial Cost for this epoch 11 = 0.4732772297914093
# Error = 0.47605275813536724
# Error = 0.47680140179901404
# Error = 0.46325764139322845
# Cost after 12 epochs is = 0.46936777914811684
# Initial Cost for this epoch 12 = 0.46936777914811684
# Error = 0.4716775368874893
# Error = 0.4725715985147393
# Error = 0.45782999343798725
# Cost after 13 epochs is = 0.46500109379638616
# Initial Cost for this epoch 13 = 0.46500109379638616
# Error = 0.4669465294537825
# Error = 0.46789840235761776
# Error = 0.45211778690205073
# Cost after 14 epochs is = 0.46037609432930976
# Initial Cost for this epoch 14 = 0.46037609432930976
# Error = 0.46220092022137216
# Error = 0.4629115683124428
# Error = 0.4463763024475146
# Cost after 15 epochs is = 0.4557183331096169
# Initial Cost for this epoch 15 = 0.4557183331096169
# Error = 0.4576936123881995
# Error = 0.45784460362232055
# Error = 0.4407624612188963
# Cost after 16 epochs is = 0.45117509836507297
# Initial Cost for this epoch 16 = 0.45117509836507297
# Error = 0.45352923391338706
# Error = 0.4529232795649016
# Error = 0.4353396919333904
# Cost after 17 epochs is = 0.44680448050211197
# Initial Cost for this epoch 17 = 0.44680448050211197
# Error = 0.449709059740967
# Error = 0.44829053196713936
# Error = 0.4301132255757004
# Cost after 18 epochs is = 0.4426103188839955
# Initial Cost for this epoch 18 = 0.4426103188839955
# Error = 0.4461852582823385
# Error = 0.4439979236161043
# Error = 0.4250586817081852
# Cost after 19 epochs is = 0.4385719828059058
# Initial Cost for this epoch 19 = 0.4385719828059058
# Error = 0.4428924741340273
# Error = 0.4400267841920343
# Error = 0.42014131224481555
# Cost after 20 epochs is = 0.4346602233238124
# Initial Cost for this epoch 20 = 0.4346602233238124
# Error = 0.43976213077821713
# Error = 0.43632162732393637
# Error = 0.41533045150132053
# Cost after 21 epochs is = 0.43084532038495443
# Initial Cost for this epoch 21 = 0.43084532038495443
# Error = 0.43672983622957967
# Error = 0.43282212635398043
# Error = 0.41060976103517843
# Cost after 22 epochs is = 0.42710232407615073
# Initial Cost for this epoch 22 = 0.42710232407615073
# Error = 0.4337415617224764
# Error = 0.42948293518472247
# Error = 0.4059793588727935
# Cost after 23 epochs is = 0.4234145156608216
# Initial Cost for this epoch 23 = 0.4234145156608216
# Error = 0.4307589943412482
# Error = 0.4262776739311089
# Error = 0.40144819208664523
# Cost after 24 epochs is = 0.41977465903595135
# Initial Cost for this epoch 24 = 0.41977465903595135
# Error = 0.4277608775835434
# Error = 0.4231907882660756
# Error = 0.3970240992718682
# Cost after 25 epochs is = 0.4161840385404137
# Initial Cost for this epoch 25 = 0.4161840385404137
# Error = 0.424737597923143
# Error = 0.4202070911874373
# Error = 0.3927111636580634
# Cost after 26 epochs is = 0.4126491926428164
# Initial Cost for this epoch 26 = 0.4126491926428164
# Error = 0.42168077541848237
# Error = 0.41730767468077856
# Error = 0.38851309329507816
# Cost after 27 epochs is = 0.40917608331330707
# Initial Cost for this epoch 27 = 0.40917608331330707
# Error = 0.41857416577670953
# Error = 0.4144726484266527
# Error = 0.38443468578831386
# Cost after 28 epochs is = 0.40576416927507336
# Initial Cost for this epoch 28 = 0.40576416927507336
# Error = 0.4153915474459246
# Error = 0.4116854170036913
# Error = 0.3804798502842156
# Cost after 29 epochs is = 0.4024043538402726
# Initial Cost for this epoch 29 = 0.4024043538402726
# Error = 0.4121015277420183
# Error = 0.4089339793951619
# Error = 0.376649558792248
# Cost after 30 epochs is = 0.39908131253338736
# Initial Cost for this epoch 30 = 0.39908131253338736
# Error = 0.4086758016131944
# Error = 0.4062079655382967
# Error = 0.3729406707680944
# Cost after 31 epochs is = 0.3957777567447759
# Initial Cost for this epoch 31 = 0.3957777567447759
# Error = 0.4050974662001392
# Error = 0.40349295081435116
# Error = 0.36934537571816356
# Cost after 32 epochs is = 0.39247862850921633
# Initial Cost for this epoch 32 = 0.39247862850921633
# Error = 0.4013657609607489
# Error = 0.4007658953139384
# Error = 0.3658520120383571
# Cost after 33 epochs is = 0.38917427453767683
# Initial Cost for this epoch 33 = 0.38917427453767683
# Error = 0.397495059421646
# Error = 0.39799573177200487
# Error = 0.36244760415978683
# Cost after 34 epochs is = 0.38586217156826963
# Initial Cost for this epoch 34 = 0.38586217156826963
# Error = 0.3935104360842624
# Error = 0.3951501382403187
# Error = 0.35912128333657206
# Cost after 35 epochs is = 0.38254732542050435
# Initial Cost for this epoch 35 = 0.38254732542050435
# Error = 0.38944421885853125
# Error = 0.3922058883292193
# Error = 0.35586725700433586
# Cost after 36 epochs is = 0.37924162801801514
# Initial Cost for this epoch 36 = 0.37924162801801514
# Error = 0.3853348785713195
# Error = 0.389158021498055
# Error = 0.35268594584456536
# Cost after 37 epochs is = 0.3759619894087522
# Initial Cost for this epoch 37 = 0.3759619894087522
# Error = 0.3812261939448166
# Error = 0.3860228508984565
# Error = 0.3495826281579527
# Cost after 38 epochs is = 0.37272703709949806
# Initial Cost for this epoch 38 = 0.37272703709949806
# Error = 0.3771643731469385
# Error = 0.38283277784005904
# Error = 0.34656441241442365
# Cost after 39 epochs is = 0.3695531370189153
# Initial Cost for this epoch 39 = 0.3695531370189153
# Error = 0.3731930247970795
# Error = 0.37962600074376157
# Error = 0.3436371305801091
# Cost after 40 epochs is = 0.36645123855728595
# Initial Cost for this epoch 40 = 0.36645123855728595
# Error = 0.36934804670511884
# Error = 0.37643671975487186
# Error = 0.34080323276822183
# Cost after 41 epochs is = 0.36342556354474764
# Initial Cost for this epoch 41 = 0.36342556354474764
# Error = 0.3656545199559021
# Error = 0.37328945516131073
# Error = 0.33806095123059193
# Cost after 42 epochs is = 0.3604740685923756
# Initial Cost for this epoch 42 = 0.3604740685923756
# Error = 0.36212611887518364
# Error = 0.3701977501157571
# Error = 0.3354045129129487
# Cost after 43 epochs is = 0.357589947624844
# Initial Cost for this epoch 43 = 0.357589947624844
# Error = 0.3587662811900696
# Error = 0.36716571717495505
# Error = 0.3328249779210137
# Cost after 44 epochs is = 0.35476343669401894
# Initial Cost for this epoch 44 = 0.35476343669401894
# Error = 0.3555701519322468
# Error = 0.3641907831562742
# Error = 0.33031130793300195
# Cost after 45 epochs is = 0.351983487327392
# Initial Cost for this epoch 45 = 0.351983487327392
# Error = 0.3525266351934509
# Error = 0.36126658806800094
# Error = 0.32785143139443323
# Cost after 46 epochs is = 0.3492391576660174
# Initial Cost for this epoch 46 = 0.3492391576660174
# Error = 0.34962022323508507
# Error = 0.358385577127417
# Error = 0.3254332280141338
# Cost after 47 epochs is = 0.3465207206060776
# Initial Cost for this epoch 47 = 0.3465207206060776
# Error = 0.34683247911258563
# Error = 0.3555411551678823
# Error = 0.3230454386582314
# Cost after 48 epochs is = 0.34382052650165995
# Initial Cost for this epoch 48 = 0.34382052650165995
# Error = 0.3441431864181191
# Error = 0.352729353944448
# Error = 0.32067852832070204
# Cost after 49 epochs is = 0.3411336364682423
# Initial Cost for this epoch 49 = 0.3411336364682423
# Error = 0.3415312949656868
# Error = 0.34994986307458853
# Error = 0.3183254961176576
# Cost after 50 epochs is = 0.3384582034161454
# Initial Cost for this epoch 50 = 0.3384582034161454
# Error = 0.33897586329761653
# Error = 0.34720613796169
# Error = 0.3159825263399798
# Cost after 51 epochs is = 0.3357955442312997
# Initial Cost for this epoch 51 = 0.3357955442312997
# Error = 0.3364571744953018
# Error = 0.34450437477557133
# Error = 0.3136492542013556
# Cost after 52 epochs is = 0.33314982745952865
# Initial Cost for this epoch 52 = 0.33314982745952865
# Error = 0.333958039895423
# Error = 0.3418515862808229
# Error = 0.3113284184874938
# Cost after 53 epochs is = 0.3305273284855775
# Initial Cost for this epoch 53 = 0.3305273284855775
# Error = 0.33146504780881325
# Error = 0.3392535447150323
# Error = 0.3090248803572549
# Cost after 54 epochs is = 0.32793532439227596
# Initial Cost for this epoch 54 = 0.32793532439227596
# Error = 0.32896935865355204
# Error = 0.33671343428678896
# Error = 0.3067442754813056
# Cost after 55 epochs is = 0.32538087333966403
# Initial Cost for this epoch 55 = 0.32538087333966403
# Error = 0.3264667932242395
# Error = 0.3342315580296679
# Error = 0.3044917050154364
# Cost after 56 epochs is = 0.3228698041429996
# Initial Cost for this epoch 56 = 0.3228698041429996
# Error = 0.32395730290293145
# Error = 0.33180585316981337
# Error = 0.3022707833065973
# Cost after 57 epochs is = 0.3204061434893141
# Initial Cost for this epoch 57 = 0.3204061434893141
# Error = 0.321444124936478
# Error = 0.32943273030879977
# Error = 0.3000831593792069
# Cost after 58 epochs is = 0.3179920087569967
# Initial Cost for this epoch 58 = 0.3179920087569967
# Error = 0.3189328772002072
# Error = 0.32710785967959793
# Error = 0.2979284582796876
# Cost after 59 epochs is = 0.3156278365079602
# Initial Cost for this epoch 59 = 0.3156278365079602
# Error = 0.3164306830570168
# Error = 0.32482674512039056
# Error = 0.29580450982144924
# Cost after 60 epochs is = 0.31331276804005825
# Initial Cost for this epoch 60 = 0.31331276804005825
# Error = 0.3139453174302539
# Error = 0.322585083790784
# Error = 0.2937077316429629
# Cost after 61 epochs is = 0.31104504856257975
# Initial Cost for this epoch 61 = 0.31104504856257975
# Error = 0.31148437340068136
# Error = 0.3203789718346478
# Error = 0.29163356935810336
# Cost after 62 epochs is = 0.30882236016196246
# Initial Cost for this epoch 62 = 0.30882236016196246
# Error = 0.3090545061075703
# Error = 0.3182050162903949
# Error = 0.2895769365635089
# Cost after 63 epochs is = 0.30664206305390584
# Initial Cost for this epoch 63 = 0.30664206305390584
# Error = 0.306660847727339
# Error = 0.3160603903080979
# Error = 0.28753262670752816
# Cost after 64 epochs is = 0.30450135241960147
# Initial Cost for this epoch 64 = 0.30450135241960147
# Error = 0.3043066719850471
# Error = 0.31394284413331974
# Error = 0.2854956845805631
# Cost after 65 epochs is = 0.3023973519297192
# Initial Cost for this epoch 65 = 0.3023973519297192
# Error = 0.3019933294230901
# Error = 0.3118506665336737
# Error = 0.28346173031729976
# Cost after 66 epochs is = 0.30032716682926974
# Initial Cost for this epoch 66 = 0.30032716682926974
# Error = 0.29972040860612015
# Error = 0.30978258350476723
# Error = 0.2814272278537627
# Cost after 67 epochs is = 0.29828791528806703
# Initial Cost for this epoch 67 = 0.29828791528806703
# Error = 0.29748603421769354
# Error = 0.3077375858490343
# Error = 0.27938968694697836
# Cost after 68 epochs is = 0.2962767504281659
# Initial Cost for this epoch 68 = 0.2962767504281659
# Error = 0.2952872030156839
# Error = 0.30571469550968244
# Error = 0.27734778598450444
# Cost after 69 epochs is = 0.29429087926138986
# Initial Cost for this epoch 69 = 0.29429087926138986
# Error = 0.29312007722192635
# Error = 0.30371270806579237
# Error = 0.27530140341020753
# Cost after 70 epochs is = 0.29232758054618363
# Initial Cost for this epoch 70 = 0.29232758054618363
# Error = 0.29098018866832015
# Error = 0.30172997503567817
# Error = 0.2732515496787908
# Cost after 71 epochs is = 0.29038422286924587
# Initial Cost for this epoch 71 = 0.29038422286924587
# Error = 0.28886254407018924
# Error = 0.29976430141423943
# Error = 0.27120020029793884
# Cost after 72 epochs is = 0.2884582873156983
# Initial Cost for this epoch 72 = 0.2884582873156983
# Error = 0.2867616550511616
# Error = 0.2978130213474308
# Error = 0.2691500444424919
# Cost after 73 epochs is = 0.2865474040156856
# Initial Cost for this epoch 73 = 0.2865474040156856
# Error = 0.28467154218119844
# Error = 0.2958732760142506
# Error = 0.2671041820177257
# Cost after 74 epochs is = 0.28464941524733695
# Initial Cost for this epoch 74 = 0.28464941524733695
# Error = 0.28258577757222336
# Error = 0.2939424591494081
# Error = 0.26506582133965917
# Cost after 75 epochs is = 0.28276247639998536
# Initial Cost for this epoch 75 = 0.28276247639998536
# Error = 0.2804976326992618
# Error = 0.29201873057379835
# Error = 0.26303804260481484
# Cost after 76 epochs is = 0.2808851981955639
# Initial Cost for this epoch 76 = 0.2808851981955639
# Error = 0.2784003839739138
# Error = 0.2901014466963254
# Error = 0.261023688577826
# Cost after 77 epochs is = 0.27901681925069327
# Initial Cost for this epoch 77 = 0.27901681925069327
# Error = 0.2762877953308718
# Error = 0.28819134761238213
# Error = 0.25902541346715924
# Cost after 78 epochs is = 0.2771573797598826
# Initial Cost for this epoch 78 = 0.2771573797598826
# Error = 0.274154744465379
# Error = 0.28629040329429506
# Error = 0.2570458634107051
# Cost after 79 epochs is = 0.27530785071725494
# Initial Cost for this epoch 79 = 0.27530785071725494
# Error = 0.271997895596116
# Error = 0.2844013595422655
# Error = 0.2550878970346457
# Cost after 80 epochs is = 0.2734701682589327
# Initial Cost for this epoch 80 = 0.2734701682589327
# Error = 0.2698162697098382
# Error = 0.28252717647725306
# Error = 0.2531547206105062
# Cost after 81 epochs is = 0.2716471381007567
# Initial Cost for this epoch 81 = 0.2716471381007567
# Error = 0.267611555778925
# Error = 0.2806706075932026
# Error = 0.251249842035807
# Cost after 82 epochs is = 0.269842209749662
# Initial Cost for this epoch 82 = 0.269842209749662
# Error = 0.2653880616348524
# Error = 0.2788340651161234
# Error = 0.24937683407189654
# Cost after 83 epochs is = 0.26805915962362364
# Initial Cost for this epoch 83 = 0.26805915962362364
# Error = 0.2631523023819165
# Error = 0.2770197305419983
# Error = 0.2475389884408039
# Cost after 84 epochs is = 0.2663017469812983
# Initial Cost for this epoch 84 = 0.2663017469812983
# Error = 0.2609123219873676
# Error = 0.27522974270704675
# Error = 0.24573898270194675
# Cost after 85 epochs is = 0.2645734069150568
# Initial Cost for this epoch 85 = 0.2645734069150568
# Error = 0.2586769015255977
# Error = 0.2734663037581588
# Error = 0.2439786568213496
# Cost after 86 epochs is = 0.26287702545542807
# Initial Cost for this epoch 86 = 0.26287702545542807
# Error = 0.25645481249255125
# Error = 0.2717316413891722
# Error = 0.24225893643888755
# Cost after 87 epochs is = 0.2612148149617114
# Initial Cost for this epoch 87 = 0.2612148149617114
# Error = 0.2542542328581759
# Error = 0.2700278638453622
# Error = 0.2405798861112861
# Cost after 88 epochs is = 0.25958828372521614
# Initial Cost for this epoch 88 = 0.25958828372521614
# Error = 0.25208237713732795
# Error = 0.2683567878626872
# Error = 0.23894084912596364
# Cost after 89 epochs is = 0.2579982779099575
# Initial Cost for this epoch 89 = 0.2579982779099575
# Error = 0.24994532740655473
# Error = 0.26671980825242947
# Error = 0.237340628132775
# Cost after 90 epochs is = 0.2564450682151906
# Initial Cost for this epoch 90 = 0.2564450682151906
# Error = 0.2478480129819268
# Error = 0.26511784013577083
# Error = 0.23577767072038708
# Cost after 91 epochs is = 0.254928456067046
# Initial Cost for this epoch 91 = 0.254928456067046
# Error = 0.24579427844464063
# Error = 0.2635513297566716
# Error = 0.2342502366813892
# Cost after 92 epochs is = 0.25344788086504855
# Initial Cost for this epoch 92 = 0.25344788086504855
# Error = 0.24378699248496236
# Error = 0.26202031122288605
# Error = 0.23275653483867387
# Cost after 93 epochs is = 0.25200251717862826
# Initial Cost for this epoch 93 = 0.25200251717862826
# Error = 0.2418281686487233
# Error = 0.2605244838798
# Error = 0.23129482573474733
# Cost after 94 epochs is = 0.2505913567341702
# Initial Cost for this epoch 94 = 0.2505913567341702
# Error = 0.23991908394080935
# Error = 0.25906329120466937
# Error = 0.22986349205166104
# Cost after 95 epochs is = 0.24921327399743567
# Initial Cost for this epoch 95 = 0.24921327399743567
# Error = 0.2380603899126123
# Error = 0.25763599036305607
# Error = 0.22846108161360262
# Cost after 96 epochs is = 0.24786707639918892
# Initial Cost for this epoch 96 = 0.24786707639918892
# Error = 0.2362522147591992
# Error = 0.25624170821183034
# Error = 0.22708632882663757
# Cost after 97 epochs is = 0.24655154127291554
# Initial Cost for this epoch 97 = 0.24655154127291554
# Error = 0.23449425623887202
# Error = 0.25487948359869256
# Error = 0.22573816015960055
# Cost after 98 epochs is = 0.24526544183973745
# Initial Cost for this epoch 98 = 0.24526544183973745
# Error = 0.23278586546397806
# Error = 0.2535482977261369
# Error = 0.22441568841352258
# Cost after 99 epochs is = 0.24400756443913588
# Initial Cost for this epoch 99 = 0.24400756443913588
# Error = 0.23112612161624427
# Error = 0.2522470949064734
# Error = 0.22311819951613857
# Cost after 100 epochs is = 0.24277671889568309
# Initial Cost for this epoch 100 = 0.24277671889568309
# Error = 0.22951389772419759
# Error = 0.2509747958977765
# Error = 0.22184513466338251
# Cost after 101 epochs is = 0.24157174356296662
# Initial Cost for this epoch 101 = 0.24157174356296662
# Error = 0.2279479178473951
# Error = 0.24973030560431211
# Error = 0.22059606990888314
# Cost after 102 epochs is = 0.2403915062584455
# Initial Cost for this epoch 102 = 0.2403915062584455
# Error = 0.22642680627723777
# Error = 0.24851251647579148
# Error = 0.2193706947787606
# Cost after 103 epochs is = 0.23923490201848538
# Initial Cost for this epoch 103 = 0.23923490201848538
# Error = 0.2249491296051699
# Error = 0.2473203085443159
# Error = 0.2181687911194468
# Cost after 104 epochs is = 0.23810084836293233
# Initial Cost for this epoch 104 = 0.23810084836293233
# Error = 0.22351343266939758
# Error = 0.24615254671976097
# Error = 0.21699021311274866
# Cost after 105 epochs is = 0.2369882785586045
# Initial Cost for this epoch 105 = 0.2369882785586045
# Error = 0.22211826944991164
# Error = 0.24500807571298389
# Error = 0.21583486915966824
# Cost after 106 epochs is = 0.2358961332070577
# Initial Cost for this epoch 106 = 0.2358961332070577
# Error = 0.2207622299452573
# Error = 0.2438857127507948
# Error = 0.21470270609786568
# Cost after 107 epochs is = 0.23482335035404148
# Initial Cost for this epoch 107 = 0.23482335035404148
# Error = 0.21944396395136018
# Error = 0.2427842380698935
# Error = 0.21359369594444097
# Cost after 108 epochs is = 0.23376885423170543
# Initial Cost for this epoch 108 = 0.23376885423170543
# Error = 0.21816220248588533
# Error = 0.2417023830229516
# Error = 0.2125078250234929
# Cost after 109 epochs is = 0.23273154271175148
# Initial Cost for this epoch 109 = 0.23273154271175148
# Error = 0.2169157773571509
# Error = 0.24063881550890245
# Error = 0.2114450849323255
# Cost after 110 epochs is = 0.23171027358802235
# Initial Cost for this epoch 110 = 0.23171027358802235
# Error = 0.21570363903825168
# Error = 0.23959212238310315
# Error = 0.21040546431625587
# Cost after 111 epochs is = 0.23070384994970392
# Initial Cost for this epoch 111 = 0.23070384994970392
# Error = 0.2145248725279312
# Error = 0.23856078857301413
# Error = 0.20938893987338297
# Cost after 112 epochs is = 0.2297110051908769
# Initial Cost for this epoch 112 = 0.2297110051908769
# Error = 0.21337871020268054
# Error = 0.23754317292420063
# Error = 0.20839546445259707
# Cost after 113 epochs is = 0.228730388674899
# Initial Cost for this epoch 113 = 0.228730388674899
# Error = 0.21226453974579568
# Error = 0.2365374814846537
# Error = 0.20742494967823782
# Cost after 114 epochs is = 0.22776055377322063
# Initial Cost for this epoch 114 = 0.22776055377322063
# Error = 0.21118190409577814
# Error = 0.23554174020883298
# Error = 0.20647724050859417
# Cost after 115 epochs is = 0.22679995093200758
# Initial Cost for this epoch 115 = 0.22679995093200758
# Error = 0.21013048914799648
# Error = 0.23455377114726844
# Error = 0.20555207996773958
# Cost after 116 epochs is = 0.2258469295020666
# Initial Cost for this epoch 116 = 0.2258469295020666
# Error = 0.2091100940823154
# Error = 0.23357117920476966
# Error = 0.20464906456721568
# Cost after 117 epochs is = 0.22489975305374513
# Initial Cost for this epoch 117 = 0.22489975305374513
# Error = 0.20812057942585852
# Error = 0.23259136028589505
# Error = 0.20376759510216944
# Cost after 118 epochs is = 0.22395663332484056
# Initial Cost for this epoch 118 = 0.22395663332484056
# Error = 0.2071617902975496
# Error = 0.23161154518792057
# Error = 0.20290683325718525
# Cost after 119 epochs is = 0.22301578715701545
# Initial Cost for this epoch 119 = 0.22301578715701545
# Error = 0.20623345750024286
# Error = 0.23062889500041592
# Error = 0.20206567989551769
# Cost after 120 epochs is = 0.22207551811817816
# Initial Cost for this epoch 120 = 0.22207551811817816
# Error = 0.20533508681881243
# Error = 0.2296406601304031
# Error = 0.20124279222003366
# Cost after 121 epochs is = 0.22113431978456188
# Initial Cost for this epoch 121 = 0.22113431978456188
# Error = 0.2044658544508387
# Error = 0.22864440362341268
# Error = 0.20043664987741974
# Cost after 122 epochs is = 0.22019099161264022
# Initial Cost for this epoch 122 = 0.22019099161264022
# Error = 0.2036245294143575
# Error = 0.22763826976646045
# Error = 0.19964566344484247
# Cost after 123 epochs is = 0.2192447527924413
# Initial Cost for this epoch 123 = 0.2192447527924413
# Error = 0.2028094383877508
# Error = 0.22662125526186294
# Error = 0.1988682985344831
# Cost after 124 epochs is = 0.21829533666645473
# Initial Cost for this epoch 124 = 0.21829533666645473
# Error = 0.2020184762321393
# Error = 0.22559342163814852
# Error = 0.1981031770364159
# Cost after 125 epochs is = 0.2173430495043951
# Initial Cost for this epoch 125 = 0.2173430495043951
# Error = 0.20124915432169196
# Error = 0.2245559846366787
# Error = 0.1973491239952327
# Cost after 126 epochs is = 0.2163887820239651
# Initial Cost for this epoch 126 = 0.2163887820239651
# Error = 0.20049867736468133
# Error = 0.2235112357054046
# Error = 0.19660515308507515
# Cost after 127 epochs is = 0.21543396811723428
# Initial Cost for this epoch 127 = 0.21543396811723428
# Error = 0.19976404775181916
# Error = 0.22246229061102674
# Error = 0.1958704117001257
# Cost after 128 epochs is = 0.2144804914106198
# Initial Cost for this epoch 128 = 0.2144804914106198
# Error = 0.19904220371870054
# Error = 0.22141270901130924
# Error = 0.1951441214606572
# Cost after 129 epochs is = 0.21353054681162603
# Initial Cost for this epoch 129 = 0.21353054681162603
# Error = 0.19833019144915162
# Error = 0.2203660680619732
# Error = 0.1944255441116521
# Cost after 130 epochs is = 0.21258647170710332
# Initial Cost for this epoch 130 = 0.21258647170710332
# Error = 0.1976253514902572
# Error = 0.2193255847917899
# Error = 0.19371398284399738
# Cost after 131 epochs is = 0.21165056870274707
# Initial Cost for this epoch 131 = 0.21165056870274707
# Error = 0.19692548104604246
# Error = 0.21829385958231737
# Error = 0.19300880889898217
# Cost after 132 epochs is = 0.2107249452830215
# Initial Cost for this epoch 132 = 0.2107249452830215
# Error = 0.19622893242226902
# Error = 0.21727276786799665
# Error = 0.19230949378216863
# Cost after 133 epochs is = 0.20981139252327477
# Initial Cost for this epoch 133 = 0.20981139252327477
# Error = 0.1955346273185257
# Error = 0.2162634816549752
# Error = 0.19161563029358256
# Cost after 134 epochs is = 0.20891131534499321
# Initial Cost for this epoch 134 = 0.20891131534499321
# Error = 0.19484199454761514
# Error = 0.21526657541388108
# Error = 0.19092693520830462
# Cost after 135 epochs is = 0.2080257146038432
# Initial Cost for this epoch 135 = 0.2080257146038432
# Error = 0.19415085911787508
# Error = 0.21428216709497513
# Error = 0.19024323563384485
# Cost after 136 epochs is = 0.20715521125911743
# Initial Cost for this epoch 136 = 0.20715521125911743
# Error = 0.1934613158041485
# Error = 0.2133100569998434
# Error = 0.189564445831052
# Cost after 137 epochs is = 0.2063000978172156
# Initial Cost for this epoch 137 = 0.2063000978172156
# Error = 0.19277361319220007
# Error = 0.21234984405211826
# Error = 0.18889054157552784
# Cost after 138 epochs is = 0.20546040221069906
# Initial Cost for this epoch 138 = 0.20546040221069906
# Error = 0.19208806224634292
# Error = 0.21140101298884
# Error = 0.1882215369756324
# Cost after 139 epochs is = 0.20463595247651792
# Initial Cost for this epoch 139 = 0.20463595247651792
# Error = 0.19140497290879602
# Error = 0.21046299446595423
# Error = 0.18755746606480236
# Cost after 140 epochs is = 0.20382643489372756
# Initial Cost for this epoch 140 = 0.20382643489372756
# Error = 0.19072461568844726
# Error = 0.20953520367277023
# Error = 0.18689836953995667
# Cost after 141 epochs is = 0.2030314421125206
# Initial Cost for this epoch 141 = 0.2030314421125206
# Error = 0.19004720246091006
# Error = 0.20861706356917623
# Error = 0.18624428596159245
# Cost after 142 epochs is = 0.2022505105771394
# Initial Cost for this epoch 142 = 0.2022505105771394
# Error = 0.18937288047498788
# Error = 0.2077080179235434
# Error = 0.18559524636647382
# Cost after 143 epochs is = 0.2014831481645622
# Initial Cost for this epoch 143 = 0.2014831481645622
# Error = 0.1887017345406732
# Error = 0.20680753798256513
# Error = 0.18495127127595148
# Cost after 144 epochs is = 0.20072885368260532
# Initial Cost for this epoch 144 = 0.20072885368260532
# Error = 0.18803379368850806
# Error = 0.2059151253622594
# Error = 0.18431236928012823
# Cost after 145 epochs is = 0.19998713001626942
# Initial Cost for this epoch 145 = 0.19998713001626942
# Error = 0.1873690397966537
# Error = 0.20503031279050696
# Error = 0.18367853660402145
# Cost after 146 epochs is = 0.19925749254879932
# Initial Cost for this epoch 146 = 0.19925749254879932
# Error = 0.18670741662306362
# Error = 0.2041526636649781
# Error = 0.18304975725499176
# Cost after 147 epochs is = 0.1985394741972504
# Initial Cost for this epoch 147 = 0.1985394741972504
# Error = 0.18604883834603086
# Error = 0.20328177096079258
# Error = 0.18242600349373647
# Cost after 148 epochs is = 0.19783262809761076
# Initial Cost for this epoch 148 = 0.19783262809761076
# Error = 0.18539319715535998
# Error = 0.20241725576269837
# Error = 0.1818072364677765
# Cost after 149 epochs is = 0.197136528703288
# Initial Cost for this epoch 149 = 0.197136528703288
# Error = 0.18474036970852412
# Error = 0.20155876554931013
# Error = 0.18119340690746732
# Cost after 150 epochs is = 0.19645077184124232
# Initial Cost for this epoch 150 = 0.19645077184124232
# Error = 0.1840902224241362
# Error = 0.20070597227915912
# Error = 0.18058445582131694
# Cost after 151 epochs is = 0.19577497410277833
# Initial Cost for this epoch 151 = 0.19577497410277833
# Error = 0.1834426156691027
# Error = 0.1998585702907078
# Error = 0.17998031514880544
# Cost after 152 epochs is = 0.19510877182377717
# Initial Cost for this epoch 152 = 0.19510877182377717
# Error = 0.18279740693424795
# Error = 0.19901627401235694
# Error = 0.17938090834120674
# Cost after 153 epochs is = 0.19445181982246476
# Initial Cost for this epoch 153 = 0.19445181982246476
# Error = 0.18215445310481695
# Error = 0.19817881547251104
# Error = 0.1787861508480683
# Cost after 154 epochs is = 0.19380379000266554
# Initial Cost for this epoch 154 = 0.19380379000266554
# Error = 0.18151361192900659
# Error = 0.19734594159755625
# Error = 0.17819595049124412
# Cost after 155 epochs is = 0.19316436988935423
# Initial Cost for this epoch 155 = 0.19316436988935423
# Error = 0.1808747427767171
# Error = 0.196517411283819
# Error = 0.17761020771081626
# Cost after 156 epochs is = 0.19253326113539793
# Initial Cost for this epoch 156 = 0.19253326113539793
# Error = 0.18023770676612352
# Error = 0.19569299222668263
# Error = 0.17702881566838613
# Cost after 157 epochs is = 0.19191017801941662
# Initial Cost for this epoch 157 = 0.19191017801941662
# Error = 0.17960236631953344
# Error = 0.19487245748552418
# Error = 0.17645166019318062
# Cost after 158 epochs is = 0.19129484594165677
# Initial Cost for this epoch 158 = 0.19129484594165677
# Error = 0.17896858419324474
# Error = 0.19405558175698115
# Error = 0.1758786195551931
# Cost after 159 epochs is = 0.19068699991556393
# Initial Cost for this epoch 159 = 0.19068699991556393
# Error = 0.17833622200897467
# Error = 0.1932421373214556
# Error = 0.1753095640470983
# Cost after 160 epochs is = 0.1900863830459123
# Initial Cost for this epoch 160 = 0.1900863830459123
# Error = 0.17770513829677392
# Error = 0.19243188961898938
# Error = 0.17474435535284927
# Cost after 161 epochs is = 0.18949274497891846
# Initial Cost for this epoch 161 = 0.18949274497891846
# Error = 0.17707518604084604
# Error = 0.19162459240100796
# Error = 0.1741828456756098
# Cost after 162 epochs is = 0.18890584030504334
# Initial Cost for this epoch 162 = 0.18890584030504334
# Error = 0.17644620969995814
# Error = 0.19081998239428438
# Error = 0.1736248765909036
# Cost after 163 epochs is = 0.18832542689071463
# Initial Cost for this epoch 163 = 0.18832542689071463
# Error = 0.17581804165272158
# Error = 0.1900177734033171
# Error = 0.17307027758245636
# Cost after 164 epochs is = 0.187751264110647
# Initial Cost for this epoch 164 = 0.187751264110647
# Error = 0.1751904979945185
# Error = 0.18921764976789518
# Error = 0.1725188642080527
# Cost after 165 epochs is = 0.187183110947603
# Initial Cost for this epoch 165 = 0.187183110947603
# Error = 0.174563373586921
# Error = 0.18841925908516693
# Error = 0.1719704358306836
# Cost after 166 epochs is = 0.18662072392122564
# Initial Cost for this epoch 166 = 0.18662072392122564
# Error = 0.17393643623194113
# Error = 0.18762220410200112
# Error = 0.1714247728362344
# Cost after 167 epochs is = 0.18606385480203386
# Initial Cost for this epoch 167 = 0.18606385480203386
# Error = 0.17330941981262307
# Error = 0.18682603368701978
# Error = 0.1708816332429726
# Cost after 168 epochs is = 0.18551224806103833
# Initial Cost for this epoch 168 = 0.18551224806103833
# Error = 0.17268201620931528
# Error = 0.18603023280735506
# Error = 0.1703407485904417
# Cost after 169 epochs is = 0.1849656380002389
# Initial Cost for this epoch 169 = 0.1849656380002389
# Error = 0.17205386576972923
# Error = 0.18523421147059485
# Error = 0.16980181897684443
# Cost after 170 epochs is = 0.1844237455054994
# Initial Cost for this epoch 170 = 0.1844237455054994
# Error = 0.17142454608507088
# Error = 0.18443729265900416
# Error = 0.1692645070963551
# Cost after 171 epochs is = 0.1838862743626208
# Initial Cost for this epoch 171 = 0.1838862743626208
# Error = 0.17079355881216948
# Error = 0.18363869939773014
# Error = 0.1687284311143182
# Cost after 172 epochs is = 0.18335290708257085
# Initial Cost for this epoch 172 = 0.18335290708257085
# Error = 0.1701603142962969
# Error = 0.1828375412850724
# Error = 0.16819315621482203
# Cost after 173 epochs is = 0.182823300196939
# Initial Cost for this epoch 173 = 0.182823300196939
# Error = 0.16952411381348653
# Error = 0.1820328011033452
# Error = 0.16765818467147653
# Cost after 174 epochs is = 0.18229707901599185
# Initial Cost for this epoch 174 = 0.18229707901599185
# Error = 0.16888412939917175
# Error = 0.18122332256468252
# Error = 0.16712294434408864
# Cost after 175 epochs is = 0.18177383189795887
# Initial Cost for this epoch 175 = 0.18177383189795887
# Error = 0.1682393815131192
# Error = 0.18040780087520641
# Error = 0.16658677561530422
# Cost after 176 epochs is = 0.1812531041710471
# Initial Cost for this epoch 176 = 0.1812531041710471
# Error = 0.1675887152804159
# Error = 0.17958477866875464
# Error = 0.1660489169867241
# Cost after 177 epochs is = 0.18073439199322372
# Initial Cost for this epoch 177 = 0.18073439199322372
# Error = 0.16693077683590204
# Error = 0.17875265098958049
# Error = 0.1655084898994388
# Cost after 178 epochs is = 0.18021713664339845
# Initial Cost for this epoch 178 = 0.18021713664339845
# Error = 0.16626399248444843
# Error = 0.1779096843482189
# Error = 0.16496448388297613
# Cost after 179 epochs is = 0.17970072002066526
# Initial Cost for this epoch 179 = 0.17970072002066526
# Error = 0.1655865550459336
# Error = 0.17705405625580048
# Error = 0.16441574391692249
# Cost after 180 epochs is = 0.17918446248010694
# Initial Cost for this epoch 180 = 0.17918446248010694
# Error = 0.16489642385768366
# Error = 0.1761839226424433
# Error = 0.16386096292115937
# Cost after 181 epochs is = 0.17866762451777396
# Initial Cost for this epoch 181 = 0.17866762451777396
# Error = 0.16419134721116138
# Error = 0.17529752042577884
# Error = 0.16329868349003426
# Cost after 182 epochs is = 0.17814941414673252
# Initial Cost for this epoch 182 = 0.17814941414673252
# Error = 0.1634689178631168
# Error = 0.17439331008248107
# Error = 0.16272731409691446
# Cost after 183 epochs is = 0.17762900192812864
# Initial Cost for this epoch 183 = 0.17762900192812864
# Error = 0.16272667250600073
# Error = 0.1734701570761577
# Error = 0.1621451655216425
# Cost after 184 epochs is = 0.17710554532657902
# Initial Cost for this epoch 184 = 0.17710554532657902
# Error = 0.1619622430524892
# Error = 0.17252754054093403
# Error = 0.16155051247827484
# Cost after 185 epochs is = 0.1765782231364188
# Initial Cost for this epoch 185 = 0.1765782231364188
# Error = 0.16117355969117161
# Error = 0.17156576341368962
# Error = 0.16094168263692868
# Cost after 186 epochs is = 0.17604627907493386
# Initial Cost for this epoch 186 = 0.17604627907493386
# Error = 0.16035909257650005
# Error = 0.1705861237619746
# Error = 0.16031717023619305
# Cost after 187 epochs is = 0.1755090714169796
# Initial Cost for this epoch 187 = 0.1755090714169796
# Error = 0.15951810319128812
# Error = 0.16959099893861532
# Error = 0.15967576513895382
# Cost after 188 epochs is = 0.17496612325160354
# Initial Cost for this epoch 188 = 0.17496612325160354
# Error = 0.15865086375507229
# Error = 0.16858379990088682
# Error = 0.15901668256038354
# Cost after 189 epochs is = 0.17441716634080806
# Initial Cost for this epoch 189 = 0.17441716634080806
# Error = 0.15775880097961123
# Error = 0.16756877634296571
# Error = 0.15833967620614164
# Cost after 190 epochs is = 0.17386217140649907
# Initial Cost for this epoch 190 = 0.17386217140649907
# Error = 0.15684453336759355
# Error = 0.16655068977100915
# Error = 0.15764511937084366
# Cost after 191 epochs is = 0.17330135932964236
# Initial Cost for this epoch 191 = 0.17330135932964236
# Error = 0.1559117959588509
# Error = 0.16553440854596332
# Error = 0.15693404356409493
# Cost after 192 epochs is = 0.1727351909347661
# Initial Cost for this epoch 192 = 0.1727351909347661
# Error = 0.15496527235828012
# Error = 0.16452450114538272
# Error = 0.15620812990587968
# Cost after 193 epochs is = 0.17216433686977486
# Initial Cost for this epoch 193 = 0.17216433686977486
# Error = 0.15401036902223467
# Error = 0.16352490244548012
# Error = 0.15546965302396232
# Cost after 194 epochs is = 0.17158963245628947
# Initial Cost for this epoch 194 = 0.17158963245628947
# Error = 0.1530529655032468
# Error = 0.16253870447293525
# Error = 0.1547213807164268
# Cost after 195 epochs is = 0.17101202441040736
# Initial Cost for this epoch 195 = 0.17101202441040736
# Error = 0.1520991608664562
# Error = 0.1615680884678686
# Error = 0.1539664366368165
# Cost after 196 epochs is = 0.17043251670317103
# Initial Cost for this epoch 196 = 0.17043251670317103
# Error = 0.15115502156693975
# Error = 0.16061438240539866
# Error = 0.15320813825359303
# Cost after 197 epochs is = 0.1698521217580925
# Initial Cost for this epoch 197 = 0.1698521217580925
# Error = 0.15022632973973335
# Error = 0.15967820677820294
# Error = 0.15244982691082837
# Cost after 198 epochs is = 0.1692718211801503
# Initial Cost for this epoch 198 = 0.1692718211801503
# Error = 0.1493183361372331
# Error = 0.15875966432091382
# Error = 0.15169470859579512
# Cost after 199 epochs is = 0.1686925378629289
# Initial Cost for this epoch 199 = 0.1686925378629289
# Error = 0.1484355336997294
# Error = 0.15785853383999368
# Error = 0.15094572163365155
# Cost after 200 epochs is = 0.16811511916363697
# Initial Cost for this epoch 200 = 0.16811511916363697
# Error = 0.14758147687936365
# Error = 0.15697443932515748
# Error = 0.1502054416835764
# Cost after 201 epochs is = 0.16754032927232954
# Initial Cost for this epoch 201 = 0.16754032927232954
# Error = 0.14675867159691386
# Error = 0.1561069782488191
# Error = 0.14947602728350948
# Cost after 202 epochs is = 0.16696884812876092
# Initial Cost for this epoch 202 = 0.16696884812876092
# Error = 0.14596855041048376
# Error = 0.15525580418997734
# Error = 0.1487592030007261
# Cost after 203 epochs is = 0.1664012742209708
# Initial Cost for this epoch 203 = 0.1664012742209708
# Error = 0.1452115317863753
# Error = 0.15442066714129968
# Error = 0.14805627322195364
# Cost after 204 epochs is = 0.16583812911304538
# Initial Cost for this epoch 204 = 0.16583812911304538
# Error = 0.14448714769969656
# Error = 0.15360141980801817
# Error = 0.14736815788014285
# Cost after 205 epochs is = 0.16527986229829186
# Initial Cost for this epoch 205 = 0.16527986229829186
# Error = 0.14379421481121793
# Error = 0.1527980003037588
# Error = 0.14669544144075009
# Cost after 206 epochs is = 0.16472685569580542
# Initial Cost for this epoch 206 = 0.16472685569580542
# Error = 0.14313102256411617
# Error = 0.1520104015831266
# Error = 0.1460384275924016
# Cost after 207 epochs is = 0.1641794276436385
# Initial Cost for this epoch 207 = 0.1641794276436385
# Error = 0.1424955153700499
# Error = 0.15123863645887187
# Error = 0.14539719375903315
# Cost after 208 epochs is = 0.1636378365447848
# Initial Cost for this epoch 208 = 0.1636378365447848
# Error = 0.1418854529755589
# Error = 0.1504827048051242
# Error = 0.14477164138617699
# Cost after 209 epochs is = 0.16310228442823924
# Initial Cost for this epoch 209 = 0.16310228442823924
# Error = 0.1412985405621096
# Error = 0.1497425671053895
# Error = 0.14416153968091203
# Cost after 210 epochs is = 0.16257292066560367
# Initial Cost for this epoch 210 = 0.16257292066560367
# Error = 0.14073252641241524
# Error = 0.149018126277186
# Error = 0.14356656191630088
# Cost after 211 epochs is = 0.16204984600014227
# Initial Cost for this epoch 211 = 0.16204984600014227
# Error = 0.14018526932215936
# Error = 0.14830921794761806
# Error = 0.14298631444618917
# Cost after 212 epochs is = 0.16153311694611852
# Initial Cost for this epoch 212 = 0.16153311694611852
# Error = 0.13965478034691042
# Error = 0.14761560816833638
# Error = 0.14242035920354615
# Cost after 213 epochs is = 0.16102275052753695
# Initial Cost for this epoch 213 = 0.16102275052753695
# Error = 0.13913924435152725
# Error = 0.14693699692491685
# Error = 0.1418682307363031
# Cost after 214 epochs is = 0.1605187292587582
# Initial Cost for this epoch 214 = 0.1605187292587582
# Error = 0.13863702669373293
# Error = 0.14627302561482738
# Error = 0.14132944886897675
# Cost after 215 epochs is = 0.16002100622851473
# Initial Cost for this epoch 215 = 0.16002100622851473
# Error = 0.13814666968779737
# Error = 0.14562328680243472
# Error = 0.1408035279697981
# Cost after 216 epochs is = 0.15952951013281236
# Initial Cost for this epoch 216 = 0.15952951013281236
# Error = 0.13766688259534643
# Error = 0.14498733487031132
# Error = 0.1402899836348659
# Cost after 217 epochs is = 0.15904415010739212
# Initial Cost for this epoch 217 = 0.15904415010739212
# Error = 0.13719652798703208
# Error = 0.14436469655836576
# Error = 0.1397883374273394
# Cost after 218 epochs is = 0.15856482023135202
# Initial Cost for this epoch 218 = 0.15856482023135202
# Error = 0.1367346065197469
# Error = 0.1437548807362797
# Error = 0.13929812015884427
# Cost after 219 epochs is = 0.15809140360390642
# Initial Cost for this epoch 219 = 0.15809140360390642
# Error = 0.1362802415210584
# Error = 0.14315738704654032
# Error = 0.13881887408135962
# Cost after 220 epochs is = 0.15762377593018193
# Initial Cost for this epoch 220 = 0.15762377593018193
# Error = 0.13583266426841367
# Error = 0.1425717132702575
# Error = 0.13835015426943448
# Cost after 221 epochs is = 0.15716180858472234
# Initial Cost for this epoch 221 = 0.15716180858472234
# Error = 0.13539120047876205
# Error = 0.1419973614103817
# Error = 0.137891529408585
# Cost after 222 epochs is = 0.15670537114993666
# Initial Cost for this epoch 222 = 0.15670537114993666
# Error = 0.13495525826059984
# Error = 0.1414338425709826
# Error = 0.13744258215916205
# Cost after 223 epochs is = 0.15625433344955736
# Initial Cost for this epoch 223 = 0.15625433344955736
# Error = 0.13452431760065958
# Error = 0.14088068075351282
# Error = 0.1370029092298097
# Cost after 224 epochs is = 0.15580856711396268
# Initial Cost for this epoch 224 = 0.15580856711396268
# Error = 0.13409792134013038
# Error = 0.14033741570636069
# Error = 0.1365721212664496
# Cost after 225 epochs is = 0.15536794672539964
# Initial Cost for this epoch 225 = 0.15536794672539964
# Error = 0.13367566752318472
# Error = 0.13980360496383348
# Error = 0.13614984263873614
# Cost after 226 epochs is = 0.1549323505975292
# Initial Cost for this epoch 226 = 0.1549323505975292
# Error = 0.13325720296062893
# Error = 0.1392788252026946
# Error = 0.1357357111847412
# Cost after 227 epochs is = 0.15450166124623355
# Initial Cost for this epoch 227 = 0.15450166124623355
# Error = 0.1328422178341475
# Error = 0.13876267303309675
# Error = 0.13532937795577524
# Cost after 228 epochs is = 0.15407576560814865
# Initial Cost for this epoch 228 = 0.15407576560814865
# Error = 0.13243044116499106
# Error = 0.13825476532865325
# Error = 0.13493050698683492
# Cost after 229 epochs is = 0.15365455506068726
# Initial Cost for this epoch 229 = 0.15365455506068726
# Error = 0.13202163698009334
# Error = 0.1377547391885349
# Error = 0.13453877510447676
# Cost after 230 epochs is = 0.1532379252930502
# Initial Cost for this epoch 230 = 0.1532379252930502
# Error = 0.1316156010247924
# Error = 0.13726225161322078
# Error = 0.13415387177319563
# Cost after 231 epochs is = 0.15282577607241118
# Initial Cost for this epoch 231 = 0.15282577607241118
# Error = 0.13121215789174606
# Error = 0.1367769789648686
# Error = 0.13377549897370933
# Cost after 232 epochs is = 0.1524180109435455
# Initial Cost for this epoch 232 = 0.1524180109435455
# Error = 0.13081115845804014
# Error = 0.13629861627314957
# Error = 0.13340337110175388
# Cost after 233 epochs is = 0.15201453689399566
# Initial Cost for this epoch 233 = 0.15201453689399566
# Error = 0.1304124775451388
# Error = 0.1358268764377659
# Error = 0.13303721487373038
# Cost after 234 epochs is = 0.1516152640107235
# Initial Cost for this epoch 234 = 0.1516152640107235
# Error = 0.13001601173784866
# Error = 0.1353614893697792
# Error = 0.13267676922533989
# Cost after 235 epochs is = 0.15122010514830617
# Initial Cost for this epoch 235 = 0.15122010514830617
# Error = 0.1296216773178766
# Error = 0.13490220110541087
# Error = 0.13232178519065177
# Cost after 236 epochs is = 0.15082897562327405
# Initial Cost for this epoch 236 = 0.15082897562327405
# Error = 0.12922940828418944
# Error = 0.13444877291825336
# Error = 0.13197202575136202
# Cost after 237 epochs is = 0.15044179294429852
# Initial Cost for this epoch 237 = 0.15044179294429852
# Error = 0.12883915444588573
# Error = 0.13400098044897762
# Error = 0.13162726564883684
# Cost after 238 epochs is = 0.15005847658370117
# Initial Cost for this epoch 238 = 0.15005847658370117
# Error = 0.1284508795835902
# Error = 0.1335586128657145
# Error = 0.1312872911545304
# Cost after 239 epochs is = 0.14967894779222837
# Initial Cost for this epoch 239 = 0.14967894779222837
# Error = 0.12806455968262026
# Error = 0.13312147206338756
# Error = 0.13095189979721833
# Cost after 240 epochs is = 0.14930312945623034
# Initial Cost for this epoch 240 = 0.14930312945623034
# Error = 0.12768018124566224
# Error = 0.13268937190635544
# Error = 0.1306209000480227
# Cost after 241 epochs is = 0.14893094599427614
# Initial Cost for this epoch 241 = 0.14893094599427614
# Error = 0.12729773969485997
# Error = 0.13226213751574303
# Error = 0.13029411096628515
# Cost after 242 epochs is = 0.1485623232887803
# Initial Cost for this epoch 242 = 0.1485623232887803
# Error = 0.12691723787352494
# Error = 0.13183960460070204
# Error = 0.12997136181094224
# Cost after 243 epochs is = 0.14819718864734013
# Initial Cost for this epoch 243 = 0.14819718864734013
# Error = 0.12653868465662502
# Error = 0.13142161883142492
# Error = 0.12965249162315434
# Cost after 244 epochs is = 0.14783547078809167
# Initial Cost for this epoch 244 = 0.14783547078809167
# Error = 0.12616209367724404
# Error = 0.13100803525091245
# Error = 0.12933734878658767
# Cost after 245 epochs is = 0.14747709984340554
# Initial Cost for this epoch 245 = 0.14747709984340554
# Error = 0.12578748217372657
# Error = 0.13059871772213133
# Error = 0.12902579057198593
# Cost after 246 epochs is = 0.14712200737654585
# Initial Cost for this epoch 246 = 0.14712200737654585
# Error = 0.1254148699595653
# Error = 0.13019353840717116
# Error = 0.1287176826725804
# Cost after 247 epochs is = 0.14677012640644171
# Initial Cost for this epoch 247 = 0.14677012640644171
# Error = 0.12504427851549882
# Error = 0.12979237727520881
# Error = 0.1284128987365361
# Cost after 248 epochs is = 0.14642139143636096
# Initial Cost for this epoch 248 = 0.14642139143636096
# Error = 0.12467573020093486
# Error = 0.12939512163642783
# Error = 0.1281113199020878
# Cost after 249 epochs is = 0.1460757384829918
# Initial Cost for this epoch 249 = 0.1460757384829918
# Error = 0.1243092475798202
# Error = 0.12900166569944527
# Error = 0.12781283434035434
# Cost after 250 epochs is = 0.14573310510315232
# Initial Cost for this epoch 250 = 0.14573310510315232
# Error = 0.1239448528544797
# Error = 0.12861191015021464
# Error = 0.1275173368100782
# Cost after 251 epochs is = 0.1453934304160344
# Initial Cost for this epoch 251 = 0.1453934304160344
# Error = 0.12358256739976793
# Error = 0.12822576175077186
# Error = 0.12722472822777564
# Cost after 252 epochs is = 0.1450566551195109
# Initial Cost for this epoch 252 = 0.1450566551195109
# Error = 0.12322241138908148
# Error = 0.1278431329565416
# Error = 0.12693491525603043
# Cost after 253 epochs is = 0.14472272149958454
# Initial Cost for this epoch 253 = 0.14472272149958454
# Error = 0.12286440350334216
# Error = 0.12746394155121668
# Error = 0.12664780991195118
# Cost after 254 epochs is = 0.14439157343251724
# Initial Cost for this epoch 254 = 0.14439157343251724
# Error = 0.1225085607139166
# Error = 0.1270881102984618
# Error = 0.12636332919715623
# Cost after 255 epochs is = 0.144063156379557
# Initial Cost for this epoch 255 = 0.144063156379557
# Error = 0.1221548981305383
# Error = 0.12671556660986982
# Error = 0.12608139475006763
# Cost after 256 epochs is = 0.14373741737447476
# Initial Cost for this epoch 256 = 0.14373741737447476
# Error = 0.12180342890558774
# Error = 0.12634624222873309
# Error = 0.1258019325207839
# Cost after 257 epochs is = 0.14341430500434466
# Initial Cost for this epoch 257 = 0.14341430500434466
# Error = 0.1214541641865172
# Error = 0.12598007292927488
# Error = 0.12552487246837143
# Cost after 258 epochs is = 0.1430937693841589
# Initial Cost for this epoch 258 = 0.1430937693841589
# Error = 0.12110711310873122
# Error = 0.12561699823104291
# Error = 0.1252501482800608
# Cost after 259 epochs is = 0.14277576212597132
# Initial Cost for this epoch 259 = 0.14277576212597132
# Error = 0.12076228282182527
# Error = 0.12525696112819115
# Error = 0.1249776971115487
# Cost after 260 epochs is = 0.14246023630331822
# Initial Cost for this epoch 260 = 0.14246023630331822
# Error = 0.1204196785427051
# Error = 0.12489990783338342
# Error = 0.12470745934739565
# Cost after 261 epochs is = 0.1421471464116893
# Initial Cost for this epoch 261 = 0.1421471464116893
# Error = 0.12007930362974449
# Error = 0.12454578753604863
# Error = 0.12443937838034998
# Cost after 262 epochs is = 0.14183644832581208
# Initial Cost for this epoch 262 = 0.14183644832581208
# Error = 0.11974115967276568
# Error = 0.12419455217470049
# Error = 0.1241734004083309
# Cost after 263 epochs is = 0.14152809925448606
# Initial Cost for this epoch 263 = 0.14152809925448606
# Error = 0.11940524659423922
# Error = 0.1238461562230162
# Error = 0.12390947424774622
# Cost after 264 epochs is = 0.14122205769366156
# Initial Cost for this epoch 264 = 0.14122205769366156
# Error = 0.11907156275768728
# Error = 0.12350055648934559
# Error = 0.12364755116180652
# Cost after 265 epochs is = 0.14091828337840104
# Initial Cost for this epoch 265 = 0.14091828337840104
# Error = 0.11874010507982885
# Error = 0.12315771192929983
# Error = 0.12338758470251461
# Cost after 266 epochs is = 0.1406167372343065
# Initial Cost for this epoch 266 = 0.1406167372343065
# Error = 0.1184108691435314
# Error = 0.12281758347104382
# Error = 0.12312953056505363
# Cost after 267 epochs is = 0.14031738132892968
# Initial Cost for this epoch 267 = 0.14031738132892968
# Error = 0.11808384930911896
# Error = 0.12248013385289505
# Error = 0.12287334645336229
# Cost after 268 epochs is = 0.14002017882361883
# Initial Cost for this epoch 268 = 0.14002017882361883
# Error = 0.11775903882203956
# Error = 0.12214532747280644
# Error = 0.12261899195576771
# Cost after 269 epochs is = 0.13972509392619464
# Initial Cost for this epoch 269 = 0.13972509392619464
# Error = 0.11743642991531025
# Error = 0.12181313024929218
# Error = 0.12236642842963624
# Cost after 270 epochs is = 0.139432091844784
# Initial Cost for this epoch 270 = 0.139432091844784
# Error = 0.1171160139055347
# Error = 0.12148350949333173
# Error = 0.12211561889410241
# Cost after 271 epochs is = 0.13914113874308448
# Initial Cost for this epoch 271 = 0.13914113874308448
# Error = 0.11679778128163194
# Error = 0.12115643379077018
# Error = 0.12186652793003638
# Cost after 272 epochs is = 0.13885220169727566
# Initial Cost for this epoch 272 = 0.13885220169727566
# Error = 0.116481721785719
# Error = 0.12083187289471133
# Error = 0.12161912158651127
# Cost after 273 epochs is = 0.13856524865474565
# Initial Cost for this epoch 273 = 0.13856524865474565
# Error = 0.1161678244858604
# Error = 0.12050979762738603
# Error = 0.12137336729312749
# Cost after 274 epochs is = 0.13828024839475223
# Initial Cost for this epoch 274 = 0.13828024839475223
# Error = 0.11585607784063122
# Error = 0.12019017979096176
# Error = 0.1211292337776451
# Cost after 275 epochs is = 0.1379971704910981
# Initial Cost for this epoch 275 = 0.1379971704910981
# Error = 0.11554646975564144
# Error = 0.11987299208674713
# Error = 0.12088669098845813
# Cost after 276 epochs is = 0.13771598527686285
# Initial Cost for this epoch 276 = 0.13771598527686285
# Error = 0.11523898763233564
# Error = 0.11955820804223613
# Error = 0.12064571002152223
# Cost after 277 epochs is = 0.1374366638111995
# Initial Cost for this epoch 277 = 0.1374366638111995
# Error = 0.11493361840951644
# Error = 0.1192458019454312
# Error = 0.12040626305141362
# Cost after 278 epochs is = 0.13715917784817844
# Initial Cost for this epoch 278 = 0.13715917784817844
# Error = 0.11463034859814679
# Error = 0.118935748785881
# Error = 0.12016832326625648
# Cost after 279 epochs is = 0.13688349980763492
# Initial Cost for this epoch 279 = 0.13688349980763492
# Error = 0.11432916431006078
# Error = 0.11862802420187202
# Error = 0.11993186480630152
# Cost after 280 epochs is = 0.13660960274795814
# Initial Cost for this epoch 280 = 0.13660960274795814
# Error = 0.11403005128126498
# Error = 0.11832260443321971
# Error = 0.11969686270598313
# Cost after 281 epochs is = 0.13633746034074273
# Initial Cost for this epoch 281 = 0.13633746034074273
# Error = 0.1137329948905397
# Error = 0.1180194662791148
# Error = 0.11946329283930755
# Cost after 282 epochs is = 0.13606704684721269
# Initial Cost for this epoch 282 = 0.13606704684721269
# Error = 0.11343798017405529
# Error = 0.11771858706049688
# Error = 0.11923113186845229
# Cost after 283 epochs is = 0.13579833709631628
# Initial Cost for this epoch 283 = 0.13579833709631628
# Error = 0.11314499183670897
# Error = 0.11741994458644638
# Error = 0.11900035719547146
# Cost after 284 epochs is = 0.13553130646438644
# Initial Cost for this epoch 284 = 0.13553130646438644
# Error = 0.11285401426086047
# Error = 0.11712351712410975
# Error = 0.1187709469170124
# Cost after 285 epochs is = 0.135265930856256
# Initial Cost for this epoch 285 = 0.135265930856256
# Error = 0.11256503151310708
# Error = 0.1168292833716997
# Error = 0.1185428797819561
# Cost after 286 epochs is = 0.13500218668771657
# Initial Cost for this epoch 286 = 0.13500218668771657
# Error = 0.11227802734969064
# Error = 0.11653722243414158
# Error = 0.11831613515189389
# Cost after 287 epochs is = 0.13474005086920995
# Initial Cost for this epoch 287 = 0.13474005086920995
# Error = 0.11199298522107423
# Error = 0.1162473138009708
# Error = 0.11809069296435425
# Cost after 288 epochs is = 0.13447950079064327
# Initial Cost for this epoch 288 = 0.13447950079064327
# Error = 0.11170988827616628
# Error = 0.11595953732611797
# Error = 0.11786653369868894
# Cost after 289 epochs is = 0.13422051430722332
# Initial Cost for this epoch 289 = 0.13422051430722332
# Error = 0.11142871936661079
# Error = 0.11567387320925604
# Error = 0.11764363834452482
# Cost after 290 epochs is = 0.13396306972620914
# Initial Cost for this epoch 290 = 0.13396306972620914
# Error = 0.111149461051495
# Error = 0.11539030197841775
# Error = 0.11742198837268213
# Cost after 291 epochs is = 0.13370714579448778
# Initial Cost for this epoch 291 = 0.13370714579448778
# Error = 0.11087209560276952
# Error = 0.11510880447362855
# Error = 0.1172015657084562
# Cost after 292 epochs is = 0.13345272168688524
# Initial Cost for this epoch 292 = 0.13345272168688524
# Error = 0.11059660501161361
# Error = 0.11482936183133471

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Loss with Epochs")
x = np.arange(0,len(costs[5:]))
ax.plot(x, costs[5:], marker='o', label='Train Accuracy')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Train Loss")

plt.legend()
#plt.savefig("accuracy_HiddenUnit_val20per.png", dpi=1000, bbox_inches='tight')
plt.show()
# Out:
# 0.5

# %%
test_accuracy
# Out:
# [88.75384615384615,
#  3.8461538461538463,
#  3.8461538461538463,
#  3.8461538461538463,
#  91.13846153846154]

# %%
train_time
# Out:
# [1574.8899838924408,
#  9.588012456893921,
#  3.52205491065979,
#  3.0311527252197266,
#  1853.354641675949]

# %%
train_accuracy
# Out:
# [97.09230769230768,
#  3.8461538461538463,
#  3.8461538461538463,
#  3.8461538461538463,
#  97.99230769230769]
