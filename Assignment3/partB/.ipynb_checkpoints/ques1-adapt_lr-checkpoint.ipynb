# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)
np.random.shuffle(X_train.to_numpy())
train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

X_train = X_train/255
X_test = X_test/255

m = X_train.shape[0] # Number of Training Samples

X_valid = X_train.iloc[(int(0.85*m)):]
valid_class = train_class[(int(0.85*m)):]
X_train = X_train.iloc[0:int(0.85*m)]
train_class = train_class[0:int(0.85*m)]


m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The total number of validation samples = {}".format(X_valid.shape[0]))

print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# The total number of training samples = 11050
# The total number of validation samples = 1950
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
valid_class_enc = pd.get_dummies(valid_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
# Out:
# --------Perform 1-hot encoding of class labels------------

# %%
#Add the intercept term to the data samples both in training and test dataset
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_valid = np.hstack((np.ones((X_valid.shape[0],1)), X_valid.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))

# %%
lr = 0.1
arch_test = [1,5,10,50,100]
arch = [arch_test[3]] #means one hidden layer with 2 perceptrons 
batch_size = 100 # Mini-Batch Size
r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
#Mini-Batch formation
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# The number of mini-batches formed is = 111

# %%
#Theta Initialization 
def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]

        theta.append(np.random.normal(0,0.01, (dim0,dim1)))
        #theta.append(0.01*(2*np.random.random((dim0, dim1))-1))
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
def activation(x):
    return 1/(1+np.exp(-x))

# %%
def forward_prop(data, theta):
    fm = []
    fm.append(data)
    for l in range(len(theta)):
        fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
def cost_total(X, theta, Y, m):
    fm = forward_prop(X, theta)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    #print("The Test Accuracy of the model = {}%".format(test_acc*100))
    return (test_acc*100)

# %%
epochs = []
train_accuracy = []
test_accuracy = []
valid_accuracy=[]
train_time = []
costs=[]

# %%
arch_test = [1, 5, 10, 50, 100]
#arch_test = [100]

# %%
arch_test=[50]

# %%
lr0=0.5
for i in range(len(arch_test)):
    theta = theta_init([arch_test[i]])
    fm = forward_prop(X_train, theta)
    epoch = 1
    early_stop = 0
    start = time.time()
    cost_init = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])
    costs.append(cost_init)
    
    while(True):
        count = 0
        lr = lr0/(np.power(epoch, 1/3))
        print("learning rate = ", lr)

        print("Initial Cost on Val dataset for this epoch {} = {}".format(epoch, cost_init))

        for b in mini_batch:
            X_b = b[0]
            Y_b = b[1]
            fm = forward_prop(X_b, theta)
            delta = [None]*len(fm)

            if (count % 60 == 0):
                print("Error on this batch = "+str(cost_total(X_b, theta, Y_b, batch_size)))
            #Backward Propagation

            for l in range(len(fm)-1, 0, -1):
                if (l == len(fm)-1):
                    delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
                else:
                    delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))

            for t in range(len(theta)):
                theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

            count+=1
        epoch+=1 #Number of epochs
        
        cost_final = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])
        if(epoch%10==0): costs.append(cost_final)
        print("Cost on val dataset after {} epochs is = {}".format(epoch, cost_final))
        
        if (abs(cost_final-cost_init) < 1e-06):
            early_stop +=1
        else:
            early_stop=0
        if (early_stop == 10):
            print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
            break

        cost_init = cost_final
    
    epochs.append(epoch)
    train_time.append(time.time()-start)
    train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
    valid_accuracy.append(calc_accuracy(X_valid, theta, valid_class_enc))
    test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
    print("\n------------------------------------------------------------------------------")
    print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
    print("------------------------------------------------------------------------------")
    print("The number of epochs = {:2.3f}".format(epochs[-1]))
    print("The training time = {:2.3f}sec".format(train_time[-1]))
    print("The training accuracy is = {:2.3f}%".format(train_accuracy[-1]))
    print("The validation accuracy is = {:2.3f}%".format(valid_accuracy[-1]))
    print("The test accuracy is = {:2.3f}%".format(test_accuracy[-1]))
    print("------------------------------------------------------------------------------\n")
# Out:
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 1 = 3.2485362370063564
# Error on this batch = 3.2484153978011956
# Error on this batch = 0.7529082086821359
# Cost on val dataset after 2 epochs is = 0.5959152274932004
# learning rate =  0.39685026299204984
# Initial Cost on Val dataset for this epoch 2 = 0.5959152274932004
# Error on this batch = 0.5959761838106553
# Error on this batch = 0.5478765849885021
# Cost on val dataset after 3 epochs is = 0.528237169271188
# learning rate =  0.3466806371753174
# Initial Cost on Val dataset for this epoch 3 = 0.528237169271188
# Error on this batch = 0.5282617758635783
# Error on this batch = 0.5156430981124607
# Cost on val dataset after 4 epochs is = 0.5087943315092469
# learning rate =  0.3149802624737183
# Initial Cost on Val dataset for this epoch 4 = 0.5087943315092469
# Error on this batch = 0.5088098621360814
# Error on this batch = 0.5032493202573498
# Cost on val dataset after 5 epochs is = 0.4999058910647221
# learning rate =  0.2924017738212866
# Initial Cost on Val dataset for this epoch 5 = 0.4999058910647221
# Error on this batch = 0.49991756275566807
# Error on this batch = 0.49684702868665964
# Cost on val dataset after 6 epochs is = 0.4949130183798165
# learning rate =  0.27516060407455223
# Initial Cost on Val dataset for this epoch 6 = 0.4949130183798165
# Error on this batch = 0.4949226275038994
# Error on this batch = 0.49299776075567964
# Cost on val dataset after 7 epochs is = 0.49175820277947924
# learning rate =  0.26137897928735515
# Initial Cost on Val dataset for this epoch 7 = 0.49175820277947924
# Error on this batch = 0.4917665587656036
# Error on this batch = 0.49045765981771977
# Cost on val dataset after 8 epochs is = 0.48960658967759074
# learning rate =  0.25
# Initial Cost on Val dataset for this epoch 8 = 0.48960658967759074
# Error on this batch = 0.48961411952002926
# Error on this batch = 0.4886722991893134
# Cost on val dataset after 9 epochs is = 0.4880583079614112
# learning rate =  0.24037492838456806
# Initial Cost on Val dataset for this epoch 9 = 0.4880583079614112
# Error on this batch = 0.48806526165969233
# Error on this batch = 0.4873588255537794
# Cost on val dataset after 10 epochs is = 0.4868989775641975
# learning rate =  0.23207944168063893
# Initial Cost on Val dataset for this epoch 10 = 0.4868989775641975
# Error on this batch = 0.4869055127649407
# Error on this batch = 0.4863585286168252
# Cost on val dataset after 11 epochs is = 0.48600384825597054
# learning rate =  0.2248221565113046
# Initial Cost on Val dataset for this epoch 11 = 0.48600384825597054
# Error on this batch = 0.48601007004696156
# Error on this batch = 0.4855758108464707
# Cost on val dataset after 12 epochs is = 0.4852956512008358
# learning rate =  0.21839511618407473
# Initial Cost on Val dataset for this epoch 12 = 0.4852956512008358
# Error on this batch = 0.4853016327206666
# Error on this batch = 0.48494983492052457
# Cost on val dataset after 13 epochs is = 0.4847241143972336
# learning rate =  0.2126451851414951
# Initial Cost on Val dataset for this epoch 13 = 0.4847241143972336
# Error on this batch = 0.4847299083312198
# Error on this batch = 0.4844401456486187
# Cost on val dataset after 14 epochs is = 0.4842552028788328
# learning rate =  0.2074566333415609
# Initial Cost on Val dataset for this epoch 14 = 0.4842552028788328
# Error on this batch = 0.48426084825975735
# Error on this batch = 0.4840188571801213
# Cost on val dataset after 15 epochs is = 0.4838651046959502
# learning rate =  0.20274006651911336
# Initial Cost on Val dataset for this epoch 15 = 0.4838651046959502
# Error on this batch = 0.4838706311242574
# Error on this batch = 0.4836661633940592
# Cost on val dataset after 16 epochs is = 0.48353669392759424
# learning rate =  0.19842513149602492
# Initial Cost on Val dataset for this epoch 16 = 0.48353669392759424
# Error on this batch = 0.48354212429617405
# Error on this batch = 0.48336763570084473
# Cost on val dataset after 17 epochs is = 0.4832573601520206
# learning rate =  0.19445555936641015
# Initial Cost on Val dataset for this epoch 17 = 0.4832573601520206
# Error on this batch = 0.48326271246530755
# Error on this batch = 0.48311253200166565
# Cost on val dataset after 18 epochs is = 0.4830176275551753
# learning rate =  0.190785707092222
# Initial Cost on Val dataset for this epoch 18 = 0.4830176275551753
# Error on this batch = 0.48302291617882065
# Error on this batch = 0.48289270261094563
# Cost on val dataset after 19 epochs is = 0.48281024875392964
# learning rate =  0.18737808839215772
# Initial Cost on Val dataset for this epoch 19 = 0.48281024875392964
# Error on this batch = 0.48281548529478313
# Error on this batch = 0.48270186174208224
# Cost on val dataset after 20 epochs is = 0.48262959390821525
# learning rate =  0.18420157493201936
# Initial Cost on Val dataset for this epoch 20 = 0.48262959390821525
# Error on this batch = 0.48263478784750946
# Error on this batch = 0.48253509006848605
# Cost on val dataset after 21 epochs is = 0.48247122905436657
# learning rate =  0.1812300621671487
# Initial Cost on Val dataset for this epoch 21 = 0.48247122905436657
# Error on this batch = 0.4824763882120686
# Error on this batch = 0.48238848746357677
# Cost on val dataset after 22 epochs is = 0.48233161890353166
# learning rate =  0.17844146387590207
# Initial Cost on Val dataset for this epoch 22 = 0.48233161890353166
# Error on this batch = 0.4823367497846812
# Error on this batch = 0.4822589257687574
# Cost on val dataset after 23 epochs is = 0.48220791343041597
# learning rate =  0.17581694345847967
# Initial Cost on Val dataset for this epoch 23 = 0.48220791343041597
# Error on this batch = 0.4822130214873676
# Error on this batch = 0.4821438696568403
# Cost on val dataset after 24 epochs is = 0.4820977920499585
# learning rate =  0.1733403185876587
# Initial Cost on Val dataset for this epoch 24 = 0.4820977920499585
# Error on this batch = 0.4821028818836613
# Error on this batch = 0.4820412447682718
# Cost on val dataset after 25 epochs is = 0.4819993481165706
# learning rate =  0.1709975946676697
# Initial Cost on Val dataset for this epoch 25 = 0.4819993481165706
# Error on this batch = 0.4820044236329605
# Error on this batch = 0.4819493392484961
# Cost on val dataset after 26 epochs is = 0.48191100213545407
# learning rate =  0.16877659529479094
# Initial Cost on Val dataset for this epoch 26 = 0.48191100213545407
# Error on this batch = 0.4819160666683307
# Error on this batch = 0.48186672926523194
# Cost on val dataset after 27 epochs is = 0.48183143573310055
# learning rate =  0.16666666666666666
# Initial Cost on Val dataset for this epoch 27 = 0.48183143573310055
# Error on this batch = 0.481836492141654
# Error on this batch = 0.4817922219939307
# Cost on val dataset after 28 epochs is = 0.481759540847372
# learning rate =  0.1646584390020874
# Initial Cost on Val dataset for this epoch 28 = 0.481759540847372
# Error on this batch = 0.48176459159431406
# Error on this batch = 0.48172481149817403
# Cost on val dataset after 29 epochs is = 0.481694380219028
# learning rate =  0.16274363236883382
# Initial Cost on Val dataset for this epoch 29 = 0.481694380219028
# Error on this batch = 0.48169942743371935
# Error on this batch = 0.4816636442458791
# Cost on val dataset after 30 epochs is = 0.48163515637422705
# learning rate =  0.16091489743427165
# Initial Cost on Val dataset for this epoch 30 = 0.48163515637422705
# Error on this batch = 0.48164020190408663
# Error on this batch = 0.48160799190724846
# Cost on val dataset after 31 epochs is = 0.4815811870558278
# learning rate =  0.15916568392288669
# Initial Cost on Val dataset for this epoch 31 = 0.4815811870558278
# Error on this batch = 0.48158623250850485
# Error on this batch = 0.4815572297129272
# Cost on val dataset after 32 epochs is = 0.4815318856017644
# learning rate =  0.15749013123685915
# Initial Cost on Val dataset for this epoch 32 = 0.4815318856017644
# Error on this batch = 0.4815369323799658
# Error on this batch = 0.4815108190988853
# Cost on val dataset after 33 epochs is = 0.4814867451538957
# learning rate =  0.155882976940936
# Initial Cost on Val dataset for this epoch 33 = 0.4814867451538957
# Error on this batch = 0.48149179448433077
# Error on this batch = 0.48146829368589955
# Cost on val dataset after 34 epochs is = 0.48144532585852357
# learning rate =  0.1543394797496521
# Initial Cost on Val dataset for this epoch 34 = 0.48144532585852357
# Error on this batch = 0.48145037881609976
# Error on this batch = 0.4814292478746979
# Cost on val dataset after 35 epochs is = 0.4814072444223841
# learning rate =  0.15285535436643993
# Initial Cost on Val dataset for this epoch 35 = 0.4814072444223841
# Error on this batch = 0.48141230195054335
# Error on this batch = 0.48139332750886854
# Cost on val dataset after 36 epochs is = 0.4813721655372526
# learning rate =  0.151426716069345
# Initial Cost on Val dataset for this epoch 36 = 0.4813721655372526
# Error on this batch = 0.48137722846515174
# Error on this batch = 0.48136022218436064
# Cost on val dataset after 37 epochs is = 0.4813397947974576
# learning rate =  0.15005003335928088
# Initial Cost on Val dataset for this epoch 37 = 0.4813397947974576
# Error on this batch = 0.4813448638545526
# Error on this batch = 0.4813296588791899
# Cost on val dataset after 38 epochs is = 0.48130987281808735
# learning rate =  0.14872208731475073
# Initial Cost on Val dataset for this epoch 38 = 0.48130987281808735
# Error on this batch = 0.4813149486465693
# Error on this batch = 0.4813013966484866
# Cost on val dataset after 39 epochs is = 0.48128217032492143
# learning rate =  0.1474399365542337
# Initial Cost on Val dataset for this epoch 39 = 0.48128217032492143
# Error on this batch = 0.481287253490365
# Error on this batch = 0.4812752221844464
# Cost on val dataset after 40 epochs is = 0.48125648403543325
# learning rate =  0.1462008869106433
# Initial Cost on Val dataset for this epoch 40 = 0.48125648403543325
# Error on this batch = 0.4812615750359523
# Error on this batch = 0.48125094608247965
# Cost on val dataset after 41 epochs is = 0.48123263318738707
# learning rate =  0.14500246508381334
# Initial Cost on Val dataset for this epoch 41 = 0.48123263318738707
# Error on this batch = 0.4812377324615351
# Error on this batch = 0.4812283996870976
# Cost on val dataset after 42 epochs is = 0.4812104566003707
# learning rate =  0.14384239566619703
# Initial Cost on Val dataset for this epoch 42 = 0.4812104566003707
# Error on this batch = 0.4812155645339833
# Error on this batch = 0.48120743241616026
# Cost on val dataset after 43 epochs is = 0.4811898101780987
# learning rate =  0.14271858104094723
# Initial Cost on Val dataset for this epoch 43 = 0.4811898101780987
# Error on this batch = 0.48119492711023976
# Error on this batch = 0.4811879094817539
# Cost on val dataset after 44 epochs is = 0.4811705647769886
# learning rate =  0.14162908373567618
# Initial Cost on Val dataset for this epoch 44 = 0.4811705647769886
# Error on this batch = 0.4811756910051328
# Error on this batch = 0.48116970994144437
# Cost on val dataset after 45 epochs is = 0.4811526043804686
# learning rate =  0.1405721108836249
# Initial Cost on Val dataset for this epoch 45 = 0.4811526043804686
# Error on this batch = 0.4811577401650343
# Error on this batch = 0.4811527250259311
# Cost on val dataset after 46 epochs is = 0.4811358245295819
# learning rate =  0.13954600049991203
# Initial Cost on Val dataset for this epoch 46 = 0.4811358245295819
# Error on this batch = 0.48114097009790513
# Error on this batch = 0.48113685669890127
# Cost on val dataset after 47 epochs is = 0.4811201309693156
# learning rate =  0.13854920932648104
# Initial Cost on Val dataset for this epoch 47 = 0.4811201309693156
# Error on this batch = 0.48112528651914416
# Error on this batch = 0.4811220164127336
# Cost on val dataset after 48 epochs is = 0.4811054384772117
# learning rate =  0.13758030203727611
# Initial Cost on Val dataset for this epoch 48 = 0.4811054384772117
# Error on this batch = 0.48111060417978624
# Error on this batch = 0.48110812403001346
# Cost on val dataset after 49 epochs is = 0.4810916698465764
# learning rate =  0.13663794162659923
# Initial Cost on Val dataset for this epoch 49 = 0.4810916698465764
# Error on this batch = 0.48109684584935253
# Error on this batch = 0.4810951068859363
# Cost on val dataset after 50 epochs is = 0.4810787550012668
# learning rate =  0.13572088082974534
# Initial Cost on Val dataset for this epoch 50 = 0.4810787550012668
# Error on this batch = 0.48108394143032684
# Error on this batch = 0.4810828989708395
# Cost on val dataset after 51 epochs is = 0.48106663022284696
# learning rate =  0.13482795444685966
# Initial Cost on Val dataset for this epoch 51 = 0.48106663022284696
# Error on this batch = 0.48107182718504116
# Error on this batch = 0.48107144021549586
# Cost on val dataset after 52 epochs is = 0.4810552374740172
# learning rate =  0.1339580724592811
# Initial Cost on Val dataset for this epoch 52 = 0.4810552374740172
# Error on this batch = 0.4810604450588684
# Error on this batch = 0.4810606758645962
# Cost on val dataset after 53 epochs is = 0.4810445238047828
# learning rate =  0.13311021384305818
# Initial Cost on Val dataset for this epoch 53 = 0.4810445238047828
# Error on this batch = 0.4810497420861852
# Error on this batch = 0.4810505559261402
# Cost on val dataset after 54 epochs is = 0.4810344408299444
# learning rate =  0.13228342099734997
# Initial Cost on Val dataset for this epoch 54 = 0.4810344408299444
# Error on this batch = 0.4810396698676803
# Error on this batch = 0.481041034686359
# Cost on val dataset after 55 epochs is = 0.48102494426824205
# learning rate =  0.13147679471646478
# Initial Cost on Val dataset for this epoch 55 = 0.48102494426824205
# Error on this batch = 0.48103018410933945
# Error on this batch = 0.48103207028136696
# Cost on val dataset after 56 epochs is = 0.48101599353494057
# learning rate =  0.13068948964367758
# Initial Cost on Val dataset for this epoch 56 = 0.48101599353494057
# Error on this batch = 0.48102124421489045
# Error on this batch = 0.4810236243180573
# Cost on val dataset after 57 epochs is = 0.48100755138086515
# learning rate =  0.12992071015297238
# Initial Cost on Val dataset for this epoch 57 = 0.48100755138086515
# Error on this batch = 0.48101281292471476
# Error on this batch = 0.481015661537851
# Cost on val dataset after 58 epochs is = 0.4809995835719068
# learning rate =  0.12916970661170635
# Initial Cost on Val dataset for this epoch 58 = 0.4809995835719068
# Error on this batch = 0.4810048559952425
# Error on this batch = 0.48100814951783377
# Cost on val dataset after 59 epochs is = 0.4809920586038782
# learning rate =  0.12843577198306824
# Initial Cost on Val dataset for this epoch 59 = 0.4809920586038782
# Error on this batch = 0.4809973419137113
# Error on this batch = 0.4810010584045894
# Cost on val dataset after 60 epochs is = 0.4809849474483184
# learning rate =  0.12771823873225885
# Initial Cost on Val dataset for this epoch 60 = 0.4809849474483184
# Error on this batch = 0.4809902416438847
# Error on this batch = 0.48099436067669255
# Cost on val dataset after 61 epochs is = 0.4809782233254556
# learning rate =  0.12701647600468316
# Initial Cost on Val dataset for this epoch 61 = 0.4809782233254556
# Error on this batch = 0.48098352839893715
# Error on this batch = 0.4809880309323796
# Cost on val dataset after 62 epochs is = 0.4809718615010533
# learning rate =  0.12632988704821413
# Initial Cost on Val dataset for this epoch 62 = 0.4809718615010533
# Error on this batch = 0.4809771774382321
# Error on this batch = 0.4809820456993842
# Cost on val dataset after 63 epochs is = 0.480965839104305
# learning rate =  0.12565790685485898
# Initial Cost on Val dataset for this epoch 63 = 0.480965839104305
# Error on this batch = 0.4809711658851542
# Error on this batch = 0.4809763832643297
# Cost on val dataset after 64 epochs is = 0.4809601349643145
# learning rate =  0.12500000000000003
# Initial Cost on Val dataset for this epoch 64 = 0.4809601349643145
# Error on this batch = 0.48096547256353606
# Error on this batch = 0.4809710235194059
# Cost on val dataset after 65 epochs is = 0.4809547294630244
# learning rate =  0.12435565865985812
# Initial Cost on Val dataset for this epoch 65 = 0.4809547294630244
# Error on this batch = 0.480960077850536
# Error on this batch = 0.48096594782435803
# Cost on val dataset after 66 epochs is = 0.4809496044027234
# learning rate =  0.12372440078998818
# Initial Cost on Val dataset for this epoch 66 = 0.4809496044027234
# Error on this batch = 0.48095496354410217
# Error on this batch = 0.48096113888205994
# Cost on val dataset after 67 epochs is = 0.4809447428865039
# learning rate =  0.1231057684495068
# Initial Cost on Val dataset for this epoch 67 = 0.4809447428865039
# Error on this batch = 0.4809501127433895
# Error on this batch = 0.4809565806261658
# Cost on val dataset after 68 epochs is = 0.4809401292102404
# learning rate =  0.12249932625741115
# Initial Cost on Val dataset for this epoch 68 = 0.4809401292102404
# Error on this batch = 0.4809455097407029
# Error on this batch = 0.48095225811951664
# Cost on val dataset after 69 epochs is = 0.4809357487648376
# learning rate =  0.12190465996880497
# Initial Cost on Val dataset for this epoch 69 = 0.4809357487648376
# Error on this batch = 0.48094113992371235
# Error on this batch = 0.48094815746214137
# Cost on val dataset after 70 epochs is = 0.48093158794764596
# learning rate =  0.12132137516012935
# Initial Cost on Val dataset for this epoch 70 = 0.48093158794764596
# Error on this batch = 0.4809369896868401
# Error on this batch = 0.4809442657078293
# Cost on val dataset after 71 epochs is = 0.48092763408207617
# learning rate =  0.1207490960136292
# Initial Cost on Val dataset for this epoch 71 = 0.48092763408207617
# Error on this batch = 0.48093304635084777
# Error on this batch = 0.48094057078837643
# Cost on val dataset after 72 epochs is = 0.4809238753445559
# learning rate =  0.12018746419228403
# Initial Cost on Val dataset for this epoch 72 = 0.4809238753445559
# Error on this batch = 0.4809292980897699
# Error on this batch = 0.48093706144470705
# Cost on val dataset after 73 epochs is = 0.4809203006980732
# learning rate =  0.11963613779731865
# Initial Cost on Val dataset for this epoch 73 = 0.4809203006980732
# Error on this batch = 0.48092573386443555
# Error on this batch = 0.4809337271641691
# Cost on val dataset after 74 epochs is = 0.48091689983163805
# learning rate =  0.11909479040119296
# Initial Cost on Val dataset for this epoch 74 = 0.48091689983163805
# Error on this batch = 0.48092234336190925
# Error on this batch = 0.4809305581233793
# Cost on val dataset after 75 epochs is = 0.4809136631050644
# learning rate =  0.11856311014966878
# Initial Cost on Val dataset for this epoch 75 = 0.4809136631050644
# Error on this batch = 0.48091911694025735
# Error on this batch = 0.48092754513606395
# Cost on val dataset after 76 epochs is = 0.48091058149855237
# learning rate =  0.11804079892717086
# Initial Cost on Val dataset for this epoch 76 = 0.48091058149855237
# Error on this batch = 0.480916045578111
# Error on this batch = 0.48092467960540464
# Cost on val dataset after 77 epochs is = 0.48090764656659213
# learning rate =  0.1175275715802136
# Initial Cost on Val dataset for this epoch 77 = 0.48090764656659213
# Error on this batch = 0.48091312082855797
# Error on this batch = 0.4809219534804498
# Cost on val dataset after 78 epochs is = 0.48090485039577974
# learning rate =  0.11702315519415757
# Initial Cost on Val dataset for this epoch 78 = 0.48090485039577974
# Error on this batch = 0.4809103347769429
# Error on this batch = 0.4809193592162018
# Cost on val dataset after 79 epochs is = 0.48090218556616543
# learning rate =  0.11652728841900283
# Initial Cost on Val dataset for this epoch 79 = 0.48090218556616543
# Error on this batch = 0.480907680002205
# Error on this batch = 0.4809168897370302
# Cost on val dataset after 80 epochs is = 0.4808996451158055
# learning rate =  0.1160397208403195
# Initial Cost on Val dataset for this epoch 80 = 0.4808996451158055
# Error on this batch = 0.480905149541417
# Error on this batch = 0.48091453840309895
# Cost on val dataset after 81 epochs is = 0.48089722250821476
# learning rate =  0.11556021239177247
# Initial Cost on Val dataset for this epoch 81 = 0.48089722250821476
# Error on this batch = 0.4809027368572286
# Error on this batch = 0.4809122989795307
# Cost on val dataset after 82 epochs is = 0.4808949116024561
# learning rate =  0.11508853280601371
# Initial Cost on Val dataset for this epoch 82 = 0.4808949116024561
# Error on this batch = 0.48090043580794617
# Error on this batch = 0.4809101656080516
# Cost on val dataset after 83 epochs is = 0.48089270662562356
# learning rate =  0.11462446110100276
# Initial Cost on Val dataset for this epoch 83 = 0.48089270662562356
# Error on this batch = 0.4808982406200069
# Error on this batch = 0.4809081327808986
# Cost on val dataset after 84 epochs is = 0.48089060214750645
# learning rate =  0.11416778509907356
# Initial Cost on Val dataset for this epoch 84 = 0.48089060214750645
# Error on this batch = 0.48089614586263535
# Error on this batch = 0.4809061953167811
# Cost on val dataset after 85 epochs is = 0.48088859305723636
# learning rate =  0.11371830097629766
# Initial Cost on Val dataset for this epoch 85 = 0.48088859305723636
# Error on this batch = 0.48089414642448347
# Error on this batch = 0.4809043483387174
# Cost on val dataset after 86 epochs is = 0.4808866745417463
# learning rate =  0.11327581283990419
# Initial Cost on Val dataset for this epoch 86 = 0.4808866745417463
# Error on this batch = 0.4808922374920823
# Error on this batch = 0.480902587253582
# Cost on val dataset after 87 epochs is = 0.48088484206588095
# learning rate =  0.11284013233170583
# Initial Cost on Val dataset for this epoch 87 = 0.48088484206588095
# Error on this batch = 0.48089041452994685
# Error on this batch = 0.4809009077332129
# Cost on val dataset after 88 epochs is = 0.480883091354017
# learning rate =  0.1124110782556523
# Initial Cost on Val dataset for this epoch 88 = 0.480883091354017
# Error on this batch = 0.4808886732621907
# Error on this batch = 0.4808993056969484
# Cost on val dataset after 89 epochs is = 0.4808814183730655
# learning rate =  0.11198847622778754
# Initial Cost on Val dataset for this epoch 89 = 0.4808814183730655
# Error on this batch = 0.48088700965552206
# Error on this batch = 0.4808977772954687
# Cost on val dataset after 90 epochs is = 0.4808798193167358
# learning rate =  0.11157215834702827
# Initial Cost on Val dataset for this epoch 90 = 0.4808798193167358
# Error on this batch = 0.4808854199035052
# Error on this batch = 0.4808963188958352
# Cost on val dataset after 91 epochs is = 0.4808782905909621
# learning rate =  0.11116196288530927
# Initial Cost on Val dataset for this epoch 91 = 0.4808782905909621
# Error on this batch = 0.4808839004119804
# Error on this batch = 0.48089492706762665
# Cost on val dataset after 92 epochs is = 0.4808768288003898
# learning rate =  0.11075773399575763
# Initial Cost on Val dataset for this epoch 92 = 0.4808768288003898
# Error on this batch = 0.4808824477855471
# Error on this batch = 0.4808935985700816
# Cost on val dataset after 93 epochs is = 0.4808754307358383
# learning rate =  0.11035932143766305
# Initial Cost on Val dataset for this epoch 93 = 0.4808754307358383
# Error on this batch = 0.48088105881502347
# Error on this batch = 0.48089233034016704
# Cost on val dataset after 94 epochs is = 0.48087409336266174
# learning rate =  0.10996658031710912
# Initial Cost on Val dataset for this epoch 94 = 0.48087409336266174
# Error on this batch = 0.48087973046580273
# Error on this batch = 0.48089111948149454
# Cost on val dataset after 95 epochs is = 0.48087281380993263
# learning rate =  0.10957937084221751
# Initial Cost on Val dataset for this epoch 95 = 0.48087281380993263
# Error on this batch = 0.4808784598670347
# Error on this batch = 0.4808899632540215
# Cost on val dataset after 96 epochs is = 0.4808715893603866
# learning rate =  0.10919755809203736
# Initial Cost on Val dataset for this epoch 96 = 0.4808715893603866
# Error on this batch = 0.480877244301566
# Error on this batch = 0.48088885906447054
# Cost on val dataset after 97 epochs is = 0.48087041744106424
# learning rate =  0.10882101179818644
# Initial Cost on Val dataset for this epoch 97 = 0.48087041744106424
# Error on this batch = 0.48087608119658093
# Error on this batch = 0.48088780445741325
# Cost on val dataset after 98 epochs is = 0.4808692956145993
# learning rate =  0.10844960613841653
# Initial Cost on Val dataset for this epoch 98 = 0.4808692956145993
# Error on this batch = 0.48087496811488606
# Error on this batch = 0.4808867971069664
# Cost on val dataset after 99 epochs is = 0.4808682215711016
# learning rate =  0.108083219541338
# Initial Cost on Val dataset for this epoch 99 = 0.4808682215711016
# Error on this batch = 0.48087390274679126
# Error on this batch = 0.48088583480905306
# Cost on val dataset after 100 epochs is = 0.4808671931205889
# learning rate =  0.1077217345015942
# Initial Cost on Val dataset for this epoch 100 = 0.4808671931205889
# Error on this batch = 0.48087288290253893
# Error on this batch = 0.48088491547418577
# Cost on val dataset after 101 epochs is = 0.48086620818592696
# learning rate =  0.10736503740482835
# Initial Cost on Val dataset for this epoch 101 = 0.48086620818592696
# Error on this batch = 0.4808719065052427
# Error on this batch = 0.4808840371207315
# Cost on val dataset after 102 epochs is = 0.4808652647962387
# learning rate =  0.10701301836183275
# Initial Cost on Val dataset for this epoch 102 = 0.4808652647962387
# Error on this batch = 0.48087097158429415
# Error on this batch = 0.480883197868625
# Cost on val dataset after 103 epochs is = 0.48086436108074826
# learning rate =  0.10666557105131397
# Initial Cost on Val dataset for this epoch 103 = 0.48086436108074826
# Error on this batch = 0.4808700762692055
# Error on this batch = 0.48088239593349286
# Cost on val dataset after 104 epochs is = 0.48086349526302746
# learning rate =  0.10632259257074755
# Initial Cost on Val dataset for this epoch 104 = 0.48086349526302746
# Error on this batch = 0.4808692187838545
# Error on this batch = 0.480881629621163
# Cost on val dataset after 105 epochs is = 0.4808626656556155
# learning rate =  0.10598398329483266
# Initial Cost on Val dataset for this epoch 105 = 0.4808626656556155
# Error on this batch = 0.4808683974411023
# Error on this batch = 0.48088089732252687
# Cost on val dataset after 106 epochs is = 0.480861870654984
# learning rate =  0.10564964674109129
# Initial Cost on Val dataset for this epoch 106 = 0.480861870654984
# Error on this batch = 0.4808676106377574
# Error on this batch = 0.48088019750873273
# Cost on val dataset after 107 epochs is = 0.480861108736824
# learning rate =  0.10531948944218769
# Initial Cost on Val dataset for this epoch 107 = 0.480861108736824
# Error on this batch = 0.48086685684986136
# Error on this batch = 0.48087952872668355
# Cost on val dataset after 108 epochs is = 0.4808603784516297
# learning rate =  0.10499342082457278
# Initial Cost on Val dataset for this epoch 108 = 0.4808603784516297
# Error on this batch = 0.4808661346282714
# Error on this batch = 0.4808788895948196
# Cost on val dataset after 109 epochs is = 0.48085967842056165
# learning rate =  0.10467135309308462
# Initial Cost on Val dataset for this epoch 109 = 0.48085967842056165
# Error on this batch = 0.48086544259452185
# Error on this batch = 0.4808782787991643
# Cost on val dataset after 110 epochs is = 0.48085900733156445
# cost initial= 0.48085967842056165 , cost final=0.48085900733156445 , change in cost= -6.710889972061373e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 1 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 110.000
# The training time = 19.355sec
# The training accuracy is = 3.982%
# The validation accuracy is = 3.077%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 1 = 3.2612390744137367
# Error on this batch = 3.26075671709982
# Error on this batch = 0.504937087256968
# Cost on val dataset after 2 epochs is = 0.48914485311568634
# learning rate =  0.39685026299204984
# Initial Cost on Val dataset for this epoch 2 = 0.48914485311568634
# Error on this batch = 0.4892994135838484
# Error on this batch = 0.48453847222827295
# Cost on val dataset after 3 epochs is = 0.48324287548247313
# learning rate =  0.3466806371753174
# Initial Cost on Val dataset for this epoch 3 = 0.48324287548247313
# Error on this batch = 0.48329605953693205
# Error on this batch = 0.4821782029565631
# Cost on val dataset after 4 epochs is = 0.4819010101347627
# learning rate =  0.3149802624737183
# Initial Cost on Val dataset for this epoch 4 = 0.4819010101347627
# Error on this batch = 0.48192274603785223
# Error on this batch = 0.4814620781919125
# Cost on val dataset after 5 epochs is = 0.4814037598924289
# learning rate =  0.2924017738212866
# Initial Cost on Val dataset for this epoch 5 = 0.4814037598924289
# Error on this batch = 0.48140999699630116
# Error on this batch = 0.4811670760388988
# Cost on val dataset after 6 epochs is = 0.4811752682449928
# learning rate =  0.27516060407455223
# Initial Cost on Val dataset for this epoch 6 = 0.4811752682449928
# Error on this batch = 0.4811721796929126
# Error on this batch = 0.48102530405755844
# Cost on val dataset after 7 epochs is = 0.4810565457995798
# learning rate =  0.26137897928735515
# Initial Cost on Val dataset for this epoch 7 = 0.4810565457995798
# Error on this batch = 0.4810471885878041
# Error on this batch = 0.4809506471020268
# Cost on val dataset after 8 epochs is = 0.480989740078366
# learning rate =  0.25
# Initial Cost on Val dataset for this epoch 8 = 0.480989740078366
# Error on this batch = 0.4809758660614535
# Error on this batch = 0.48090897313813585
# Cost on val dataset after 9 epochs is = 0.48094999006762706
# learning rate =  0.24037492838456806
# Initial Cost on Val dataset for this epoch 9 = 0.48094999006762706
# Error on this batch = 0.4809327054699667
# Error on this batch = 0.48088482013121825
# Cost on val dataset after 10 epochs is = 0.48092534556347033
# learning rate =  0.23207944168063893
# Initial Cost on Val dataset for this epoch 10 = 0.48092534556347033
# Error on this batch = 0.4809053988192362
# Error on this batch = 0.4808705033410125
# Cost on val dataset after 11 epochs is = 0.4809095792269845
# learning rate =  0.2248221565113046
# Initial Cost on Val dataset for this epoch 11 = 0.4809095792269845
# Error on this batch = 0.4808875033445855
# Error on this batch = 0.48086193549508305
# Cost on val dataset after 12 epochs is = 0.4808992420107993
# learning rate =  0.21839511618407473
# Initial Cost on Val dataset for this epoch 12 = 0.4808992420107993
# Error on this batch = 0.48087543179819237
# Error on this batch = 0.48085682818619474
# Cost on val dataset after 13 epochs is = 0.4808923305696511
# learning rate =  0.2126451851414951
# Initial Cost on Val dataset for this epoch 13 = 0.4808923305696511
# Error on this batch = 0.48086708762390656
# Error on this batch = 0.48085384818004046
# Cost on val dataset after 14 epochs is = 0.48088763610426166
# learning rate =  0.2074566333415609
# Initial Cost on Val dataset for this epoch 14 = 0.48088763610426166
# Error on this batch = 0.4808611965592926
# Error on this batch = 0.4808521940975834
# Cost on val dataset after 15 epochs is = 0.4808844061925521
# learning rate =  0.20274006651911336
# Initial Cost on Val dataset for this epoch 15 = 0.4808844061925521
# Error on this batch = 0.4808569586513836
# Error on this batch = 0.4808513722585447
# Cost on val dataset after 16 epochs is = 0.48088216024678154
# learning rate =  0.19842513149602492
# Initial Cost on Val dataset for this epoch 16 = 0.48088216024678154
# Error on this batch = 0.48085385783187806
# Error on this batch = 0.4808510726474162
# Cost on val dataset after 17 epochs is = 0.48088058458696
# learning rate =  0.19445555936641015
# Initial Cost on Val dataset for this epoch 17 = 0.48088058458696
# Error on this batch = 0.4808515533106269
# Error on this batch = 0.48085109773292145
# Cost on val dataset after 18 epochs is = 0.48087947068653114
# learning rate =  0.190785707092222
# Initial Cost on Val dataset for this epoch 18 = 0.48087947068653114
# Error on this batch = 0.48084981543282584
# Error on this batch = 0.4808513203515477
# Cost on val dataset after 19 epochs is = 0.4808786777421816
# learning rate =  0.18737808839215772
# Initial Cost on Val dataset for this epoch 19 = 0.4808786777421816
# Error on this batch = 0.48084848664845986
# Error on this batch = 0.48085165813579295
# Cost on val dataset after 20 epochs is = 0.4808781094049781
# learning rate =  0.18420157493201936
# Initial Cost on Val dataset for this epoch 20 = 0.4808781094049781
# Error on this batch = 0.4808474571408992
# Error on this batch = 0.48085205764310146
# Cost on val dataset after 21 epochs is = 0.48087769899317556
# learning rate =  0.1812300621671487
# Initial Cost on Val dataset for this epoch 21 = 0.48087769899317556
# Error on this batch = 0.4808466492612567
# Error on this batch = 0.4808524843193731
# Cost on val dataset after 22 epochs is = 0.48087739991219636
# learning rate =  0.17844146387590207
# Initial Cost on Val dataset for this epoch 22 = 0.48087739991219636
# Error on this batch = 0.4808460073866151
# Error on this batch = 0.48085291605007613
# Cost on val dataset after 23 epochs is = 0.480877179341761
# learning rate =  0.17581694345847967
# Initial Cost on Val dataset for this epoch 23 = 0.480877179341761
# Error on this batch = 0.48084549119379577
# Error on this batch = 0.4808533389601348
# Cost on val dataset after 24 epochs is = 0.48087701401280414
# learning rate =  0.1733403185876587
# Initial Cost on Val dataset for this epoch 24 = 0.48087701401280414
# Error on this batch = 0.4808450711267294
# Error on this batch = 0.48085374464723074
# Cost on val dataset after 25 epochs is = 0.48087688734422057
# learning rate =  0.1709975946676697
# Initial Cost on Val dataset for this epoch 25 = 0.48087688734422057
# Error on this batch = 0.48084472529771194
# Error on this batch = 0.4808541283422652
# Cost on val dataset after 26 epochs is = 0.4808767874781563
# learning rate =  0.16877659529479094
# Initial Cost on Val dataset for this epoch 26 = 0.4808767874781563
# Error on this batch = 0.48084443734097015
# Error on this batch = 0.4808544876772298
# Cost on val dataset after 27 epochs is = 0.48087670591729775
# learning rate =  0.16666666666666666
# Initial Cost on Val dataset for this epoch 27 = 0.48087670591729775
# Error on this batch = 0.4808441949078961
# Error on this batch = 0.4808548218554329
# Cost on val dataset after 28 epochs is = 0.4808766365705502
# cost initial= 0.48087670591729775 , cost final=0.4808766365705502 , change in cost= -6.934674756653436e-08
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 5 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 28.000
# The training time = 5.959sec
# The training accuracy is = 3.973%
# The validation accuracy is = 3.128%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 1 = 3.2604056951832394
# Error on this batch = 3.261099591361877
# Error on this batch = 0.4875822450148562
# Cost on val dataset after 2 epochs is = 0.48299178398291226
# learning rate =  0.39685026299204984
# Initial Cost on Val dataset for this epoch 2 = 0.48299178398291226
# Error on this batch = 0.483119927771045
# Error on this batch = 0.48146542738432396
# Cost on val dataset after 3 epochs is = 0.481395918971557
# learning rate =  0.3466806371753174
# Initial Cost on Val dataset for this epoch 3 = 0.481395918971557
# Error on this batch = 0.481397407880485
# Error on this batch = 0.4810055622453153
# Cost on val dataset after 4 epochs is = 0.4811275329988229
# learning rate =  0.3149802624737183
# Initial Cost on Val dataset for this epoch 4 = 0.4811275329988229
# Error on this batch = 0.4810880331950599
# Error on this batch = 0.4809160162970717
# Cost on val dataset after 5 epochs is = 0.48105100374902215
# learning rate =  0.2924017738212866
# Initial Cost on Val dataset for this epoch 5 = 0.48105100374902215
# Error on this batch = 0.4809913029012527
# Error on this batch = 0.48089405659478235
# Cost on val dataset after 6 epochs is = 0.4810226135187993
# learning rate =  0.27516060407455223
# Initial Cost on Val dataset for this epoch 6 = 0.4810226135187993
# Error on this batch = 0.48095118040303775
# Error on this batch = 0.480888802970072
# Cost on val dataset after 7 epochs is = 0.4810098686202732
# learning rate =  0.26137897928735515
# Initial Cost on Val dataset for this epoch 7 = 0.4810098686202732
# Error on this batch = 0.4809310563723406
# Error on this batch = 0.480888085759688
# Cost on val dataset after 8 epochs is = 0.4810030909616262
# learning rate =  0.25
# Initial Cost on Val dataset for this epoch 8 = 0.4810030909616262
# Error on this batch = 0.4809194422647386
# Error on this batch = 0.4808884916470469
# Cost on val dataset after 9 epochs is = 0.4809988708691594
# learning rate =  0.24037492838456806
# Initial Cost on Val dataset for this epoch 9 = 0.4809988708691594
# Error on this batch = 0.4809119902065524
# Error on this batch = 0.4808890152347637
# Cost on val dataset after 10 epochs is = 0.48099585811623025
# learning rate =  0.23207944168063893
# Initial Cost on Val dataset for this epoch 10 = 0.48099585811623025
# Error on this batch = 0.4809068095231064
# Error on this batch = 0.48088938373725704
# Cost on val dataset after 11 epochs is = 0.4809934681272819
# learning rate =  0.2248221565113046
# Initial Cost on Val dataset for this epoch 11 = 0.4809934681272819
# Error on this batch = 0.48090298126845155
# Error on this batch = 0.4808895540128479
# Cost on val dataset after 12 epochs is = 0.4809914286175415
# learning rate =  0.21839511618407473
# Initial Cost on Val dataset for this epoch 12 = 0.4809914286175415
# Error on this batch = 0.4809000157197821
# Error on this batch = 0.48088955037373526
# Cost on val dataset after 13 epochs is = 0.48098960443177097
# learning rate =  0.2126451851414951
# Initial Cost on Val dataset for this epoch 13 = 0.48098960443177097
# Error on this batch = 0.48089763117018197
# Error on this batch = 0.4808894111972082
# Cost on val dataset after 14 epochs is = 0.48098792445151156
# learning rate =  0.2074566333415609
# Initial Cost on Val dataset for this epoch 14 = 0.48098792445151156
# Error on this batch = 0.4808956550751245
# Error on this batch = 0.48088917221052685
# Cost on val dataset after 15 epochs is = 0.48098634909783233
# learning rate =  0.20274006651911336
# Initial Cost on Val dataset for this epoch 15 = 0.48098634909783233
# Error on this batch = 0.4808939762309419
# Error on this batch = 0.48088886233434497
# Cost on val dataset after 16 epochs is = 0.48098485508125716
# learning rate =  0.19842513149602492
# Initial Cost on Val dataset for this epoch 16 = 0.48098485508125716
# Error on this batch = 0.48089251996545657
# Error on this batch = 0.4808885036648773
# Cost on val dataset after 17 epochs is = 0.48098342789947857
# learning rate =  0.19445555936641015
# Initial Cost on Val dataset for this epoch 17 = 0.48098342789947857
# Error on this batch = 0.48089123444773224
# Error on this batch = 0.48088811261597414
# Cost on val dataset after 18 epochs is = 0.4809820579881151
# learning rate =  0.190785707092222
# Initial Cost on Val dataset for this epoch 18 = 0.4809820579881151
# Error on this batch = 0.4808900827147541
# Error on this batch = 0.48088770119757485
# Cost on val dataset after 19 epochs is = 0.4809807386692468
# learning rate =  0.18737808839215772
# Initial Cost on Val dataset for this epoch 19 = 0.4809807386692468
# Error on this batch = 0.4808890378067672
# Error on this batch = 0.4808872781179775
# Cost on val dataset after 20 epochs is = 0.48097946501938177
# learning rate =  0.18420157493201936
# Initial Cost on Val dataset for this epoch 20 = 0.48097946501938177
# Error on this batch = 0.4808880796797878
# Error on this batch = 0.4808868496502187
# Cost on val dataset after 21 epochs is = 0.4809782332243137
# learning rate =  0.1812300621671487
# Initial Cost on Val dataset for this epoch 21 = 0.4809782332243137
# Error on this batch = 0.48088719318000345
# Error on this batch = 0.480886420285201
# Cost on val dataset after 22 epochs is = 0.48097704020013476
# learning rate =  0.17844146387590207
# Initial Cost on Val dataset for this epoch 22 = 0.48097704020013476
# Error on this batch = 0.4808863666775247
# Error on this batch = 0.48088599321413805
# Cost on val dataset after 23 epochs is = 0.48097588336402974
# learning rate =  0.17581694345847967
# Initial Cost on Val dataset for this epoch 23 = 0.48097588336402974
# Error on this batch = 0.4808855911232841
# Error on this batch = 0.48088557068145604
# Cost on val dataset after 24 epochs is = 0.4809747604916407
# learning rate =  0.1733403185876587
# Initial Cost on Val dataset for this epoch 24 = 0.4809747604916407
# Error on this batch = 0.4808848593852292
# Error on this batch = 0.48088515424188744
# Cost on val dataset after 25 epochs is = 0.48097366962572086
# learning rate =  0.1709975946676697
# Initial Cost on Val dataset for this epoch 25 = 0.48097366962572086
# Error on this batch = 0.48088416577330423
# Error on this batch = 0.4808847449476073
# Cost on val dataset after 26 epochs is = 0.4809726090158864
# learning rate =  0.16877659529479094
# Initial Cost on Val dataset for this epoch 26 = 0.4809726090158864
# Error on this batch = 0.48088350569464683
# Error on this batch = 0.48088434348458226
# Cost on val dataset after 27 epochs is = 0.4809715770776424
# learning rate =  0.16666666666666666
# Initial Cost on Val dataset for this epoch 27 = 0.4809715770776424
# Error on this batch = 0.4808828754001597
# Error on this batch = 0.48088395027210895
# Cost on val dataset after 28 epochs is = 0.4809705723636136
# learning rate =  0.1646584390020874
# Initial Cost on Val dataset for this epoch 28 = 0.4809705723636136
# Error on this batch = 0.4808822717961583
# Error on this batch = 0.48088356553566036
# Cost on val dataset after 29 epochs is = 0.48096959354267116
# learning rate =  0.16274363236883382
# Initial Cost on Val dataset for this epoch 29 = 0.48096959354267116
# Error on this batch = 0.4808816923029655
# Error on this batch = 0.48088318936033103
# Cost on val dataset after 30 epochs is = 0.4809686393842795
# learning rate =  0.16091489743427165
# Initial Cost on Val dataset for this epoch 30 = 0.4809686393842795
# Error on this batch = 0.4808811347477618
# Error on this batch = 0.4808828217301459
# Cost on val dataset after 31 epochs is = 0.4809677087463772
# learning rate =  0.15916568392288669
# Initial Cost on Val dataset for this epoch 31 = 0.4809677087463772
# Error on this batch = 0.48088059728268434
# Error on this batch = 0.48088246255703054
# Cost on val dataset after 32 epochs is = 0.4809668005657076
# learning rate =  0.15749013123685915
# Initial Cost on Val dataset for this epoch 32 = 0.4809668005657076
# Error on this batch = 0.480880078321707
# Error on this batch = 0.48088211170219636
# Cost on val dataset after 33 epochs is = 0.4809659138498929
# learning rate =  0.155882976940936
# Initial Cost on Val dataset for this epoch 33 = 0.4809659138498929
# Error on this batch = 0.4808795764916112
# Error on this batch = 0.48088176899194035
# Cost on val dataset after 34 epochs is = 0.4809650476707835
# learning rate =  0.1543394797496521
# Initial Cost on Val dataset for this epoch 34 = 0.4809650476707835
# Error on this batch = 0.4808790905936086
# Error on this batch = 0.48088143422931795
# Cost on val dataset after 35 epochs is = 0.48096420115876815
# learning rate =  0.15285535436643993
# Initial Cost on Val dataset for this epoch 35 = 0.48096420115876815
# Error on this batch = 0.48087861957307826
# Error on this batch = 0.48088110720275945
# Cost on val dataset after 36 epochs is = 0.48096337349782514
# learning rate =  0.151426716069345
# Initial Cost on Val dataset for this epoch 36 = 0.48096337349782514
# Error on this batch = 0.4808781624955266
# Error on this batch = 0.4808807876924121
# Cost on val dataset after 37 epochs is = 0.48096256392116554
# learning rate =  0.15005003335928088
# Initial Cost on Val dataset for this epoch 37 = 0.48096256392116554
# Error on this batch = 0.480877718527355
# Error on this batch = 0.4808804754747902
# Cost on val dataset after 38 epochs is = 0.48096177170735516
# cost initial= 0.48096256392116554 , cost final=0.48096177170735516 , change in cost= -7.922138103855225e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 10 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 38.000
# The training time = 8.568sec
# The training accuracy is = 3.864%
# The validation accuracy is = 3.744%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 1 = 3.2484922605227444
# Error on this batch = 3.248418619994768
# Error on this batch = 0.48174041167323495
# Cost on val dataset after 2 epochs is = 0.48174922168863826
# learning rate =  0.39685026299204984
# Initial Cost on Val dataset for this epoch 2 = 0.48174922168863826
# Error on this batch = 0.48154505190530944
# Error on this batch = 0.4815030867968804
# Cost on val dataset after 3 epochs is = 0.4816626450861969
# learning rate =  0.3466806371753174
# Initial Cost on Val dataset for this epoch 3 = 0.4816626450861969
# Error on this batch = 0.4813544831744995
# Error on this batch = 0.48148000528623996
# Cost on val dataset after 4 epochs is = 0.4816303857965533
# learning rate =  0.3149802624737183
# Initial Cost on Val dataset for this epoch 4 = 0.4816303857965533
# Error on this batch = 0.48129936156981845
# Error on this batch = 0.4814595346452293
# Cost on val dataset after 5 epochs is = 0.48160515693022027
# learning rate =  0.2924017738212866
# Initial Cost on Val dataset for this epoch 5 = 0.48160515693022027
# Error on this batch = 0.4812696946564134
# Error on this batch = 0.4814399160791899
# Cost on val dataset after 6 epochs is = 0.4815820885481765
# learning rate =  0.27516060407455223
# Initial Cost on Val dataset for this epoch 6 = 0.4815820885481765
# Error on this batch = 0.4812478959094038
# Error on this batch = 0.48142053772415244
# Cost on val dataset after 7 epochs is = 0.48155985106210025
# learning rate =  0.26137897928735515
# Initial Cost on Val dataset for this epoch 7 = 0.48155985106210025
# Error on this batch = 0.48122898198201264
# Error on this batch = 0.4814010724870377
# Cost on val dataset after 8 epochs is = 0.48153785974009344
# learning rate =  0.25
# Initial Cost on Val dataset for this epoch 8 = 0.48153785974009344
# Error on this batch = 0.4812111075790743
# Error on this batch = 0.4813812922960702
# Cost on val dataset after 9 epochs is = 0.4815157688509421
# learning rate =  0.24037492838456806
# Initial Cost on Val dataset for this epoch 9 = 0.4815157688509421
# Error on this batch = 0.4811934310938044
# Error on this batch = 0.48136100907090157
# Cost on val dataset after 10 epochs is = 0.48149333163771985
# learning rate =  0.23207944168063893
# Initial Cost on Val dataset for this epoch 10 = 0.48149333163771985
# Error on this batch = 0.4811754898408994
# Error on this batch = 0.48134005428813953
# Cost on val dataset after 11 epochs is = 0.48147034889299734
# learning rate =  0.2248221565113046
# Initial Cost on Val dataset for this epoch 11 = 0.48147034889299734
# Error on this batch = 0.4811569825345399
# Error on this batch = 0.48131826933234223
# Cost on val dataset after 12 epochs is = 0.4814466457636386
# learning rate =  0.21839511618407473
# Initial Cost on Val dataset for this epoch 12 = 0.4814466457636386
# Error on this batch = 0.48113768242196314
# Error on this batch = 0.4812954994789078
# Cost on val dataset after 13 epochs is = 0.48142205952983586
# learning rate =  0.2126451851414951
# Initial Cost on Val dataset for this epoch 13 = 0.48142205952983586
# Error on this batch = 0.481117398280171
# Error on this batch = 0.48127158954816185
# Cost on val dataset after 14 epochs is = 0.4813964323092471
# learning rate =  0.2074566333415609
# Initial Cost on Val dataset for this epoch 14 = 0.4813964323092471
# Error on this batch = 0.4810959549377759
# Error on this batch = 0.48124638051436414
# Cost on val dataset after 15 epochs is = 0.48136960620711455
# learning rate =  0.20274006651911336
# Initial Cost on Val dataset for this epoch 15 = 0.48136960620711455
# Error on this batch = 0.4810731824960907
# Error on this batch = 0.48121970669783265
# ...
# Cost on val dataset after 5227 epochs is = 0.07631975922039838
# learning rate =  0.028810613364364402
# Initial Cost on Val dataset for this epoch 5227 = 0.07631975922039838
# Error on this batch = 0.020095492026139358
# Error on this batch = 0.02269150348478854
# Cost on val dataset after 5228 epochs is = 0.07631874195368504
# learning rate =  0.02880877630427115
# Initial Cost on Val dataset for this epoch 5228 = 0.07631874195368504
# Error on this batch = 0.020092737871453964
# Error on this batch = 0.022689034946474906
# Cost on val dataset after 5229 epochs is = 0.07631772504207021
# learning rate =  0.02880693971263642
# Initial Cost on Val dataset for this epoch 5229 = 0.07631772504207021
# Error on this batch = 0.02008998501405752
# Error on this batch = 0.022686567620827842
# Cost on val dataset after 5230 epochs is = 0.07631670848523688
# learning rate =  0.028805103589251202
# Initial Cost on Val dataset for this epoch 5230 = 0.07631670848523688
# Error on this batch = 0.02008723345372487
# Error on this batch = 0.022684101506012563
# Cost on val dataset after 5231 epochs is = 0.07631569228286841
# learning rate =  0.02880326793390662
# Initial Cost on Val dataset for this epoch 5231 = 0.07631569228286841
# Error on this batch = 0.020084483190236688
# Error on this batch = 0.022681636600192352
# Cost on val dataset after 5232 epochs is = 0.07631467643464894
# learning rate =  0.02880143274639392
# Initial Cost on Val dataset for this epoch 5232 = 0.07631467643464894
# Error on this batch = 0.020081734223379506
# Error on this batch = 0.022679172901528495
# Cost on val dataset after 5233 epochs is = 0.07631366094026303
# learning rate =  0.02879959802650449
# Initial Cost on Val dataset for this epoch 5233 = 0.07631366094026303
# Error on this batch = 0.020078986552945623
# Error on this batch = 0.022676710408180298
# Cost on val dataset after 5234 epochs is = 0.0763126457993958
# learning rate =  0.02879776377402984
# Initial Cost on Val dataset for this epoch 5234 = 0.0763126457993958
# Error on this batch = 0.02007624017873318
# Error on this batch = 0.022674249118305116
# Cost on val dataset after 5235 epochs is = 0.076311631011733
# learning rate =  0.02879592998876164
# Initial Cost on Val dataset for this epoch 5235 = 0.076311631011733
# Error on this batch = 0.02007349510054611
# Error on this batch = 0.02267178903005832
# Cost on val dataset after 5236 epochs is = 0.07631061657696085
# learning rate =  0.028794096670491657
# Initial Cost on Val dataset for this epoch 5236 = 0.07631061657696085
# Error on this batch = 0.020070751318194153
# Error on this batch = 0.022669330141593395
# Cost on val dataset after 5237 epochs is = 0.07630960249476615
# learning rate =  0.02879226381901182
# Initial Cost on Val dataset for this epoch 5237 = 0.07630960249476615
# Error on this batch = 0.02006800883149275
# Error on this batch = 0.02266687245106185
# Cost on val dataset after 5238 epochs is = 0.07630858876483618
# learning rate =  0.02879043143411417
# Initial Cost on Val dataset for this epoch 5238 = 0.07630858876483618
# Error on this batch = 0.02006526764026316
# Error on this batch = 0.02266441595661328
# Cost on val dataset after 5239 epochs is = 0.0763075753868588
# learning rate =  0.028788599515590894
# Initial Cost on Val dataset for this epoch 5239 = 0.0763075753868588
# Error on this batch = 0.020062527744332335
# Error on this batch = 0.022661960656395357
# Cost on val dataset after 5240 epochs is = 0.07630656236052237
# learning rate =  0.0287867680632343
# Initial Cost on Val dataset for this epoch 5240 = 0.07630656236052237
# Error on this batch = 0.02005978914353298
# Error on this batch = 0.02265950654855382
# Cost on val dataset after 5241 epochs is = 0.07630554968551577
# learning rate =  0.028784937076836836
# Initial Cost on Val dataset for this epoch 5241 = 0.07630554968551577
# Error on this batch = 0.0200570518377035
# Error on this batch = 0.022657053631232535
# Cost on val dataset after 5242 epochs is = 0.07630453736152838
# learning rate =  0.02878310655619109
# Initial Cost on Val dataset for this epoch 5242 = 0.07630453736152838
# Error on this batch = 0.020054315826687995
# Error on this batch = 0.0226546019025735
# Cost on val dataset after 5243 epochs is = 0.07630352538825015
# learning rate =  0.028781276501089754
# Initial Cost on Val dataset for this epoch 5243 = 0.07630352538825015
# Error on this batch = 0.02005158111033629
# Error on this batch = 0.02265215136071677
# Cost on val dataset after 5244 epochs is = 0.07630251376537145
# learning rate =  0.028779446911325682
# Initial Cost on Val dataset for this epoch 5244 = 0.07630251376537145
# Error on this batch = 0.02004884768850384
# Error on this batch = 0.022649702003800565
# Cost on val dataset after 5245 epochs is = 0.07630150249258318
# learning rate =  0.028777617786691842
# Initial Cost on Val dataset for this epoch 5245 = 0.07630150249258318
# Error on this batch = 0.02004611556105177
# Error on this batch = 0.022647253829961207
# Cost on val dataset after 5246 epochs is = 0.07630049156957676
# learning rate =  0.028775789126981338
# Initial Cost on Val dataset for this epoch 5246 = 0.07630049156957676
# Error on this batch = 0.020043384727846832
# Error on this batch = 0.0226448068373332
# Cost on val dataset after 5247 epochs is = 0.0762994809960441
# learning rate =  0.028773960931987412
# Initial Cost on Val dataset for this epoch 5247 = 0.0762994809960441
# Error on this batch = 0.02004065518876146
# Error on this batch = 0.022642361024049165
# Cost on val dataset after 5248 epochs is = 0.07629847077167755
# learning rate =  0.028772133201503427
# Initial Cost on Val dataset for this epoch 5248 = 0.07629847077167755
# Error on this batch = 0.020037926943673633
# Error on this batch = 0.02263991638823992
# Cost on val dataset after 5249 epochs is = 0.07629746089617
# learning rate =  0.028770305935322885
# Initial Cost on Val dataset for this epoch 5249 = 0.07629746089617
# Error on this batch = 0.02003519999246699
# Error on this batch = 0.022637472928034405
# Cost on val dataset after 5250 epochs is = 0.07629645136921477
# learning rate =  0.02876847913323941
# Initial Cost on Val dataset for this epoch 5250 = 0.07629645136921477
# Error on this batch = 0.0200324743350307
# Error on this batch = 0.022635030641559785
# Cost on val dataset after 5251 epochs is = 0.0762954421905057
# learning rate =  0.02876665279504676
# Initial Cost on Val dataset for this epoch 5251 = 0.0762954421905057
# Error on this batch = 0.02002974997125957
# Error on this batch = 0.022632589526941353
# Cost on val dataset after 5252 epochs is = 0.07629443335973705
# learning rate =  0.028764826920538836
# Initial Cost on Val dataset for this epoch 5252 = 0.07629443335973705
# Error on this batch = 0.020027026901053912
# Error on this batch = 0.022630149582302677
# Cost on val dataset after 5253 epochs is = 0.07629342487660358
# learning rate =  0.028763001509509663
# Initial Cost on Val dataset for this epoch 5253 = 0.07629342487660358
# Error on this batch = 0.020024305124319592
# Error on this batch = 0.02262771080576547
# Cost on val dataset after 5254 epochs is = 0.07629241674080046
# learning rate =  0.028761176561753386
# Initial Cost on Val dataset for this epoch 5254 = 0.07629241674080046
# Error on this batch = 0.02002158464096804
# Error on this batch = 0.022625273195449686
# Cost on val dataset after 5255 epochs is = 0.07629140895202342
# learning rate =  0.028759352077064287
# Initial Cost on Val dataset for this epoch 5255 = 0.07629140895202342
# Error on this batch = 0.02001886545091615
# Error on this batch = 0.02262283674947352
# Cost on val dataset after 5256 epochs is = 0.07629040150996852
# learning rate =  0.02875752805523679
# Initial Cost on Val dataset for this epoch 5256 = 0.07629040150996852
# Error on this batch = 0.02001614755408634
# Error on this batch = 0.022620401465953358
# Cost on val dataset after 5257 epochs is = 0.07628939441433236
# learning rate =  0.02875570449606543
# Initial Cost on Val dataset for this epoch 5257 = 0.07628939441433236
# Error on this batch = 0.020013430950406516
# Error on this batch = 0.02261796734300387
# Cost on val dataset after 5258 epochs is = 0.07628838766481193
# learning rate =  0.028753881399344886
# Initial Cost on Val dataset for this epoch 5258 = 0.07628838766481193
# Error on this batch = 0.02001071563981003
# Error on this batch = 0.022615534378737957
# Cost on val dataset after 5259 epochs is = 0.07628738126110467
# learning rate =  0.028752058764869966
# Initial Cost on Val dataset for this epoch 5259 = 0.07628738126110467
# Error on this batch = 0.02000800162223574
# Error on this batch = 0.02261310257126679
# Cost on val dataset after 5260 epochs is = 0.07628637520290847
# learning rate =  0.028750236592435603
# Initial Cost on Val dataset for this epoch 5260 = 0.07628637520290847
# Error on this batch = 0.020005288897627854
# Error on this batch = 0.02261067191869982
# Cost on val dataset after 5261 epochs is = 0.07628536948992166
# learning rate =  0.028748414881836853
# Initial Cost on Val dataset for this epoch 5261 = 0.07628536948992166
# Error on this batch = 0.020002577465936085
# Error on this batch = 0.022608242419144768
# Cost on val dataset after 5262 epochs is = 0.07628436412184297
# learning rate =  0.02874659363286892
# Initial Cost on Val dataset for this epoch 5262 = 0.07628436412184297
# Error on this batch = 0.019999867327115547
# Error on this batch = 0.022605814070707667
# Cost on val dataset after 5263 epochs is = 0.07628335909837156
# learning rate =  0.028744772845327136
# Initial Cost on Val dataset for this epoch 5263 = 0.07628335909837156
# Error on this batch = 0.019997158481126695
# Error on this batch = 0.022603386871492822
# Cost on val dataset after 5264 epochs is = 0.07628235441920704
# learning rate =  0.02874295251900694
# Initial Cost on Val dataset for this epoch 5264 = 0.07628235441920704
# Error on this batch = 0.01999445092793539
# Error on this batch = 0.022600960819602906
# Cost on val dataset after 5265 epochs is = 0.07628135008404942
# learning rate =  0.028741132653703927
# Initial Cost on Val dataset for this epoch 5265 = 0.07628135008404942
# Error on this batch = 0.019991744667512853
# Error on this batch = 0.022598535913138828
# Cost on val dataset after 5266 epochs is = 0.07628034609259905
# learning rate =  0.0287393132492138
# Initial Cost on Val dataset for this epoch 5266 = 0.07628034609259905
# Error on this batch = 0.01998903969983567
# Error on this batch = 0.022596112150199917
# Cost on val dataset after 5267 epochs is = 0.07627934244455677
# learning rate =  0.02873749430533241
# Initial Cost on Val dataset for this epoch 5267 = 0.07627934244455677
# Error on this batch = 0.019986336024885726
# Error on this batch = 0.022593689528883784
# Cost on val dataset after 5268 epochs is = 0.07627833913962387
# learning rate =  0.028735675821855728
# Initial Cost on Val dataset for this epoch 5268 = 0.07627833913962387
# Error on this batch = 0.019983633642650236
# Error on this batch = 0.022591268047286412
# Cost on val dataset after 5269 epochs is = 0.07627733617750192
# learning rate =  0.02873385779857985
# Initial Cost on Val dataset for this epoch 5269 = 0.07627733617750192
# Error on this batch = 0.019980932553121694
# Error on this batch = 0.022588847703502165
# Cost on val dataset after 5270 epochs is = 0.07627633355789294
# learning rate =  0.028732040235301008
# Initial Cost on Val dataset for this epoch 5270 = 0.07627633355789294
# Error on this batch = 0.019978232756297936
# Error on this batch = 0.022586428495623742
# Cost on val dataset after 5271 epochs is = 0.07627533128049939
# learning rate =  0.028730223131815558
# Initial Cost on Val dataset for this epoch 5271 = 0.07627533128049939
# Error on this batch = 0.019975534252181987
# Error on this batch = 0.02258401042174226
# Cost on val dataset after 5272 epochs is = 0.07627432934502404
# learning rate =  0.02872840648791999
# Initial Cost on Val dataset for this epoch 5272 = 0.07627432934502404
# Error on this batch = 0.019972837040782166
# Error on this batch = 0.0225815934799472
# Cost on val dataset after 5273 epochs is = 0.07627332775117007
# learning rate =  0.02872659030341092
# Initial Cost on Val dataset for this epoch 5273 = 0.07627332775117007
# Error on this batch = 0.01997014112211201
# Error on this batch = 0.02257917766832649
# Cost on val dataset after 5274 epochs is = 0.07627232649864112
# learning rate =  0.028724774578085092
# Initial Cost on Val dataset for this epoch 5274 = 0.07627232649864112
# Error on this batch = 0.0199674464961903
# Error on this batch = 0.02257676298496642
# Cost on val dataset after 5275 epochs is = 0.07627132558714103
# learning rate =  0.02872295931173938
# Initial Cost on Val dataset for this epoch 5275 = 0.07627132558714103
# Error on this batch = 0.019964753163040982
# Error on this batch = 0.022574349427951713
# Cost on val dataset after 5276 epochs is = 0.07627032501637425
# learning rate =  0.028721144504170782
# Initial Cost on Val dataset for this epoch 5276 = 0.07627032501637425
# Error on this batch = 0.019962061122693178
# Error on this batch = 0.02257193699536555
# Cost on val dataset after 5277 epochs is = 0.07626932478604534
# learning rate =  0.02871933015517643
# Initial Cost on Val dataset for this epoch 5277 = 0.07626932478604534
# Error on this batch = 0.01995937037518123
# Error on this batch = 0.02256952568528953
# Cost on val dataset after 5278 epochs is = 0.0762683248958595
# learning rate =  0.028717516264553582
# Initial Cost on Val dataset for this epoch 5278 = 0.0762683248958595
# Error on this batch = 0.019956680920544596
# Error on this batch = 0.022567115495803747
# Cost on val dataset after 5279 epochs is = 0.07626732534552207
# learning rate =  0.02871570283209962
# Initial Cost on Val dataset for this epoch 5279 = 0.07626732534552207
# Error on this batch = 0.01995399275882787
# Error on this batch = 0.02256470642498673
# Cost on val dataset after 5280 epochs is = 0.07626632613473884
# learning rate =  0.02871388985761207
# Initial Cost on Val dataset for this epoch 5280 = 0.07626632613473884
# Error on this batch = 0.019951305890080744
# Error on this batch = 0.022562298470915464
# Cost on val dataset after 5281 epochs is = 0.07626532726321598
# learning rate =  0.028712077340888553
# Initial Cost on Val dataset for this epoch 5281 = 0.07626532726321598
# Error on this batch = 0.019948620314358047
# Error on this batch = 0.022559891631665475
# Cost on val dataset after 5282 epochs is = 0.07626432873065997
# learning rate =  0.028710265281726856
# Initial Cost on Val dataset for this epoch 5282 = 0.07626432873065997
# Error on this batch = 0.019945936031719676
# Error on this batch = 0.022557485905310735
# Cost on val dataset after 5283 epochs is = 0.07626333053677768
# learning rate =  0.028708453679924868
# Initial Cost on Val dataset for this epoch 5283 = 0.07626333053677768
# Error on this batch = 0.019943253042230605
# Error on this batch = 0.022555081289923746
# Cost on val dataset after 5284 epochs is = 0.07626233268127626
# learning rate =  0.02870664253528061
# Initial Cost on Val dataset for this epoch 5284 = 0.07626233268127626
# Error on this batch = 0.019940571345960827
# Error on this batch = 0.02255267778357557
# Cost on val dataset after 5285 epochs is = 0.07626133516386323
# learning rate =  0.028704831847592236
# Initial Cost on Val dataset for this epoch 5285 = 0.07626133516386323
# Error on this batch = 0.019937890942985363
# Error on this batch = 0.0225502753843357
# Cost on val dataset after 5286 epochs is = 0.07626033798424653
# learning rate =  0.028703021616658032
# Initial Cost on Val dataset for this epoch 5286 = 0.07626033798424653
# Error on this batch = 0.01993521183338429
# Error on this batch = 0.022547874090272257
# Cost on val dataset after 5287 epochs is = 0.07625934114213431
# cost initial= 0.07626033798424653 , cost final=0.07625934114213431 , change in cost= -9.968421122164006e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 100 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 5287.000
# The training time = 1130.154sec
# The training accuracy is = 96.670%
# The validation accuracy is = 91.641%
# The test accuracy is = 90.323%
# ------------------------------------------------------------------------------

# %%
train_accuracy
# Out:
# [3.9728506787330318,
#  3.9728506787330318,
#  3.9728506787330318,
#  96.24434389140272,
#  97.30316742081449]

# %%
epochs
# Out:
# [44, 17, 42, 1810, 2298]

# %%
train_time
# Out:
# [2.2222840785980225,
#  1.0398175716400146,
#  2.9016783237457275,
#  296.58650255203247,
#  646.5434665679932]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Train Loss with Epochs with ReLU")
x = np.arange(0,len(costs[1:300]))
ax.plot(x, costs[1:300], marker='o', label='Train Loss')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Train Loss")

plt.legend()
#plt.savefig("relu_trainloss.png", dpi=1000, bbox_inches='tight')
plt.show()
