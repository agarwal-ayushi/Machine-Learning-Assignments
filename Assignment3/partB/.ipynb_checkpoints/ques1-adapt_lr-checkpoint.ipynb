# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)
np.random.shuffle(X_train.to_numpy())
train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

X_train = X_train/255
X_test = X_test/255

m = X_train.shape[0] # Number of Training Samples

X_valid = X_train.iloc[(int(0.85*m)):]
valid_class = train_class[(int(0.85*m)):]
X_train = X_train.iloc[0:int(0.85*m)]
train_class = train_class[0:int(0.85*m)]


m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The total number of validation samples = {}".format(X_valid.shape[0]))

print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# The total number of training samples = 11050
# The total number of validation samples = 1950
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
valid_class_enc = pd.get_dummies(valid_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
# Out:
# --------Perform 1-hot encoding of class labels------------

# %%
#Add the intercept term to the data samples both in training and test dataset
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_valid = np.hstack((np.ones((X_valid.shape[0],1)), X_valid.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))

# %%
lr = 0.1
arch_test = [1,5,10,50,100]
arch = [arch_test[3]] #means one hidden layer with 2 perceptrons 
batch_size = 100 # Mini-Batch Size
r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
#Mini-Batch formation
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# The number of mini-batches formed is = 111

# %%
#Theta Initialization 
def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]

        theta.append(np.random.normal(0,0.01, (dim0,dim1)))
        #theta.append(2*np.random.random((dim0, dim1))-1)
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
def activation(x):
    return 1/(1+np.exp(-x))

# %%
def forward_prop(data, theta):
    fm = []
    fm.append(data)
    for l in range(len(theta)):
        fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
def cost_total(X, theta, Y, m):
    fm = forward_prop(X, theta)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    #print("The Test Accuracy of the model = {}%".format(test_acc*100))
    return (test_acc*100)

# %%
epochs = []
train_accuracy = []
test_accuracy = []
valid_accuracy=[]
train_time = []
costs=[]

# %%
arch_test = [1, 5, 10, 50, 100]
#arch_test = [100]

# %%
arch_test=[50]

# %%
lr0=0.5
for i in range(len(arch_test)):
    theta = theta_init([arch_test[i]])
    fm = forward_prop(X_train, theta)
    epoch = 1
    early_stop = 0
    start = time.time()
    cost_init = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])
    costs.append(cost_init)
    
    while(True):
        count = 0
        lr = lr0/(np.power(epoch, 1/2))
        print("learning rate = ", lr)

        print("Initial Cost on Val dataset for this epoch {} = {}".format(epoch, cost_init))

        for b in mini_batch:
            X_b = b[0]
            Y_b = b[1]
            fm = forward_prop(X_b, theta)
            delta = [None]*len(fm)

            if (count % 60 == 0):
                print("Error on this batch = "+str(cost_total(X_b, theta, Y_b, batch_size)))
            #Backward Propagation

            for l in range(len(fm)-1, 0, -1):
                if (l == len(fm)-1):
                    delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
                else:
                    delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))

            for t in range(len(theta)):
                theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

            count+=1
        epoch+=1 #Number of epochs
        
        cost_final = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])
        if(epoch%10==0): costs.append(cost_final)
        print("Cost on val dataset after {} epochs is = {}".format(epoch, cost_final))
        
        if (abs(cost_final-cost_init) < 1e-06):
            early_stop +=1
        else:
            early_stop=0
        if (early_stop == 5):
            print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
            break

        cost_init = cost_final
    
    epochs.append(epoch)
    train_time.append(time.time()-start)
    train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
    valid_accuracy.append(calc_accuracy(X_valid, theta, valid_class_enc))
    test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
    print("\n------------------------------------------------------------------------------")
    print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
    print("------------------------------------------------------------------------------")
    print("The number of epochs = {:2.3f}".format(epochs[-1]))
    print("The training time = {:2.3f}sec".format(train_time[-1]))
    print("The training accuracy is = {:2.3f}%".format(train_accuracy[-1]))
    print("The validation accuracy is = {:2.3f}%".format(valid_accuracy[-1]))
    print("The test accuracy is = {:2.3f}%".format(test_accuracy[-1]))
    print("------------------------------------------------------------------------------\n")
# Out:
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 1 = 3.2686062405828964
# Error on this batch = 3.269225489109819
# Error on this batch = 0.4821951052988973
# Cost on val dataset after 2 epochs is = 0.4817456808872023
# learning rate =  0.35355339059327373
# Initial Cost on Val dataset for this epoch 2 = 0.4817456808872023
# Error on this batch = 0.4819658349052505
# Error on this batch = 0.48153289779063835
# Cost on val dataset after 3 epochs is = 0.4816949698086296
# learning rate =  0.2886751345948129
# Initial Cost on Val dataset for this epoch 3 = 0.4816949698086296
# Error on this batch = 0.4817876994362447
# Error on this batch = 0.48145544470021334
# Cost on val dataset after 4 epochs is = 0.4816734248288804
# learning rate =  0.25
# Initial Cost on Val dataset for this epoch 4 = 0.4816734248288804
# Error on this batch = 0.4817221280752247
# Error on this batch = 0.48142069936772475
# Cost on val dataset after 5 epochs is = 0.48165516585220997
# learning rate =  0.22360679774997896
# Initial Cost on Val dataset for this epoch 5 = 0.48165516585220997
# Error on this batch = 0.4816819550306148
# Error on this batch = 0.48139750492491856
# Cost on val dataset after 6 epochs is = 0.48163847224310624
# learning rate =  0.20412414523193154
# Initial Cost on Val dataset for this epoch 6 = 0.48163847224310624
# Error on this batch = 0.4816519720398715
# Error on this batch = 0.48137888495319786
# Cost on val dataset after 7 epochs is = 0.48162279961360727
# learning rate =  0.1889822365046136
# Initial Cost on Val dataset for this epoch 7 = 0.48162279961360727
# Error on this batch = 0.48162720705453915
# Error on this batch = 0.48136255160798713
# Cost on val dataset after 8 epochs is = 0.48160784244571797
# learning rate =  0.17677669529663687
# Initial Cost on Val dataset for this epoch 8 = 0.48160784244571797
# Error on this batch = 0.4816055303201732
# Error on this batch = 0.48134753915774214
# Cost on val dataset after 9 epochs is = 0.48159339814397906
# learning rate =  0.16666666666666666
# Initial Cost on Val dataset for this epoch 9 = 0.48159339814397906
# Error on this batch = 0.48158585651274427
# Error on this batch = 0.4813333531294509
# Cost on val dataset after 10 epochs is = 0.48157932223683014
# learning rate =  0.15811388300841897
# Initial Cost on Val dataset for this epoch 10 = 0.48157932223683014
# Error on this batch = 0.4815675600004491
# Error on this batch = 0.4813197012503674
# Cost on val dataset after 11 epochs is = 0.4815655067142307
# learning rate =  0.15075567228888181
# Initial Cost on Val dataset for this epoch 11 = 0.4815655067142307
# Error on this batch = 0.4815502459304695
# Error on this batch = 0.4813063920452345
# Cost on val dataset after 12 epochs is = 0.4815518677913213
# learning rate =  0.14433756729740646
# Initial Cost on Val dataset for this epoch 12 = 0.4815518677913213
# Error on this batch = 0.4815336474360124
# Error on this batch = 0.48129329051439174
# Cost on val dataset after 13 epochs is = 0.4815383384361517
# learning rate =  0.1386750490563073
# Initial Cost on Val dataset for this epoch 13 = 0.4815383384361517
# Error on this batch = 0.4815175742817768
# Error on this batch = 0.48128029618890383
# Cost on val dataset after 14 epochs is = 0.4815248635677243
# learning rate =  0.1336306209562122
# Initial Cost on Val dataset for this epoch 14 = 0.4815248635677243
# Error on this batch = 0.4815018849422347
# Error on this batch = 0.4812673311035669
# Cost on val dataset after 15 epochs is = 0.4815113968467075
# learning rate =  0.12909944487358055
# Initial Cost on Val dataset for this epoch 15 = 0.4815113968467075
# Error on this batch = 0.4814864703525693
# Error on this batch = 0.4812543326556836
# Cost on val dataset after 16 epochs is = 0.4814978984598681
# learning rate =  0.125
# Initial Cost on Val dataset for this epoch 16 = 0.4814978984598681
# Error on this batch = 0.48147124391532575
# Error on this batch = 0.4812412490934561
# Cost on val dataset after 17 epochs is = 0.48148433354744713
# learning rate =  0.12126781251816648
# Initial Cost on Val dataset for this epoch 17 = 0.48148433354744713
# Error on this batch = 0.4814561350684653
# Error on this batch = 0.48122803652551377
# Cost on val dataset after 18 epochs is = 0.48147067105950203
# learning rate =  0.11785113019775793
# Initial Cost on Val dataset for this epoch 18 = 0.48147067105950203
# Error on this batch = 0.481441084985637
# Error on this batch = 0.48121465686257525
# Cost on val dataset after 19 epochs is = 0.48145688290617644
# learning rate =  0.11470786693528087
# Initial Cost on Val dataset for this epoch 19 = 0.48145688290617644
# Error on this batch = 0.48142604360821667
# Error on this batch = 0.4812010763570716
# Cost on val dataset after 20 epochs is = 0.4814429433141311
# learning rate =  0.11180339887498948
# Initial Cost on Val dataset for this epoch 20 = 0.4814429433141311
# Error on this batch = 0.48141096753960627
# Error on this batch = 0.48118726454063854
# Cost on val dataset after 21 epochs is = 0.4814288283305943
# learning rate =  0.1091089451179962
# Initial Cost on Val dataset for this epoch 21 = 0.4814288283305943
# Error on this batch = 0.48139581851526986
# Error on this batch = 0.48117319343427983
# Cost on val dataset after 22 epochs is = 0.4814145154350732
# learning rate =  0.10660035817780521
# Initial Cost on Val dataset for this epoch 22 = 0.4814145154350732
# Error on this batch = 0.4813805622675744
# Error on this batch = 0.48115883694999584
# Cost on val dataset after 23 epochs is = 0.48139998323088073
# learning rate =  0.10425720702853739
# Initial Cost on Val dataset for this epoch 23 = 0.48139998323088073
# Error on this batch = 0.4813651676677308
# Error on this batch = 0.4811441704296211
# Cost on val dataset after 24 epochs is = 0.48138521119671457
# learning rate =  0.10206207261596577
# Initial Cost on Val dataset for this epoch 24 = 0.48138521119671457
# Error on this batch = 0.48134960606623567
# Error on this batch = 0.4811291702837076
# Cost on val dataset after 25 epochs is = 0.48137017948401617
# learning rate =  0.1
# Initial Cost on Val dataset for this epoch 25 = 0.48137017948401617
# Error on this batch = 0.48133385077811064
# Error on this batch = 0.4811138137044563
# Cost on val dataset after 26 epochs is = 0.48135486874965
# learning rate =  0.09805806756909202
# Initial Cost on Val dataset for this epoch 26 = 0.48135486874965
# Error on this batch = 0.4813178766754817
# Error on this batch = 0.48109807843417957
# Cost on val dataset after 27 epochs is = 0.4813392600161324
# learning rate =  0.09622504486493763
# Initial Cost on Val dataset for this epoch 27 = 0.4813392600161324
# Error on this batch = 0.4813016598608911
# Error on this batch = 0.4810819425758838
# Cost on val dataset after 28 epochs is = 0.4813233345535536
# learning rate =  0.0944911182523068
# Initial Cost on Val dataset for this epoch 28 = 0.4813233345535536
# Error on this batch = 0.48128517740212723
# Error on this batch = 0.4810653844361304
# Cost on val dataset after 29 epochs is = 0.4813070737787435
# learning rate =  0.09284766908852593
# Initial Cost on Val dataset for this epoch 29 = 0.4813070737787435
# Error on this batch = 0.4812684071144901
# Error on this batch = 0.4810483823928511
# Cost on val dataset after 30 epochs is = 0.48129045916824953
# learning rate =  0.09128709291752768
# Initial Cost on Val dataset for this epoch 30 = 0.48129045916824953
# Error on this batch = 0.4812513273800243
# Error on this batch = 0.48103091478260623
# Cost on val dataset after 31 epochs is = 0.4812734721824663
# learning rate =  0.08980265101338746
# Initial Cost on Val dataset for this epoch 31 = 0.4812734721824663
# Error on this batch = 0.48123391699584966
# Error on this batch = 0.4810129598030949
# Cost on val dataset after 32 epochs is = 0.48125609419882737
# learning rate =  0.08838834764831843
# Initial Cost on Val dataset for this epoch 32 = 0.48125609419882737
# Error on this batch = 0.4812161550455988
# Error on this batch = 0.48099449542769473
# Cost on val dataset after 33 epochs is = 0.4812383064524116
# learning rate =  0.08703882797784893
# Initial Cost on Val dataset for this epoch 33 = 0.4812383064524116
# Error on this batch = 0.4811980207893586
# Error on this batch = 0.4809754993295323
# Cost on val dataset after 34 epochs is = 0.4812200899826507
# learning rate =  0.08574929257125441
# Initial Cost on Val dataset for this epoch 34 = 0.4812200899826507
# Error on this batch = 0.48117949356853945
# Error on this batch = 0.4809559488131315
# Cost on val dataset after 35 epochs is = 0.4812014255850857
# learning rate =  0.08451542547285165
# Initial Cost on Val dataset for this epoch 35 = 0.4812014255850857
# Error on this batch = 0.4811605527228756
# Error on this batch = 0.48093582075209634
# Cost on val dataset after 36 epochs is = 0.48118229376732236
# learning rate =  0.08333333333333333
# Initial Cost on Val dataset for this epoch 36 = 0.48118229376732236
# Error on this batch = 0.481141177517346
# Error on this batch = 0.4809150915316034
# Cost on val dataset after 37 epochs is = 0.4811626747084974
# learning rate =  0.08219949365267865
# Initial Cost on Val dataset for this epoch 37 = 0.4811626747084974
# Error on this batch = 0.48112134707725646
# Error on this batch = 0.4808937369947233
# Cost on val dataset after 38 epochs is = 0.48114254822169444
# learning rate =  0.08111071056538127
# Initial Cost on Val dataset for this epoch 38 = 0.48114254822169444
# Error on this batch = 0.4811010403300756
# Error on this batch = 0.48087173239177916
# Cost on val dataset after 39 epochs is = 0.4811218937188444
# learning rate =  0.08006407690254357
# Initial Cost on Val dataset for this epoch 39 = 0.4811218937188444
# Error on this batch = 0.48108023595288435
# Error on this batch = 0.480849052332099
# Cost on val dataset after 40 epochs is = 0.48110069017773416
# learning rate =  0.07905694150420949
# Initial Cost on Val dataset for this epoch 40 = 0.48110069017773416
# Error on this batch = 0.4810589123245172
# Error on this batch = 0.4808256707376401
# Cost on val dataset after 41 epochs is = 0.481078916110802
# learning rate =  0.07808688094430304
# Initial Cost on Val dataset for this epoch 41 = 0.481078916110802
# Error on this batch = 0.4810370474816354
# Error on this batch = 0.4808015607980496
# Cost on val dataset after 42 epochs is = 0.48105654953545873
# learning rate =  0.07715167498104596
# Initial Cost on Val dataset for this epoch 42 = 0.48105654953545873
# Error on this batch = 0.4810146190781111
# Error on this batch = 0.48077669492680697
# Cost on val dataset after 43 epochs is = 0.48103356794570884
# learning rate =  0.07624928516630233
# Initial Cost on Val dataset for this epoch 43 = 0.48103356794570884
# Error on this batch = 0.48099160434720295
# Error on this batch = 0.48075104471814994
# Cost on val dataset after 44 epochs is = 0.4810099482848821
# learning rate =  0.07537783614444091
# Initial Cost on Val dataset for this epoch 44 = 0.4810099482848821
# Error on this batch = 0.4809679800660892
# Error on this batch = 0.48072458090453224
# Cost on val dataset after 45 epochs is = 0.4809856669193109
# learning rate =  0.07453559924999299
# Initial Cost on Val dataset for this epoch 45 = 0.4809856669193109
# Error on this batch = 0.48094372252239226
# Error on this batch = 0.48069727331440376
# Cost on val dataset after 46 epochs is = 0.4809606996128101
# learning rate =  0.07372097807744857
# Initial Cost on Val dataset for this epoch 46 = 0.4809606996128101
# Error on this batch = 0.48091880748238086
# Error on this batch = 0.4806690908301306
# Cost on val dataset after 47 epochs is = 0.48093502150183115
# learning rate =  0.07293249574894728
# Initial Cost on Val dataset for this epoch 47 = 0.48093502150183115
# Error on this batch = 0.48089321016057834
# Error on this batch = 0.4806400013458996
# Cost on val dataset after 48 epochs is = 0.48090860707117344
# learning rate =  0.07216878364870323
# Initial Cost on Val dataset for this epoch 48 = 0.48090860707117344
# Error on this batch = 0.48086690519053926
# Error on this batch = 0.48060997172547226
# Cost on val dataset after 49 epochs is = 0.4808814301301471
# learning rate =  0.07142857142857142
# Initial Cost on Val dataset for this epoch 49 = 0.4808814301301471
# Error on this batch = 0.48083986659658196
# Error on this batch = 0.48057896775966447
# Cost on val dataset after 50 epochs is = 0.48085346378908383
# learning rate =  0.07071067811865475
# Initial Cost on Val dataset for this epoch 50 = 0.48085346378908383
# Error on this batch = 0.4808120677662844
# Error on this batch = 0.48054695412344717
# Cost on val dataset after 51 epochs is = 0.48082468043609716
# learning rate =  0.07001400420140048
# Initial Cost on Val dataset for this epoch 51 = 0.48082468043609716
# Error on this batch = 0.480783481423566
# Error on this batch = 0.48051389433256475
# Cost on val dataset after 52 epochs is = 0.48079505171399584
# learning rate =  0.06933752452815364
# Initial Cost on Val dataset for this epoch 52 = 0.48079505171399584
# Error on this batch = 0.48075407960218886
# Error on this batch = 0.4804797506995817
# Cost on val dataset after 53 epochs is = 0.48076454849725364
# learning rate =  0.06868028197434452
# Initial Cost on Val dataset for this epoch 53 = 0.48076454849725364
# Error on this batch = 0.48072383361951854
# Error on this batch = 0.48044448428926595
# Cost on val dataset after 54 epochs is = 0.48073314086893654
# learning rate =  0.06804138174397717
# Initial Cost on Val dataset for this epoch 54 = 0.48073314086893654
# Error on this batch = 0.4806927140503912
# Error on this batch = 0.4804080548732252
# Cost on val dataset after 55 epochs is = 0.48070079809748967
# learning rate =  0.06741998624632421
# Initial Cost on Val dataset for this epoch 55 = 0.48070079809748967
# Error on this batch = 0.48066069070093564
# Error on this batch = 0.4803704208837104
# Cost on val dataset after 56 epochs is = 0.4806674886132815
# learning rate =  0.0668153104781061
# Initial Cost on Val dataset for this epoch 56 = 0.4806674886132815
# Error on this batch = 0.4806277325822013
# Error on this batch = 0.4803315393665007
# Cost on val dataset after 57 epochs is = 0.4806331799848018
# learning rate =  0.06622661785325219
# Initial Cost on Val dataset for this epoch 57 = 0.4806331799848018
# Error on this batch = 0.4805938078834456
# Error on this batch = 0.48029136593278465
# Cost on val dataset after 58 epochs is = 0.48059783889440955
# learning rate =  0.06565321642986127
# Initial Cost on Val dataset for this epoch 58 = 0.48059783889440955
# Error on this batch = 0.48055888394492924
# Error on this batch = 0.48024985470994613
# Cost on val dataset after 59 epochs is = 0.4805614311135242
# learning rate =  0.06509445549041194
# Initial Cost on Val dataset for this epoch 59 = 0.4805614311135242
# Error on this batch = 0.48052292723007817
# Error on this batch = 0.4802069582911647
# Cost on val dataset after 60 epochs is = 0.48052392147715495
# learning rate =  0.06454972243679027
# Initial Cost on Val dataset for this epoch 60 = 0.48052392147715495
# Error on this batch = 0.4804859032968608
# Error on this batch = 0.4801626276837314
# Cost on val dataset after 61 epochs is = 0.48048527385766404
# learning rate =  0.06401843996644799
# Initial Cost on Val dataset for this epoch 61 = 0.48048527385766404
# Error on this batch = 0.48044777676823996
# Error on this batch = 0.4801168122559817
# Cost on val dataset after 62 epochs is = 0.48044545113766185
# learning rate =  0.06350006350009525
# Initial Cost on Val dataset for this epoch 62 = 0.48044545113766185
# Error on this batch = 0.48040851130155765
# Error on this batch = 0.48006945968273856
# Cost on val dataset after 63 epochs is = 0.4804044151819374
# learning rate =  0.0629940788348712
# Initial Cost on Val dataset for this epoch 63 = 0.4804044151819374
# Error on this batch = 0.4803680695567144
# Error on this batch = 0.4800205158891545
# Cost on val dataset after 64 epochs is = 0.48036212680833346
# learning rate =  0.0625
# Initial Cost on Val dataset for this epoch 64 = 0.48036212680833346
# Error on this batch = 0.48032641316301333
# Error on this batch = 0.47996992499284113
# Cost on val dataset after 65 epochs is = 0.4803185457574838
# learning rate =  0.062017367294604234
# Initial Cost on Val dataset for this epoch 65 = 0.4803185457574838
# Error on this batch = 0.4802835026845438
# Error on this batch = 0.47991762924416154
# Cost on val dataset after 66 epochs is = 0.4802736306613398
# learning rate =  0.06154574548966636
# Initial Cost on Val dataset for this epoch 66 = 0.4802736306613398
# Error on this batch = 0.48023929758398987
# Error on this batch = 0.47986356896456694
# Cost on val dataset after 67 epochs is = 0.4802273390104259
# learning rate =  0.06108472217815261
# Initial Cost on Val dataset for this epoch 67 = 0.4802273390104259
# Error on this batch = 0.4801937561847588
# Error on this batch = 0.47980768248284683
# Cost on val dataset after 68 epochs is = 0.4801796271197761
# learning rate =  0.06063390625908324
# Initial Cost on Val dataset for this epoch 68 = 0.4801796271197761
# Error on this batch = 0.48014683563133653
# Error on this batch = 0.47974990606916407
# Cost on val dataset after 69 epochs is = 0.4801304500935203
# learning rate =  0.0601929265428846
# Initial Cost on Val dataset for this epoch 69 = 0.4801304500935203
# Error on this batch = 0.48009849184779135
# Error on this batch = 0.47969017386674173
# Cost on val dataset after 70 epochs is = 0.48007976178810385
# learning rate =  0.05976143046671968
# Initial Cost on Val dataset for this epoch 70 = 0.48007976178810385
# Error on this batch = 0.48004867949436053
# Error on this batch = 0.4796284178210699
# Cost on val dataset after 71 epochs is = 0.4800275147741434
# learning rate =  0.05933908290969266
# Initial Cost on Val dataset for this epoch 71 = 0.4800275147741434
# Error on this batch = 0.4799973519220717
# Error on this batch = 0.4795645676064978
# Cost on val dataset after 72 epochs is = 0.479973660296936
# learning rate =  0.05892556509887897
# Initial Cost on Val dataset for this epoch 72 = 0.479973660296936
# Error on this batch = 0.4799444611253659
# Error on this batch = 0.4794985505500823
# Cost on val dataset after 73 epochs is = 0.4799181482356649
# learning rate =  0.058520573598065284
# Initial Cost on Val dataset for this epoch 73 = 0.4799181482356649
# Error on this batch = 0.4798899576927071
# Error on this batch = 0.47943029155256356
# Cost on val dataset after 74 epochs is = 0.47986092706135736
# learning rate =  0.05812381937190964
# Initial Cost on Val dataset for this epoch 74 = 0.47986092706135736
# Error on this batch = 0.4798337907551799
# Error on this batch = 0.4793597130063476
# Cost on val dataset after 75 epochs is = 0.47980194379367247
# learning rate =  0.05773502691896257
# Initial Cost on Val dataset for this epoch 75 = 0.47980194379367247
# Error on this batch = 0.4797759079330943
# Error on this batch = 0.4792867347103807
# Cost on val dataset after 76 epochs is = 0.47974114395661827
# learning rate =  0.057353933467640436
# Initial Cost on Val dataset for this epoch 76 = 0.47974114395661827
# Error on this batch = 0.4797162552806351
# Error on this batch = 0.4792112737818131
# Cost on val dataset after 77 epochs is = 0.4796784715333137
# learning rate =  0.05698028822981897
# Initial Cost on Val dataset for this epoch 77 = 0.4796784715333137
# Error on this batch = 0.479654777228609
# Error on this batch = 0.479133244564361
# Cost on val dataset after 78 epochs is = 0.47961386891993124
# learning rate =  0.05661385170722978
# Initial Cost on Val dataset for this epoch 78 = 0.47961386891993124
# Error on this batch = 0.47959141652536064
# Error on this batch = 0.47905255853329337
# Cost on val dataset after 79 epochs is = 0.47954727687897686
# learning rate =  0.0562543950463012
# Initial Cost on Val dataset for this epoch 79 = 0.47954727687897686
# Error on this batch = 0.4795261141759468
# Error on this batch = 0.47896912419699134
# Cost on val dataset after 80 epochs is = 0.47947863449207934
# learning rate =  0.05590169943749474
# Initial Cost on Val dataset for this epoch 80 = 0.47947863449207934
# Error on this batch = 0.47945880937967433
# Error on this batch = 0.4788828469950474
# Cost on val dataset after 81 epochs is = 0.47940787911248595
# learning rate =  0.05555555555555555
# Initial Cost on Val dataset for this epoch 81 = 0.47940787911248595
# Error on this batch = 0.4793894394661234
# Error on this batch = 0.4787936291929074
# Cost on val dataset after 82 epochs is = 0.4793349463174734
# learning rate =  0.05521576303742327
# Initial Cost on Val dataset for this epoch 82 = 0.4793349463174734
# Error on this batch = 0.4793179398298012
# Error on this batch = 0.4787013697730859
# Cost on val dataset after 83 epochs is = 0.4792597698609106
# learning rate =  0.05488212999484517
# Initial Cost on Val dataset for this epoch 83 = 0.4792597698609106
# Error on this batch = 0.4792442438635829
# Error on this batch = 0.4786059643230257
# Cost on val dataset after 84 epochs is = 0.47918228162622434
# learning rate =  0.0545544725589981
# Initial Cost on Val dataset for this epoch 84 = 0.47918228162622434
# Error on this batch = 0.479168282891127
# Error on this batch = 0.4785073049197206
# Cost on val dataset after 85 epochs is = 0.47910241158004613
# learning rate =  0.05423261445466404
# Initial Cost on Val dataset for this epoch 85 = 0.47910241158004613
# Error on this batch = 0.47908998609846515
# Error on this batch = 0.4784052800112687
# Cost on val dataset after 86 epochs is = 0.4790200877268408
# learning rate =  0.053916386601719206
# Initial Cost on Val dataset for this epoch 86 = 0.4790200877268408
# Error on this batch = 0.4790092804650024
# Error on this batch = 0.4782997742955864
# Cost on val dataset after 87 epochs is = 0.47893523606484145
# learning rate =  0.05360562674188974
# Initial Cost on Val dataset for this epoch 87 = 0.47893523606484145
# Error on this batch = 0.4789260906941851
# Error on this batch = 0.47819066859657994
# Cost on val dataset after 88 epochs is = 0.47884778054364985
# learning rate =  0.053300179088902604
# Initial Cost on Val dataset for this epoch 88 = 0.47884778054364985
# Error on this batch = 0.47884033914413515
# Error on this batch = 0.4780778397381538
# Cost on val dataset after 89 epochs is = 0.47875764302388985
# learning rate =  0.052999894000318
# Initial Cost on Val dataset for this epoch 89 = 0.47875764302388985
# Error on this batch = 0.47875194575858104
# Error on this batch = 0.47796116041652187
# Cost on val dataset after 90 epochs is = 0.47866474323934166
# learning rate =  0.05270462766947299
# Initial Cost on Val dataset for this epoch 90 = 0.47866474323934166
# Error on this batch = 0.4786608279984692
# Error on this batch = 0.4778404990713957
# Cost on val dataset after 91 epochs is = 0.4785689987620258
# learning rate =  0.052414241836095915
# Initial Cost on Val dataset for this epoch 91 = 0.4785689987620258
# Error on this batch = 0.47856690077468855
# Error on this batch = 0.4777157197567422
# Cost on val dataset after 92 epochs is = 0.4784703249707551
# learning rate =  0.05212860351426869
# Initial Cost on Val dataset for this epoch 92 = 0.4784703249707551
# Error on this batch = 0.4784700763824016
# Error on this batch = 0.4775866820119397
# Cost on val dataset after 93 epochs is = 0.4783686350237283
# learning rate =  0.05184758473652126
# Initial Cost on Val dataset for this epoch 93 = 0.4783686350237283
# Error on this batch = 0.47837026443755226
# Error on this batch = 0.4774532407343227
# Cost on val dataset after 94 epochs is = 0.4782638398358033
# learning rate =  0.05157106231293967
# Initial Cost on Val dataset for this epoch 94 = 0.4782638398358033
# Error on this batch = 0.4782673718161995
# Error on this batch = 0.47731524605428133
# Cost on val dataset after 95 epochs is = 0.4781558480611586
# learning rate =  0.051298917604257706
# Initial Cost on Val dataset for this epoch 95 = 0.4781558480611586
# Error on this batch = 0.4781613025974215
# Error on this batch = 0.47717254321429475
# Cost on val dataset after 96 epochs is = 0.4780445660821363
# learning rate =  0.051031036307982884
# Initial Cost on Val dataset for this epoch 96 = 0.4780445660821363
# Error on this batch = 0.4780519580106495
# Error on this batch = 0.4770249724535103
# Cost on val dataset after 97 epochs is = 0.4779298980051503
# learning rate =  0.05076730825668096
# Initial Cost on Val dataset for this epoch 97 = 0.4779298980051503
# Error on this batch = 0.47793923638840763
# Error on this batch = 0.4768723688997521
# Cost on val dataset after 98 epochs is = 0.4778117456646501
# learning rate =  0.050507627227610534
# Initial Cost on Val dataset for this epoch 98 = 0.4778117456646501
# Error on this batch = 0.4778230331255843
# Error on this batch = 0.4767145624711458
# Cost on val dataset after 99 epochs is = 0.4776900086362453
# learning rate =  0.050251890762960605
# Initial Cost on Val dataset for this epoch 99 = 0.4776900086362453
# Error on this batch = 0.4777032406465152
# Error on this batch = 0.47655137778989654
# Cost on val dataset after 100 epochs is = 0.4775645842602232
# learning rate =  0.05
# Initial Cost on Val dataset for this epoch 100 = 0.4775645842602232
# Error on this batch = 0.477579748381337
# Error on this batch = 0.47638263411113957
# Cost on val dataset after 101 epochs is = 0.4774353676768361
# learning rate =  0.04975185951049946
# Initial Cost on Val dataset for this epoch 101 = 0.4774353676768361
# Error on this batch = 0.47745244275327026
# Error on this batch = 0.47620814527022054
# Cost on val dataset after 102 epochs is = 0.47730225187488157
# learning rate =  0.04950737714883372
# Initial Cost on Val dataset for this epoch 102 = 0.47730225187488157
# Error on this batch = 0.4773212071787052
# Error on this batch = 0.47602771965224067
# Cost on val dataset after 103 epochs is = 0.477165127755266
# learning rate =  0.04926646390821466
# Initial Cost on Val dataset for this epoch 103 = 0.477165127755266
# Error on this batch = 0.4771859220822009
# Error on this batch = 0.4758411601882302
# Cost on val dataset after 104 epochs is = 0.47702388421140873
# learning rate =  0.04902903378454601
# Initial Cost on Val dataset for this epoch 104 = 0.47702388421140873
# Error on this batch = 0.47704646492876623
# Error on this batch = 0.47564826438289126
# Cost on val dataset after 105 epochs is = 0.47687840822852506
# learning rate =  0.048795003647426664
# Initial Cost on Val dataset for this epoch 105 = 0.47687840822852506
# Error on this batch = 0.47690271027605946
# Error on this batch = 0.4754488243794725
# Cost on val dataset after 106 epochs is = 0.4767285850040043
# learning rate =  0.04856429311786321
# Initial Cost on Val dataset for this epoch 106 = 0.4767285850040043
# Error on this batch = 0.47675452984943373
# Error on this batch = 0.4752426270680003
# Cost on val dataset after 107 epochs is = 0.4765742980912783
# learning rate =  0.04833682445228318
# Initial Cost on Val dataset for this epoch 107 = 0.4765742980912783
# Error on this batch = 0.47660179264304886
# Error on this batch = 0.4750294542437926
# Cost on val dataset after 108 epochs is = 0.47641542956974925
# learning rate =  0.048112522432468816
# Initial Cost on Val dataset for this epoch 108 = 0.47641542956974925
# Error on this batch = 0.47644436505057547
# Error on this batch = 0.4748090828239028
# Cost on val dataset after 109 epochs is = 0.47625186024350225
# learning rate =  0.04789131426105757
# Initial Cost on Val dataset for this epoch 109 = 0.47625186024350225
# Error on this batch = 0.47628211102931106
# Error on this batch = 0.47458128512987685
# Cost on val dataset after 110 epochs is = 0.4760834698716692
# learning rate =  0.04767312946227962
# Initial Cost on Val dataset for this epoch 110 = 0.4760834698716692
# Error on this batch = 0.47611489230181947
# Error on this batch = 0.4743458292459335
# Cost on val dataset after 111 epochs is = 0.47591013743341304
# learning rate =  0.04745789978762495
# Initial Cost on Val dataset for this epoch 111 = 0.47591013743341304
# Error on this batch = 0.4759425685994682
# Error on this batch = 0.474102479462373
# Cost on val dataset after 112 epochs is = 0.47573174143057
# learning rate =  0.0472455591261534
# Initial Cost on Val dataset for this epoch 112 = 0.47573174143057
# Error on this batch = 0.4757649979524581
# Error on this batch = 0.47385099681465276
# Cost on val dataset after 113 epochs is = 0.47554816023099555
# learning rate =  0.047036043419179864
# Initial Cost on Val dataset for this epoch 113 = 0.47554816023099555
# Error on this batch = 0.47558203703111984
# Error on this batch = 0.47359113972910505
# Cost on val dataset after 114 epochs is = 0.47535927245560633
# learning rate =  0.0468292905790847
# Initial Cost on Val dataset for this epoch 114 = 0.47535927245560633
# Error on this batch = 0.47539354154333835
# Error on this batch = 0.4733226647866573
# Cost on val dataset after 115 epochs is = 0.4751649574119645
# learning rate =  0.04662524041201569
# Initial Cost on Val dataset for this epoch 115 = 0.4751649574119645
# Error on this batch = 0.47519936669296436
# Error on this batch = 0.4730453276161131
# Cost on val dataset after 116 epochs is = 0.4749650955770136
# learning rate =  0.046423834544262965
# Initial Cost on Val dataset for this epoch 116 = 0.4749650955770136
# Error on this batch = 0.4749993677039436
# Error on this batch = 0.4727588839284802
# Cost on val dataset after 117 epochs is = 0.474759569131214
# learning rate =  0.046225016352102424
# Initial Cost on Val dataset for this epoch 117 = 0.474759569131214
# Error on this batch = 0.4747934004146024
# Error on this batch = 0.47246309070343584
# Cost on val dataset after 118 epochs is = 0.4745482625458291
# learning rate =  0.04602873089491617
# Initial Cost on Val dataset for this epoch 118 = 0.4745482625458291
# Error on this batch = 0.474581321946053
# Error on this batch = 0.4721577075382162
# Cost on val dataset after 119 epochs is = 0.47433106322446406
# learning rate =  0.045834924851410566
# Initial Cost on Val dataset for this epoch 119 = 0.47433106322446406
# Error on this batch = 0.4743629914479815
# Error on this batch = 0.47184249816791424
# Cost on val dataset after 120 epochs is = 0.47410786219913825
# learning rate =  0.04564354645876384
# Initial Cost on Val dataset for this epoch 120 = 0.47410786219913825
# Error on this batch = 0.4741382709241226
# Error on this batch = 0.4715172321643036
# Cost on val dataset after 121 epochs is = 0.4738785548801625
# learning rate =  0.045454545454545456
# Initial Cost on Val dataset for this epoch 121 = 0.4738785548801625
# Error on this batch = 0.4739070261384727
# Error on this batch = 0.471181686817755
# Cost on val dataset after 122 epochs is = 0.47364304185789236
# learning rate =  0.045267873021259265
# Initial Cost on Val dataset for this epoch 122 = 0.47364304185789236
# Error on this batch = 0.47366912760172597
# Error on this batch = 0.4708356492035392
# Cost on val dataset after 123 epochs is = 0.47340122975302
# learning rate =  0.045083481733371615
# Initial Cost on Val dataset for this epoch 123 = 0.47340122975302
# Error on this batch = 0.47342445163550095
# Error on this batch = 0.47047891842970424
# Cost on val dataset after 124 epochs is = 0.47315303211046567
# learning rate =  0.04490132550669373
# Initial Cost on Val dataset for this epoch 124 = 0.47315303211046567
# Error on this batch = 0.47317288150966164
# Error on this batch = 0.4701113080587709
# Cost on val dataset after 125 epochs is = 0.47289837033013477
# learning rate =  0.044721359549995794
# Initial Cost on Val dataset for this epoch 125 = 0.47289837033013477
# Error on this batch = 0.4729143086454184
# Error on this batch = 0.4697326486896665
# Cost on val dataset after 126 epochs is = 0.4726371746258529
# learning rate =  0.0445435403187374
# Initial Cost on Val dataset for this epoch 126 = 0.4726371746258529
# Error on this batch = 0.47264863387395234
# Error on this batch = 0.46934279067965934
# Cost on val dataset after 127 epochs is = 0.4723693850017029
# learning rate =  0.04436782547080569
# Initial Cost on Val dataset for this epoch 127 = 0.4723693850017029
# Error on this batch = 0.4723757687370839
# Error on this batch = 0.468941606978645
# Cost on val dataset after 128 epochs is = 0.4720949522328338
# learning rate =  0.044194173824159216
# Initial Cost on Val dataset for this epoch 128 = 0.4720949522328338
# Error on this batch = 0.47209563681307876
# Error on this batch = 0.4685289960401247
# Cost on val dataset after 129 epochs is = 0.4718138388356408
# learning rate =  0.04402254531628119
# Initial Cost on Val dataset for this epoch 129 = 0.4718138388356408
# Error on this batch = 0.4718081750471639
# Error on this batch = 0.4681048847648244
# Cost on val dataset after 130 epochs is = 0.47152602001012894
# learning rate =  0.043852900965351466
# Initial Cost on Val dataset for this epoch 130 = 0.47152602001012894
# Error on this batch = 0.4715133350628429
# Error on this batch = 0.4676692314244508
# Cost on val dataset after 131 epochs is = 0.47123148453536295
# learning rate =  0.0436852028330519
# Initial Cost on Val dataset for this epoch 131 = 0.47123148453536295
# Error on this batch = 0.4712110844268315
# Error on this batch = 0.46722202850494127
# Cost on val dataset after 132 epochs is = 0.470930235597284
# learning rate =  0.04351941398892446
# Initial Cost on Val dataset for this epoch 132 = 0.470930235597284
# Error on this batch = 0.47090140783757783
# Error on this batch = 0.46676330540120836
# Cost on val dataset after 133 epochs is = 0.47062229152696494
# learning rate =  0.043355498476206
# Initial Cost on Val dataset for this epoch 133 = 0.47062229152696494
# Error on this batch = 0.47058430820510083
# Error on this batch = 0.4662931308893238
# Cost on val dataset after 134 epochs is = 0.4703076864267003
# learning rate =  0.04319342127906801
# Initial Cost on Val dataset for this epoch 134 = 0.4703076864267003
# Error on this batch = 0.4702598075885092
# Error on this batch = 0.46581161529787796
# Cost on val dataset after 135 epochs is = 0.46998647066129917
# learning rate =  0.04303314829119352
# Initial Cost on Val dataset for this epoch 135 = 0.46998647066129917
# Error on this batch = 0.46992794795725734
# Error on this batch = 0.4653189122984441
# Cost on val dataset after 136 epochs is = 0.46965871119268227
# learning rate =  0.042874646285627205
# Initial Cost on Val dataset for this epoch 136 = 0.46965871119268227
# Error on this batch = 0.4695887917431628
# Error on this batch = 0.46481522023616495
# Cost on val dataset after 137 epochs is = 0.4693244917374416
# learning rate =  0.04271788288583805
# Initial Cost on Val dataset for this epoch 137 = 0.4693244917374416
# Error on this batch = 0.4692424221525816
# Error on this batch = 0.46430078292587196
# Cost on val dataset after 138 epochs is = 0.46898391272946377
# learning rate =  0.04256282653793743
# Initial Cost on Val dataset for this epoch 138 = 0.46898391272946377
# Error on this batch = 0.4688889432120087
# Error on this batch = 0.4637758898471017
# Cost on val dataset after 139 epochs is = 0.46863709107303997
# learning rate =  0.042409446483998546
# Initial Cost on Val dataset for this epoch 139 = 0.46863709107303997
# Error on this batch = 0.46852847952572263
# Error on this batch = 0.4632408756829554
# Cost on val dataset after 140 epochs is = 0.4682841596760444
# learning rate =  0.042257712736425826
# Initial Cost on Val dataset for this epoch 140 = 0.4682841596760444
# Error on this batch = 0.46816117573084975
# Error on this batch = 0.46269611916279374
# Cost on val dataset after 141 epochs is = 0.4679252667576718
# learning rate =  0.04210759605332595
# Initial Cost on Val dataset for this epoch 141 = 0.4679252667576718
# Error on this batch = 0.46778719564315124
# Error on this batch = 0.4621420411868665
# Cost on val dataset after 142 epochs is = 0.46756057493072384
# learning rate =  0.041959067914834454
# Initial Cost on Val dataset for this epoch 142 = 0.46756057493072384
# Error on this batch = 0.46740672109568054
# Error on this batch = 0.4615791022314886
# Cost on val dataset after 143 epochs is = 0.46719026006434244
# learning rate =  0.04181210050035454
# Initial Cost on Val dataset for this epoch 143 = 0.46719026006434244
# Error on this batch = 0.4670199504817994
# Error on this batch = 0.461007799055433
# Cost on val dataset after 144 epochs is = 0.4668145099391848
# learning rate =  0.041666666666666664
# Initial Cost on Val dataset for this epoch 144 = 0.4668145099391848
# Error on this batch = 0.4666270970234669
# Error on this batch = 0.4604286607507706
# Cost on val dataset after 145 epochs is = 0.46643352271303923
# learning rate =  0.041522739926869986
# Initial Cost on Val dataset for this epoch 145 = 0.46643352271303923
# Error on this batch = 0.4662283867947437
# Error on this batch = 0.45984224420333336
# Cost on val dataset after 146 epochs is = 0.46604750522057514
# learning rate =  0.0413802944301184
# Initial Cost on Val dataset for this epoch 146 = 0.46604750522057514
# Error on this batch = 0.4658240565386154
# Error on this batch = 0.4592491290481471
# Cost on val dataset after 147 epochs is = 0.465656671136001
# learning rate =  0.041239304942116126
# Initial Cost on Val dataset for this epoch 147 = 0.465656671136001
# Error on this batch = 0.46541435132212267
# Error on this batch = 0.4586499122225214
# Cost on val dataset after 148 epochs is = 0.4652612390316839
# learning rate =  0.04109974682633932
# Initial Cost on Val dataset for this epoch 148 = 0.4652612390316839
# Error on this batch = 0.46499952208002127
# Error on this batch = 0.4580452022330744
# Cost on val dataset after 149 epochs is = 0.46486143036903427
# learning rate =  0.04096159602595203
# Initial Cost on Val dataset for this epoch 149 = 0.46486143036903427
# Error on this batch = 0.46457982310055285
# Error on this batch = 0.457435613262121
# Cost on val dataset after 150 epochs is = 0.46445746746005534
# learning rate =  0.040824829046386304
# Initial Cost on Val dataset for this epoch 150 = 0.46445746746005534
# Error on this batch = 0.4641555095082221
# Error on this batch = 0.4568217592431597
# Cost on val dataset after 151 epochs is = 0.4640495714388029
# learning rate =  0.04068942293855797
# Initial Cost on Val dataset for this epoch 151 = 0.4640495714388029
# Error on this batch = 0.463726834797763
# Error on this batch = 0.4562042480345265
# Cost on val dataset after 152 epochs is = 0.4636379602815721
# learning rate =  0.040555355282690636
# Initial Cost on Val dataset for this epoch 152 = 0.4636379602815721
# Error on this batch = 0.4632940484708146
# Error on this batch = 0.45558367581483195
# Cost on val dataset after 153 epochs is = 0.46322284691295446
# learning rate =  0.040422604172722164
# Initial Cost on Val dataset for this epoch 153 = 0.46322284691295446
# Error on this batch = 0.462857393822428
# Error on this batch = 0.4549606218139853
# Cost on val dataset after 154 epochs is = 0.4628044374320978
# learning rate =  0.040291148201269014
# Initial Cost on Val dataset for this epoch 154 = 0.4628044374320978
# Error on this batch = 0.4624171059186805
# Error on this batch = 0.4543356434801071
# Cost on val dataset after 155 epochs is = 0.46238292948966864
# learning rate =  0.04016096644512494
# Initial Cost on Val dataset for this epoch 155 = 0.46238292948966864
# Error on this batch = 0.46197340979971224
# Error on this batch = 0.45370927216624213
# Cost on val dataset after 156 epochs is = 0.46195851084137113
# learning rate =  0.04003203845127178
# Initial Cost on Val dataset for this epoch 156 = 0.46195851084137113
# Error on this batch = 0.46152651893479874
# Error on this batch = 0.4530820094024206
# Cost on val dataset after 157 epochs is = 0.4615313580986098
# learning rate =  0.03990434422338111
# Initial Cost on Val dataset for this epoch 157 = 0.4615313580986098
# Error on this batch = 0.46107663394800263
# Error on this batch = 0.4524543237992013
# Cost on val dataset after 158 epochs is = 0.46110163569122325
# learning rate =  0.0397778642087865
# Initial Cost on Val dataset for this epoch 158 = 0.46110163569122325
# Error on this batch = 0.4606239416248563
# Error on this batch = 0.4518266486092661
# Cost on val dataset after 159 epochs is = 0.4606694950513958
# learning rate =  0.03965257928590721
# Initial Cost on Val dataset for this epoch 159 = 0.4606694950513958
# Error on this batch = 0.46016861420273103
# Error on this batch = 0.45119937995472603
# Cost on val dataset after 160 epochs is = 0.46023507402209296
# learning rate =  0.03952847075210474
# Initial Cost on Val dataset for this epoch 160 = 0.46023507402209296
# Error on this batch = 0.45971080894031136
# Error on this batch = 0.4505728757102451
# Cost on val dataset after 161 epochs is = 0.4597984964878546
# learning rate =  0.03940552031195503
# Initial Cost on Val dataset for this epoch 161 = 0.4597984964878546
# Error on this batch = 0.45925066795511554
# Error on this batch = 0.4499474550164172
# Cost on val dataset after 162 epochs is = 0.4593598722207111
# learning rate =  0.039283710065919304
# Initial Cost on Val dataset for this epoch 162 = 0.4593598722207111
# Error on this batch = 0.45878831831243744
# Error on this batch = 0.44932339838445
# Cost on val dataset after 163 epochs is = 0.4589192969294801
# learning rate =  0.03916302249939787
# Initial Cost on Val dataset for this epoch 163 = 0.4589192969294801
# Error on this batch = 0.45832387234450983
# Error on this batch = 0.44870094834234253
# Cost on val dataset after 164 epochs is = 0.4584768524968767
# learning rate =  0.03904344047215152
# Initial Cost on Val dataset for this epoch 164 = 0.4584768524968767
# Error on this batch = 0.45785742817514946
# Error on this batch = 0.448080310564474
# Cost on val dataset after 165 epochs is = 0.45803260738578866
# learning rate =  0.03892494720807615
# Initial Cost on Val dataset for this epoch 165 = 0.45803260738578866
# Error on this batch = 0.4573890704226096
# Error on this batch = 0.4474616554208317
# Cost on val dataset after 166 epochs is = 0.4575866171937506
# learning rate =  0.03880752628531664
# Initial Cost on Val dataset for this epoch 166 = 0.4575866171937506
# Error on this batch = 0.45691887105181317
# Error on this batch = 0.44684511987883313
# Cost on val dataset after 167 epochs is = 0.4571389253331077
# learning rate =  0.03869116162670684
# Initial Cost on Val dataset for this epoch 167 = 0.4571389253331077
# Error on this batch = 0.4564468903464608
# Error on this batch = 0.4462308096896372
# Cost on val dataset after 168 epochs is = 0.4566895638135461
# learning rate =  0.03857583749052298
# Initial Cost on Val dataset for this epoch 168 = 0.4566895638135461
# Error on this batch = 0.45597317797163095
# Error on this batch = 0.44561880179171093
# Cost on val dataset after 169 epochs is = 0.45623855410352254
# learning rate =  0.038461538461538464
# Initial Cost on Val dataset for this epoch 169 = 0.45623855410352254
# Error on this batch = 0.45549777409828723
# Error on this batch = 0.44500914686691445
# Cost on val dataset after 170 epochs is = 0.45578590804758573
# learning rate =  0.03834824944236852
# Initial Cost on Val dataset for this epoch 170 = 0.45578590804758573
# Error on this batch = 0.4550207105624763
# Error on this batch = 0.444401871988171
# Cost on val dataset after 171 epochs is = 0.45533162881754286
# learning rate =  0.038235955645093626
# Initial Cost on Val dataset for this epoch 171 = 0.45533162881754286
# Error on this batch = 0.45454201203381717
# Error on this batch = 0.44379698330259487
# Cost on val dataset after 172 epochs is = 0.45487571187680603
# learning rate =  0.038124642583151166
# Initial Cost on Val dataset for this epoch 172 = 0.45487571187680603
# Error on this batch = 0.45406169717004885
# Error on this batch = 0.44319446869945645
# Cost on val dataset after 173 epochs is = 0.45441814593895374
# learning rate =  0.038014296063485276
# Initial Cost on Val dataset for this epoch 173 = 0.45441814593895374
# Error on this batch = 0.4535797797368138
# Error on this batch = 0.4425943004183131
# Cost on val dataset after 174 epochs is = 0.453958913903463
# learning rate =  0.03790490217894517
# Initial Cost on Val dataset for this epoch 174 = 0.453958913903463
# Error on this batch = 0.45309626967441646
# Error on this batch = 0.4419964375587949
# Cost on val dataset after 175 epochs is = 0.45349799375364663
# learning rate =  0.03779644730092272
# Initial Cost on Val dataset for this epoch 175 = 0.45349799375364663
# Error on this batch = 0.45261117409594137
# Error on this batch = 0.44140082845971185
# Cost on val dataset after 176 epochs is = 0.45303535940396306
# learning rate =  0.037688918072220454
# Initial Cost on Val dataset for this epoch 176 = 0.45303535940396306
# Error on this batch = 0.4521244982037699
# Error on this batch = 0.4408074129211803
# Cost on val dataset after 177 epochs is = 0.4525709814860111
# learning rate =  0.037582301400141446
# Initial Cost on Val dataset for this epoch 177 = 0.4525709814860111
# Error on this batch = 0.4516362461141424
# Error on this batch = 0.4402161242492375
# Cost on val dataset after 178 epochs is = 0.4521048280646156
# learning rate =  0.03747658444979307
# Initial Cost on Val dataset for this epoch 178 = 0.4521048280646156
# Error on this batch = 0.45114642158193863
# Error on this batch = 0.43962689110782166
# Cost on val dataset after 179 epochs is = 0.45163686527741653
# learning rate =  0.037371754637596795
# Initial Cost on Val dataset for this epoch 179 = 0.45163686527741653
# Error on this batch = 0.45065502862024376
# Error on this batch = 0.43903963916797845
# Cost on val dataset after 180 epochs is = 0.451167057893247
# learning rate =  0.037267799624996496
# Initial Cost on Val dataset for this epoch 180 = 0.451167057893247
# Error on this batch = 0.4501620720115174
# Error on this batch = 0.4384542925486781
# Cost on val dataset after 181 epochs is = 0.4506953697863298
# learning rate =  0.03716470731235832
# Initial Cost on Val dataset for this epoch 181 = 0.4506953697863298
# Error on this batch = 0.44966755770925615
# Error on this batch = 0.4378707750476508
# Cost on val dataset after 182 epochs is = 0.4502217643248917
# learning rate =  0.03706246583305506
# Initial Cost on Val dataset for this epoch 182 = 0.4502217643248917
# Error on this batch = 0.44917149313092664
# Error on this batch = 0.43728901116418295
# Cost on val dataset after 183 epochs is = 0.44974620467421045
# learning rate =  0.03696106354772864
# Initial Cost on Val dataset for this epoch 183 = 0.44974620467421045
# Error on this batch = 0.44867388734464103
# Error on this batch = 0.43670892691885377
# Cost on val dataset after 184 epochs is = 0.4492686540153458
# learning rate =  0.036860489038724284
# Initial Cost on Val dataset for this epoch 184 = 0.4492686540153458
# Error on this batch = 0.4481747511535229
# Error on this batch = 0.4361304504777472
# Cost on val dataset after 185 epochs is = 0.4487890756818865
# learning rate =  0.036760731104690386
# Initial Cost on Val dataset for this epoch 185 = 0.4487890756818865
# Error on this batch = 0.4476740970829986
# Error on this batch = 0.43555351259077185
# Cost on val dataset after 186 epochs is = 0.44830743321795075
# learning rate =  0.036661778755338326
# Initial Cost on Val dataset for this epoch 186 = 0.44830743321795075
# Error on this batch = 0.4471719392773084
# Error on this batch = 0.43497804685538244
# Cost on val dataset after 187 epochs is = 0.4478236903614441
# learning rate =  0.036563621206356534
# Initial Cost on Val dataset for this epoch 187 = 0.4478236903614441
# Error on this batch = 0.44666829331239655
# Error on this batch = 0.4344039898182567
# Cost on val dataset after 188 epochs is = 0.44733781095718345
# learning rate =  0.03646624787447364
# Initial Cost on Val dataset for this epoch 188 = 0.44733781095718345
# Error on this batch = 0.4461631759329987
# Error on this batch = 0.4338312809283602
# Cost on val dataset after 189 epochs is = 0.44684975880497296
# learning rate =  0.036369648372665396
# Initial Cost on Val dataset for this epoch 189 = 0.44684975880497296
# Error on this batch = 0.44565660472220336
# Error on this batch = 0.43325986235538344
# Cost on val dataset after 190 epochs is = 0.44635949744806835
# learning rate =  0.03627381250550058
# Initial Cost on Val dataset for this epoch 190 = 0.44635949744806835
# Error on this batch = 0.4451485977120435
# Error on this batch = 0.4326896786877795
# Cost on val dataset after 191 epochs is = 0.44586698990769175
# learning rate =  0.03617873026462108
# Initial Cost on Val dataset for this epoch 191 = 0.44586698990769175
# Error on this batch = 0.44463917294377175
# Error on this batch = 0.4321206765246126
# Cost on val dataset after 192 epochs is = 0.44537219836939385
# learning rate =  0.036084391824351615
# Initial Cost on Val dataset for this epoch 192 = 0.44537219836939385
# Error on this batch = 0.444128347986418
# Error on this batch = 0.4315528039751895
# Cost on val dataset after 193 epochs is = 0.44487508382709195
# learning rate =  0.035990787537434725
# Initial Cost on Val dataset for this epoch 193 = 0.44487508382709195
# Error on this batch = 0.44361613942202105
# Error on this batch = 0.4309860100800188
# Cost on val dataset after 194 epochs is = 0.4443756056905681
# learning rate =  0.03589790793088691
# ...
# learning rate =  0.004807692307692308
# Initial Cost on Val dataset for this epoch 10816 = 0.0999097380102392
# Error on this batch = 0.08159550306383011
# Error on this batch = 0.05579350523360397
# Cost on val dataset after 10817 epochs is = 0.09990857934487199
# learning rate =  0.0048074700740125854
# Initial Cost on Val dataset for this epoch 10817 = 0.09990857934487199
# Error on this batch = 0.08159297978153288
# Error on this batch = 0.05579156208529424
# Cost on val dataset after 10818 epochs is = 0.09990742086019332
# learning rate =  0.004807247871148008
# Initial Cost on Val dataset for this epoch 10818 = 0.09990742086019332
# Error on this batch = 0.08159045683533651
# Error on this batch = 0.05578961913743081
# Cost on val dataset after 10819 epochs is = 0.09990626255616507
# learning rate =  0.004807025699091453
# Initial Cost on Val dataset for this epoch 10819 = 0.09990626255616507
# Error on this batch = 0.08158793422518716
# Error on this batch = 0.05578767638995987
# Cost on val dataset after 10820 epochs is = 0.0999051044327491
# learning rate =  0.004806803557835801
# Initial Cost on Val dataset for this epoch 10820 = 0.0999051044327491
# Error on this batch = 0.0815854119510309
# Error on this batch = 0.05578573384282768
# Cost on val dataset after 10821 epochs is = 0.09990394648990726
# learning rate =  0.004806581447373939
# Initial Cost on Val dataset for this epoch 10821 = 0.09990394648990726
# Error on this batch = 0.08158289001281378
# Error on this batch = 0.05578379149598044
# Cost on val dataset after 10822 epochs is = 0.09990278872760149
# learning rate =  0.00480635936769875
# Initial Cost on Val dataset for this epoch 10822 = 0.09990278872760149
# Error on this batch = 0.0815803684104819
# Error on this batch = 0.055781849349364414
# Cost on val dataset after 10823 epochs is = 0.09990163114579367
# learning rate =  0.004806137318803125
# Initial Cost on Val dataset for this epoch 10823 = 0.09990163114579367
# Error on this batch = 0.08157784714398136
# Error on this batch = 0.05577990740292584
# Cost on val dataset after 10824 epochs is = 0.09990047374444562
# learning rate =  0.004805915300679952
# Initial Cost on Val dataset for this epoch 10824 = 0.09990047374444562
# Error on this batch = 0.08157532621325818
# Error on this batch = 0.05577796565661098
# Cost on val dataset after 10825 epochs is = 0.09989931652351938
# learning rate =  0.004805693313322127
# Initial Cost on Val dataset for this epoch 10825 = 0.09989931652351938
# Error on this batch = 0.08157280561825857
# Error on this batch = 0.05577602411036617
# Cost on val dataset after 10826 epochs is = 0.09989815948297681
# learning rate =  0.004805471356722544
# Initial Cost on Val dataset for this epoch 10826 = 0.09989815948297681
# Error on this batch = 0.0815702853589286
# Error on this batch = 0.05577408276413763
# Cost on val dataset after 10827 epochs is = 0.09989700262277984
# learning rate =  0.0048052494308741
# Initial Cost on Val dataset for this epoch 10827 = 0.09989700262277984
# Error on this batch = 0.08156776543521434
# Error on this batch = 0.055772141617871765
# Cost on val dataset after 10828 epochs is = 0.09989584594289044
# learning rate =  0.004805027535769695
# Initial Cost on Val dataset for this epoch 10828 = 0.09989584594289044
# Error on this batch = 0.08156524584706194
# Error on this batch = 0.05577020067151487
# Cost on val dataset after 10829 epochs is = 0.09989468944327058
# learning rate =  0.004804805671402232
# Initial Cost on Val dataset for this epoch 10829 = 0.09989468944327058
# Error on this batch = 0.0815627265944175
# Error on this batch = 0.05576825992501329
# Cost on val dataset after 10830 epochs is = 0.09989353312388217
# learning rate =  0.004804583837764615
# Initial Cost on Val dataset for this epoch 10830 = 0.09989353312388217
# Error on this batch = 0.08156020767722719
# Error on this batch = 0.055766319378313355
# Cost on val dataset after 10831 epochs is = 0.09989237698468725
# learning rate =  0.004804362034849751
# Initial Cost on Val dataset for this epoch 10831 = 0.09989237698468725
# Error on this batch = 0.0815576890954371
# Error on this batch = 0.05576437903136143
# Cost on val dataset after 10832 epochs is = 0.09989122102564779
# learning rate =  0.004804140262650549
# Initial Cost on Val dataset for this epoch 10832 = 0.09989122102564779
# Error on this batch = 0.08155517084899337
# Error on this batch = 0.05576243888410394
# Cost on val dataset after 10833 epochs is = 0.09989006524672572
# learning rate =  0.004803918521159921
# Initial Cost on Val dataset for this epoch 10833 = 0.09989006524672572
# Error on this batch = 0.08155265293784218
# Error on this batch = 0.055760498936487275
# Cost on val dataset after 10834 epochs is = 0.09988890964788315
# learning rate =  0.00480369681037078
# Initial Cost on Val dataset for this epoch 10834 = 0.09988890964788315
# Error on this batch = 0.08155013536192968
# Error on this batch = 0.055758559188457846
# Cost on val dataset after 10835 epochs is = 0.09988775422908201
# learning rate =  0.0048034751302760414
# Initial Cost on Val dataset for this epoch 10835 = 0.09988775422908201
# Error on this batch = 0.081547618121202
# Error on this batch = 0.055756619639962056
# Cost on val dataset after 10836 epochs is = 0.09988659899028435
# learning rate =  0.004803253480868625
# Initial Cost on Val dataset for this epoch 10836 = 0.09988659899028435
# Error on this batch = 0.08154510121560535
# Error on this batch = 0.05575468029094637
# Cost on val dataset after 10837 epochs is = 0.09988544393145223
# learning rate =  0.0048030318621414495
# Initial Cost on Val dataset for this epoch 10837 = 0.09988544393145223
# Error on this batch = 0.08154258464508579
# Error on this batch = 0.0557527411413572
# Cost on val dataset after 10838 epochs is = 0.09988428905254768
# learning rate =  0.00480281027408744
# Initial Cost on Val dataset for this epoch 10838 = 0.09988428905254768
# Error on this batch = 0.08154006840958963
# Error on this batch = 0.055750802191141084
# Cost on val dataset after 10839 epochs is = 0.09988313435353272
# learning rate =  0.004802588716699519
# Initial Cost on Val dataset for this epoch 10839 = 0.09988313435353272
# Error on this batch = 0.08153755250906297
# Error on this batch = 0.05574886344024442
# Cost on val dataset after 10840 epochs is = 0.09988197983436949
# learning rate =  0.004802367189970616
# Initial Cost on Val dataset for this epoch 10840 = 0.09988197983436949
# Error on this batch = 0.08153503694345209
# Error on this batch = 0.05574692488861377
# Cost on val dataset after 10841 epochs is = 0.09988082549501998
# learning rate =  0.00480214569389366
# Initial Cost on Val dataset for this epoch 10841 = 0.09988082549501998
# Error on this batch = 0.08153252171270299
# Error on this batch = 0.05574498653619561
# Cost on val dataset after 10842 epochs is = 0.09987967133544633
# learning rate =  0.004801924228461583
# Initial Cost on Val dataset for this epoch 10842 = 0.09987967133544633
# Error on this batch = 0.08153000681676206
# Error on this batch = 0.055743048382936505
# Cost on val dataset after 10843 epochs is = 0.0998785173556106
# learning rate =  0.004801702793667318
# Initial Cost on Val dataset for this epoch 10843 = 0.0998785173556106
# Error on this batch = 0.08152749225557536
# Error on this batch = 0.055741110428782915
# Cost on val dataset after 10844 epochs is = 0.09987736355547494
# learning rate =  0.004801481389503805
# Initial Cost on Val dataset for this epoch 10844 = 0.09987736355547494
# Error on this batch = 0.0815249780290892
# Error on this batch = 0.05573917267368142
# Cost on val dataset after 10845 epochs is = 0.09987620993500143
# learning rate =  0.004801260015963978
# Initial Cost on Val dataset for this epoch 10845 = 0.09987620993500143
# Error on this batch = 0.08152246413724973
# Error on this batch = 0.05573723511757861
# Cost on val dataset after 10846 epochs is = 0.0998750564941522
# learning rate =  0.004801038673040782
# Initial Cost on Val dataset for this epoch 10846 = 0.0998750564941522
# Error on this batch = 0.08151995058000325
# Error on this batch = 0.055735297760421076
# Cost on val dataset after 10847 epochs is = 0.09987390323288936
# learning rate =  0.004800817360727159
# Initial Cost on Val dataset for this epoch 10847 = 0.09987390323288936
# Error on this batch = 0.08151743735729586
# Error on this batch = 0.05573336060215534
# Cost on val dataset after 10848 epochs is = 0.09987275015117512
# learning rate =  0.004800596079016054
# Initial Cost on Val dataset for this epoch 10848 = 0.09987275015117512
# Error on this batch = 0.08151492446907387
# Error on this batch = 0.05573142364272807
# Cost on val dataset after 10849 epochs is = 0.09987159724897156
# learning rate =  0.004800374827900415
# Initial Cost on Val dataset for this epoch 10849 = 0.09987159724897156
# Error on this batch = 0.08151241191528354
# Error on this batch = 0.055729486882085844
# Cost on val dataset after 10850 epochs is = 0.09987044452624087
# learning rate =  0.004800153607373193
# Initial Cost on Val dataset for this epoch 10850 = 0.09987044452624087
# Error on this batch = 0.08150989969587101
# Error on this batch = 0.05572755032017534
# Cost on val dataset after 10851 epochs is = 0.09986929198294525
# learning rate =  0.004799932417427341
# Initial Cost on Val dataset for this epoch 10851 = 0.09986929198294525
# Error on this batch = 0.08150738781078266
# Error on this batch = 0.05572561395694314
# Cost on val dataset after 10852 epochs is = 0.09986813961904684
# learning rate =  0.004799711258055812
# Initial Cost on Val dataset for this epoch 10852 = 0.09986813961904684
# Error on this batch = 0.08150487625996462
# Error on this batch = 0.05572367779233596
# Cost on val dataset after 10853 epochs is = 0.09986698743450788
# learning rate =  0.004799490129251564
# Initial Cost on Val dataset for this epoch 10853 = 0.09986698743450788
# Error on this batch = 0.0815023650433632
# Error on this batch = 0.05572174182630046
# Cost on val dataset after 10854 epochs is = 0.09986583542929053
# learning rate =  0.004799269031007556
# Initial Cost on Val dataset for this epoch 10854 = 0.09986583542929053
# Error on this batch = 0.08149985416092466
# Error on this batch = 0.05571980605878336
# Cost on val dataset after 10855 epochs is = 0.09986468360335697
# learning rate =  0.00479904796331675
# Initial Cost on Val dataset for this epoch 10855 = 0.09986468360335697
# Error on this batch = 0.0814973436125953
# Error on this batch = 0.055717870489731286
# Cost on val dataset after 10856 epochs is = 0.09986353195666953
# learning rate =  0.0047988269261721095
# Initial Cost on Val dataset for this epoch 10856 = 0.09986353195666953
# Error on this batch = 0.08149483339832131
# Error on this batch = 0.055715935119091016
# Cost on val dataset after 10857 epochs is = 0.09986238048919036
# learning rate =  0.004798605919566601
# Initial Cost on Val dataset for this epoch 10857 = 0.09986238048919036
# Error on this batch = 0.08149232351804901
# Error on this batch = 0.05571399994680923
# Cost on val dataset after 10858 epochs is = 0.09986122920088168
# learning rate =  0.004798384943493192
# Initial Cost on Val dataset for this epoch 10858 = 0.09986122920088168
# Error on this batch = 0.08148981397172475
# Error on this batch = 0.055712064972832764
# Cost on val dataset after 10859 epochs is = 0.09986007809170583
# learning rate =  0.004798163997944854
# Initial Cost on Val dataset for this epoch 10859 = 0.09986007809170583
# Error on this batch = 0.08148730475929472
# Error on this batch = 0.05571013019710828
# Cost on val dataset after 10860 epochs is = 0.099858927161625
# learning rate =  0.004797943082914559
# Initial Cost on Val dataset for this epoch 10860 = 0.099858927161625
# Error on this batch = 0.08148479588070526
# Error on this batch = 0.05570819561958257
# Cost on val dataset after 10861 epochs is = 0.0998577764106015
# learning rate =  0.004797722198395283
# Initial Cost on Val dataset for this epoch 10861 = 0.0998577764106015
# Error on this batch = 0.08148228733590265
# Error on this batch = 0.05570626124020243
# Cost on val dataset after 10862 epochs is = 0.09985662583859758
# learning rate =  0.004797501344380003
# Initial Cost on Val dataset for this epoch 10862 = 0.09985662583859758
# Error on this batch = 0.08147977912483326
# Error on this batch = 0.05570432705891471
# Cost on val dataset after 10863 epochs is = 0.09985547544557555
# learning rate =  0.0047972805208616985
# Initial Cost on Val dataset for this epoch 10863 = 0.09985547544557555
# Error on this batch = 0.08147727124744336
# Error on this batch = 0.05570239307566613
# Cost on val dataset after 10864 epochs is = 0.09985432523149772
# learning rate =  0.004797059727833352
# Initial Cost on Val dataset for this epoch 10864 = 0.09985432523149772
# Error on this batch = 0.0814747637036792
# Error on this batch = 0.055700459290403605
# Cost on val dataset after 10865 epochs is = 0.09985317519632635
# learning rate =  0.004796838965287946
# Initial Cost on Val dataset for this epoch 10865 = 0.09985317519632635
# Error on this batch = 0.08147225649348723
# Error on this batch = 0.055698525703073924
# Cost on val dataset after 10866 epochs is = 0.09985202534002383
# learning rate =  0.0047966182332184705
# Initial Cost on Val dataset for this epoch 10866 = 0.09985202534002383
# Error on this batch = 0.08146974961681369
# Error on this batch = 0.05569659231362389
# Cost on val dataset after 10867 epochs is = 0.09985087566255241
# learning rate =  0.004796397531617911
# Initial Cost on Val dataset for this epoch 10867 = 0.09985087566255241
# Error on this batch = 0.08146724307360494
# Error on this batch = 0.055694659122000466
# Cost on val dataset after 10868 epochs is = 0.09984972616387448
# learning rate =  0.004796176860479259
# Initial Cost on Val dataset for this epoch 10868 = 0.09984972616387448
# Error on this batch = 0.08146473686380733
# Error on this batch = 0.0556927261281505
# Cost on val dataset after 10869 epochs is = 0.09984857684395239
# learning rate =  0.00479595621979551
# Initial Cost on Val dataset for this epoch 10869 = 0.09984857684395239
# Error on this batch = 0.08146223098736721
# Error on this batch = 0.05569079333202087
# Cost on val dataset after 10870 epochs is = 0.0998474277027485
# learning rate =  0.004795735609559656
# Initial Cost on Val dataset for this epoch 10870 = 0.0998474277027485
# Error on this batch = 0.08145972544423084
# Error on this batch = 0.055688860733558505
# Cost on val dataset after 10871 epochs is = 0.09984627874022514
# learning rate =  0.004795515029764697
# Initial Cost on Val dataset for this epoch 10871 = 0.09984627874022514
# Error on this batch = 0.08145722023434473
# Error on this batch = 0.05568692833271034
# Cost on val dataset after 10872 epochs is = 0.09984512995634472
# learning rate =  0.004795294480403634
# Initial Cost on Val dataset for this epoch 10872 = 0.09984512995634472
# Error on this batch = 0.08145471535765512
# Error on this batch = 0.05568499612942326
# Cost on val dataset after 10873 epochs is = 0.09984398135106963
# learning rate =  0.004795073961469465
# Initial Cost on Val dataset for this epoch 10873 = 0.09984398135106963
# Error on this batch = 0.0814522108141084
# Error on this batch = 0.05568306412364428
# Cost on val dataset after 10874 epochs is = 0.09984283292436227
# learning rate =  0.004794853472955199
# Initial Cost on Val dataset for this epoch 10874 = 0.09984283292436227
# Error on this batch = 0.08144970660365097
# Error on this batch = 0.05568113231532028
# Cost on val dataset after 10875 epochs is = 0.09984168467618504
# learning rate =  0.004794633014853841
# Initial Cost on Val dataset for this epoch 10875 = 0.09984168467618504
# Error on this batch = 0.08144720272622917
# Error on this batch = 0.0556792007043983
# Cost on val dataset after 10876 epochs is = 0.09984053660650036
# learning rate =  0.0047944125871584005
# Initial Cost on Val dataset for this epoch 10876 = 0.09984053660650036
# Error on this batch = 0.08144469918178945
# Error on this batch = 0.05567726929082533
# --------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-16-2b95085eb29f> in <module>
#      33
#      34             for t in range(len(theta)):
# ---> 35                 theta[t] += lr*np.dot(fm[t].T, delta[t+1])
#      36
#      37             count+=1
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
valid_accuracy
# Out:
# [2.871794871794872,
#  45.38461538461539,
#  69.53846153846153,
#  87.28205128205128,
#  86.51282051282051]

# %%
test_accuracy
# Out:
# [3.8461538461538463,
#  45.353846153846156,
#  66.72307692307692,
#  86.1076923076923,
#  84.63076923076923]

# %%
train_time
# Out:
# [4.912621259689331,
#  1454.2231917381287,
#  440.65885043144226,
#  363.5994551181793,
#  2274.1894056797028]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Train Loss with Epochs with ReLU")
x = np.arange(0,len(costs[1:300]))
ax.plot(x, costs[1:300], marker='o', label='Train Loss')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Train Loss")

plt.legend()
#plt.savefig("relu_trainloss.png", dpi=1000, bbox_inches='tight')
plt.show()
