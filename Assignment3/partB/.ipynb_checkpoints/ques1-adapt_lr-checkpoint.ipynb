# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)
np.random.shuffle(X_train.to_numpy())
train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

X_train = X_train/255
X_test = X_test/255

m = X_train.shape[0] # Number of Training Samples

X_valid = X_train.iloc[(int(0.85*m)):]
valid_class = train_class[(int(0.85*m)):]
X_train = X_train.iloc[0:int(0.85*m)]
train_class = train_class[0:int(0.85*m)]


m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The total number of validation samples = {}".format(X_valid.shape[0]))

print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# The total number of training samples = 11050
# The total number of validation samples = 1950
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
valid_class_enc = pd.get_dummies(valid_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
# Out:
# --------Perform 1-hot encoding of class labels------------

# %%
#Add the intercept term to the data samples both in training and test dataset
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_valid = np.hstack((np.ones((X_valid.shape[0],1)), X_valid.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))

# %%
lr = 0.1
arch_test = [1,5,10,50,100]
arch = [arch_test[3]] #means one hidden layer with 2 perceptrons 
batch_size = 100 # Mini-Batch Size
r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
#Mini-Batch formation
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# The number of mini-batches formed is = 111

# %%
#Theta Initialization 
def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]

        theta.append(2*np.random.random((dim0, dim1))-1)
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
def activation(x):
    return 1/(1+np.exp(-x))

# %%
def forward_prop(data, theta):
    fm = []
    fm.append(data)
    for l in range(len(theta)):
        fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
def cost_total(X, theta, Y, m):
    fm = forward_prop(X, theta)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    #print("The Test Accuracy of the model = {}%".format(test_acc*100))
    return (test_acc*100)

# %%
epochs = []
train_accuracy = []
test_accuracy = []
valid_accuracy=[]
train_time = []

# %%
arch_test = [1, 5, 10, 50, 100]
#arch_test = [50]

# %%
lr0=1.5
for i in range(len(arch_test)):
    theta = theta_init([arch_test[i]])
    fm = forward_prop(X_train, theta)
    epoch = 1
    start = time.time()
    cost_init = cost_total(X_valid, theta, valid_class_enc, m)

    while(True):
        count = 0
        lr = lr0/(np.power(epoch, 1/3))
        print("learning rate = ", lr)

        print("Initial Cost on Val dataset for this epoch {} = {}".format(epoch, cost_init))

        for b in mini_batch:
            X_b = b[0]
            Y_b = b[1]
            fm = forward_prop(X_b, theta)
            delta = [None]*len(fm)

            if (count % 60 == 0):
                print("Error on this batch = "+str(cost_total(X_b, theta, Y_b, batch_size)))
            #Backward Propagation

            for l in range(len(fm)-1, 0, -1):
                if (l == len(fm)-1):
                    delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
                else:
                    delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))

            for t in range(len(theta)):
                theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

            count+=1
        epoch+=1 #Number of epochs
        
        cost_final = cost_total(X_valid, theta, valid_class_enc, m)
        print("Cost on val dataset after {} epochs is = {}".format(epoch, cost_final))
        if (abs(cost_final-cost_init) < 1e-07):
            print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
            break
        cost_init = cost_final
    epochs.append(epoch)
    train_time.append(time.time()-start)
    train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
    valid_accuracy.append(calc_accuracy(X_valid, theta, valid_class_enc))
    test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
    print("\n------------------------------------------------------------------------------")
    print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
    print("------------------------------------------------------------------------------")
    print("The number of epochs = {:2.3f}".format(epochs[-1]))
    print("The training time = {:2.3f}sec".format(train_time[-1]))
    print("The training accuracy is = {:2.3f}%".format(train_accuracy[-1]))
    print("The validation accuracy is = {:2.3f}%".format(valid_accuracy[-1]))
    print("The test accuracy is = {:2.3f}%".format(test_accuracy[-1]))
    print("------------------------------------------------------------------------------\n")
# Out:
# learning rate =  1.5
# Initial Cost on Val dataset for this epoch 1 = 0.6237366296578414
# Error on this batch = 3.5088345346628147
# Error on this batch = 3.2503330591730224
# Cost on val dataset after 2 epochs is = 0.5735459576902762
# learning rate =  1.1905507889761495
# Initial Cost on Val dataset for this epoch 2 = 0.5735459576902762
# Error on this batch = 3.2500419652773984
# Error on this batch = 3.2498406027875912
# Cost on val dataset after 3 epochs is = 0.573504310178997
# learning rate =  1.040041911525952
# Initial Cost on Val dataset for this epoch 3 = 0.573504310178997
# Error on this batch = 3.2498871115243926
# Error on this batch = 3.249546208378276
# Cost on val dataset after 4 epochs is = 0.5734459308373425
# learning rate =  0.944940787421155
# Initial Cost on Val dataset for this epoch 4 = 0.5734459308373425
# Error on this batch = 3.249598229216718
# Error on this batch = 3.248327632236004
# Cost on val dataset after 5 epochs is = 0.5728770117371392
# learning rate =  0.8772053214638599
# Initial Cost on Val dataset for this epoch 5 = 0.5728770117371392
# Error on this batch = 3.24429047701246
# Error on this batch = 0.8166409386881458
# Cost on val dataset after 6 epochs is = 0.0990332064779687
# learning rate =  0.8254818122236567
# Initial Cost on Val dataset for this epoch 6 = 0.0990332064779687
# Error on this batch = 0.5597933261324726
# Error on this batch = 0.5152124045303844
# Cost on val dataset after 7 epochs is = 0.08874796847065311
# learning rate =  0.7841369378620654
# Initial Cost on Val dataset for this epoch 7 = 0.08874796847065311
# Error on this batch = 0.501700086513257
# Error on this batch = 0.49415117069391
# Cost on val dataset after 8 epochs is = 0.08674832170687982
# learning rate =  0.75
# Initial Cost on Val dataset for this epoch 8 = 0.08674832170687982
# Error on this batch = 0.4904714816663385
# Error on this batch = 0.4877940995726073
# Cost on val dataset after 9 epochs is = 0.08599539123649656
# learning rate =  0.7211247851537042
# Initial Cost on Val dataset for this epoch 9 = 0.08599539123649656
# Error on this batch = 0.48627487410597886
# Error on this batch = 0.4850056878763734
# Cost on val dataset after 10 epochs is = 0.08562852735438899
# learning rate =  0.6962383250419169
# Initial Cost on Val dataset for this epoch 10 = 0.08562852735438899
# Error on this batch = 0.4842445965069537
# Error on this batch = 0.4835375282205496
# Cost on val dataset after 11 epochs is = 0.08542252784256953
# learning rate =  0.6744664695339139
# Initial Cost on Val dataset for this epoch 11 = 0.08542252784256953
# Error on this batch = 0.48311317086544664
# Error on this batch = 0.48267485724950265
# Cost on val dataset after 12 epochs is = 0.08529587494522166
# learning rate =  0.6551853485522241
# Initial Cost on Val dataset for this epoch 12 = 0.08529587494522166
# Error on this batch = 0.4824233426221304
# Error on this batch = 0.48212929539580757
# Cost on val dataset after 13 epochs is = 0.08521291615879964
# learning rate =  0.6379355554244853
# Initial Cost on Val dataset for this epoch 13 = 0.08521291615879964
# Error on this batch = 0.48197567969536736
# Error on this batch = 0.48176556480682514
# Cost on val dataset after 14 epochs is = 0.08515596647255842
# learning rate =  0.6223699000246826
# Initial Cost on Val dataset for this epoch 14 = 0.08515596647255842
# Error on this batch = 0.48167152485610587
# Error on this batch = 0.4815132048873632
# Cost on val dataset after 15 epochs is = 0.08511542440995798
# learning rate =  0.6082201995573401
# Initial Cost on Val dataset for this epoch 15 = 0.08511542440995798
# Error on this batch = 0.4814574671322899
# Error on this batch = 0.4813325707817402
# Cost on val dataset after 16 epochs is = 0.08508570975344404
# learning rate =  0.5952753944880748
# Initial Cost on Val dataset for this epoch 16 = 0.08508570975344404
# Error on this batch = 0.4813025579645583
# Error on this batch = 0.4811999917050833
# Cost on val dataset after 17 epochs is = 0.08506340188858047
# learning rate =  0.5833666780992305
# Initial Cost on Val dataset for this epoch 17 = 0.08506340188858047
# Error on this batch = 0.48118788661375583
# Error on this batch = 0.48110065254107126
# Cost on val dataset after 18 epochs is = 0.08504631220862605
# learning rate =  0.5723571212766659
# Initial Cost on Val dataset for this epoch 18 = 0.08504631220862605
# Error on this batch = 0.48110139441317595
# Error on this batch = 0.4810249185199336
# Cost on val dataset after 19 epochs is = 0.08503299017192145
# learning rate =  0.5621342651764731
# Initial Cost on Val dataset for this epoch 19 = 0.08503299017192145
# Error on this batch = 0.4810351180099345
# Error on this batch = 0.48096632152959395
# Cost on val dataset after 20 epochs is = 0.08502244564366909
# learning rate =  0.552604724796058
# Initial Cost on Val dataset for this epoch 20 = 0.08502244564366909
# Error on this batch = 0.48098364242993535
# Error on this batch = 0.4809204015315397
# Cost on val dataset after 21 epochs is = 0.08501398562983618
# learning rate =  0.5436901865014462
# Initial Cost on Val dataset for this epoch 21 = 0.08501398562983618
# Error on this batch = 0.48094319312523054
# Error on this batch = 0.48088401205992803
# Cost on val dataset after 22 epochs is = 0.08500711455232779
# learning rate =  0.5353243916277062
# Initial Cost on Val dataset for this epoch 22 = 0.08500711455232779
# Error on this batch = 0.4809110824453225
# Error on this batch = 0.4808548891258342
# Cost on val dataset after 23 epochs is = 0.08500147131843802
# learning rate =  0.5274508303754389
# Initial Cost on Val dataset for this epoch 23 = 0.08500147131843802
# Error on this batch = 0.48088536103494206
# Error on this batch = 0.48083137545786614
# Cost on val dataset after 24 epochs is = 0.08499678847214077
# learning rate =  0.520020955762976
# Initial Cost on Val dataset for this epoch 24 = 0.08499678847214077
# Error on this batch = 0.48086459202618087
# Error on this batch = 0.4808122394304742
# Cost on val dataset after 25 epochs is = 0.08499286501606132
# learning rate =  0.5129927840030091
# Initial Cost on Val dataset for this epoch 25 = 0.08499286501606132
# Error on this batch = 0.48084770112894676
# Error on this batch = 0.48079655340327376
# Cost on val dataset after 26 epochs is = 0.0849895479308794
# learning rate =  0.5063297858843728
# Initial Cost on Val dataset for this epoch 26 = 0.0849895479308794
# Error on this batch = 0.48083387492778057
# Error on this batch = 0.4807836102988391
# Cost on val dataset after 27 epochs is = 0.08498671936327774
# learning rate =  0.5
# Initial Cost on Val dataset for this epoch 27 = 0.08498671936327774
# Error on this batch = 0.48082249054239307
# Error on this batch = 0.48077286535453234
# Cost on val dataset after 28 epochs is = 0.08498428758865276
# learning rate =  0.4939753170062622
# Initial Cost on Val dataset for this epoch 28 = 0.08498428758865276
# Error on this batch = 0.48081306613590735
# Error on this batch = 0.480763894785728
# Cost on val dataset after 29 epochs is = 0.08498218053641884
# learning rate =  0.48823089710650147
# Initial Cost on Val dataset for this epoch 29 = 0.08498218053641884
# Error on this batch = 0.4808052255494556
# Error on this batch = 0.48075636601796995
# Cost on val dataset after 30 epochs is = 0.08498034108549672
# learning rate =  0.4827446923028149
# Initial Cost on Val dataset for this epoch 30 = 0.08498034108549672
# Error on this batch = 0.48079867267585696
# Error on this batch = 0.4807500159642676
# Cost on val dataset after 31 epochs is = 0.08497872360201895
# learning rate =  0.4774970517686601
# Initial Cost on Val dataset for this epoch 31 = 0.08497872360201895
# Error on this batch = 0.4807931726537389
# Error on this batch = 0.48074463498102277
# Cost on val dataset after 32 epochs is = 0.08497729136134279
# learning rate =  0.4724703937105775
# Initial Cost on Val dataset for this epoch 32 = 0.08497729136134279
# Error on this batch = 0.4807885379067112
# Error on this batch = 0.4807400548869957
# Cost on val dataset after 33 epochs is = 0.08497601460788537
# learning rate =  0.467648930822808
# Initial Cost on Val dataset for this epoch 33 = 0.08497601460788537
# Error on this batch = 0.4807846176694301
# Error on this batch = 0.4807361399257162
# Cost on val dataset after 34 epochs is = 0.08497486908056423
# learning rate =  0.46301843924895625
# Initial Cost on Val dataset for this epoch 34 = 0.08497486908056423
# Error on this batch = 0.48078129005323905
# Error on this batch = 0.48073277988472657
# Cost on val dataset after 35 epochs is = 0.08497383488190724
# learning rate =  0.4585660630993198
# Initial Cost on Val dataset for this epoch 35 = 0.08497383488190724
# Error on this batch = 0.48077845598184044
# Error on this batch = 0.48072988481196255
# Cost on val dataset after 36 epochs is = 0.08497289560343634
# learning rate =  0.454280148208035
# Initial Cost on Val dataset for this epoch 36 = 0.08497289560343634
# Error on this batch = 0.4807760345179907
# Error on this batch = 0.480727380926359
# Cost on val dataset after 37 epochs is = 0.0849720376439701
# learning rate =  0.4501501000778427
# Initial Cost on Val dataset for this epoch 37 = 0.0849720376439701
# Error on this batch = 0.4807739592346358
# Error on this batch = 0.480725207429481
# Cost on val dataset after 38 epochs is = 0.08497124967443612
# learning rate =  0.4461662619442522
# Initial Cost on Val dataset for this epoch 38 = 0.08497124967443612
# Error on this batch = 0.48077217537710154
# Error on this batch = 0.48072331400266993
# Cost on val dataset after 39 epochs is = 0.08497052221486104
# learning rate =  0.44231980966270107
# Initial Cost on Val dataset for this epoch 39 = 0.08497052221486104
# Error on this batch = 0.48077063762927774
# Error on this batch = 0.48072165882981077
# Cost on val dataset after 40 epochs is = 0.08496984729791038
# learning rate =  0.43860266073192994
# Initial Cost on Val dataset for this epoch 40 = 0.08496984729791038
# Error on this batch = 0.48076930834445064
# Error on this batch = 0.48072020702605783
# Cost on val dataset after 41 epochs is = 0.08496921819968367
# learning rate =  0.43500739525144
# Initial Cost on Val dataset for this epoch 41 = 0.08496921819968367
# Error on this batch = 0.48076815613610585
# Error on this batch = 0.4807189293822299
# Cost on val dataset after 42 epochs is = 0.08496862922312241
# learning rate =  0.43152718699859105
# Initial Cost on Val dataset for this epoch 42 = 0.08496862922312241
# Error on this batch = 0.48076715474944
# Error on this batch = 0.48071780135623043
# Cost on val dataset after 43 epochs is = 0.08496807552283557
# learning rate =  0.4281557431228417
# Initial Cost on Val dataset for this epoch 43 = 0.08496807552283557
# Error on this batch = 0.4807662821531259
# Error on this batch = 0.48071680225893415
# Cost on val dataset after 44 epochs is = 0.0849675529627234
# learning rate =  0.4248872512070286
# Initial Cost on Val dataset for this epoch 44 = 0.0849675529627234
# Error on this batch = 0.4807655198048952
# Error on this batch = 0.4807159145940176
# Cost on val dataset after 45 epochs is = 0.0849670579997185
# learning rate =  0.42171633265087466
# Initial Cost on Val dataset for this epoch 45 = 0.0849670579997185
# Error on this batch = 0.48076485205503844
# Error on this batch = 0.4807151235203033
# Cost on val dataset after 46 epochs is = 0.08496658758843428
# learning rate =  0.4186380014997361
# Initial Cost on Val dataset for this epoch 46 = 0.08496658758843428
# Error on this batch = 0.48076426565990105
# Error on this batch = 0.4807144164120905
# Cost on val dataset after 47 epochs is = 0.08496613910263352
# learning rate =  0.4156476279794431
# Initial Cost on Val dataset for this epoch 47 = 0.08496613910263352
# Error on this batch = 0.48076374938352573
# Error on this batch = 0.4807137824982187
# Cost on val dataset after 48 epochs is = 0.0849657102702922
# learning rate =  0.4127409061118284
# Initial Cost on Val dataset for this epoch 48 = 0.0849657102702922
# Error on this batch = 0.4807632936702595
# Error on this batch = 0.4807132125646819
# Cost on val dataset after 49 epochs is = 0.08496529911970231
# learning rate =  0.40991382487979766
# Initial Cost on Val dataset for this epoch 49 = 0.08496529911970231
# Error on this batch = 0.48076289037473374
# Error on this batch = 0.4807126987087482
# Cost on val dataset after 50 epochs is = 0.08496490393457513
# learning rate =  0.407162642489236
# Initial Cost on Val dataset for this epoch 50 = 0.08496490393457513
# Error on this batch = 0.48076253253842155
# Error on this batch = 0.48071223413499353
# Cost on val dataset after 51 epochs is = 0.08496452321651322
# learning rate =  0.40448386334057895
# Initial Cost on Val dataset for this epoch 51 = 0.08496452321651322
# Error on this batch = 0.4807622142041534
# Error on this batch = 0.48071181298557103
# Cost on val dataset after 52 epochs is = 0.08496415565353832
# learning rate =  0.4018742173778433
# Initial Cost on Val dataset for this epoch 52 = 0.08496415565353832
# Error on this batch = 0.4807619302616801
# Error on this batch = 0.48071143019854573
# Cost on val dataset after 53 epochs is = 0.08496380009361439
# learning rate =  0.3993306415291746
# Initial Cost on Val dataset for this epoch 53 = 0.08496380009361439
# Error on this batch = 0.48076167631871913
# Error on this batch = 0.4807110813893148
# Cost on val dataset after 54 epochs is = 0.08496345552230572
# learning rate =  0.3968502629920499
# Initial Cost on Val dataset for this epoch 54 = 0.08496345552230572
# Error on this batch = 0.4807614485929861
# Error on this batch = 0.48071076275107916
# Cost on val dataset after 55 epochs is = 0.08496312104386912
# learning rate =  0.39443038414939435
# Initial Cost on Val dataset for this epoch 55 = 0.08496312104386912
# Error on this batch = 0.4807612438215638
# Error on this batch = 0.48071047097108577
# Cost on val dataset after 56 epochs is = 0.08496279586520769
# learning rate =  0.3920684689310327
# Initial Cost on Val dataset for this epoch 56 = 0.08496279586520769
# Error on this batch = 0.48076105918463524
# Error on this batch = 0.48071020315996493
# Cost on val dataset after 57 epochs is = 0.08496247928221616
# learning rate =  0.3897621304589171
# Initial Cost on Val dataset for this epoch 57 = 0.08496247928221616
# Error on this batch = 0.4807608922411532
# Error on this batch = 0.48070995679196915
# Cost on val dataset after 58 epochs is = 0.0849621706681311
# learning rate =  0.3875091198351191
# Initial Cost on Val dataset for this epoch 58 = 0.0849621706681311
# Error on this batch = 0.4807607408744564
# Error on this batch = 0.4807097296543158
# Cost on val dataset after 59 epochs is = 0.0849618694635664
# learning rate =  0.38530731594920475
# Initial Cost on Val dataset for this epoch 59 = 0.0849618694635664
# Error on this batch = 0.4807606032461938
# Error on this batch = 0.48070951980414833
# Cost on val dataset after 60 epochs is = 0.08496157516796983
# learning rate =  0.38315471619677655
# Initial Cost on Val dataset for this epoch 60 = 0.08496157516796983
# Error on this batch = 0.48076047775720804
# Error on this batch = 0.4807093255318922
# Cost on val dataset after 61 epochs is = 0.08496128733228
# learning rate =  0.38104942801404945
# Initial Cost on Val dataset for this epoch 61 = 0.08496128733228
# Error on this batch = 0.4807603630142613
# Error on this batch = 0.4807091453299886
# Cost on val dataset after 62 epochs is = 0.08496100555260121
# learning rate =  0.3789896611446424
# Initial Cost on Val dataset for this epoch 62 = 0.08496100555260121
# Error on this batch = 0.48076025780167536
# Error on this batch = 0.48070897786616346
# Cost on val dataset after 63 epochs is = 0.08496072946474245
# learning rate =  0.3769737205645769
# Initial Cost on Val dataset for this epoch 63 = 0.08496072946474245
# Error on this batch = 0.48076016105711794
# Error on this batch = 0.4807088219605282
# Cost on val dataset after 64 epochs is = 0.08496045873949251
# learning rate =  0.37500000000000006
# Initial Cost on Val dataset for this epoch 64 = 0.08496045873949251
# Error on this batch = 0.48076007185089104
# Error on this batch = 0.4807086765659249
# Cost on val dataset after 65 epochs is = 0.08496019307852311
# learning rate =  0.3730669759795744
# Initial Cost on Val dataset for this epoch 65 = 0.08496019307852311
# Error on this batch = 0.4807599893681861
# Error on this batch = 0.48070854075102526
# Cost on val dataset after 66 epochs is = 0.08495993221082936
# learning rate =  0.37117320236996454
# Initial Cost on Val dataset for this epoch 66 = 0.08495993221082936
# Error on this batch = 0.48075991289385456
# Error on this batch = 0.4807084136857702
# Cost on val dataset after 67 epochs is = 0.08495967588963071
# learning rate =  0.3693173053485204
# Initial Cost on Val dataset for this epoch 67 = 0.08495967588963071
# Error on this batch = 0.4807598417993188
# Error on this batch = 0.4807082946288048
# Cost on val dataset after 68 epochs is = 0.08495942388966768
# learning rate =  0.3674979787722335
# Initial Cost on Val dataset for this epoch 68 = 0.08495942388966768
# Error on this batch = 0.4807597755313029
# Error on this batch = 0.4807081829166141
# Cost on val dataset after 69 epochs is = 0.08495917600483889
# learning rate =  0.36571397990641485
# Initial Cost on Val dataset for this epoch 69 = 0.08495917600483889
# Error on this batch = 0.48075971360211794
# Error on this batch = 0.4807080779541154
# Cost on val dataset after 70 epochs is = 0.08495893204613206
# learning rate =  0.36396412548038803
# Initial Cost on Val dataset for this epoch 70 = 0.08495893204613206
# Error on this batch = 0.4807596555812749
# Error on this batch = 0.4807079792064971
# Cost on val dataset after 71 epochs is = 0.0849586918398087
# learning rate =  0.36224728804088757
# Initial Cost on Val dataset for this epoch 71 = 0.0849586918398087
# Error on this batch = 0.4807596010882329
# Error on this batch = 0.48070788619212673
# Cost on val dataset after 72 epochs is = 0.08495845522580857
# learning rate =  0.3605623925768521
# Initial Cost on Val dataset for this epoch 72 = 0.08495845522580857
# Error on this batch = 0.4807595497861219
# Error on this batch = 0.48070779847637907
# Cost on val dataset after 73 epochs is = 0.08495822205634493
# learning rate =  0.3589084133919559
# Initial Cost on Val dataset for this epoch 73 = 0.08495822205634493
# Error on this batch = 0.4807595013763009
# Error on this batch = 0.48070771566625553
# Cost on val dataset after 74 epochs is = 0.08495799219466522
# learning rate =  0.3572843712035789
# Initial Cost on Val dataset for this epoch 74 = 0.08495799219466522
# Error on this batch = 0.4807594555936352
# Error on this batch = 0.48070763740568584
# Cost on val dataset after 75 epochs is = 0.0849577655139562
# learning rate =  0.35568933044900636
# Initial Cost on Val dataset for this epoch 75 = 0.0849577655139562
# Error on this batch = 0.4807594122023919
# Error on this batch = 0.4807075633714193
# Cost on val dataset after 76 epochs is = 0.08495754189637467
# learning rate =  0.3541223967815126
# Initial Cost on Val dataset for this epoch 76 = 0.08495754189637467
# Error on this batch = 0.4807593709926688
# Error on this batch = 0.48070749326942563
# Cost on val dataset after 77 epochs is = 0.08495732123218803
# learning rate =  0.3525827147406408
# Initial Cost on Val dataset for this epoch 77 = 0.08495732123218803
# Error on this batch = 0.48075933177728397
# Error on this batch = 0.48070742683173834
# Cost on val dataset after 78 epochs is = 0.08495710341901133
# learning rate =  0.3510694655824727
# Initial Cost on Val dataset for this epoch 78 = 0.08495710341901133
# Error on this batch = 0.4807592943890632
# Error on this batch = 0.48070736381367923
# Cost on val dataset after 79 epochs is = 0.08495688836112798
# learning rate =  0.34958186525700846
# Initial Cost on Val dataset for this epoch 79 = 0.08495688836112798
# Error on this batch = 0.48075925867847136
# Error on this batch = 0.48070730399141814
# Cost on val dataset after 80 epochs is = 0.08495667596888487
# learning rate =  0.3481191625209585
# Initial Cost on Val dataset for this epoch 80 = 0.08495667596888487
# Error on this batch = 0.4807592245115426
# Error on this batch = 0.48070724715982005
# Cost on val dataset after 81 epochs is = 0.08495646615815239
# learning rate =  0.3466806371753174
# Initial Cost on Val dataset for this epoch 81 = 0.08495646615815239
# Error on this batch = 0.4807591917680697
# Error on this batch = 0.4807071931305461
# Cost on val dataset after 82 epochs is = 0.08495625884984155
# learning rate =  0.34526559841804116
# Initial Cost on Val dataset for this epoch 82 = 0.08495625884984155
# Error on this batch = 0.48075916034001703
# Error on this batch = 0.4807071417303739
# Cost on val dataset after 83 epochs is = 0.0849560539694719
# learning rate =  0.34387338330300826
# Initial Cost on Val dataset for this epoch 83 = 0.0849560539694719
# Error on this batch = 0.4807591301301299
# Error on this batch = 0.48070709279970986
# Cost on val dataset after 84 epochs is = 0.0849558514467837
# learning rate =  0.3425033552972207
# Initial Cost on Val dataset for this epoch 84 = 0.0849558514467837
# Error on this batch = 0.48075910105071407
# Error on this batch = 0.48070704619127114
# Cost on val dataset after 85 epochs is = 0.08495565121538984
# learning rate =  0.341154902928893
# Initial Cost on Val dataset for this epoch 85 = 0.08495565121538984
# Error on this batch = 0.4807590730225632
# Error on this batch = 0.48070700176891307
# Cost on val dataset after 86 epochs is = 0.0849554532124625
# learning rate =  0.3398274385197126
# Initial Cost on Val dataset for this epoch 86 = 0.0849554532124625
# Error on this batch = 0.4807590459740149
# Error on this batch = 0.4807069594065875
# Cost on val dataset after 87 epochs is = 0.08495525737845103
# learning rate =  0.3385203969951175
# Initial Cost on Val dataset for this epoch 87 = 0.08495525737845103
# Error on this batch = 0.4807590198401211
# Error on this batch = 0.48070691898741374
# Cost on val dataset after 88 epochs is = 0.08495506365682702
# learning rate =  0.33723323476695694
# Initial Cost on Val dataset for this epoch 88 = 0.08495506365682702
# Error on this batch = 0.4807589945619158
# Error on this batch = 0.4807068804028501
# Cost on val dataset after 89 epochs is = 0.08495487199385444
# learning rate =  0.33596542868336265
# Initial Cost on Val dataset for this epoch 89 = 0.08495487199385444
# Error on this batch = 0.4807589700857699
# Error on this batch = 0.48070684355195265
# Cost on val dataset after 90 epochs is = 0.08495468233838095
# learning rate =  0.3347164750410848
# Initial Cost on Val dataset for this epoch 90 = 0.08495468233838095
# Error on this batch = 0.4807589463628208
# Error on this batch = 0.4807068083407124
# Cost on val dataset after 91 epochs is = 0.08495449464164923
# learning rate =  0.3334858886559278
# Initial Cost on Val dataset for this epoch 91 = 0.08495449464164923
# Error on this batch = 0.48075892334846926
# Error on this batch = 0.48070677468146034
# Cost on val dataset after 92 epochs is = 0.08495430885712545
# learning rate =  0.3322732019872729
# Initial Cost on Val dataset for this epoch 92 = 0.08495430885712545
# Error on this batch = 0.48075890100193347
# Error on this batch = 0.48070674249233386
# Cost on val dataset after 93 epochs is = 0.08495412494034338
# learning rate =  0.33107796431298914
# Initial Cost on Val dataset for this epoch 93 = 0.08495412494034338
# Error on this batch = 0.4807588792858546
# Error on this batch = 0.48070671169679585
# Cost on val dataset after 94 epochs is = 0.08495394284876238
# learning rate =  0.3298997409513274
# Initial Cost on Val dataset for this epoch 94 = 0.08495394284876238
# Error on this batch = 0.48075885816594693
# Error on this batch = 0.4807066822232025
# Cost on val dataset after 95 epochs is = 0.08495376254163801
# learning rate =  0.3287381125266525
# Initial Cost on Val dataset for this epoch 95 = 0.08495376254163801
# Error on this batch = 0.4807588376106874
# Error on this batch = 0.48070665400441237
# Cost on val dataset after 96 epochs is = 0.08495358397990384
# learning rate =  0.32759267427611205
# Initial Cost on Val dataset for this epoch 96 = 0.08495358397990384
# Error on this batch = 0.48075881759104055
# Error on this batch = 0.4807066269774336
# Cost on val dataset after 97 epochs is = 0.0849534071260633
# learning rate =  0.32646303539455934
# Initial Cost on Val dataset for this epoch 97 = 0.0849534071260633
# Error on this batch = 0.4807587980802132
# Error on this batch = 0.4807066010831049
# Cost on val dataset after 98 epochs is = 0.08495323194409059
# learning rate =  0.3253488184152496
# Initial Cost on Val dataset for this epoch 98 = 0.08495323194409059
# Error on this batch = 0.4807587790534363
# Error on this batch = 0.48070657626580543
# Cost on val dataset after 99 epochs is = 0.08495305839934014
# learning rate =  0.324249658624014
# Initial Cost on Val dataset for this epoch 99 = 0.08495305839934014
# Error on this batch = 0.48075876048777083
# Error on this batch = 0.48070655247319166
# Cost on val dataset after 100 epochs is = 0.08495288645846293
# learning rate =  0.3231652035047826
# Initial Cost on Val dataset for this epoch 100 = 0.08495288645846293
# Error on this batch = 0.480758742361935
# Error on this batch = 0.480706529655959
# Cost on val dataset after 101 epochs is = 0.08495271608932999
# learning rate =  0.32209511221448506
# Initial Cost on Val dataset for this epoch 101 = 0.08495271608932999
# Error on this batch = 0.480758724656149
# Error on this batch = 0.4807065077676233
# Cost on val dataset after 102 epochs is = 0.08495254726096171
# learning rate =  0.32103905508549824
# Initial Cost on Val dataset for this epoch 102 = 0.08495254726096171
# Error on this batch = 0.4807587073519977
# Error on this batch = 0.48070648676432215
# Cost on val dataset after 103 epochs is = 0.08495237994346268
# learning rate =  0.3199967131539419
# Initial Cost on Val dataset for this epoch 103 = 0.08495237994346268
# Error on this batch = 0.48075869043230657
# Error on this batch = 0.48070646660463356
# Cost on val dataset after 104 epochs is = 0.08495221410796158
# learning rate =  0.31896777771224266
# Initial Cost on Val dataset for this epoch 104 = 0.08495221410796158
# Error on this batch = 0.48075867388103105
# Error on this batch = 0.48070644724940975
# Cost on val dataset after 105 epochs is = 0.08495204972655555
# learning rate =  0.317951949884498
# Initial Cost on Val dataset for this epoch 105 = 0.08495204972655555
# Error on this batch = 0.4807586576831578
# Error on this batch = 0.48070642866162444
# Cost on val dataset after 106 epochs is = 0.08495188677225865
# learning rate =  0.31694894022327386
# Initial Cost on Val dataset for this epoch 106 = 0.08495188677225865
# Error on this batch = 0.4807586418246156
# Error on this batch = 0.4807064108062339
# Cost on val dataset after 107 epochs is = 0.08495172521895418
# learning rate =  0.3159584683265631
# Initial Cost on Val dataset for this epoch 107 = 0.08495172521895418
# Error on this batch = 0.4807586262921952
# Error on this batch = 0.4807063936500477
# Cost on val dataset after 108 epochs is = 0.08495156504135033
# learning rate =  0.3149802624737183
# Initial Cost on Val dataset for this epoch 108 = 0.08495156504135033
# Error on this batch = 0.4807586110734775
# Error on this batch = 0.4807063771616106
# Cost on val dataset after 109 epochs is = 0.08495140621493891
# learning rate =  0.31401405927925385
# Initial Cost on Val dataset for this epoch 109 = 0.08495140621493891
# Error on this batch = 0.4807585961567692
# Error on this batch = 0.4807063613110944
# Cost on val dataset after 110 epochs is = 0.08495124871595708
# learning rate =  0.31305960336348476
# Initial Cost on Val dataset for this epoch 110 = 0.08495124871595708
# Error on this batch = 0.48075858153104395
# Error on this batch = 0.4807063460701962
# Cost on val dataset after 111 epochs is = 0.0849510925213516
# learning rate =  0.3121166470390388
# Initial Cost on Val dataset for this epoch 111 = 0.0849510925213516
# Error on this batch = 0.4807585671858899
# Error on this batch = 0.48070633141204605
# Cost on val dataset after 112 epochs is = 0.08495093760874549
# learning rate =  0.3111849500123413
# Initial Cost on Val dataset for this epoch 112 = 0.08495093760874549
# Error on this batch = 0.480758553111462
# Error on this batch = 0.48070631731112073
# Cost on val dataset after 113 epochs is = 0.08495078395640682
# learning rate =  0.31026427909923227
# Initial Cost on Val dataset for this epoch 113 = 0.08495078395640682
# Error on this batch = 0.480758539298439
# Error on this batch = 0.48070630374316403
# Cost on val dataset after 114 epochs is = 0.08495063154321966
# learning rate =  0.3093544079539258
# Initial Cost on Val dataset for this epoch 114 = 0.08495063154321966
# Error on this batch = 0.48075852573798444
# Error on this batch = 0.4807062906851127
# Cost on val dataset after 115 epochs is = 0.0849504803486568
# learning rate =  0.30845511681057786
# Initial Cost on Val dataset for this epoch 115 = 0.0849504803486568
# Error on this batch = 0.48075851242171125
# Error on this batch = 0.48070627811502803
# Cost on val dataset after 116 epochs is = 0.08495033035275414
# learning rate =  0.30756619223676956
# Initial Cost on Val dataset for this epoch 116 = 0.08495033035275414
# Error on this batch = 0.4807584993416494
# Error on this batch = 0.4807062660120313
# Cost on val dataset after 117 epochs is = 0.08495018153608672
# learning rate =  0.30668742689826056
# Initial Cost on Val dataset for this epoch 117 = 0.08495018153608672
# Error on this batch = 0.48075848649021696
# Error on this batch = 0.4807062543562448
# Cost on val dataset after 118 epochs is = 0.0849500338797461
# learning rate =  0.3058186193344055
# Initial Cost on Val dataset for this epoch 118 = 0.0849500338797461
# Error on this batch = 0.48075847386019305
# Error on this batch = 0.4807062431287356
# Cost on val dataset after 119 epochs is = 0.08494988736531933
# learning rate =  0.30495957374366384
# Initial Cost on Val dataset for this epoch 119 = 0.08494988736531933
# Error on this batch = 0.48075846144469403
# Error on this batch = 0.4807062323114649
# Cost on val dataset after 120 epochs is = 0.08494974197486883
# learning rate =  0.30411009977867004
# Initial Cost on Val dataset for this epoch 120 = 0.08494974197486883
# Error on this batch = 0.48075844923715083
# Error on this batch = 0.48070622188723827
# Cost on val dataset after 121 epochs is = 0.0849495976909136
# learning rate =  0.3032700123503612
# Initial Cost on Val dataset for this epoch 121 = 0.0849495976909136
# Error on this batch = 0.48075843723128886
# Error on this batch = 0.4807062118396613
# Cost on val dataset after 122 epochs is = 0.08494945449641146
# learning rate =  0.30243913144069146
# Initial Cost on Val dataset for this epoch 122 = 0.08494945449641146
# Error on this batch = 0.4807584254211094
# Error on this batch = 0.48070620215309684
# Cost on val dataset after 123 epochs is = 0.0849493123747424
# learning rate =  0.3016172819234887
# Initial Cost on Val dataset for this epoch 123 = 0.0849493123747424
# Error on this batch = 0.48075841380087264
# Error on this batch = 0.4807061928126252
# Cost on val dataset after 124 epochs is = 0.08494917130969248
# learning rate =  0.30080429339303844
# Initial Cost on Val dataset for this epoch 124 = 0.08494917130969248
# Error on this batch = 0.4807584023650817
# Error on this batch = 0.4807061838040073
# Cost on val dataset after 125 epochs is = 0.08494903128543906
# learning rate =  0.30000000000000004
# Initial Cost on Val dataset for this epoch 125 = 0.08494903128543906
# Error on this batch = 0.4807583911084685
# Error on this batch = 0.4807061751136491
# Cost on val dataset after 126 epochs is = 0.08494889228653647
# learning rate =  0.2992042402942877
# Initial Cost on Val dataset for this epoch 126 = 0.08494889228653647
# Error on this batch = 0.48075838002598065
# Error on this batch = 0.4807061667285689
# Cost on val dataset after 127 epochs is = 0.08494875429790252
# learning rate =  0.2984168570745668
# Initial Cost on Val dataset for this epoch 127 = 0.08494875429790252
# Error on this batch = 0.48075836911276826
# Error on this batch = 0.4807061586363669
# Cost on val dataset after 128 epochs is = 0.08494861730480581
# learning rate =  0.29763769724403744
# Initial Cost on Val dataset for this epoch 128 = 0.08494861730480581
# Error on this batch = 0.4807583583641741
# Error on this batch = 0.48070615082519524
# Cost on val dataset after 129 epochs is = 0.08494848129285347
# learning rate =  0.2968666116721965
# Initial Cost on Val dataset for this epoch 129 = 0.08494848129285347
# Error on this batch = 0.4807583477757218
# Error on this batch = 0.48070614328373124
# Cost on val dataset after 130 epochs is = 0.08494834624797966
# learning rate =  0.2961034550622857
# Initial Cost on Val dataset for this epoch 130 = 0.08494834624797966
# Error on this batch = 0.4807583373431067
# Error on this batch = 0.4807061360011515
# Cost on val dataset after 131 epochs is = 0.08494821215643464
# learning rate =  0.29534808582414945
# Initial Cost on Val dataset for this epoch 131 = 0.08494821215643464
# Error on this batch = 0.4807583270621871
# Error on this batch = 0.480706128967107
# Cost on val dataset after 132 epochs is = 0.08494807900477418
# learning rate =  0.2946003659522436
# Initial Cost on Val dataset for this epoch 132 = 0.08494807900477418
# Error on this batch = 0.48075831692897525
# Error on this batch = 0.48070612217170067
# Cost on val dataset after 133 epochs is = 0.08494794677984971
# learning rate =  0.29386016090854794
# Initial Cost on Val dataset for this epoch 133 = 0.08494794677984971
# Error on this batch = 0.48075830693963006
# Error on this batch = 0.4807061156054654
# Cost on val dataset after 134 epochs is = 0.08494781546879873
# learning rate =  0.293127339510151
# Initial Cost on Val dataset for this epoch 134 = 0.08494781546879873
# Error on this batch = 0.4807582970904497
# Error on this batch = 0.48070610925934354
# Cost on val dataset after 135 epochs is = 0.08494768505903585
# learning rate =  0.2924017738212866
# Initial Cost on Val dataset for this epoch 135 = 0.08494768505903585
# Error on this batch = 0.4807582873778648
# Error on this batch = 0.48070610312466727
# Cost on val dataset after 136 epochs is = 0.08494755553824397
# learning rate =  0.29168333904961524
# Initial Cost on Val dataset for this epoch 136 = 0.08494755553824397
# Error on this batch = 0.48075827779843205
# Error on this batch = 0.48070609719314067
# Cost on val dataset after 137 epochs is = 0.08494742689436609
# learning rate =  0.2909719134465526
# Initial Cost on Val dataset for this epoch 137 = 0.08494742689436609
# Error on this batch = 0.48075826834882845
# Error on this batch = 0.4807060914568216
# Cost on val dataset after 138 epochs is = 0.08494729911559734
# learning rate =  0.29026737821146
# Initial Cost on Val dataset for this epoch 138 = 0.08494729911559734
# Error on this batch = 0.48075825902584557
# Error on this batch = 0.48070608590810593
# Cost on val dataset after 139 epochs is = 0.08494717219037748
# learning rate =  0.28956961739951936
# Initial Cost on Val dataset for this epoch 139 = 0.08494717219037748
# Error on this batch = 0.4807582498263846
# Error on this batch = 0.4807060805397116
# Cost on val dataset after 140 epochs is = 0.0849470461073835
# learning rate =  0.28887851783312685
# Initial Cost on Val dataset for this epoch 140 = 0.0849470461073835
# Error on this batch = 0.4807582407474511
# Error on this batch = 0.4807060753446635
# Cost on val dataset after 141 epochs is = 0.08494692085552283
# learning rate =  0.28819396901664524
# Initial Cost on Val dataset for this epoch 141 = 0.08494692085552283
# Error on this batch = 0.4807582317861507
# Error on this batch = 0.48070607031628004
# Cost on val dataset after 142 epochs is = 0.08494679642392644
# learning rate =  0.2875158630543661
# Initial Cost on Val dataset for this epoch 142 = 0.08494679642392644
# Error on this batch = 0.48075822293968473
# Error on this batch = 0.4807060654481592
# Cost on val dataset after 143 epochs is = 0.08494667280194265
# learning rate =  0.2868440945715393
# Initial Cost on Val dataset for this epoch 143 = 0.08494667280194265
# Error on this batch = 0.4807582142053461
# Error on this batch = 0.48070606073416616
# Cost on val dataset after 144 epochs is = 0.08494654997913083
# learning rate =  0.28617856063833297
# Initial Cost on Val dataset for this epoch 144 = 0.08494654997913083
# Error on this batch = 0.4807582055805152
# Error on this batch = 0.48070605616842105
# Cost on val dataset after 145 epochs is = 0.08494642794525561
# learning rate =  0.2855191606965982
# Initial Cost on Val dataset for this epoch 145 = 0.08494642794525561
# Error on this batch = 0.4807581970626567
# Error on this batch = 0.48070605174528797
# Cost on val dataset after 146 epochs is = 0.08494630669028105
# learning rate =  0.28486579648931415
# Initial Cost on Val dataset for this epoch 146 = 0.08494630669028105
# Error on this batch = 0.4807581886493159
# Error on this batch = 0.4807060474593635
# Cost on val dataset after 147 epochs is = 0.0849461862043653
# learning rate =  0.2842183719925994
# Initial Cost on Val dataset for this epoch 147 = 0.0849461862043653
# Error on this batch = 0.48075818033811546
# Error on this batch = 0.4807060433054669
# Cost on val dataset after 148 epochs is = 0.0849460664778553
# learning rate =  0.2835767933501789
# Initial Cost on Val dataset for this epoch 148 = 0.0849460664778553
# Error on this batch = 0.4807581721267522
# Error on this batch = 0.48070603927862965
# Cost on val dataset after 149 epochs is = 0.08494594750128172
# learning rate =  0.28294096881020125
# Initial Cost on Val dataset for this epoch 149 = 0.08494594750128172
# Error on this batch = 0.48075816401299437
# Error on this batch = 0.48070603537408674
# Cost on val dataset after 150 epochs is = 0.08494582926535409
# learning rate =  0.2823108086643086
# Initial Cost on Val dataset for this epoch 150 = 0.08494582926535409
# Error on this batch = 0.480758155994679
# Error on this batch = 0.48070603158726727
# Cost on val dataset after 151 epochs is = 0.084945711760956
# learning rate =  0.2816862251888624
# Initial Cost on Val dataset for this epoch 151 = 0.084945711760956
# Error on this batch = 0.4807581480697087
# Error on this batch = 0.4807060279137862
# Cost on val dataset after 152 epochs is = 0.08494559497914078
# learning rate =  0.2810671325882366
# Initial Cost on Val dataset for this epoch 152 = 0.08494559497914078
# Error on this batch = 0.4807581402360498
# Error on this batch = 0.48070602434943616
# Cost on val dataset after 153 epochs is = 0.08494547891112696
# learning rate =  0.2804534469400918
# Initial Cost on Val dataset for this epoch 153 = 0.08494547891112696
# Error on this batch = 0.4807581324917294
# Error on this batch = 0.48070602089017983
# Cost on val dataset after 154 epochs is = 0.08494536354829406
# learning rate =  0.2798450861425484
# Initial Cost on Val dataset for this epoch 154 = 0.08494536354829406
# Error on this batch = 0.4807581248348336
# Error on this batch = 0.4807060175321425
# Cost on val dataset after 155 epochs is = 0.0849452488821786
# learning rate =  0.27924196986318184
# Initial Cost on Val dataset for this epoch 155 = 0.0849452488821786
# Error on this batch = 0.4807581172635051
# Error on this batch = 0.48070601427160514
# Cost on val dataset after 156 epochs is = 0.08494513490447009
# learning rate =  0.2786440194897654
# Initial Cost on Val dataset for this epoch 156 = 0.08494513490447009
# Error on this batch = 0.4807581097759408
# Error on this batch = 0.4807060111049975
# Cost on val dataset after 157 epochs is = 0.08494502160700729
# learning rate =  0.2780511580826894
# Initial Cost on Val dataset for this epoch 157 = 0.08494502160700729
# Error on this batch = 0.48075810237039046
# Error on this batch = 0.48070600802889224
# Cost on val dataset after 158 epochs is = 0.08494490898177451
# learning rate =  0.2774633103289903
# Initial Cost on Val dataset for this epoch 158 = 0.08494490898177451
# Error on this batch = 0.4807580950451543
# Error on this batch = 0.4807060050399983
# Cost on val dataset after 159 epochs is = 0.08494479702089804
# learning rate =  0.276880402497925
# Initial Cost on Val dataset for this epoch 159 = 0.08494479702089804
# Error on this batch = 0.48075808779858153
# Error on this batch = 0.4807060021351554
# Cost on val dataset after 160 epochs is = 0.08494468571664268
# learning rate =  0.276302362398029
# Initial Cost on Val dataset for this epoch 160 = 0.08494468571664268
# Error on this batch = 0.4807580806290684
# Error on this batch = 0.48070599931132846
# Cost on val dataset after 161 epochs is = 0.08494457506140853
# learning rate =  0.2757291193356003
# Initial Cost on Val dataset for this epoch 161 = 0.08494457506140853
# Error on this batch = 0.48075807353505656
# Error on this batch = 0.48070599656560237
# Cost on val dataset after 162 epochs is = 0.08494446504772765
# learning rate =  0.27516060407455223
# Initial Cost on Val dataset for this epoch 162 = 0.08494446504772765
# Error on this batch = 0.48075806651503167
# Error on this batch = 0.48070599389517654
# Cost on val dataset after 163 epochs is = 0.08494435566826103
# learning rate =  0.27459674879758383
# Initial Cost on Val dataset for this epoch 163 = 0.08494435566826103
# Error on this batch = 0.48075805956752166
# Error on this batch = 0.48070599129736075
# Cost on val dataset after 164 epochs is = 0.08494424691579548
# learning rate =  0.2740374870686142
# Initial Cost on Val dataset for this epoch 164 = 0.08494424691579548
# Error on this batch = 0.4807580526910955
# Error on this batch = 0.4807059887695702
# Cost on val dataset after 165 epochs is = 0.08494413878324082
# learning rate =  0.27348275379643444
# Initial Cost on Val dataset for this epoch 165 = 0.08494413878324082
# Error on this batch = 0.4807580458843615
# Error on this batch = 0.480705986309321
# Cost on val dataset after 166 epochs is = 0.08494403126362693
# learning rate =  0.2729324851995296
# Initial Cost on Val dataset for this epoch 166 = 0.08494403126362693
# Error on this batch = 0.4807580391459663
# Error on this batch = 0.4807059839142259
# Cost on val dataset after 167 epochs is = 0.08494392435010098
# learning rate =  0.27238661877202625
# Initial Cost on Val dataset for this epoch 167 = 0.08494392435010098
# Error on this batch = 0.4807580324745935
# Error on this batch = 0.48070598158199107
# Cost on val dataset after 168 epochs is = 0.08494381803592496
# learning rate =  0.2718450932507231
# Initial Cost on Val dataset for this epoch 168 = 0.08494381803592496
# Error on this batch = 0.4807580258689623
# Error on this batch = 0.4807059793104111
# Cost on val dataset after 169 epochs is = 0.08494371231447284
# learning rate =  0.27130784858316437
# Initial Cost on Val dataset for this epoch 169 = 0.08494371231447284
# Error on this batch = 0.48075801932782625
# Error on this batch = 0.48070597709736573
# Cost on val dataset after 170 epochs is = 0.08494360717922823
# learning rate =  0.27077482589671686
# Initial Cost on Val dataset for this epoch 170 = 0.08494360717922823
# Error on this batch = 0.4807580128499725
# Error on this batch = 0.48070597494081724
# Cost on val dataset after 171 epochs is = 0.08494350262378189
# learning rate =  0.2702459674686131
# Initial Cost on Val dataset for this epoch 171 = 0.08494350262378189
# Error on this batch = 0.4807580064342203
# Error on this batch = 0.48070597283880573
# Cost on val dataset after 172 epochs is = 0.08494339864182927
# learning rate =  0.26972121669692517
# Initial Cost on Val dataset for this epoch 172 = 0.08494339864182927
# Error on this batch = 0.48075800007942016
# Error on this batch = 0.48070597078944666
# Cost on val dataset after 173 epochs is = 0.08494329522716837
# learning rate =  0.2692005180724355
# Initial Cost on Val dataset for this epoch 173 = 0.08494329522716837
# Error on this batch = 0.48075799378445283
# Error on this batch = 0.48070596879092775
# Cost on val dataset after 174 epochs is = 0.08494319237369743
# learning rate =  0.268683817151371
# Initial Cost on Val dataset for this epoch 174 = 0.08494319237369743
# Error on this batch = 0.4807579875482284
# Error on this batch = 0.4807059668415059
# Cost on val dataset after 175 epochs is = 0.08494309007541272
# learning rate =  0.26817106052897033
# Initial Cost on Val dataset for this epoch 175 = 0.08494309007541272
# Error on this batch = 0.480757981369685
# Error on this batch = 0.48070596493950435
# Cost on val dataset after 176 epochs is = 0.08494298832640644
# learning rate =  0.2676621958138531
# Initial Cost on Val dataset for this epoch 176 = 0.08494298832640644
# Error on this batch = 0.48075797524778846
# Error on this batch = 0.48070596308331
# Cost on val dataset after 177 epochs is = 0.08494288712086476
# learning rate =  0.26715717160316327
# Initial Cost on Val dataset for this epoch 177 = 0.08494288712086476
# Error on this batch = 0.4807579691815309
# Error on this batch = 0.4807059612713711
# Cost on val dataset after 178 epochs is = 0.08494278645306569
# learning rate =  0.2666559374584585
# Initial Cost on Val dataset for this epoch 178 = 0.08494278645306569
# Error on this batch = 0.48075796316993014
# Error on this batch = 0.48070595950219436
# Cost on val dataset after 179 epochs is = 0.08494268631737721
# learning rate =  0.26615844388231935
# Initial Cost on Val dataset for this epoch 179 = 0.08494268631737721
# Error on this batch = 0.4807579572120291
# Error on this batch = 0.48070595777434294
# Cost on val dataset after 180 epochs is = 0.08494258670825544
# cost initial= 0.08494268631737721 , cost final=0.08494258670825544 , change in cost= -9.960912177031656e-08
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 1 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 180.000
# The training time = 9.575sec
# The training accuracy is = 3.973%
# The validation accuracy is = 3.128%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# learning rate =  1.5
# Initial Cost on Val dataset for this epoch 1 = 0.7211481339157843
# Error on this batch = 4.153921484961275
# Error on this batch = 0.488797181209911
# Cost on val dataset after 2 epochs is = 0.08525534289840886
# learning rate =  1.1905507889761495
# Initial Cost on Val dataset for this epoch 2 = 0.08525534289840886
# Error on this batch = 0.48275458024713863
# Error on this batch = 0.4814543168276639
# Cost on val dataset after 3 epochs is = 0.08493283989289399
# learning rate =  1.040041911525952
# Initial Cost on Val dataset for this epoch 3 = 0.08493283989289399
# Error on this batch = 0.48095847896118005
# Error on this batch = 0.4807734397833828
# Cost on val dataset after 4 epochs is = 0.08486935798909309
# learning rate =  0.944940787421155
# Initial Cost on Val dataset for this epoch 4 = 0.08486935798909309
# Error on this batch = 0.480630200162001
# Error on this batch = 0.4805731455092907
# Cost on val dataset after 5 epochs is = 0.08484467877233692
# learning rate =  0.8772053214638599
# Initial Cost on Val dataset for this epoch 5 = 0.08484467877233692
# Error on this batch = 0.48052162414500826
# Error on this batch = 0.48046637104316403
# Cost on val dataset after 6 epochs is = 0.08482966846272112
# learning rate =  0.8254818122236567
# Initial Cost on Val dataset for this epoch 6 = 0.08482966846272112
# Error on this batch = 0.4804682193772923
# Error on this batch = 0.48037960546963293
# Cost on val dataset after 7 epochs is = 0.08481743395880666
# learning rate =  0.7841369378620654
# Initial Cost on Val dataset for this epoch 7 = 0.08481743395880666
# Error on this batch = 0.4804303335326705
# Error on this batch = 0.4802917958793775
# Cost on val dataset after 8 epochs is = 0.08480578795583898
# learning rate =  0.75
# Initial Cost on Val dataset for this epoch 8 = 0.08480578795583898
# Error on this batch = 0.4803949273842564
# Error on this batch = 0.4801967256289497
# Cost on val dataset after 9 epochs is = 0.08479388184078877
# learning rate =  0.7211247851537042
# Initial Cost on Val dataset for this epoch 9 = 0.08479388184078877
# Error on this batch = 0.48035687054243953
# Error on this batch = 0.4800951571319192
# Cost on val dataset after 10 epochs is = 0.08478134147348688
# learning rate =  0.6962383250419169
# Initial Cost on Val dataset for this epoch 10 = 0.08478134147348688
# Error on this batch = 0.48031405844324937
# Error on this batch = 0.47999154446100123
# Cost on val dataset after 11 epochs is = 0.08476800658927008
# learning rate =  0.6744664695339139
# Initial Cost on Val dataset for this epoch 11 = 0.08476800658927008
# Error on this batch = 0.48026586777778896
# Error on this batch = 0.4798905870892831
# Cost on val dataset after 12 epochs is = 0.08475383531282989
# learning rate =  0.6551853485522241
# Initial Cost on Val dataset for this epoch 12 = 0.08475383531282989
# Error on this batch = 0.48021252851748425
# Error on this batch = 0.47979454747943634
# Cost on val dataset after 13 epochs is = 0.08473883787509437
# learning rate =  0.6379355554244853
# ...
# Initial Cost on Val dataset for this epoch 1435 = 0.07508945897077182
# Error on this batch = 0.4349195745400766
# Error on this batch = 0.43500020109700577
# Cost on val dataset after 1436 epochs is = 0.07508903264478034
# learning rate =  0.132955542295615
# Initial Cost on Val dataset for this epoch 1436 = 0.07508903264478034
# Error on this batch = 0.43491427173315045
# Error on this batch = 0.43499669304992894
# Cost on val dataset after 1437 epochs is = 0.0750886068908828
# learning rate =  0.13292469414084288
# Initial Cost on Val dataset for this epoch 1437 = 0.0750886068908828
# Error on this batch = 0.43490894826445103
# Error on this batch = 0.4349931857601173
# Cost on val dataset after 1438 epochs is = 0.07508818171296029
# learning rate =  0.13289387459553678
# Initial Cost on Val dataset for this epoch 1438 = 0.07508818171296029
# Error on this batch = 0.4349036039807197
# Error on this batch = 0.43498967925076115
# Cost on val dataset after 1439 epochs is = 0.07508775711477951
# learning rate =  0.1328630836132958
# Initial Cost on Val dataset for this epoch 1439 = 0.07508775711477951
# Error on this batch = 0.43489823873473493
# Error on this batch = 0.43498617354365066
# Cost on val dataset after 1440 epochs is = 0.07508733310000061
# learning rate =  0.1328323211478264
# Initial Cost on Val dataset for this epoch 1440 = 0.07508733310000061
# Error on this batch = 0.4348928523853043
# Error on this batch = 0.4349826686592344
# Cost on val dataset after 1441 epochs is = 0.07508690967218616
# learning rate =  0.1328015871529423
# Initial Cost on Val dataset for this epoch 1441 = 0.07508690967218616
# Error on this batch = 0.434887444797248
# Error on this batch = 0.4349791646166799
# Cost on val dataset after 1442 epochs is = 0.07508648683481035
# learning rate =  0.13277088158256392
# Initial Cost on Val dataset for this epoch 1442 = 0.07508648683481035
# Error on this batch = 0.434882015841376
# Error on this batch = 0.43497566143393784
# Cost on val dataset after 1443 epochs is = 0.07508606459126914
# learning rate =  0.13274020439071815
# Initial Cost on Val dataset for this epoch 1443 = 0.07508606459126914
# Error on this batch = 0.43487656539445857
# Error on this batch = 0.43497215912780673
# Cost on val dataset after 1444 epochs is = 0.07508564294489053
# learning rate =  0.13270955553153804
# Initial Cost on Val dataset for this epoch 1444 = 0.07508564294489053
# Error on this batch = 0.43487109333919266
# Error on this batch = 0.43496865771400006
# Cost on val dataset after 1445 epochs is = 0.07508522189894541
# learning rate =  0.1326789349592625
# Initial Cost on Val dataset for this epoch 1445 = 0.07508522189894541
# Error on this batch = 0.43486559956416615
# Error on this batch = 0.43496515720721435
# Cost on val dataset after 1446 epochs is = 0.07508480145665855
# learning rate =  0.1326483426282359
# Initial Cost on Val dataset for this epoch 1446 = 0.07508480145665855
# Error on this batch = 0.4348600839638209
# Error on this batch = 0.43496165762119776
# Cost on val dataset after 1447 epochs is = 0.07508438162121975
# learning rate =  0.13261777849290787
# Initial Cost on Val dataset for this epoch 1447 = 0.07508438162121975
# Error on this batch = 0.43485454643841454
# Error on this batch = 0.434958158968819
# Cost on val dataset after 1448 epochs is = 0.07508396239579511
# learning rate =  0.13258724250783283
# Initial Cost on Val dataset for this epoch 1448 = 0.07508396239579511
# Error on this batch = 0.4348489868939853
# Error on this batch = 0.4349546612621367
# Cost on val dataset after 1449 epochs is = 0.07508354378353832
# learning rate =  0.13255673462766987
# Initial Cost on Val dataset for this epoch 1449 = 0.07508354378353832
# Error on this batch = 0.4348434052423187
# Error on this batch = 0.4349511645124678
# Cost on val dataset after 1450 epochs is = 0.07508312578760154
# learning rate =  0.13252625480718228
# Initial Cost on Val dataset for this epoch 1450 = 0.07508312578760154
# Error on this batch = 0.4348378014009161
# Error on this batch = 0.434947668730455
# Cost on val dataset after 1451 epochs is = 0.07508270841114645
# learning rate =  0.1324958030012373
# Initial Cost on Val dataset for this epoch 1451 = 0.07508270841114645
# Error on this batch = 0.43483217529297125
# Error on this batch = 0.43494417392613444
# Cost on val dataset after 1452 epochs is = 0.07508229165735471
# learning rate =  0.13246537916480583
# Initial Cost on Val dataset for this epoch 1452 = 0.07508229165735471
# Error on this batch = 0.43482652684734846
# Error on this batch = 0.43494068010900033
# Cost on val dataset after 1453 epochs is = 0.07508187552943814
# learning rate =  0.13243498325296207
# Initial Cost on Val dataset for this epoch 1453 = 0.07508187552943814
# Error on this batch = 0.4348208559985692
# Error on this batch = 0.43493718728806924
# Cost on val dataset after 1454 epochs is = 0.07508146003064844
# learning rate =  0.1324046152208832
# Initial Cost on Val dataset for this epoch 1454 = 0.07508146003064844
# Error on this batch = 0.43481516268680376
# Error on this batch = 0.43493369547194266
# Cost on val dataset after 1455 epochs is = 0.07508104516428638
# learning rate =  0.13237427502384924
# Initial Cost on Val dataset for this epoch 1455 = 0.07508104516428638
# Error on this batch = 0.4348094468578714
# Error on this batch = 0.43493020466886556
# Cost on val dataset after 1456 epochs is = 0.07508063093371029
# learning rate =  0.13234396261724243
# Initial Cost on Val dataset for this epoch 1456 = 0.07508063093371029
# Error on this batch = 0.4348037084632458
# Error on this batch = 0.43492671488678564
# Cost on val dataset after 1457 epochs is = 0.075080217342344
# learning rate =  0.13231367795654728
# Initial Cost on Val dataset for this epoch 1457 = 0.075080217342344
# Error on this batch = 0.43479794746006983
# Error on this batch = 0.4349232261334079
# Cost on val dataset after 1458 epochs is = 0.07507980439368399
# learning rate =  0.13228342099735
# Initial Cost on Val dataset for this epoch 1458 = 0.07507980439368399
# Error on this batch = 0.4347921638111757
# Error on this batch = 0.43491973841624754
# Cost on val dataset after 1459 epochs is = 0.07507939209130576
# learning rate =  0.13225319169533828
# Initial Cost on Val dataset for this epoch 1459 = 0.07507939209130576
# Error on this batch = 0.43478635748511424
# Error on this batch = 0.4349162517426802
# Cost on val dataset after 1460 epochs is = 0.0750789804388694
# learning rate =  0.13222299000630108
# Initial Cost on Val dataset for this epoch 1460 = 0.0750789804388694
# Error on this batch = 0.43478052845618986
# Error on this batch = 0.4349127661199893
# Cost on val dataset after 1461 epochs is = 0.07507856944012427
# learning rate =  0.13219281588612825
# Initial Cost on Val dataset for this epoch 1461 = 0.07507856944012427
# Error on this batch = 0.43477467670450237
# Error on this batch = 0.43490928155541014
# Cost on val dataset after 1462 epochs is = 0.07507815909891276
# learning rate =  0.13216266929081014
# Initial Cost on Val dataset for this epoch 1462 = 0.07507815909891276
# Error on this batch = 0.4347688022159947
# Error on this batch = 0.43490579805617247
# Cost on val dataset after 1463 epochs is = 0.07507774941917326
# learning rate =  0.13213255017643744
# Initial Cost on Val dataset for this epoch 1463 = 0.07507774941917326
# Error on this batch = 0.43476290498250586
# Error on this batch = 0.4349023156295378
# Cost on val dataset after 1464 epochs is = 0.07507734040494203
# learning rate =  0.1321024584992009
# Initial Cost on Val dataset for this epoch 1464 = 0.07507734040494203
# Error on this batch = 0.4347569850018286
# Error on this batch = 0.4348988342828367
# Cost on val dataset after 1465 epochs is = 0.0750769320603542
# learning rate =  0.1320723942153909
# Initial Cost on Val dataset for this epoch 1465 = 0.0750769320603542
# Error on this batch = 0.4347510422777702
# Error on this batch = 0.43489535402350044
# Cost on val dataset after 1466 epochs is = 0.07507652438964378
# learning rate =  0.13204235728139727
# Initial Cost on Val dataset for this epoch 1466 = 0.07507652438964378
# Error on this batch = 0.43474507682021674
# Error on this batch = 0.43489187485909164
# Cost on val dataset after 1467 epochs is = 0.07507611739714279
# learning rate =  0.1320123476537089
# Initial Cost on Val dataset for this epoch 1467 = 0.07507611739714279
# Error on this batch = 0.4347390886451972
# Error on this batch = 0.4348883967973311
# Cost on val dataset after 1468 epochs is = 0.07507571108727928
# learning rate =  0.13198236528891355
# Initial Cost on Val dataset for this epoch 1468 = 0.07507571108727928
# Error on this batch = 0.43473307777494974
# Error on this batch = 0.4348849198461223
# Cost on val dataset after 1469 epochs is = 0.07507530546457472
# learning rate =  0.1319524101436975
# Initial Cost on Val dataset for this epoch 1469 = 0.07507530546457472
# Error on this batch = 0.43472704423798575
# Error on this batch = 0.43488144401357287
# Cost on val dataset after 1470 epochs is = 0.07507490053364005
# learning rate =  0.13192248217484528
# Initial Cost on Val dataset for this epoch 1470 = 0.07507490053364005
# Error on this batch = 0.43472098806915266
# Error on this batch = 0.43487796930801403
# Cost on val dataset after 1471 epochs is = 0.07507449629917126
# learning rate =  0.1318925813392393
# Initial Cost on Val dataset for this epoch 1471 = 0.07507449629917126
# Error on this batch = 0.43471490930969175
# Error on this batch = 0.434874495738016
# Cost on val dataset after 1472 epochs is = 0.07507409276594379
# learning rate =  0.13186270759385976
# Initial Cost on Val dataset for this epoch 1472 = 0.07507409276594379
# Error on this batch = 0.4347088080072929
# Error on this batch = 0.4348710233124033
# Cost on val dataset after 1473 epochs is = 0.07507368993880639
# learning rate =  0.13183286089578414
# Initial Cost on Val dataset for this epoch 1473 = 0.07507368993880639
# Error on this batch = 0.43470268421614167
# Error on this batch = 0.43486755204026567
# Cost on val dataset after 1474 epochs is = 0.075073287822674
# learning rate =  0.13180304120218697
# Initial Cost on Val dataset for this epoch 1474 = 0.075073287822674
# Error on this batch = 0.43469653799695857
# Error on this batch = 0.4348640819309675
# Cost on val dataset after 1475 epochs is = 0.07507288642252
# learning rate =  0.13177324847033972
# Initial Cost on Val dataset for this epoch 1475 = 0.07507288642252
# Error on this batch = 0.43469036941703076
# Error on this batch = 0.43486061299415585
# Cost on val dataset after 1476 epochs is = 0.07507248574336775
# learning rate =  0.13174348265761027
# Initial Cost on Val dataset for this epoch 1476 = 0.07507248574336775
# Error on this batch = 0.4346841785502314
# Error on this batch = 0.43485714523976543
# Cost on val dataset after 1477 epochs is = 0.0750720857902816
# learning rate =  0.13171374372146274
# Initial Cost on Val dataset for this epoch 1477 = 0.0750720857902816
# Error on this batch = 0.43467796547702864
# Error on this batch = 0.4348536786780221
# Cost on val dataset after 1478 epochs is = 0.07507168656835718
# learning rate =  0.13168403161945727
# Initial Cost on Val dataset for this epoch 1478 = 0.07507168656835718
# Error on this batch = 0.43467173028448036
# Error on this batch = 0.4348502133194453
# Cost on val dataset after 1479 epochs is = 0.07507128808271142
# learning rate =  0.1316543463092496
# Initial Cost on Val dataset for this epoch 1479 = 0.07507128808271142
# Error on this batch = 0.43466547306621606
# Error on this batch = 0.43484674917484795
# Cost on val dataset after 1480 epochs is = 0.07507089033847188
# learning rate =  0.1316246877485909
# Initial Cost on Val dataset for this epoch 1480 = 0.07507089033847188
# Error on this batch = 0.43465919392240204
# Error on this batch = 0.4348432862553355
# Cost on val dataset after 1481 epochs is = 0.07507049334076599
# learning rate =  0.1315950558953274
# Initial Cost on Val dataset for this epoch 1481 = 0.07507049334076599
# Error on this batch = 0.43465289295969056
# Error on this batch = 0.43483982457230375
# Cost on val dataset after 1482 epochs is = 0.0750700970947098
# learning rate =  0.1315654507074003
# Initial Cost on Val dataset for this epoch 1482 = 0.0750700970947098
# Error on this batch = 0.43464657029115217
# Error on this batch = 0.4348363641374347
# Cost on val dataset after 1483 epochs is = 0.07506970160539658
# learning rate =  0.1315358721428452
# Initial Cost on Val dataset for this epoch 1483 = 0.07506970160539658
# Error on this batch = 0.43464022603618846
# Error on this batch = 0.4348329049626925
# Cost on val dataset after 1484 epochs is = 0.07506930687788535
# learning rate =  0.13150632015979205
# Initial Cost on Val dataset for this epoch 1484 = 0.07506930687788535
# Error on this batch = 0.43463386032042706
# Error on this batch = 0.4348294470603172
# Cost on val dataset after 1485 epochs is = 0.07506891291718917
# learning rate =  0.13147679471646478
# Initial Cost on Val dataset for this epoch 1485 = 0.07506891291718917
# Error on this batch = 0.43462747327559653
# Error on this batch = 0.43482599044281856
# Cost on val dataset after 1486 epochs is = 0.07506851972826357
# learning rate =  0.1314472957711811
# Initial Cost on Val dataset for this epoch 1486 = 0.07506851972826357
# Error on this batch = 0.43462106503938047
# Error on this batch = 0.43482253512296903
# Cost on val dataset after 1487 epochs is = 0.075068127315995
# learning rate =  0.13141782328235216
# Initial Cost on Val dataset for this epoch 1487 = 0.075068127315995
# Error on this batch = 0.4346146357552526
# Error on this batch = 0.43481908111379514
# Cost on val dataset after 1488 epochs is = 0.07506773568518937
# learning rate =  0.13138837720848223
# Initial Cost on Val dataset for this epoch 1488 = 0.07506773568518937
# Error on this batch = 0.43460818557228936
# Error on this batch = 0.4348156284285696
# Cost on val dataset after 1489 epochs is = 0.0750673448405608
# learning rate =  0.13135895750816862
# Initial Cost on Val dataset for this epoch 1489 = 0.0750673448405608
# Error on this batch = 0.43460171464496344
# Error on this batch = 0.43481217708080194
# Cost on val dataset after 1490 epochs is = 0.07506695478672078
# learning rate =  0.1313295641401012
# Initial Cost on Val dataset for this epoch 1490 = 0.07506695478672078
# Error on this batch = 0.4345952231329157
# Error on this batch = 0.43480872708422963
# Cost on val dataset after 1491 epochs is = 0.0750665655281674
# learning rate =  0.13130019706306215
# Initial Cost on Val dataset for this epoch 1491 = 0.0750665655281674
# Error on this batch = 0.43458871120070697
# Error on this batch = 0.43480527845280764
# Cost on val dataset after 1492 epochs is = 0.07506617706927518
# learning rate =  0.1312708562359259
# Initial Cost on Val dataset for this epoch 1492 = 0.07506617706927518
# Error on this batch = 0.43458217901754914
# Error on this batch = 0.43480183120069876
# Cost on val dataset after 1493 epochs is = 0.0750657894142852
# learning rate =  0.1312415416176587
# Initial Cost on Val dataset for this epoch 1493 = 0.0750657894142852
# Error on this batch = 0.43457562675701794
# Error on this batch = 0.43479838534226345
# Cost on val dataset after 1494 epochs is = 0.07506540256729587
# learning rate =  0.13121225316731824
# Initial Cost on Val dataset for this epoch 1494 = 0.07506540256729587
# Error on this batch = 0.4345690545967457
# Error on this batch = 0.43479494089204934
# Cost on val dataset after 1495 epochs is = 0.07506501653225398
# learning rate =  0.13118299084405366
# Initial Cost on Val dataset for this epoch 1495 = 0.07506501653225398
# Error on this batch = 0.43456246271809634
# Error on this batch = 0.43479149786478033
# Cost on val dataset after 1496 epochs is = 0.07506463131294672
# learning rate =  0.13115375460710504
# Initial Cost on Val dataset for this epoch 1496 = 0.07506463131294672
# Error on this batch = 0.43455585130582364
# Error on this batch = 0.4347880562753464
# Cost on val dataset after 1497 epochs is = 0.07506424691299382
# learning rate =  0.13112454441580335
# Initial Cost on Val dataset for this epoch 1497 = 0.07506424691299382
# Error on this batch = 0.43454922054771217
# Error on this batch = 0.4347846161387925
# Cost on val dataset after 1498 epochs is = 0.07506386333584082
# learning rate =  0.13109536022956994
# Initial Cost on Val dataset for this epoch 1498 = 0.07506386333584082
# Error on this batch = 0.4345425706342047

# %%
test_accuracy
# Out:
# [3.8461538461538463,
#  14.046153846153848,
#  68.27692307692308,
#  86.01538461538462,
#  80.07692307692308,
#  77.04615384615384,
#  80.87692307692308,
#  79.93846153846154]

# %%
epochs
# Out:
# [52, 4437, 9803, 7909, 14918, 9888, 10596, 6803]

# %%
valid_accuracy
# Out:
# [3.128205128205128,
#  14.000000000000002,
#  69.94871794871796,
#  86.56410256410257,
#  80.35897435897435,
#  77.64102564102564,
#  81.8974358974359,
#  80.82051282051282]

# %%
1.5/np.power(2039, (1/3))
# Out:
# 0.118291130898163
