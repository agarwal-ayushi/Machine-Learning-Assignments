# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)

np.random.shuffle(X_train.to_numpy()) #Randomly shuffle the training data for batching

train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

print("----------------Preprocessing the data-------------------")
X_train = X_train/255
X_test = X_test/255

m = X_train.shape[0] # Number of Training Samples

#Separating 15% of the training Data as Validation Dataset
X_valid = X_train.iloc[(int(0.85*m)):]
valid_class = train_class[(int(0.85*m)):]
X_train = X_train.iloc[0:int(0.85*m)]
train_class = train_class[0:int(0.85*m)]


m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The total number of validation samples = {}".format(X_valid.shape[0]))
print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# ----------------Preprocessing the data-------------------
# The total number of training samples = 11050
# The total number of validation samples = 1950
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
valid_class_enc = pd.get_dummies(valid_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
print("--------------------Done----------------------------------")
# Out:
# --------Perform 1-hot encoding of class labels------------
# --------------------Done----------------------------------

# %%
#Add the intercept term to the data samples both in training and test dataset
print("--------Adding the intercept term in the dataset as bias------------")
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_valid = np.hstack((np.ones((X_valid.shape[0],1)), X_valid.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))
print("-----------------------------Done----------------------------------")
# Out:
# --------Adding the intercept term in the dataset as bias------------
# -----------------------------Done----------------------------------

# %%
#Mini-Batch formation

batch_size = 100 # Mini-Batch Size

print("----------------Forming mini-batches of size {}---------------------".format(batch_size))
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# ----------------Forming mini-batches of size 100---------------------
# The number of mini-batches formed is = 111

# %%
#Theta Initialization 

def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]
        theta.append(np.random.normal(0,0.01, (dim0,dim1)))
        #theta.append(0.01*(2*np.random.random((dim0, dim1))-1))
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
# Sigmoid activation function
def activation(x):
    return 1/(1+np.exp(-x))

#ReLU Activation Function
def relu_act(x):
    return np.maximum(0.0, x)

#Derivative of ReLU activation Function
def deriv_relu(x):
    x[x<=0] = 0
    x[x>0] = 1
    return x

# %%
# Forward propagation

def forward_prop(data, theta, act_fn='sigmoid'):
    fm = []
    fm.append(data)
    if (act_fn == 'sigmoid'):
        for l in range(len(theta)):
            fm.append(activation(np.dot(fm[l], theta[l])))
    elif(act_fn == 'relu'):
        for l in range(len(theta)):
            if (l != len(theta)-1):
                fm.append(relu_act(np.dot(fm[l], theta[l])))
            else:
                fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
# Backward propagation
def backward_prop(fm, Y_b, theta, batch_size, act_fn='sigmoid'):
    delta = [None]*len(fm)
    for l in range(len(fm)-1, 0, -1):
        if (l == len(fm)-1):
            delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
        else:
            if (act_fn == 'sigmoid'):
                delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))
            elif(act_fn == 'relu'):
                delta[l]=np.dot(delta[l+1], theta[l].T)*deriv_relu(fm[l])
    return delta

# %%
def cost_total(X, theta, Y, m, act_fn='sigmoid'):
    fm = forward_prop(X, theta, act_fn)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    return (test_acc*100)

# %% [markdown]
# ## PART AB - One Hidden Layer Neural Network

# %%
lr = 0.1 # Fixed Learning rate
arch_test = [1,5,10,50,100] # Specifically for part a and b
arch = [50] #means one hidden layer with 50 perceptrons (DEFAULT)

r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
epochs = []
train_accuracy = []
test_accuracy = []
valid_accuracy = []
train_time = []

plt_epoch = []
plt_train_acc = []
plt_val_acc = []
plt_test_acc = []
costs= []

# %%
arch=[100, 100]
lr=0.1
theta = theta_init(arch)
#print(theta[0].shape, theta[1].shape, theta[2].shape)
print("Training the network with {} hidden layer with {} units".format(len(arch), arch))
print("The parameters of the layers are of the shape:")

for i in range(len(theta)):
    print("theta between layer {} and layer {} is {}".format(i, i+1,theta[i].shape))

early_stop=0 #Early stop count of iteration

epoch = 1 # Number of epochs
start = time.time()

cost_init = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0], 'relu')

while(True):
    count = 0

    print("Initial Cost on Val dataset for this epoch {} = {}".format(epoch, cost_init))

    for b in mini_batch:
        X_b = b[0]
        Y_b = b[1]
        fm = forward_prop(X_b, theta, 'relu')
        delta = [None]*len(fm)

        if (count % 60 == 0):
            print("Error on this batch = "+str(cost_total(X_b, theta, Y_b, batch_size,'relu')))

        #Backward Propagation

        delta = backward_prop(fm, Y_b, theta, batch_size, 'relu')
#         for l in range(len(fm)-1, 0, -1):
#             if (l == len(fm)-1):
#                 delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
#                 #print("delta for last layer = ", delta[l])
#             else:
#                 delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))
#                 #print("delta for hidden layer = ", delta[l])


        for t in range(len(theta)):
            theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

        count+=1

#         if epoch %10 == 0:
#                 costs.append(cost_init)
#         if (epoch % 200 == 0):
#             plt_epoch.append(epoch)
#             plt_train_acc.append(calc_accuracy(X_train, theta, train_class_enc))
#             plt_val_acc.append(calc_accuracy(X_valid, theta, valid_class_enc))
#             plt_test_acc.append(calc_accuracy(X_test, theta, test_actual_class_enc))

    epoch+=1 #Number of epochs

    cost_final = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0], 'relu')
    print("Cost on val dataset after {} epochs is = {}".format(epoch, cost_final))
    if (abs(cost_final-cost_init) < 1e-07):
        early_stop +=1
    else:
        early_stop=0
    if (early_stop == 10):
        print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
        break
    cost_init = cost_final
epochs.append(epoch)
train_time.append(time.time()-start)
train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
valid_accuracy.append(calc_accuracy(X_valid, theta, valid_class_enc))
test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
print("\n------------------------------------------------------------------------------")
print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
print("------------------------------------------------------------------------------")
print("The number of epochs = {:2.3f}".format(epochs[-1]))
print("The training time = {:2.3f}sec".format(train_time[-1]))
print("The training accuracy is = {:2.3f}%".format(train_accuracy[-1]))
print("The validation accuracy is = {:2.3f}%".format(valid_accuracy[-1]))
print("The test accuracy is = {:2.3f}%".format(test_accuracy[-1]))
print("------------------------------------------------------------------------------\n")
# Out:
# Training the network with 2 hidden layer with [100, 100] units
# The parameters of the layers are of the shape:
# theta between layer 0 and layer 1 is (785, 100)
# theta between layer 1 and layer 2 is (100, 100)
# theta between layer 2 and layer 3 is (100, 26)
# Initial Cost on Val dataset for this epoch 1 = 3.250361262094908
# Error on this batch = 3.2503710357492923
# Error on this batch = 0.4920623716061671
# Cost on val dataset after 2 epochs is = 0.49033057147822595
# Initial Cost on Val dataset for this epoch 2 = 0.49033057147822595
# Error on this batch = 0.49051169763308244
# Error on this batch = 0.491434554702269
# Cost on val dataset after 3 epochs is = 0.4894954924581196
# Initial Cost on Val dataset for this epoch 3 = 0.4894954924581196
# Error on this batch = 0.4900728653449521
# Error on this batch = 0.49129262256467243
# Cost on val dataset after 4 epochs is = 0.4890496877698743
# Initial Cost on Val dataset for this epoch 4 = 0.4890496877698743
# Error on this batch = 0.4898484883112238
# Error on this batch = 0.4912459184197991
# Cost on val dataset after 5 epochs is = 0.48872706413586137
# Initial Cost on Val dataset for this epoch 5 = 0.48872706413586137
# Error on this batch = 0.48966362279047077
# Error on this batch = 0.4911566451047834
# Cost on val dataset after 6 epochs is = 0.48844349537020243
# Initial Cost on Val dataset for this epoch 6 = 0.48844349537020243
# Error on this batch = 0.48945298475530225
# Error on this batch = 0.49099403393606056
# Cost on val dataset after 7 epochs is = 0.4881639092266981
# Initial Cost on Val dataset for this epoch 7 = 0.4881639092266981
# Error on this batch = 0.48919754649663133
# Error on this batch = 0.4907444523196419
# Cost on val dataset after 8 epochs is = 0.48786938619678266
# Initial Cost on Val dataset for this epoch 8 = 0.48786938619678266
# Error on this batch = 0.488884310663034
# Error on this batch = 0.4904053468317231
# Cost on val dataset after 9 epochs is = 0.4875487807309388
# Initial Cost on Val dataset for this epoch 9 = 0.4875487807309388
# Error on this batch = 0.48850810835859854
# Error on this batch = 0.4899671665856162
# Cost on val dataset after 10 epochs is = 0.48719148485207825
# Initial Cost on Val dataset for this epoch 10 = 0.48719148485207825
# Error on this batch = 0.48806987496351445
# Error on this batch = 0.4894213187537716
# Cost on val dataset after 11 epochs is = 0.4867891736182447
# Initial Cost on Val dataset for this epoch 11 = 0.4867891736182447
# Error on this batch = 0.48756925718826005
# Error on this batch = 0.48877389662728454
# Cost on val dataset after 12 epochs is = 0.4863366219428952
# Initial Cost on Val dataset for this epoch 12 = 0.4863366219428952
# Error on this batch = 0.4870115708359359
# Error on this batch = 0.4880326825418298
# Cost on val dataset after 13 epochs is = 0.4858336009294553
# Initial Cost on Val dataset for this epoch 13 = 0.4858336009294553
# Error on this batch = 0.4864110171386846
# Error on this batch = 0.48722290564661186
# Cost on val dataset after 14 epochs is = 0.4852858322313246
# Initial Cost on Val dataset for this epoch 14 = 0.4852858322313246
# Error on this batch = 0.48578675864180154
# Error on this batch = 0.48637244061577106
# Cost on val dataset after 15 epochs is = 0.4847107964809996
# Initial Cost on Val dataset for this epoch 15 = 0.4847107964809996
# Error on this batch = 0.48515027204137773
# Error on this batch = 0.48551008031174214
# Cost on val dataset after 16 epochs is = 0.48412560554281603
# Initial Cost on Val dataset for this epoch 16 = 0.48412560554281603
# Error on this batch = 0.48451585634587174
# Error on this batch = 0.48467045535185693
# Cost on val dataset after 17 epochs is = 0.4835519346397775
# Initial Cost on Val dataset for this epoch 17 = 0.4835519346397775
# Error on this batch = 0.48389598712121873
# Error on this batch = 0.48388283831158446
# Cost on val dataset after 18 epochs is = 0.48301510696597816
# Initial Cost on Val dataset for this epoch 18 = 0.48301510696597816
# Error on this batch = 0.4833084032809552
# Error on this batch = 0.4831705910794643
# Cost on val dataset after 19 epochs is = 0.48253667676903955
# Initial Cost on Val dataset for this epoch 19 = 0.48253667676903955
# Error on this batch = 0.4827729804154706
# Error on this batch = 0.4825633632801803
# Cost on val dataset after 20 epochs is = 0.4821314947322624
# Initial Cost on Val dataset for this epoch 20 = 0.4821314947322624
# Error on this batch = 0.48231041805254493
# Error on this batch = 0.4820744530930325
# Cost on val dataset after 21 epochs is = 0.48180359778178616
# Initial Cost on Val dataset for this epoch 21 = 0.48180359778178616
# Error on this batch = 0.48192714409517623
# Error on this batch = 0.48169603858783006
# Cost on val dataset after 22 epochs is = 0.48154811611007137
# Initial Cost on Val dataset for this epoch 22 = 0.48154811611007137
# Error on this batch = 0.4816211264497749
# Error on this batch = 0.48141636967898777
# Cost on val dataset after 23 epochs is = 0.4813556919906881
# Initial Cost on Val dataset for this epoch 23 = 0.4813556919906881
# Error on this batch = 0.4813824115565345
# Error on this batch = 0.4812167723947883
# Cost on val dataset after 24 epochs is = 0.4812140819905459
# Initial Cost on Val dataset for this epoch 24 = 0.4812140819905459
# Error on this batch = 0.48119703020686894
# Error on this batch = 0.4810789622657243
# Cost on val dataset after 25 epochs is = 0.48111190179109375
# Initial Cost on Val dataset for this epoch 25 = 0.48111190179109375
# Error on this batch = 0.48105195319227473
# Error on this batch = 0.48098747740574055
# Cost on val dataset after 26 epochs is = 0.4810396435493598
# Initial Cost on Val dataset for this epoch 26 = 0.4810396435493598
# Error on this batch = 0.4809367730175075
# Error on this batch = 0.4809297808194269
# Cost on val dataset after 27 epochs is = 0.4809892733791183
# Initial Cost on Val dataset for this epoch 27 = 0.4809892733791183
# Error on this batch = 0.4808440800481526
# Error on this batch = 0.4808947891026172
# Cost on val dataset after 28 epochs is = 0.48095409659475874
# Initial Cost on Val dataset for this epoch 28 = 0.48095409659475874
# Error on this batch = 0.4807681195203555
# Error on this batch = 0.480874361922529
# Cost on val dataset after 29 epochs is = 0.4809300456505209
# Initial Cost on Val dataset for this epoch 29 = 0.4809300456505209
# Error on this batch = 0.48070661304666856
# Error on this batch = 0.48086266149802925
# Cost on val dataset after 30 epochs is = 0.4809134676763113
# Initial Cost on Val dataset for this epoch 30 = 0.4809134676763113
# Error on this batch = 0.48065747361894057
# Error on this batch = 0.4808558796962287
# Cost on val dataset after 31 epochs is = 0.4809018388776274
# Initial Cost on Val dataset for this epoch 31 = 0.4809018388776274
# Error on this batch = 0.48061810673881494
# Error on this batch = 0.4808511353857397
# Cost on val dataset after 32 epochs is = 0.48089324761157537
# Initial Cost on Val dataset for this epoch 32 = 0.48089324761157537
# Error on this batch = 0.48058634350281265
# Error on this batch = 0.48084680127528073
# Cost on val dataset after 33 epochs is = 0.4808862163003782
# Initial Cost on Val dataset for this epoch 33 = 0.4808862163003782
# Error on this batch = 0.48056039848163834
# Error on this batch = 0.480841715577175
# Cost on val dataset after 34 epochs is = 0.4808796785529193
# Initial Cost on Val dataset for this epoch 34 = 0.4808796785529193
# Error on this batch = 0.4805378435558901
# Error on this batch = 0.4808359285884435
# Cost on val dataset after 35 epochs is = 0.4808736816627032
# Initial Cost on Val dataset for this epoch 35 = 0.4808736816627032
# Error on this batch = 0.4805184564863082
# Error on this batch = 0.4808299151928743
# Cost on val dataset after 36 epochs is = 0.48086807274713467
# Initial Cost on Val dataset for this epoch 36 = 0.48086807274713467
# Error on this batch = 0.4805023443261338
# Error on this batch = 0.4808235625469577
# Cost on val dataset after 37 epochs is = 0.48086246844374936
# Initial Cost on Val dataset for this epoch 37 = 0.48086246844374936
# Error on this batch = 0.4804882551029918
# Error on this batch = 0.4808167270551887
# Cost on val dataset after 38 epochs is = 0.4808566402487827
# Initial Cost on Val dataset for this epoch 38 = 0.4808566402487827
# Error on this batch = 0.4804752995434743
# Error on this batch = 0.48080931095433144
# Cost on val dataset after 39 epochs is = 0.4808502475542545
# Initial Cost on Val dataset for this epoch 39 = 0.4808502475542545
# Error on this batch = 0.48046248062261593
# Error on this batch = 0.4808005744592636
# Cost on val dataset after 40 epochs is = 0.48084258528555057
# Initial Cost on Val dataset for this epoch 40 = 0.48084258528555057
# Error on this batch = 0.48044833822492367
# Error on this batch = 0.48079031736997074
# Cost on val dataset after 41 epochs is = 0.4808348977013195
# Initial Cost on Val dataset for this epoch 41 = 0.4808348977013195
# Error on this batch = 0.48043475260731355
# Error on this batch = 0.4807807322777386
# Cost on val dataset after 42 epochs is = 0.48082762238068444
# Initial Cost on Val dataset for this epoch 42 = 0.48082762238068444
# Error on this batch = 0.4804224999031733
# Error on this batch = 0.4807713185793975
# Cost on val dataset after 43 epochs is = 0.4808200594498004
# Initial Cost on Val dataset for this epoch 43 = 0.4808200594498004
# Error on this batch = 0.480410314977924
# Error on this batch = 0.48076139997595896
# Cost on val dataset after 44 epochs is = 0.4808116791326072
# Initial Cost on Val dataset for this epoch 44 = 0.4808116791326072
# Error on this batch = 0.48039712203713053
# Error on this batch = 0.48075047873098514
# Cost on val dataset after 45 epochs is = 0.480801960789197
# Initial Cost on Val dataset for this epoch 45 = 0.480801960789197
# Error on this batch = 0.4803816326917877
# Error on this batch = 0.48073924788584776
# Cost on val dataset after 46 epochs is = 0.480792173723537
# Initial Cost on Val dataset for this epoch 46 = 0.480792173723537
# Error on this batch = 0.4803662682571109
# Error on this batch = 0.4807277034485305
# Cost on val dataset after 47 epochs is = 0.48078234251356167
# Initial Cost on Val dataset for this epoch 47 = 0.48078234251356167
# Error on this batch = 0.48035114089679626
# Error on this batch = 0.48071581228405097
# Cost on val dataset after 48 epochs is = 0.48077222835768874
# Initial Cost on Val dataset for this epoch 48 = 0.48077222835768874
# Error on this batch = 0.48033571490734234
# Error on this batch = 0.48070338945884916
# Cost on val dataset after 49 epochs is = 0.4807616936246362
# Initial Cost on Val dataset for this epoch 49 = 0.4807616936246362
# Error on this batch = 0.48031959084724923
# Error on this batch = 0.4806903714127468
# Cost on val dataset after 50 epochs is = 0.480750625601465
# Initial Cost on Val dataset for this epoch 50 = 0.480750625601465
# Error on this batch = 0.48030254784279264
# Error on this batch = 0.4806765965620046
# Cost on val dataset after 51 epochs is = 0.4807387307544058
# Initial Cost on Val dataset for this epoch 51 = 0.4807387307544058
# Error on this batch = 0.4802841538302923
# Error on this batch = 0.4806617052639078
# Cost on val dataset after 52 epochs is = 0.4807259328318645
# Initial Cost on Val dataset for this epoch 52 = 0.4807259328318645
# Error on this batch = 0.480264395624162
# Error on this batch = 0.4806462508789589
# Cost on val dataset after 53 epochs is = 0.4807129229240774
# Initial Cost on Val dataset for this epoch 53 = 0.4807129229240774
# Error on this batch = 0.4802442580807804
# Error on this batch = 0.4806305799015367
# Cost on val dataset after 54 epochs is = 0.4806993879348696
# Initial Cost on Val dataset for this epoch 54 = 0.4806993879348696
# Error on this batch = 0.48022313428517494
# Error on this batch = 0.48061437276592983
# Cost on val dataset after 55 epochs is = 0.48068513163227267
# Initial Cost on Val dataset for this epoch 55 = 0.48068513163227267
# Error on this batch = 0.4802008655105053
# Error on this batch = 0.48059726259563074
# Cost on val dataset after 56 epochs is = 0.4806699367208872
# Initial Cost on Val dataset for this epoch 56 = 0.4806699367208872
# Error on this batch = 0.4801770853294944
# Error on this batch = 0.48057936969983217
# Cost on val dataset after 57 epochs is = 0.4806539690001391
# Initial Cost on Val dataset for this epoch 57 = 0.4806539690001391
# Error on this batch = 0.48015192410514657
# Error on this batch = 0.48056128826643657
# Cost on val dataset after 58 epochs is = 0.48063728388260396
# Initial Cost on Val dataset for this epoch 58 = 0.48063728388260396
# Error on this batch = 0.48012530740057174
# Error on this batch = 0.48054259800788274
# Cost on val dataset after 59 epochs is = 0.48061980046583835
# Initial Cost on Val dataset for this epoch 59 = 0.48061980046583835
# Error on this batch = 0.48009693694500044
# Error on this batch = 0.48052316465240325
# Cost on val dataset after 60 epochs is = 0.48060132752977086
# Initial Cost on Val dataset for this epoch 60 = 0.48060132752977086
# Error on this batch = 0.4800668826312447
# Error on this batch = 0.48050291507412335
# Cost on val dataset after 61 epochs is = 0.48058184863861897
# Initial Cost on Val dataset for this epoch 61 = 0.48058184863861897
# Error on this batch = 0.4800349381891597
# Error on this batch = 0.48048170923421324
# Cost on val dataset after 62 epochs is = 0.480561268581565
# Initial Cost on Val dataset for this epoch 62 = 0.480561268581565
# Error on this batch = 0.4800008638721851
# Error on this batch = 0.4804595261938144
# Cost on val dataset after 63 epochs is = 0.48053948107479055
# Initial Cost on Val dataset for this epoch 63 = 0.48053948107479055
# Error on this batch = 0.4799645258379593
# Error on this batch = 0.48043619435284385
# Cost on val dataset after 64 epochs is = 0.48051644005180216
# Initial Cost on Val dataset for this epoch 64 = 0.48051644005180216
# Error on this batch = 0.4799261040909704
# Error on this batch = 0.4804114878027783
# Cost on val dataset after 65 epochs is = 0.48049197721056397
# Initial Cost on Val dataset for this epoch 65 = 0.48049197721056397
# Error on this batch = 0.4798852068217234
# Error on this batch = 0.48038527922056773
# Cost on val dataset after 66 epochs is = 0.4804659899701439
# Initial Cost on Val dataset for this epoch 66 = 0.4804659899701439
# Error on this batch = 0.479841746438532
# Error on this batch = 0.4803573409447599
# Cost on val dataset after 67 epochs is = 0.48043790153137717
# Initial Cost on Val dataset for this epoch 67 = 0.48043790153137717
# Error on this batch = 0.4797952021702945
# Error on this batch = 0.48032694641055806
# Cost on val dataset after 68 epochs is = 0.48040679591224167
# Initial Cost on Val dataset for this epoch 68 = 0.48040679591224167
# Error on this batch = 0.4797442620519395
# Error on this batch = 0.48029391337346555
# Cost on val dataset after 69 epochs is = 0.48037383823317303
# Initial Cost on Val dataset for this epoch 69 = 0.48037383823317303
# Error on this batch = 0.4796899586383871
# Error on this batch = 0.4802593638395548
# Cost on val dataset after 70 epochs is = 0.4803391886585956
# Initial Cost on Val dataset for this epoch 70 = 0.4803391886585956
# Error on this batch = 0.47963212097008184
# Error on this batch = 0.48022281380160536
# Cost on val dataset after 71 epochs is = 0.4803023262545996
# Initial Cost on Val dataset for this epoch 71 = 0.4803023262545996
# Error on this batch = 0.4795703834568684
# Error on this batch = 0.480183782077917
# Cost on val dataset after 72 epochs is = 0.48026303606029247
# Initial Cost on Val dataset for this epoch 72 = 0.48026303606029247
# Error on this batch = 0.4795041827094588
# Error on this batch = 0.48014240728129265
# Cost on val dataset after 73 epochs is = 0.4802210346885084
# Initial Cost on Val dataset for this epoch 73 = 0.4802210346885084
# Error on this batch = 0.4794326596941349
# Error on this batch = 0.48009887982739174
# Cost on val dataset after 74 epochs is = 0.4801762020302246
# Initial Cost on Val dataset for this epoch 74 = 0.4801762020302246
# Error on this batch = 0.47935502530114976
# Error on this batch = 0.48005266256935025
# Cost on val dataset after 75 epochs is = 0.48012814850157115
# Initial Cost on Val dataset for this epoch 75 = 0.48012814850157115
# Error on this batch = 0.4792706837801966
# Error on this batch = 0.4800033105205681
# Cost on val dataset after 76 epochs is = 0.48007662671215784
# Initial Cost on Val dataset for this epoch 76 = 0.48007662671215784
# Error on this batch = 0.4791788363004717
# Error on this batch = 0.4799505830179953
# Cost on val dataset after 77 epochs is = 0.48002084877828355
# Initial Cost on Val dataset for this epoch 77 = 0.48002084877828355
# Error on this batch = 0.4790784816529074
# Error on this batch = 0.4798932612659017
# Cost on val dataset after 78 epochs is = 0.4799599898410078
# Initial Cost on Val dataset for this epoch 78 = 0.4799599898410078
# Error on this batch = 0.47896853584914423
# Error on this batch = 0.479830313953102
# Cost on val dataset after 79 epochs is = 0.4798929730522615
# Initial Cost on Val dataset for this epoch 79 = 0.4798929730522615
# Error on this batch = 0.47884749777517566
# Error on this batch = 0.4797624593406578
# Cost on val dataset after 80 epochs is = 0.47982114940995013
# Initial Cost on Val dataset for this epoch 80 = 0.47982114940995013
# Error on this batch = 0.4787158384517271
# Error on this batch = 0.4796892062370135
# Cost on val dataset after 81 epochs is = 0.4797436649876125
# Initial Cost on Val dataset for this epoch 81 = 0.4797436649876125
# Error on this batch = 0.47857179329062094
# Error on this batch = 0.4796098219687403
# Cost on val dataset after 82 epochs is = 0.47965959656608226
# Initial Cost on Val dataset for this epoch 82 = 0.47965959656608226
# Error on this batch = 0.47841373079694277
# Error on this batch = 0.479523948345066
# Cost on val dataset after 83 epochs is = 0.47956787885802776
# Initial Cost on Val dataset for this epoch 83 = 0.47956787885802776
# Error on this batch = 0.47824041287171964
# Error on this batch = 0.4794305627766419
# Cost on val dataset after 84 epochs is = 0.4794680347165747
# Initial Cost on Val dataset for this epoch 84 = 0.4794680347165747
# Error on this batch = 0.47804975371436637
# Error on this batch = 0.4793283866299305
# Cost on val dataset after 85 epochs is = 0.4793589588099961
# Initial Cost on Val dataset for this epoch 85 = 0.4793589588099961
# Error on this batch = 0.4778393177991333
# Error on this batch = 0.47921596834119357
# Cost on val dataset after 86 epochs is = 0.47923947294455777
# Initial Cost on Val dataset for this epoch 86 = 0.47923947294455777
# Error on this batch = 0.47760815806346224
# Error on this batch = 0.4790934874165403
# Cost on val dataset after 87 epochs is = 0.479107846675635
# Initial Cost on Val dataset for this epoch 87 = 0.479107846675635
# Error on this batch = 0.4773521029915364
# Error on this batch = 0.4789595489425573
# Cost on val dataset after 88 epochs is = 0.4789628102217389
# Initial Cost on Val dataset for this epoch 88 = 0.4789628102217389
# Error on this batch = 0.47706821717215825
# Error on this batch = 0.47881300846173747
# Cost on val dataset after 89 epochs is = 0.4788026411910936
# Initial Cost on Val dataset for this epoch 89 = 0.4788026411910936
# Error on this batch = 0.4767526737488684
# Error on this batch = 0.47865199066422753
# Cost on val dataset after 90 epochs is = 0.47862524518452243
# Initial Cost on Val dataset for this epoch 90 = 0.47862524518452243
# Error on this batch = 0.47640112065232415
# Error on this batch = 0.4784752922069873
# Cost on val dataset after 91 epochs is = 0.4784277818343389
# Initial Cost on Val dataset for this epoch 91 = 0.4784277818343389
# Error on this batch = 0.4760089304926848
# Error on this batch = 0.47828000839288143
# Cost on val dataset after 92 epochs is = 0.47820793621872504
# Initial Cost on Val dataset for this epoch 92 = 0.47820793621872504
# Error on this batch = 0.47557124390257133
# Error on this batch = 0.4780660273435091
# Cost on val dataset after 93 epochs is = 0.47796265532126697
# Initial Cost on Val dataset for this epoch 93 = 0.47796265532126697
# Error on this batch = 0.4750810239997775
# Error on this batch = 0.4778298396089704
# Cost on val dataset after 94 epochs is = 0.47768873402521866
# Initial Cost on Val dataset for this epoch 94 = 0.47768873402521866
# Error on this batch = 0.47453054204145323
# Error on this batch = 0.4775702679340479
# Cost on val dataset after 95 epochs is = 0.4773807786059066
# Initial Cost on Val dataset for this epoch 95 = 0.4773807786059066
# Error on this batch = 0.47391473059380035
# Error on this batch = 0.47728462461509524
# Cost on val dataset after 96 epochs is = 0.47703483847128214
# Initial Cost on Val dataset for this epoch 96 = 0.47703483847128214
# Error on this batch = 0.4732239563331618
# Error on this batch = 0.4769692264790324
# Cost on val dataset after 97 epochs is = 0.4766460200313853
# Initial Cost on Val dataset for this epoch 97 = 0.4766460200313853
# Error on this batch = 0.47245089394653084
# Error on this batch = 0.47661899472866653
# Cost on val dataset after 98 epochs is = 0.4762097266391206
# Initial Cost on Val dataset for this epoch 98 = 0.4762097266391206
# Error on this batch = 0.4715903110353413
# Error on this batch = 0.47623097096552147
# Cost on val dataset after 99 epochs is = 0.47571969613993415
# Initial Cost on Val dataset for this epoch 99 = 0.47571969613993415
# Error on this batch = 0.4706415661125105
# Error on this batch = 0.4757993496084181
# Cost on val dataset after 100 epochs is = 0.4751706354628758
# Initial Cost on Val dataset for this epoch 100 = 0.4751706354628758
# Error on this batch = 0.46959548084228914
# Error on this batch = 0.4753199363989999
# Cost on val dataset after 101 epochs is = 0.4745574509635935
# Initial Cost on Val dataset for this epoch 101 = 0.4745574509635935
# Error on this batch = 0.468457761542679
# Error on this batch = 0.474787203725696
# Cost on val dataset after 102 epochs is = 0.47387812512197885
# Initial Cost on Val dataset for this epoch 102 = 0.47387812512197885
# Error on this batch = 0.46723907986141117
# Error on this batch = 0.47419926200570134
# Cost on val dataset after 103 epochs is = 0.47312692665393846
# Initial Cost on Val dataset for this epoch 103 = 0.47312692665393846
# Error on this batch = 0.46593164667569015
# Error on this batch = 0.4735398660701893
# Cost on val dataset after 104 epochs is = 0.4723013160164084
# Initial Cost on Val dataset for this epoch 104 = 0.4723013160164084
# Error on this batch = 0.4645287214952687
# Error on this batch = 0.4727975076353929
# Cost on val dataset after 105 epochs is = 0.4713971335957928
# Initial Cost on Val dataset for this epoch 105 = 0.4713971335957928
# Error on this batch = 0.46303880357679317
# Error on this batch = 0.4719715673138521
# Cost on val dataset after 106 epochs is = 0.47040869161188387
# Initial Cost on Val dataset for this epoch 106 = 0.47040869161188387
# Error on this batch = 0.4614567438381587
# Error on this batch = 0.47103264505696796
# Cost on val dataset after 107 epochs is = 0.4693268670898503
# Initial Cost on Val dataset for this epoch 107 = 0.4693268670898503
# Error on this batch = 0.4597794134395592
# Error on this batch = 0.46996248510589345
# Cost on val dataset after 108 epochs is = 0.4681409416896397
# Initial Cost on Val dataset for this epoch 108 = 0.4681409416896397
# Error on this batch = 0.45797990270846684
# Error on this batch = 0.46873230915252256
# Cost on val dataset after 109 epochs is = 0.4668441673424082
# Initial Cost on Val dataset for this epoch 109 = 0.4668441673424082
# Error on this batch = 0.4560492677137571
# Error on this batch = 0.4673573200128638
# Cost on val dataset after 110 epochs is = 0.4654313599745581
# Initial Cost on Val dataset for this epoch 110 = 0.4654313599745581
# Error on this batch = 0.4539712955018092
# Error on this batch = 0.4658168992478509
# Cost on val dataset after 111 epochs is = 0.46389435570943477
# Initial Cost on Val dataset for this epoch 111 = 0.46389435570943477
# Error on this batch = 0.4517407730236529
# Error on this batch = 0.4641184520173553
# Cost on val dataset after 112 epochs is = 0.4622199494010585
# Initial Cost on Val dataset for this epoch 112 = 0.4622199494010585
# Error on this batch = 0.44936664505626184
# Error on this batch = 0.4622510033011625
# Cost on val dataset after 113 epochs is = 0.4604054852780127
# Initial Cost on Val dataset for this epoch 113 = 0.4604054852780127
# Error on this batch = 0.44682183115488217
# Error on this batch = 0.4602327634122276
# Cost on val dataset after 114 epochs is = 0.4584604310374634
# Initial Cost on Val dataset for this epoch 114 = 0.4584604310374634
# Error on this batch = 0.4441342776487235
# Error on this batch = 0.4580801750281222
# Cost on val dataset after 115 epochs is = 0.456398039163679
# Initial Cost on Val dataset for this epoch 115 = 0.456398039163679
# Error on this batch = 0.44134762647153636
# Error on this batch = 0.4557843966796067
# Cost on val dataset after 116 epochs is = 0.45424369506127493
# Initial Cost on Val dataset for this epoch 116 = 0.45424369506127493
# Error on this batch = 0.43852238001703653
# Error on this batch = 0.4533835564865488
# Cost on val dataset after 117 epochs is = 0.45201681695839313
# Initial Cost on Val dataset for this epoch 117 = 0.45201681695839313
# Error on this batch = 0.43564941990095307
# Error on this batch = 0.45091758792286085
# Cost on val dataset after 118 epochs is = 0.4497332959307563
# Initial Cost on Val dataset for this epoch 118 = 0.4497332959307563
# Error on this batch = 0.4328168685651557
# Error on this batch = 0.44834725379927065
# Cost on val dataset after 119 epochs is = 0.4474170908236172
# Initial Cost on Val dataset for this epoch 119 = 0.4474170908236172
# Error on this batch = 0.4300394765743758
# Error on this batch = 0.4457190617502492
# Cost on val dataset after 120 epochs is = 0.44507327949599296
# Initial Cost on Val dataset for this epoch 120 = 0.44507327949599296
# Error on this batch = 0.4273221490677227
# Error on this batch = 0.442965492387423
# Cost on val dataset after 121 epochs is = 0.44270897547618054
# Initial Cost on Val dataset for this epoch 121 = 0.44270897547618054
# Error on this batch = 0.42470470491183493
# Error on this batch = 0.44011168374467813
# Cost on val dataset after 122 epochs is = 0.44031182649453965
# Initial Cost on Val dataset for this epoch 122 = 0.44031182649453965
# Error on this batch = 0.4221451439142105
# Error on this batch = 0.4370950577091424
# Cost on val dataset after 123 epochs is = 0.4378996331780509
# Initial Cost on Val dataset for this epoch 123 = 0.4378996331780509
# Error on this batch = 0.41961890361622767
# Error on this batch = 0.4340310013967482
# Cost on val dataset after 124 epochs is = 0.4354620023119548
# Initial Cost on Val dataset for this epoch 124 = 0.4354620023119548
# Error on this batch = 0.41714195187203085
# Error on this batch = 0.43087279987248506
# Cost on val dataset after 125 epochs is = 0.4330210313320269
# Initial Cost on Val dataset for this epoch 125 = 0.4330210313320269
# Error on this batch = 0.41469537791700994
# Error on this batch = 0.4276742039682823
# Cost on val dataset after 126 epochs is = 0.43058797829685763
# Initial Cost on Val dataset for this epoch 126 = 0.43058797829685763
# Error on this batch = 0.4123195284171739
# Error on this batch = 0.4245080402773557
# Cost on val dataset after 127 epochs is = 0.42820244177887296
# Initial Cost on Val dataset for this epoch 127 = 0.42820244177887296
# Error on this batch = 0.41003987527387653
# Error on this batch = 0.4214365411271045
# Cost on val dataset after 128 epochs is = 0.42587778343983984
# Initial Cost on Val dataset for this epoch 128 = 0.42587778343983984
# Error on this batch = 0.40785745736249424
# Error on this batch = 0.4184689802137133
# Cost on val dataset after 129 epochs is = 0.4236408617889715
# Initial Cost on Val dataset for this epoch 129 = 0.4236408617889715
# Error on this batch = 0.4057745235362093
# Error on this batch = 0.41565567517293334
# Cost on val dataset after 130 epochs is = 0.4215016064850778
# Initial Cost on Val dataset for this epoch 130 = 0.4215016064850778
# Error on this batch = 0.4038048481036462
# Error on this batch = 0.41301723366941007
# Cost on val dataset after 131 epochs is = 0.4194691288031104
# Initial Cost on Val dataset for this epoch 131 = 0.4194691288031104
# Error on this batch = 0.4019238856056386
# Error on this batch = 0.41055310414210155
# Cost on val dataset after 132 epochs is = 0.4175299246940292
# Initial Cost on Val dataset for this epoch 132 = 0.4175299246940292
# Error on this batch = 0.40012160529015733
# Error on this batch = 0.4082489383230549
# Cost on val dataset after 133 epochs is = 0.41567865356241585
# Initial Cost on Val dataset for this epoch 133 = 0.41567865356241585
# Error on this batch = 0.39839764036653225
# Error on this batch = 0.40605557125241853
# Cost on val dataset after 134 epochs is = 0.4139059971441411
# Initial Cost on Val dataset for this epoch 134 = 0.4139059971441411
# Error on this batch = 0.3968105692968602
# Error on this batch = 0.403946987117946
# Cost on val dataset after 135 epochs is = 0.412186665540409
# Initial Cost on Val dataset for this epoch 135 = 0.412186665540409
# Error on this batch = 0.39526460146618564
# Error on this batch = 0.40195382767954885
# Cost on val dataset after 136 epochs is = 0.41051150683813653
# Initial Cost on Val dataset for this epoch 136 = 0.41051150683813653
# Error on this batch = 0.3937381800618946
# Error on this batch = 0.40001188115912945
# Cost on val dataset after 137 epochs is = 0.40886238275421677
# Initial Cost on Val dataset for this epoch 137 = 0.40886238275421677
# Error on this batch = 0.3922643945813573
# Error on this batch = 0.39814968888877367
# Cost on val dataset after 138 epochs is = 0.4072347782496526
# Initial Cost on Val dataset for this epoch 138 = 0.4072347782496526
# Error on this batch = 0.39085620549325056
# Error on this batch = 0.39629826647821664
# Cost on val dataset after 139 epochs is = 0.40561457746328117
# Initial Cost on Val dataset for this epoch 139 = 0.40561457746328117
# Error on this batch = 0.3894845355971107
# Error on this batch = 0.3944895844236357
# Cost on val dataset after 140 epochs is = 0.40398486817266716
# Initial Cost on Val dataset for this epoch 140 = 0.40398486817266716
# Error on this batch = 0.388136882531996
# Error on this batch = 0.3927305725460829
# Cost on val dataset after 141 epochs is = 0.40234534517066667
# Initial Cost on Val dataset for this epoch 141 = 0.40234534517066667
# Error on this batch = 0.3868354350879959
# Error on this batch = 0.39098655088415174
# Cost on val dataset after 142 epochs is = 0.4006816507553622
# Initial Cost on Val dataset for this epoch 142 = 0.4006816507553622
# Error on this batch = 0.38552794206390345
# Error on this batch = 0.38927214777706604
# Cost on val dataset after 143 epochs is = 0.39899346125116003
# Initial Cost on Val dataset for this epoch 143 = 0.39899346125116003
# Error on this batch = 0.3841793713222077
# Error on this batch = 0.38758845430897
# Cost on val dataset after 144 epochs is = 0.3972938687019191
# Initial Cost on Val dataset for this epoch 144 = 0.3972938687019191
# Error on this batch = 0.3828107239440577
# Error on this batch = 0.3859339587042004
# Cost on val dataset after 145 epochs is = 0.3955782761184906
# Initial Cost on Val dataset for this epoch 145 = 0.3955782761184906
# Error on this batch = 0.38142817864012424
# Error on this batch = 0.3843080272359462
# Cost on val dataset after 146 epochs is = 0.39386012517337615
# Initial Cost on Val dataset for this epoch 146 = 0.39386012517337615
# Error on this batch = 0.3800207427788312
# Error on this batch = 0.3826768347775621
# Cost on val dataset after 147 epochs is = 0.3921451571363943
# Initial Cost on Val dataset for this epoch 147 = 0.3921451571363943
# Error on this batch = 0.3785857555344475
# Error on this batch = 0.38106447818145855
# Cost on val dataset after 148 epochs is = 0.39043180148301837
# Initial Cost on Val dataset for this epoch 148 = 0.39043180148301837
# Error on this batch = 0.3771050869699913
# Error on this batch = 0.37948830707076414
# Cost on val dataset after 149 epochs is = 0.3887362453237203
# Initial Cost on Val dataset for this epoch 149 = 0.3887362453237203
# Error on this batch = 0.37562218289855753
# Error on this batch = 0.3779517950755495
# Cost on val dataset after 150 epochs is = 0.3870736614451935
# Initial Cost on Val dataset for this epoch 150 = 0.3870736614451935
# Error on this batch = 0.37414168881488447
# Error on this batch = 0.3764599609827596
# Cost on val dataset after 151 epochs is = 0.3854478637906306
# Initial Cost on Val dataset for this epoch 151 = 0.3854478637906306
# Error on this batch = 0.37267054262764576
# Error on this batch = 0.3750015133088711
# Cost on val dataset after 152 epochs is = 0.3838645630471877
# Initial Cost on Val dataset for this epoch 152 = 0.3838645630471877
# Error on this batch = 0.3711953826659733
# Error on this batch = 0.3735667211215716
# Cost on val dataset after 153 epochs is = 0.3823298933951556
# Initial Cost on Val dataset for this epoch 153 = 0.3823298933951556
# Error on this batch = 0.36974973760672414
# Error on this batch = 0.3721800970737536
# Cost on val dataset after 154 epochs is = 0.3808453665136398
# Initial Cost on Val dataset for this epoch 154 = 0.3808453665136398
# Error on this batch = 0.36831961087235227
# Error on this batch = 0.37085482017110494
# Cost on val dataset after 155 epochs is = 0.3794193125988733
# Initial Cost on Val dataset for this epoch 155 = 0.3794193125988733
# Error on this batch = 0.36689808130807927
# Error on this batch = 0.3695842251585863
# Cost on val dataset after 156 epochs is = 0.3780443738244203
# Initial Cost on Val dataset for this epoch 156 = 0.3780443738244203
# Error on this batch = 0.36551241505128557
# Error on this batch = 0.36835052183127703
# Cost on val dataset after 157 epochs is = 0.37672544885611886
# Initial Cost on Val dataset for this epoch 157 = 0.37672544885611886
# Error on this batch = 0.36416586953669494
# Error on this batch = 0.3671654520828427
# Cost on val dataset after 158 epochs is = 0.37545694493512055
# Initial Cost on Val dataset for this epoch 158 = 0.37545694493512055
# Error on this batch = 0.36285219874827745
# Error on this batch = 0.36601721539606125
# Cost on val dataset after 159 epochs is = 0.3742407586545034
# Initial Cost on Val dataset for this epoch 159 = 0.3742407586545034
# Error on this batch = 0.36157307381112685
# Error on this batch = 0.36493380303551304
# Cost on val dataset after 160 epochs is = 0.37306534392061114
# Initial Cost on Val dataset for this epoch 160 = 0.37306534392061114
# Error on this batch = 0.3603375057308918
# Error on this batch = 0.3638980902831403
# Cost on val dataset after 161 epochs is = 0.3719344443076067
# Initial Cost on Val dataset for this epoch 161 = 0.3719344443076067
# Error on this batch = 0.35913783033664376
# Error on this batch = 0.3629019126779846
# Cost on val dataset after 162 epochs is = 0.37084331530144987
# Initial Cost on Val dataset for this epoch 162 = 0.37084331530144987
# Error on this batch = 0.3579863186598188
# Error on this batch = 0.3619362190862382
# Cost on val dataset after 163 epochs is = 0.3697918379929906
# Initial Cost on Val dataset for this epoch 163 = 0.3697918379929906
# Error on this batch = 0.35686107162850184
# Error on this batch = 0.3610130791024747
# Cost on val dataset after 164 epochs is = 0.36877784908396244
# Initial Cost on Val dataset for this epoch 164 = 0.36877784908396244
# Error on this batch = 0.3557809948417119
# Error on this batch = 0.36012936967266607
# Cost on val dataset after 165 epochs is = 0.3677987706534542
# Initial Cost on Val dataset for this epoch 165 = 0.3677987706534542
# Error on this batch = 0.3547254396483686
# Error on this batch = 0.3592626348735972
# Cost on val dataset after 166 epochs is = 0.36684957685796
# Initial Cost on Val dataset for this epoch 166 = 0.36684957685796
# Error on this batch = 0.35370100505767776
# Error on this batch = 0.3584412884038323
# Cost on val dataset after 167 epochs is = 0.3659288759159368
# Initial Cost on Val dataset for this epoch 167 = 0.3659288759159368
# Error on this batch = 0.35268611059391547
# Error on this batch = 0.3576432286092399
# Cost on val dataset after 168 epochs is = 0.36503676501963833
# Initial Cost on Val dataset for this epoch 168 = 0.36503676501963833
# Error on this batch = 0.35171193982536314
# Error on this batch = 0.35687897688243764
# Cost on val dataset after 169 epochs is = 0.364172636943111
# Initial Cost on Val dataset for this epoch 169 = 0.364172636943111
# Error on this batch = 0.3507556888107375
# Error on this batch = 0.3561532020300837
# Cost on val dataset after 170 epochs is = 0.36333413832936784
# Initial Cost on Val dataset for this epoch 170 = 0.36333413832936784
# Error on this batch = 0.3498331469405515
# Error on this batch = 0.35544574158575903
# Cost on val dataset after 171 epochs is = 0.3625177222750669
# Initial Cost on Val dataset for this epoch 171 = 0.3625177222750669
# Error on this batch = 0.348929264385136
# Error on this batch = 0.35476369056821605
# Cost on val dataset after 172 epochs is = 0.36172910888551735
# Initial Cost on Val dataset for this epoch 172 = 0.36172910888551735
# Error on this batch = 0.3480441350989122
# Error on this batch = 0.3540927794068623
# Cost on val dataset after 173 epochs is = 0.3609555526682982
# Initial Cost on Val dataset for this epoch 173 = 0.3609555526682982
# Error on this batch = 0.3471948917273459
# Error on this batch = 0.35342683349559706
# Cost on val dataset after 174 epochs is = 0.3602021493696028
# Initial Cost on Val dataset for this epoch 174 = 0.3602021493696028
# Error on this batch = 0.3463627188997079
# Error on this batch = 0.3527721256993058
# Cost on val dataset after 175 epochs is = 0.3594712330040453
# Initial Cost on Val dataset for this epoch 175 = 0.3594712330040453
# Error on this batch = 0.3455728230184127
# Error on this batch = 0.3521453907763702
# Cost on val dataset after 176 epochs is = 0.35875759549112163
# Initial Cost on Val dataset for this epoch 176 = 0.35875759549112163
# Error on this batch = 0.3447837067439018
# Error on this batch = 0.35153040162406496
# Cost on val dataset after 177 epochs is = 0.3580603778655578
# Initial Cost on Val dataset for this epoch 177 = 0.3580603778655578
# Error on this batch = 0.3440066516446891
# Error on this batch = 0.3509246957304201
# Cost on val dataset after 178 epochs is = 0.35738109092453335
# Initial Cost on Val dataset for this epoch 178 = 0.35738109092453335
# Error on this batch = 0.3432533909517993
# Error on this batch = 0.35035047649427425
# Cost on val dataset after 179 epochs is = 0.3567179641573516
# Initial Cost on Val dataset for this epoch 179 = 0.3567179641573516
# Error on this batch = 0.34250515113408475
# Error on this batch = 0.3497795425064939
# Cost on val dataset after 180 epochs is = 0.35607249940257146
# Initial Cost on Val dataset for this epoch 180 = 0.35607249940257146
# Error on this batch = 0.34177089982293235
# Error on this batch = 0.3492390239226584
# Cost on val dataset after 181 epochs is = 0.3554428658301384
# Initial Cost on Val dataset for this epoch 181 = 0.3554428658301384
# Error on this batch = 0.3410470929123883
# Error on this batch = 0.3486974707342808
# Cost on val dataset after 182 epochs is = 0.35482465643791006
# Initial Cost on Val dataset for this epoch 182 = 0.35482465643791006
# Error on this batch = 0.34032744987609376
# Error on this batch = 0.3481739042751302
# Cost on val dataset after 183 epochs is = 0.3542202891118394
# Initial Cost on Val dataset for this epoch 183 = 0.3542202891118394
# Error on this batch = 0.3396121003312894
# Error on this batch = 0.3476494687305708
# Cost on val dataset after 184 epochs is = 0.35362691318686895
# Initial Cost on Val dataset for this epoch 184 = 0.35362691318686895
# Error on this batch = 0.3389160607512832
# Error on this batch = 0.34713718780895947
# Cost on val dataset after 185 epochs is = 0.3530461040889729
# Initial Cost on Val dataset for this epoch 185 = 0.3530461040889729
# Error on this batch = 0.3382373822371316
# Error on this batch = 0.34662520929796203
# Cost on val dataset after 186 epochs is = 0.35247667653494363
# Initial Cost on Val dataset for this epoch 186 = 0.35247667653494363
# Error on this batch = 0.33757312012602164
# Error on this batch = 0.34613652420704727
# Cost on val dataset after 187 epochs is = 0.3519171958406292
# Initial Cost on Val dataset for this epoch 187 = 0.3519171958406292
# Error on this batch = 0.3369098652474812
# Error on this batch = 0.3456481669892073
# Cost on val dataset after 188 epochs is = 0.3513684389057171
# Initial Cost on Val dataset for this epoch 188 = 0.3513684389057171
# Error on this batch = 0.33626170276024897
# Error on this batch = 0.34515992679667734
# Cost on val dataset after 189 epochs is = 0.3508268966424266
# Initial Cost on Val dataset for this epoch 189 = 0.3508268966424266
# Error on this batch = 0.3356012634123313
# Error on this batch = 0.34468186933610306
# Cost on val dataset after 190 epochs is = 0.35029515861582255
# Initial Cost on Val dataset for this epoch 190 = 0.35029515861582255
# Error on this batch = 0.33495256941152673
# Error on this batch = 0.344207822485471
# Cost on val dataset after 191 epochs is = 0.34977225875631973
# Initial Cost on Val dataset for this epoch 191 = 0.34977225875631973
# Error on this batch = 0.3343194485051144
# Error on this batch = 0.34375263853993004
# Cost on val dataset after 192 epochs is = 0.3492566492584015
# Initial Cost on Val dataset for this epoch 192 = 0.3492566492584015
# Error on this batch = 0.3336824675658865
# Error on this batch = 0.34329192446142953
# Cost on val dataset after 193 epochs is = 0.34874531547988835
# Initial Cost on Val dataset for this epoch 193 = 0.34874531547988835
# Error on this batch = 0.3330468728501333
# Error on this batch = 0.34283653562748134
# Cost on val dataset after 194 epochs is = 0.3482400478611801
# Initial Cost on Val dataset for this epoch 194 = 0.3482400478611801
# Error on this batch = 0.33240529537120966
# Error on this batch = 0.3423783933597905
# Cost on val dataset after 195 epochs is = 0.3477423012819245
# Initial Cost on Val dataset for this epoch 195 = 0.3477423012819245
# Error on this batch = 0.3317663707967141
# Error on this batch = 0.3419301033958145
# Cost on val dataset after 196 epochs is = 0.3472478465959645
# Initial Cost on Val dataset for this epoch 196 = 0.3472478465959645
# Error on this batch = 0.33112768109845575
# Error on this batch = 0.3414735877523712
# Cost on val dataset after 197 epochs is = 0.3467608158721074
# Initial Cost on Val dataset for this epoch 197 = 0.3467608158721074
# Error on this batch = 0.33049031013075153
# Error on this batch = 0.34102221872505567
# Cost on val dataset after 198 epochs is = 0.34627969810497417
# Initial Cost on Val dataset for this epoch 198 = 0.34627969810497417
# Error on this batch = 0.3298393978476677
# Error on this batch = 0.34056163657137
# Cost on val dataset after 199 epochs is = 0.345804497136932
# Initial Cost on Val dataset for this epoch 199 = 0.345804497136932
# Error on this batch = 0.3291822449071852
# Error on this batch = 0.34009960601762823
# Cost on val dataset after 200 epochs is = 0.34533090978697945
# Initial Cost on Val dataset for this epoch 200 = 0.34533090978697945
# Error on this batch = 0.3284980918445726
# Error on this batch = 0.33962167486962413
# Cost on val dataset after 201 epochs is = 0.3448593098983024
# Initial Cost on Val dataset for this epoch 201 = 0.3448593098983024
# Error on this batch = 0.32780935703044906
# Error on this batch = 0.33914663786394345
# Cost on val dataset after 202 epochs is = 0.3443907731440813
# Initial Cost on Val dataset for this epoch 202 = 0.3443907731440813
# Error on this batch = 0.32712040270307924
# Error on this batch = 0.338673811525869
# Cost on val dataset after 203 epochs is = 0.34391942523831615
# Initial Cost on Val dataset for this epoch 203 = 0.34391942523831615
# Error on this batch = 0.3263861640950044
# Error on this batch = 0.33818971686835736
# Cost on val dataset after 204 epochs is = 0.343447461577385
# Initial Cost on Val dataset for this epoch 204 = 0.343447461577385
# Error on this batch = 0.325641675052256
# Error on this batch = 0.3377092383646692
# Cost on val dataset after 205 epochs is = 0.34296867776398277
# Initial Cost on Val dataset for this epoch 205 = 0.34296867776398277
# Error on this batch = 0.3248939935169049
# Error on this batch = 0.3372118667105569
# Cost on val dataset after 206 epochs is = 0.34248564292783656
# Initial Cost on Val dataset for this epoch 206 = 0.34248564292783656
# Error on this batch = 0.3241491777479368
# Error on this batch = 0.3367068201349669
# Cost on val dataset after 207 epochs is = 0.34199401741821955
# Initial Cost on Val dataset for this epoch 207 = 0.34199401741821955
# Error on this batch = 0.3233813628519276
# Error on this batch = 0.33619829679325997
# Cost on val dataset after 208 epochs is = 0.34149513665703246
# Initial Cost on Val dataset for this epoch 208 = 0.34149513665703246
# Error on this batch = 0.32261282755115617
# Error on this batch = 0.3356635003991697
# Cost on val dataset after 209 epochs is = 0.34099017706884666
# Initial Cost on Val dataset for this epoch 209 = 0.34099017706884666
# Error on this batch = 0.3218097380677182
# Error on this batch = 0.3351273543833485
# Cost on val dataset after 210 epochs is = 0.3404818239919025
# Initial Cost on Val dataset for this epoch 210 = 0.3404818239919025
# Error on this batch = 0.32100943167288265
# Error on this batch = 0.3345844259632398
# Cost on val dataset after 211 epochs is = 0.339969269847973
# Initial Cost on Val dataset for this epoch 211 = 0.339969269847973
# Error on this batch = 0.32021851207091173
# Error on this batch = 0.33404294321874717
# Cost on val dataset after 212 epochs is = 0.3394525302375519
# Initial Cost on Val dataset for this epoch 212 = 0.3394525302375519
# Error on this batch = 0.31942704180591025
# Error on this batch = 0.3334930746291937
# Cost on val dataset after 213 epochs is = 0.3389321659400318
# Initial Cost on Val dataset for this epoch 213 = 0.3389321659400318
# Error on this batch = 0.31860218998634404
# Error on this batch = 0.33294598788954105
# Cost on val dataset after 214 epochs is = 0.33840843058379233
# Initial Cost on Val dataset for this epoch 214 = 0.33840843058379233
# Error on this batch = 0.31776469168353294
# Error on this batch = 0.3323968393744944
# Cost on val dataset after 215 epochs is = 0.33787937365009557
# Initial Cost on Val dataset for this epoch 215 = 0.33787937365009557
# Error on this batch = 0.3169566892735623
# Error on this batch = 0.33182809796718216
# Cost on val dataset after 216 epochs is = 0.3373469452148384
# Initial Cost on Val dataset for this epoch 216 = 0.3373469452148384
# Error on this batch = 0.3161333165427688
# Error on this batch = 0.3312667863598924
# Cost on val dataset after 217 epochs is = 0.3368129068451901
# Initial Cost on Val dataset for this epoch 217 = 0.3368129068451901
# Error on this batch = 0.3152886891265901
# Error on this batch = 0.33069597338882245
# Cost on val dataset after 218 epochs is = 0.3362735011509118
# Initial Cost on Val dataset for this epoch 218 = 0.3362735011509118
# Error on this batch = 0.3144346519812447
# Error on this batch = 0.33012214498397646
# Cost on val dataset after 219 epochs is = 0.3357235644689793
# Initial Cost on Val dataset for this epoch 219 = 0.3357235644689793
# Error on this batch = 0.31355435980562246
# Error on this batch = 0.3295441894639603
# Cost on val dataset after 220 epochs is = 0.3351694044382711
# Initial Cost on Val dataset for this epoch 220 = 0.3351694044382711
# Error on this batch = 0.31268527461520373
# Error on this batch = 0.32895970326516183
# Cost on val dataset after 221 epochs is = 0.3346084129718529
# Initial Cost on Val dataset for this epoch 221 = 0.3346084129718529
# Error on this batch = 0.31180387874672677
# Error on this batch = 0.3283597876383458
# Cost on val dataset after 222 epochs is = 0.33404460808392106
# Initial Cost on Val dataset for this epoch 222 = 0.33404460808392106
# Error on this batch = 0.3109086832678278
# Error on this batch = 0.32775265360718286
# Cost on val dataset after 223 epochs is = 0.3334779808120868
# Initial Cost on Val dataset for this epoch 223 = 0.3334779808120868
# Error on this batch = 0.31000002849747377
# Error on this batch = 0.32713355941831795
# Cost on val dataset after 224 epochs is = 0.33290628247913184
# Initial Cost on Val dataset for this epoch 224 = 0.33290628247913184
# Error on this batch = 0.3090808141108813
# Error on this batch = 0.32651762324929534
# Cost on val dataset after 225 epochs is = 0.33233244100958653
# Initial Cost on Val dataset for this epoch 225 = 0.33233244100958653
# Error on this batch = 0.3081587542302247
# Error on this batch = 0.3258799566825424
# Cost on val dataset after 226 epochs is = 0.33175119158963573
# Initial Cost on Val dataset for this epoch 226 = 0.33175119158963573
# Error on this batch = 0.30724549908626636
# ...
# Error on this batch = 0.28542032165441805
# Error on this batch = 0.30892425806753565
# Cost on val dataset after 251 epochs is = 0.31696160348897906
# Initial Cost on Val dataset for this epoch 251 = 0.31696160348897906
# Error on this batch = 0.2846298357351486
# Error on this batch = 0.3082032868566701
# Cost on val dataset after 252 epochs is = 0.31636535629732243
# Initial Cost on Val dataset for this epoch 252 = 0.31636535629732243
# Error on this batch = 0.2838563887803582
# Error on this batch = 0.30748001669770497
# Cost on val dataset after 253 epochs is = 0.3157608429291198
# Initial Cost on Val dataset for this epoch 253 = 0.3157608429291198
# Error on this batch = 0.28309173447457625
# Error on this batch = 0.30673966537867414
# Cost on val dataset after 254 epochs is = 0.3151557745342037
# Initial Cost on Val dataset for this epoch 254 = 0.3151557745342037
# Error on this batch = 0.2823350167232856
# Error on this batch = 0.3059723953084999
# Cost on val dataset after 255 epochs is = 0.3145513182169389
# Initial Cost on Val dataset for this epoch 255 = 0.3145513182169389
# Error on this batch = 0.2815898914984433
# Error on this batch = 0.3052115359215224
# Cost on val dataset after 256 epochs is = 0.3139436731579162
# Initial Cost on Val dataset for this epoch 256 = 0.3139436731579162
# Error on this batch = 0.2808619646848899
# Error on this batch = 0.30443933026539977
# Cost on val dataset after 257 epochs is = 0.31333232035306186
# Initial Cost on Val dataset for this epoch 257 = 0.31333232035306186
# Error on this batch = 0.2801376625089328
# Error on this batch = 0.30365108242337285
# Cost on val dataset after 258 epochs is = 0.3127161523239958
# Initial Cost on Val dataset for this epoch 258 = 0.3127161523239958
# Error on this batch = 0.2794336110408111
# Error on this batch = 0.30283244926924796
# Cost on val dataset after 259 epochs is = 0.3120934258363599
# Initial Cost on Val dataset for this epoch 259 = 0.3120934258363599
# Error on this batch = 0.27872234517384586
# Error on this batch = 0.30199721219155246
# Cost on val dataset after 260 epochs is = 0.31146169479358365
# Initial Cost on Val dataset for this epoch 260 = 0.31146169479358365
# Error on this batch = 0.2780101214784097
# Error on this batch = 0.30114890390878996
# Cost on val dataset after 261 epochs is = 0.31082458597770024
# Initial Cost on Val dataset for this epoch 261 = 0.31082458597770024
# Error on this batch = 0.27728401958516846
# Error on this batch = 0.30031662125511327
# Cost on val dataset after 262 epochs is = 0.3101835534837644
# Initial Cost on Val dataset for this epoch 262 = 0.3101835534837644
# Error on this batch = 0.27654812016826485
# Error on this batch = 0.29947065164403436
# Cost on val dataset after 263 epochs is = 0.3095351297974559
# Initial Cost on Val dataset for this epoch 263 = 0.3095351297974559
# Error on this batch = 0.27582785261078663
# Error on this batch = 0.29860463171575524
# Cost on val dataset after 264 epochs is = 0.30887261000349026
# Initial Cost on Val dataset for this epoch 264 = 0.30887261000349026
# Error on this batch = 0.27510656484440604
# Error on this batch = 0.2977397038819342
# Cost on val dataset after 265 epochs is = 0.3081984358897692
# Initial Cost on Val dataset for this epoch 265 = 0.3081984358897692
# Error on this batch = 0.274388537561242
# Error on this batch = 0.2968462803906196
# Cost on val dataset after 266 epochs is = 0.30751751896520113
# Initial Cost on Val dataset for this epoch 266 = 0.30751751896520113
# Error on this batch = 0.27368183227069814
# Error on this batch = 0.29595781173926344
# Cost on val dataset after 267 epochs is = 0.30681735828528617
# Initial Cost on Val dataset for this epoch 267 = 0.30681735828528617
# Error on this batch = 0.27297075963022566
# Error on this batch = 0.29507034314455505
# Cost on val dataset after 268 epochs is = 0.30610780245872277
# Initial Cost on Val dataset for this epoch 268 = 0.30610780245872277
# Error on this batch = 0.2722560404705843
# Error on this batch = 0.29417313144070834
# Cost on val dataset after 269 epochs is = 0.30537943829102154
# Initial Cost on Val dataset for this epoch 269 = 0.30537943829102154
# Error on this batch = 0.2715260024492468
# Error on this batch = 0.29327684335296567
# Cost on val dataset after 270 epochs is = 0.30463246549634515
# Initial Cost on Val dataset for this epoch 270 = 0.30463246549634515
# Error on this batch = 0.2707591839955778
# Error on this batch = 0.2923728970140328
# Cost on val dataset after 271 epochs is = 0.3038772288336266
# Initial Cost on Val dataset for this epoch 271 = 0.3038772288336266
# Error on this batch = 0.2699938819890639
# Error on this batch = 0.2914687350014596
# Cost on val dataset after 272 epochs is = 0.30310683907804425
# Initial Cost on Val dataset for this epoch 272 = 0.30310683907804425
# Error on this batch = 0.2692354226264682
# Error on this batch = 0.2905618102833936
# Cost on val dataset after 273 epochs is = 0.3023300214686722
# Initial Cost on Val dataset for this epoch 273 = 0.3023300214686722
# Error on this batch = 0.2684822404024399
# Error on this batch = 0.2896370319518093
# Cost on val dataset after 274 epochs is = 0.30153878938941914
# Initial Cost on Val dataset for this epoch 274 = 0.30153878938941914
# Error on this batch = 0.2677269501089774
# Error on this batch = 0.28869708574636066
# Cost on val dataset after 275 epochs is = 0.30073132085719745
# Initial Cost on Val dataset for this epoch 275 = 0.30073132085719745
# Error on this batch = 0.26696816078942875
# Error on this batch = 0.28773245214790627
# Cost on val dataset after 276 epochs is = 0.2999163276570836
# Initial Cost on Val dataset for this epoch 276 = 0.2999163276570836
# Error on this batch = 0.2662129571206755
# Error on this batch = 0.2867550294792705
# Cost on val dataset after 277 epochs is = 0.29908466354489704
# Initial Cost on Val dataset for this epoch 277 = 0.29908466354489704
# Error on this batch = 0.2654591749724347
# Error on this batch = 0.2857397897023575
# Cost on val dataset after 278 epochs is = 0.29823728663353477
# Initial Cost on Val dataset for this epoch 278 = 0.29823728663353477
# Error on this batch = 0.2647326766996046
# Error on this batch = 0.28472532903967995
# Cost on val dataset after 279 epochs is = 0.29736834303620935
# Initial Cost on Val dataset for this epoch 279 = 0.29736834303620935
# Error on this batch = 0.26396312596165544
# Error on this batch = 0.2836893757274183
# Cost on val dataset after 280 epochs is = 0.29648819055529657
# Initial Cost on Val dataset for this epoch 280 = 0.29648819055529657
# Error on this batch = 0.26321892462958524
# Error on this batch = 0.28262220103752705
# Cost on val dataset after 281 epochs is = 0.2955938780189464
# Initial Cost on Val dataset for this epoch 281 = 0.2955938780189464
# Error on this batch = 0.26247327039139
# Error on this batch = 0.28150839319791615
# Cost on val dataset after 282 epochs is = 0.2946824882992259
# Initial Cost on Val dataset for this epoch 282 = 0.2946824882992259
# Error on this batch = 0.26173633202703217
# Error on this batch = 0.2803859347697229
# Cost on val dataset after 283 epochs is = 0.2937529522567873
# Initial Cost on Val dataset for this epoch 283 = 0.2937529522567873
# Error on this batch = 0.2609930360554325
# Error on this batch = 0.27925021232575914
# Cost on val dataset after 284 epochs is = 0.2928056276374544
# Initial Cost on Val dataset for this epoch 284 = 0.2928056276374544
# Error on this batch = 0.26025965394849204
# Error on this batch = 0.27811639219340156
# Cost on val dataset after 285 epochs is = 0.29184691705694227
# Initial Cost on Val dataset for this epoch 285 = 0.29184691705694227
# Error on this batch = 0.2595039527744604
# Error on this batch = 0.2769689854548094
# Cost on val dataset after 286 epochs is = 0.29087210307599626
# Initial Cost on Val dataset for this epoch 286 = 0.29087210307599626
# Error on this batch = 0.25876068779060263
# Error on this batch = 0.27579392883249554
# Cost on val dataset after 287 epochs is = 0.2898785425090575
# Initial Cost on Val dataset for this epoch 287 = 0.2898785425090575
# Error on this batch = 0.2580175373257829
# Error on this batch = 0.27459563952060206
# Cost on val dataset after 288 epochs is = 0.28888634029812577
# Initial Cost on Val dataset for this epoch 288 = 0.28888634029812577
# Error on this batch = 0.2572995969285939
# Error on this batch = 0.27340748798731856
# Cost on val dataset after 289 epochs is = 0.2878831304800488
# Initial Cost on Val dataset for this epoch 289 = 0.2878831304800488
# Error on this batch = 0.2565857823601654
# Error on this batch = 0.27217848040470816
# Cost on val dataset after 290 epochs is = 0.28687432145582625
# Initial Cost on Val dataset for this epoch 290 = 0.28687432145582625
# Error on this batch = 0.2558741345047926
# Error on this batch = 0.2709358781615449
# Cost on val dataset after 291 epochs is = 0.2858484052535104
# Initial Cost on Val dataset for this epoch 291 = 0.2858484052535104
# Error on this batch = 0.2551441828313057
# Error on this batch = 0.269707139280784
# Cost on val dataset after 292 epochs is = 0.28482626870361677
# Initial Cost on Val dataset for this epoch 292 = 0.28482626870361677
# Error on this batch = 0.2544171734878647
# Error on this batch = 0.26848519321204384
# Cost on val dataset after 293 epochs is = 0.2837951945623959
# Initial Cost on Val dataset for this epoch 293 = 0.2837951945623959
# Error on this batch = 0.2536822401290119
# Error on this batch = 0.2672563117214512
# Cost on val dataset after 294 epochs is = 0.2827653308124038
# Initial Cost on Val dataset for this epoch 294 = 0.2827653308124038
# Error on this batch = 0.25293485325887993
# Error on this batch = 0.26602928778607504
# Cost on val dataset after 295 epochs is = 0.28173628051464417
# Initial Cost on Val dataset for this epoch 295 = 0.28173628051464417
# Error on this batch = 0.252162529849887
# Error on this batch = 0.2648158358057644
# Cost on val dataset after 296 epochs is = 0.2807114789817486
# Initial Cost on Val dataset for this epoch 296 = 0.2807114789817486
# Error on this batch = 0.25136356520579123
# Error on this batch = 0.2636088418529044
# Cost on val dataset after 297 epochs is = 0.2797014759006311
# Initial Cost on Val dataset for this epoch 297 = 0.2797014759006311
# Error on this batch = 0.25055783388930264
# Error on this batch = 0.26243573380005525
# Cost on val dataset after 298 epochs is = 0.27869374228551747
# Initial Cost on Val dataset for this epoch 298 = 0.27869374228551747
# Error on this batch = 0.24974149306075574
# Error on this batch = 0.2612743760943304
# Cost on val dataset after 299 epochs is = 0.27770135930903
# Initial Cost on Val dataset for this epoch 299 = 0.27770135930903
# Error on this batch = 0.24893584002482116
# Error on this batch = 0.26013179849397433
# Cost on val dataset after 300 epochs is = 0.27672511360592317
# Initial Cost on Val dataset for this epoch 300 = 0.27672511360592317
# Error on this batch = 0.24811635709017368
# Error on this batch = 0.2590168460912907
# Cost on val dataset after 301 epochs is = 0.2757477245769096
# Initial Cost on Val dataset for this epoch 301 = 0.2757477245769096
# Error on this batch = 0.24730853375095932
# Error on this batch = 0.257888432500217
# Cost on val dataset after 302 epochs is = 0.2747689991765472
# Initial Cost on Val dataset for this epoch 302 = 0.2747689991765472
# Error on this batch = 0.2465018266630825
# Error on this batch = 0.2567715531322984
# Cost on val dataset after 303 epochs is = 0.2737955874987833
# Initial Cost on Val dataset for this epoch 303 = 0.2737955874987833
# Error on this batch = 0.24570617344656653
# Error on this batch = 0.2556660629392313
# Cost on val dataset after 304 epochs is = 0.27282828681814136
# Initial Cost on Val dataset for this epoch 304 = 0.27282828681814136
# Error on this batch = 0.24490428260754904
# Error on this batch = 0.25461098101455676
# Cost on val dataset after 305 epochs is = 0.271867938294409
# Initial Cost on Val dataset for this epoch 305 = 0.271867938294409
# Error on this batch = 0.2440836949210514
# Error on this batch = 0.2535617267124288
# Cost on val dataset after 306 epochs is = 0.2709046584398039
# Initial Cost on Val dataset for this epoch 306 = 0.2709046584398039
# Error on this batch = 0.24326674673032828
# Error on this batch = 0.252523217895699
# Cost on val dataset after 307 epochs is = 0.2699593823897522
# Initial Cost on Val dataset for this epoch 307 = 0.2699593823897522
# Error on this batch = 0.24242911792730995
# Error on this batch = 0.25152062719664897
# Cost on val dataset after 308 epochs is = 0.2690171006485623
# Initial Cost on Val dataset for this epoch 308 = 0.2690171006485623
# Error on this batch = 0.24162554041209874
# Error on this batch = 0.250529153880099
# Cost on val dataset after 309 epochs is = 0.2680760236319905
# Initial Cost on Val dataset for this epoch 309 = 0.2680760236319905
# Error on this batch = 0.2408161145953141
# Error on this batch = 0.24955785073135717
# Cost on val dataset after 310 epochs is = 0.26712835623880954
# Initial Cost on Val dataset for this epoch 310 = 0.26712835623880954
# Error on this batch = 0.23997538187583678
# Error on this batch = 0.24858275209705605
# Cost on val dataset after 311 epochs is = 0.2661896112143011
# Initial Cost on Val dataset for this epoch 311 = 0.2661896112143011
# Error on this batch = 0.23916739083755262
# Error on this batch = 0.24763989042223158
# Cost on val dataset after 312 epochs is = 0.26525602259955783
# Initial Cost on Val dataset for this epoch 312 = 0.26525602259955783
# Error on this batch = 0.23834855485714251
# Error on this batch = 0.24674213802719172
# Cost on val dataset after 313 epochs is = 0.26433652589152135
# Initial Cost on Val dataset for this epoch 313 = 0.26433652589152135
# Error on this batch = 0.2375471389311634
# Error on this batch = 0.2458613879149629
# Cost on val dataset after 314 epochs is = 0.2634269855938419
# Initial Cost on Val dataset for this epoch 314 = 0.2634269855938419
# Error on this batch = 0.2367642407246621
# Error on this batch = 0.24497324273256987
# Cost on val dataset after 315 epochs is = 0.26253453620121286
# Initial Cost on Val dataset for this epoch 315 = 0.26253453620121286
# Error on this batch = 0.2359997230972457
# Error on this batch = 0.24412109303657895
# Cost on val dataset after 316 epochs is = 0.2616499655607614
# Initial Cost on Val dataset for this epoch 316 = 0.2616499655607614
# Error on this batch = 0.23524638655635607
# Error on this batch = 0.24327058093203796
# Cost on val dataset after 317 epochs is = 0.26078565465748554
# Initial Cost on Val dataset for this epoch 317 = 0.26078565465748554
# Error on this batch = 0.23452518352446447
# Error on this batch = 0.24245007487511921
# Cost on val dataset after 318 epochs is = 0.25992560555447924
# Initial Cost on Val dataset for this epoch 318 = 0.25992560555447924
# Error on this batch = 0.23380077337953295
# Error on this batch = 0.24161837158505134
# Cost on val dataset after 319 epochs is = 0.25908722180137544
# Initial Cost on Val dataset for this epoch 319 = 0.25908722180137544
# Error on this batch = 0.2330843113363206
# Error on this batch = 0.24081166950050367
# Cost on val dataset after 320 epochs is = 0.25825379028339074
# Initial Cost on Val dataset for this epoch 320 = 0.25825379028339074
# Error on this batch = 0.2323491298250155
# Error on this batch = 0.2400355076618023
# Cost on val dataset after 321 epochs is = 0.25743731918857843
# Initial Cost on Val dataset for this epoch 321 = 0.25743731918857843
# Error on this batch = 0.23161563841945787
# Error on this batch = 0.23929444614728815
# Cost on val dataset after 322 epochs is = 0.2566334992812951
# Initial Cost on Val dataset for this epoch 322 = 0.2566334992812951
# Error on this batch = 0.23090870549923145
# Error on this batch = 0.23856278760711788
# Cost on val dataset after 323 epochs is = 0.25583593671479926
# Initial Cost on Val dataset for this epoch 323 = 0.25583593671479926
# Error on this batch = 0.2301990706491572
# Error on this batch = 0.2378529566604078
# --------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-104-8484aa2a6773> in <module>
#      43
#      44         for t in range(len(theta)):
# ---> 45             theta[t] += lr*np.dot(fm[t].T, delta[t+1])
#      46
#      47         count+=1
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
calc_accuracy(X_test, theta, test_actual_class_enc)
# epochs
# train_accuracy
# test_accuracy
# valid_accuracy
# train_time
# Out:
# 5.2153846153846155

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Accuracy with Epochs for #HU=100")
#x = np.arange(0,len(costs))
ax.plot(plt_epoch, plt_train_acc, marker='o', label='Train Accuracy')
ax.plot(plt_epoch, plt_val_acc, marker='o', label='Valid Accuracy')
ax.plot(plt_epoch, plt_test_acc, marker='o', label='Test Accuracy')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Accuracy")

plt.legend()
#plt.savefig("plots/val_loss/accuracy_HiddenUnit100_valloss15per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Validation Loss with Epochs for #HU=100")
x = np.arange(0,len(costs))
ax.plot(x, costs, marker='o', label='Validation Loss')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Validation Loss")

plt.legend()
#plt.savefig("plots/val_loss/partb_val_loss15per_100units.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
len(costs)
# Out:
# 17649

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Accuracy with number of hidden units \n in one hidden layer network")
ax.plot(arch_test, train_accuracy, marker='o', label='Train Accuracy')
ax.plot(arch_test, valid_accuracy, marker='o',label='Validation Accuracy')
ax.plot(arch_test, test_accuracy, marker='o', label='Test Accuracy')
ax.set_xlabel("number of hidden units")
ax.set_ylabel("Accuracy (%)")

plt.legend()
#plt.savefig("accuracy_HiddenUnit_val20per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(211)
plt.title("Epochs/Time with number of hidden units \n in one hidden layer network")
ax.plot(arch_test, epochs, c='b', marker='o', label='#epochs')
ax.set_xlabel("number of hidden units")
ax.set_ylabel("Epochs")
ax.legend()

ax1 = fig.add_subplot(212)
ax1.plot(arch_test, train_time, c='b', marker='o', label='train time')
ax1.set_xlabel("number of hidden units")
ax1.set_ylabel("train time(sec)")
plt.legend()
#plt.savefig("epochs_time_HiddenUnit_val20per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.set_title("Accuracy with number of epochs for \n 1 hidden layer of 100 units")
# ax.plot(plt_epoch, plt_train_acc, c='b', label='Train Accuracy')
# ax.plot(plt_epoch, plt_val_acc, c='m',label='Validation Accuracy')
# ax.plot(plt_epoch, plt_test_acc, c='g', label='Test Accuracy')
# ax.set_xlabel("number of epochs")
# ax.set_ylabel("Accuracy (%)")
#
# plt.legend()
# #plt.savefig("accuracy_epoch_100_valloss.png", dpi=1000, bbox_inches='tight')
# plt.show()
