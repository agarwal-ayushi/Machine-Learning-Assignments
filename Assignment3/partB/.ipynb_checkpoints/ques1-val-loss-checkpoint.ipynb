# %%
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

# %%
print("----------------Reading the Data-------------------------")
PATH = os.getcwd()
os.chdir('Alphabets/')

X_train = pd.read_csv('train.csv', sep=',', header=None, index_col=False)
X_test = pd.read_csv('test.csv', sep=',', header=None, index_col=False)
np.random.shuffle(X_train.to_numpy())
train_class = X_train[X_train.columns[-1]]
test_actual_class = X_test[X_test.columns[-1]]

X_train = X_train.drop(X_train.columns[-1], axis=1)
X_test = X_test.drop(X_test.columns[-1], axis=1)

print("----------------Data Reading completed-------------------")

os.chdir('../')

X_train = X_train/255
X_test = X_test/255

m = X_train.shape[0] # Number of Training Samples

X_valid = X_train.iloc[(int(0.85*m)):]
valid_class = train_class[(int(0.85*m)):]
X_train = X_train.iloc[0:int(0.85*m)]
train_class = train_class[0:int(0.85*m)]


m = X_train.shape[0] # Number of Training Samples
n = X_train.shape[1] # Number of input features

print("The total number of training samples = {}".format(m))
print("The total number of validation samples = {}".format(X_valid.shape[0]))

print("The number of features = {}".format(n))
# Out:
# ----------------Reading the Data-------------------------
# ----------------Data Reading completed-------------------
# The total number of training samples = 11050
# The total number of validation samples = 1950
# The number of features = 784

# %%
#To get the one hot encoding of each label
print("--------Perform 1-hot encoding of class labels------------")

train_class_enc = pd.get_dummies(train_class).to_numpy()
valid_class_enc = pd.get_dummies(valid_class).to_numpy()
test_actual_class_enc = pd.get_dummies(test_actual_class).to_numpy()
# Out:
# --------Perform 1-hot encoding of class labels------------

# %%
#Add the intercept term to the data samples both in training and test dataset
X_train = np.hstack((np.ones((m,1)),X_train.to_numpy()))
X_valid = np.hstack((np.ones((X_valid.shape[0],1)), X_valid.to_numpy()))
X_test = np.hstack((np.ones((X_test.shape[0],1)),X_test.to_numpy()))

# %%
lr = 0.1
arch_test = [1,5,10,50,100]
arch = [50] #means one hidden layer with 2 perceptrons 
batch_size = 100 # Mini-Batch Size
r = np.max(train_class) + 1 # Default value of the number of classes = 26

# %%
#Mini-Batch formation
mini_batch = [(X_train[i:i+batch_size,:], train_class_enc[i:i+batch_size]) for i in range(0, m, batch_size)]
print("The number of mini-batches formed is = {}".format(len(mini_batch)))
# Out:
# The number of mini-batches formed is = 111

# %%
#Theta Initialization 
#np.random.seed(1)
def theta_init(arch=[50]):
    theta = []
    for i in range(len(arch)+1):
        if i == 0:
            dim0=n+1
            dim1=arch[i]
        elif (i == len(arch)):
            dim0=arch[i-1]
            dim1 = r
        else:
            dim0=arch[i-1]
            dim1= arch[i]
        #theta.append(np.random.normal(0,0.01, (dim0,dim1)))
        theta.append(0.01*(2*np.random.random((dim0, dim1))-1))
        #theta.append(np.zeros((dim0, dim1)))
    return theta

# %%
def activation(x):
    return 1/(1+np.exp(-x))

# %%
def forward_prop(data, theta):
    fm = []
    fm.append(data)
    for l in range(len(theta)):
        fm.append(activation(np.dot(fm[l], theta[l])))
    return fm

# %%
def cost_total(X, theta, Y, m):
    fm = forward_prop(X, theta)
    cost = (1/(2*m))*np.sum((Y-fm[-1])**2)
    return cost

# %%
def calc_accuracy(data, theta, actual_class):
    pred_class = forward_prop(data, theta)
    test_pred_class = pred_class[-1]
    for i in range(len(test_pred_class)):
        test_pred_class[i][test_pred_class[i] == np.max(test_pred_class[i])] = 1
        test_pred_class[i][test_pred_class[i] != np.max(test_pred_class[i])] = 0


    test_acc = 0
    for i in range(len(actual_class)):
        if (np.array_equal(test_pred_class[i], actual_class[i])):
            test_acc+=1
    test_acc /= data.shape[0]

    #print("The Test Accuracy of the model = {}%".format(test_acc*100))
    return (test_acc*100)

# %%
epochs = []
train_accuracy = []
test_accuracy = []
valid_accuracy = []
train_time = []

plt_epoch = []
plt_train_acc = []
plt_val_acc = []
plt_test_acc = []
costs= []

# %%
arch_test = [1, 5, 10, 50, 100]

# %%
lr = 0.1
for i in range(len(arch_test)):
    theta = theta_init([arch_test[i]])
    print(theta[0].shape, theta[1].shape)
    early_stop=0
    epoch = 1
    start = time.time()
    cost_init = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])

    while(True):
        count = 0
        
        print("Initial Cost on Val dataset for this epoch {} = {}".format(epoch, cost_init))

        for b in mini_batch:
            X_b = b[0]
            Y_b = b[1]
            fm = forward_prop(X_b, theta)
            delta = [None]*len(fm)

            if (count % 60 == 0):
                print("Error on this batch = "+str(cost_total(X_b, theta, Y_b, batch_size)))
            #Backward Propagation

            for l in range(len(fm)-1, 0, -1):
                if (l == len(fm)-1):
                    delta[l] = ((1/batch_size)*(Y_b - fm[l])*fm[l]*(1-fm[l]))
                    #print("delta for last layer = ", delta[l])
                else:
                    delta[l]=(np.dot(delta[l+1], theta[l].T)*fm[l]*(1-fm[l]))
                    #print("delta for hidden layer = ", delta[l])


            for t in range(len(theta)):
                theta[t] += lr*np.dot(fm[t].T, delta[t+1]) 

            count+=1
            
#         if epoch %10 == 0:
#                 costs.append(cost_init)
#         if (epoch % 200 == 0):
#             plt_epoch.append(epoch)
#             plt_train_acc.append(calc_accuracy(X_train, theta, train_class_enc))
#             plt_val_acc.append(calc_accuracy(X_valid, theta, valid_class_enc))
#             plt_test_acc.append(calc_accuracy(X_test, theta, test_actual_class_enc))
        
        epoch+=1 #Number of epochs
        
        cost_final = cost_total(X_valid, theta, valid_class_enc, X_valid.shape[0])
        print("Cost on val dataset after {} epochs is = {}".format(epoch, cost_final))
        if (abs(cost_final-cost_init) < 1e-06):
            early_stop +=1
        else:
            early_stop=0
        if (early_stop == 10):
            print("cost initial= {} , cost final={} , change in cost= {}".format(cost_init,cost_final, cost_final-cost_init))
            break
        cost_init = cost_final
    epochs.append(epoch)
    train_time.append(time.time()-start)
    train_accuracy.append(calc_accuracy(X_train, theta, train_class_enc))
    valid_accuracy.append(calc_accuracy(X_valid, theta, valid_class_enc))
    test_accuracy.append(calc_accuracy(X_test, theta, test_actual_class_enc))
    print("\n------------------------------------------------------------------------------")
    print("The stats for number of units in the hidden layer = {} are as below:".format(arch_test[i]))
    print("------------------------------------------------------------------------------")
    print("The number of epochs = {:2.3f}".format(epochs[-1]))
    print("The training time = {:2.3f}sec".format(train_time[-1]))
    print("The training accuracy is = {:2.3f}%".format(train_accuracy[-1]))
    print("The validation accuracy is = {:2.3f}%".format(valid_accuracy[-1]))
    print("The test accuracy is = {:2.3f}%".format(test_accuracy[-1]))
    print("------------------------------------------------------------------------------\n")
# Out:
# (785, 1) (1, 26)
# Initial Cost on Val dataset for this epoch 1 = 3.2526384514123348
# Error on this batch = 3.2526844209023524
# Error on this batch = 1.9936593751722855
# Cost on val dataset after 2 epochs is = 1.3916987213899195
# Initial Cost on Val dataset for this epoch 2 = 1.3916987213899195
# Error on this batch = 1.3913441084946339
# Error on this batch = 1.0499611883481341
# Cost on val dataset after 3 epochs is = 0.8932332945976998
# Initial Cost on Val dataset for this epoch 3 = 0.8932332945976998
# Error on this batch = 0.8930282900794593
# Error on this batch = 0.7828199598327271
# Cost on val dataset after 4 epochs is = 0.7213968919640076
# Initial Cost on Val dataset for this epoch 4 = 0.7213968919640076
# Error on this batch = 0.721246339744042
# Error on this batch = 0.672118873070588
# Cost on val dataset after 5 epochs is = 0.641375460001454
# Initial Cost on Val dataset for this epoch 5 = 0.641375460001454
# Error on this batch = 0.641250529152576
# Error on this batch = 0.6147974295539146
# Cost on val dataset after 6 epochs is = 0.5969551007917794
# Initial Cost on Val dataset for this epoch 6 = 0.5969551007917794
# Error on this batch = 0.5968443263581698
# Error on this batch = 0.5808031414227558
# Cost on val dataset after 7 epochs is = 0.5693939063189221
# Initial Cost on Val dataset for this epoch 7 = 0.5693939063189221
# Error on this batch = 0.5692917696487726
# Error on this batch = 0.5587490262770151
# Cost on val dataset after 8 epochs is = 0.5509418640979354
# Initial Cost on Val dataset for this epoch 8 = 0.5509418640979354
# Error on this batch = 0.5508453477190554
# Error on this batch = 0.5435046548060238
# Cost on val dataset after 9 epochs is = 0.5378897657480721
# Initial Cost on Val dataset for this epoch 9 = 0.5378897657480721
# Error on this batch = 0.5377970649248629
# Error on this batch = 0.5324601971580795
# Cost on val dataset after 10 epochs is = 0.5282658284385154
# Initial Cost on Val dataset for this epoch 10 = 0.5282658284385154
# Error on this batch = 0.5281757899300968
# Error on this batch = 0.524163805440899
# Cost on val dataset after 11 epochs is = 0.5209358419535751
# Initial Cost on Val dataset for this epoch 11 = 0.5209358419535751
# Error on this batch = 0.5208476905649261
# Error on this batch = 0.5177504967324862
# Cost on val dataset after 12 epochs is = 0.5152060951893236
# Initial Cost on Val dataset for this epoch 12 = 0.5152060951893236
# Error on this batch = 0.5151192886594526
# Error on this batch = 0.5126762355698985
# Cost on val dataset after 13 epochs is = 0.510630956383288
# Initial Cost on Val dataset for this epoch 13 = 0.510630956383288
# Error on this batch = 0.5105451030237499
# Error on this batch = 0.5085834980582126
# Cost on val dataset after 14 epochs is = 0.5069124372752113
# Initial Cost on Val dataset for this epoch 14 = 0.5069124372752113
# Error on this batch = 0.5068272466182085
# Error on this batch = 0.5052286564428001
# Cost on val dataset after 15 epochs is = 0.5038445074646458
# Initial Cost on Val dataset for this epoch 15 = 0.5038445074646458
# Error on this batch = 0.5037597593396613
# Error on this batch = 0.5024405633630634
# Cost on val dataset after 16 epochs is = 0.5012806360597953
# Initial Cost on Val dataset for this epoch 16 = 0.5012806360597953
# Error on this batch = 0.5011961604784533
# Error on this batch = 0.5000958310025853
# Cost on val dataset after 17 epochs is = 0.4991140576558044
# Initial Cost on Val dataset for this epoch 17 = 0.4991140576558044
# Error on this batch = 0.4990297213045775
# Error on this batch = 0.4981034941524645
# Cost on val dataset after 18 epochs is = 0.49726533465335726
# Initial Cost on Val dataset for this epoch 18 = 0.49726533465335726
# Error on this batch = 0.4971810315720188
# Error on this batch = 0.4963951737926782
# Cost on val dataset after 19 epochs is = 0.49567427053288005
# Initial Cost on Val dataset for this epoch 19 = 0.49567427053288005
# Error on this batch = 0.49558991552694
# Error on this batch = 0.4949185837510882
# Cost on val dataset after 20 epochs is = 0.4942945073312833
# Initial Cost on Val dataset for this epoch 20 = 0.4942945073312833
# Error on this batch = 0.494210031218565
# Error on this batch = 0.4936331343645132
# Cost on val dataset after 21 epochs is = 0.49308982905294657
# Initial Cost on Val dataset for this epoch 21 = 0.49308982905294657
# Error on this batch = 0.4930051751699287
# Error on this batch = 0.492506888561459
# Cost on val dataset after 22 epochs is = 0.49203157813016407
# Initial Cost on Val dataset for this epoch 22 = 0.49203157813016407
# Error on this batch = 0.49194669972182853
# Error on this batch = 0.4915144119069393
# Cost on val dataset after 23 epochs is = 0.4910968152655139
# Initial Cost on Val dataset for this epoch 23 = 0.4910968152655139
# Error on this batch = 0.49101167350647174
# Error on this batch = 0.4906352266978995
# Cost on val dataset after 24 epochs is = 0.4902669862572669
# Initial Cost on Val dataset for this epoch 24 = 0.4902669862572669
# Error on this batch = 0.4901815487315518
# Error on this batch = 0.48985268235607077
# Cost on val dataset after 25 epochs is = 0.4895269411599626
# Initial Cost on Val dataset for this epoch 25 = 0.4895269411599626
# Error on this batch = 0.4894411806791496
# Error on this batch = 0.48915311788651894
# Cost on val dataset after 26 epochs is = 0.48886420251723445
# Initial Cost on Val dataset for this epoch 26 = 0.48886420251723445
# Error on this batch = 0.4887780961915631
# Error on this batch = 0.488525232588145
# Cost on val dataset after 27 epochs is = 0.48826841242131774
# Initial Cost on Val dataset for this epoch 27 = 0.48826841242131774
# Error on this batch = 0.4881819409223902
# Error on this batch = 0.4879596074628137
# Cost on val dataset after 28 epochs is = 0.48773090979761957
# Initial Cost on Val dataset for this epoch 28 = 0.48773090979761957
# Error on this batch = 0.48764405676782957
# Error on this batch = 0.4874483371594817
# Cost on val dataset after 29 epochs is = 0.4872444037624916
# Initial Cost on Val dataset for this epoch 29 = 0.4872444037624916
# Error on this batch = 0.4871571553380203
# Error on this batch = 0.48698474400734887
# Cost on val dataset after 30 epochs is = 0.4868027187119187
# Initial Cost on Val dataset for this epoch 30 = 0.4868027187119187
# Error on this batch = 0.4867150631344839
# Error on this batch = 0.4865631537149179
# Cost on val dataset after 31 epochs is = 0.48640059356157606
# Initial Cost on Val dataset for this epoch 31 = 0.48640059356157606
# Error on this batch = 0.48631252086016724
# Error on this batch = 0.48617871788644523
# Cost on val dataset after 32 epochs is = 0.4860335222876423
# Initial Cost on Val dataset for this epoch 32 = 0.4860335222876423
# Error on this batch = 0.485945024015897
# Error on this batch = 0.48582727243380575
# Cost on val dataset after 33 epochs is = 0.4856976262682663
# Initial Cost on Val dataset for this epoch 33 = 0.4856976262682663
# Error on this batch = 0.48560869528643014
# Error on this batch = 0.4855052237626318
# Cost on val dataset after 34 epochs is = 0.48538955132864836
# Initial Cost on Val dataset for this epoch 34 = 0.48538955132864836
# Error on this batch = 0.4853001816215116
# Error on this batch = 0.4852094566330491
# Cost on val dataset after 35 epochs is = 0.4851063841358958
# Initial Cost on Val dataset for this epoch 35 = 0.4851063841358958
# Error on this batch = 0.4850165706599577
# Error on this batch = 0.48493725907033525
# Cost on val dataset after 36 epochs is = 0.48484558386784743
# Initial Cost on Val dataset for this epoch 36 = 0.48484558386784743
# Error on this batch = 0.4847553224223751
# Error on this batch = 0.4846862607881575
# Cost on val dataset after 37 epochs is = 0.4846049260263903
# Initial Cost on Val dataset for this epoch 37 = 0.4846049260263903
# Error on this batch = 0.48451421314412507
# Error on this batch = 0.48445438239631505
# Cost on val dataset after 38 epochs is = 0.48438245597304996
# Initial Cost on Val dataset for this epoch 38 = 0.48438245597304996
# Error on this batch = 0.4842912888271609
# Error on this batch = 0.484239793272656
# Cost on val dataset after 39 epochs is = 0.4841764502978763
# Initial Cost on Val dataset for this epoch 39 = 0.4841764502978763
# Error on this batch = 0.4840848266224158
# Error on this batch = 0.4840408764391231
# Cost on val dataset after 40 epochs is = 0.48398538453797746
# Initial Cost on Val dataset for this epoch 40 = 0.48398538453797746
# Error on this batch = 0.48389330255961727
# Error on this batch = 0.48385619913327177
# Cost on val dataset after 41 epochs is = 0.4838079060725878
# Initial Cost on Val dataset for this epoch 41 = 0.4838079060725878
# Error on this batch = 0.4837153644518157
# Error on this batch = 0.48368448803687747
# Cost on val dataset after 42 epochs is = 0.48364281126118003
# Initial Cost on Val dataset for this epoch 42 = 0.48364281126118003
# Error on this batch = 0.4835498090414745
# Error on this batch = 0.48352460833262867
# Cost on val dataset after 43 epochs is = 0.48348902607734917
# Initial Cost on Val dataset for this epoch 43 = 0.48348902607734917
# Error on this batch = 0.48339556264110156
# Error on this batch = 0.48337554592318144
# Cost on val dataset after 44 epochs is = 0.48334558963684665
# Initial Cost on Val dataset for this epoch 44 = 0.48334558963684665
# Error on this batch = 0.4832516646670176
# Error on this batch = 0.4832363922750186
# Cost on val dataset after 45 epochs is = 0.48321164013278145
# Initial Cost on Val dataset for this epoch 45 = 0.48321164013278145
# Error on this batch = 0.4831172535794457
# Error on this batch = 0.48310633145074766
# Cost on val dataset after 46 epochs is = 0.4830864027817706
# Initial Cost on Val dataset for this epoch 46 = 0.4830864027817706
# Error on this batch = 0.4829915548328467
# Error on this batch = 0.4829846289738542
# Cost on val dataset after 47 epochs is = 0.4829691794570927
# Initial Cost on Val dataset for this epoch 47 = 0.4829691794570927
# Error on this batch = 0.48287387051266306
# Error on this batch = 0.4828706222340995
# Cost on val dataset after 48 epochs is = 0.48285933974273915
# Initial Cost on Val dataset for this epoch 48 = 0.48285933974273915
# Error on this batch = 0.48276357039246515
# Error on this batch = 0.4827637121932833
# Cost on val dataset after 49 epochs is = 0.48275631318881296
# Initial Cost on Val dataset for this epoch 49 = 0.48275631318881296
# Error on this batch = 0.4826600841920221
# Error on this batch = 0.4826633561926489
# Cost on val dataset after 50 epochs is = 0.48265958258635067
# Initial Cost on Val dataset for this epoch 50 = 0.48265958258635067
# Error on this batch = 0.4825628948544401
# Error on this batch = 0.4825690616969086
# Cost on val dataset after 51 epochs is = 0.4825686781102148
# Initial Cost on Val dataset for this epoch 51 = 0.4825686781102148
# Error on this batch = 0.48247153269106646
# Error on this batch = 0.4824803808372968
# Cost on val dataset after 52 epochs is = 0.48248317220364717
# Initial Cost on Val dataset for this epoch 52 = 0.48248317220364717
# Error on this batch = 0.4823855702677956
# Error on this batch = 0.48239690563850146
# Cost on val dataset after 53 epochs is = 0.48240267509850787
# Initial Cost on Val dataset for this epoch 53 = 0.48240267509850787
# Error on this batch = 0.48230461792683954
# Error on this batch = 0.48231826383274895
# Cost on val dataset after 54 epochs is = 0.48232683088204775
# Initial Cost on Val dataset for this epoch 54 = 0.48232683088204775
# Error on this batch = 0.4822283198548394
# Error on this batch = 0.4822441151795149
# Cost on val dataset after 55 epochs is = 0.4822553140349447
# Initial Cost on Val dataset for this epoch 55 = 0.4822553140349447
# Error on this batch = 0.4821563506220777
# Error on this batch = 0.48217414822190874
# Cost on val dataset after 56 epochs is = 0.48218782637685553
# Initial Cost on Val dataset for this epoch 56 = 0.48218782637685553
# Error on this batch = 0.48208841212906445
# Error on this batch = 0.48210807742123024
# Cost on val dataset after 57 epochs is = 0.48212409436531894
# Initial Cost on Val dataset for this epoch 57 = 0.48212409436531894
# Error on this batch = 0.48202423090635166
# Error on this batch = 0.48204564061990623
# Cost on val dataset after 58 epochs is = 0.4820638667018478
# Initial Cost on Val dataset for this epoch 58 = 0.4820638667018478
# Error on this batch = 0.4819635557214288
# Error on this batch = 0.481986596790306
# Cost on val dataset after 59 epochs is = 0.48200691220574843
# Initial Cost on Val dataset for this epoch 59 = 0.48200691220574843
# Error on this batch = 0.4819061554532556
# Error on this batch = 0.48193072403304743
# Cost on val dataset after 60 epochs is = 0.4819530179218512
# Initial Cost on Val dataset for this epoch 60 = 0.4819530179218512
# Error on this batch = 0.48185181720062276
# Error on this batch = 0.4818778177935603
# Cost on val dataset after 61 epochs is = 0.48190198743307977
# Initial Cost on Val dataset for this epoch 61 = 0.48190198743307977
# Error on this batch = 0.48180034459528137
# Error on this batch = 0.48182768927002045
# Cost on val dataset after 62 epochs is = 0.4818536393528056
# Initial Cost on Val dataset for this epoch 62 = 0.4818536393528056
# Error on this batch = 0.48175155629479655
# Error on this batch = 0.48178016398945245
# Cost on val dataset after 63 epochs is = 0.4818078059753507
# Initial Cost on Val dataset for this epoch 63 = 0.4818078059753507
# Error on this batch = 0.48170528463349355
# Error on this batch = 0.48173508053193076
# Cost on val dataset after 64 epochs is = 0.48176433206588937
# Initial Cost on Val dataset for this epoch 64 = 0.48176433206588937
# Error on this batch = 0.48166137441275625
# Error on this batch = 0.4816922893854731
# Cost on val dataset after 65 epochs is = 0.481723073773481
# Initial Cost on Val dataset for this epoch 65 = 0.481723073773481
# Error on this batch = 0.48161968181441456
# Error on this batch = 0.4816516519164968
# Cost on val dataset after 66 epochs is = 0.4816838976530756
# Initial Cost on Val dataset for this epoch 66 = 0.4816838976530756
# Error on this batch = 0.4815800734230657
# Error on this batch = 0.48161303944265854
# Cost on val dataset after 67 epochs is = 0.48164667978414527
# Initial Cost on Val dataset for this epoch 67 = 0.48164667978414527
# Error on this batch = 0.4815424253449912
# Error on this batch = 0.4815763323965719
# Cost on val dataset after 68 epochs is = 0.4816113049751537
# Initial Cost on Val dataset for this epoch 68 = 0.4816113049751537
# Error on this batch = 0.48150662241288156
# Error on this batch = 0.48154141957033575
# Cost on val dataset after 69 epochs is = 0.4815776660444181
# Initial Cost on Val dataset for this epoch 69 = 0.4815776660444181
# Error on this batch = 0.48147255746692624
# Error on this batch = 0.4815081974320469
# Cost on val dataset after 70 epochs is = 0.48154566316907
# Initial Cost on Val dataset for this epoch 70 = 0.48154566316907
# Error on this batch = 0.481440130703982
# Error on this batch = 0.48147656950654877
# Cost on val dataset after 71 epochs is = 0.4815152032948312
# Initial Cost on Val dataset for this epoch 71 = 0.4815152032948312
# Error on this batch = 0.4814092490875342
# Error on this batch = 0.48144644581358875
# Cost on val dataset after 72 epochs is = 0.48148619960018124
# Initial Cost on Val dataset for this epoch 72 = 0.48148619960018124
# Error on this batch = 0.4813798258120323
# Error on this batch = 0.4814177423573747
# Cost on val dataset after 73 epochs is = 0.48145857100925593
# Initial Cost on Val dataset for this epoch 73 = 0.48145857100925593
# Error on this batch = 0.48135177981593985
# Error on this batch = 0.48139038066221207
# Cost on val dataset after 74 epochs is = 0.48143224174846544
# Initial Cost on Val dataset for this epoch 74 = 0.48143224174846544
# Error on this batch = 0.48132503533848914
# Error on this batch = 0.48136428734952325
# Cost on val dataset after 75 epochs is = 0.48140714094240034
# Initial Cost on Val dataset for this epoch 75 = 0.48140714094240034
# Error on this batch = 0.4812995215157119
# Error on this batch = 0.4813393937520818
# Cost on val dataset after 76 epochs is = 0.48138320224509085
# Initial Cost on Val dataset for this epoch 76 = 0.48138320224509085
# Error on this batch = 0.48127517201181025
# Error on this batch = 0.48131563556176044
# Cost on val dataset after 77 epochs is = 0.4813603635031239
# Initial Cost on Val dataset for this epoch 77 = 0.4813603635031239
# Error on this batch = 0.48125192468237593
# Error on this batch = 0.48129295250750376
# Cost on val dataset after 78 epochs is = 0.4813385664475099
# Initial Cost on Val dataset for this epoch 78 = 0.4813385664475099
# Error on this batch = 0.4812297212663498
# Error on this batch = 0.4812712880605956
# Cost on val dataset after 79 epochs is = 0.48131775641152674
# Initial Cost on Val dataset for this epoch 79 = 0.48131775641152674
# Error on this batch = 0.4812085071039492
# Error on this batch = 0.48125058916460695
# Cost on val dataset after 80 epochs is = 0.481297882072065
# Initial Cost on Val dataset for this epoch 80 = 0.481297882072065
# Error on this batch = 0.4811882308780904
# Error on this batch = 0.48123080598769025
# Cost on val dataset after 81 epochs is = 0.48127889521226774
# Initial Cost on Val dataset for this epoch 81 = 0.48127889521226774
# Error on this batch = 0.481168844377097
# Error on this batch = 0.4812118916951302
# Cost on val dataset after 82 epochs is = 0.4812607505034793
# Initial Cost on Val dataset for this epoch 82 = 0.4812607505034793
# Error on this batch = 0.4811503022767134
# Error on this batch = 0.4811938022402809
# Cost on val dataset after 83 epochs is = 0.48124340530473325
# Initial Cost on Val dataset for this epoch 83 = 0.48124340530473325
# Error on this batch = 0.48113256193964943
# Error on this batch = 0.48117649617221103
# Cost on val dataset after 84 epochs is = 0.48122681947818435
# Initial Cost on Val dataset for this epoch 84 = 0.48122681947818435
# Error on this batch = 0.48111558323106524
# Error on this batch = 0.48115993445854743
# Cost on val dataset after 85 epochs is = 0.48121095521905255
# Initial Cost on Val dataset for this epoch 85 = 0.48121095521905255
# Error on this batch = 0.4810993283485646
# Error on this batch = 0.48114408032216277
# Cost on val dataset after 86 epochs is = 0.48119577689879295
# Initial Cost on Val dataset for this epoch 86 = 0.48119577689879295
# Error on this batch = 0.481083761665407
# Error on this batch = 0.48112889909048473
# Cost on val dataset after 87 epochs is = 0.4811812509203276
# Initial Cost on Val dataset for this epoch 87 = 0.4811812509203276
# Error on this batch = 0.4810688495857814
# Error on this batch = 0.48111435805632646
# Cost on val dataset after 88 epochs is = 0.4811673455842932
# Initial Cost on Val dataset for this epoch 88 = 0.4811673455842932
# Error on this batch = 0.48105456041108996
# Error on this batch = 0.48110042634924266
# Cost on val dataset after 89 epochs is = 0.48115403096535986
# Initial Cost on Val dataset for this epoch 89 = 0.48115403096535986
# Error on this batch = 0.481040864216301
# Error on this batch = 0.48108707481651347
# Cost on val dataset after 90 epochs is = 0.48114127879776264
# Initial Cost on Val dataset for this epoch 90 = 0.48114127879776264
# Error on this batch = 0.48102773273551097
# Error on this batch = 0.48107427591294366
# Cost on val dataset after 91 epochs is = 0.48112906236927333
# Initial Cost on Val dataset for this epoch 91 = 0.48112906236927333
# Error on this batch = 0.48101513925594547
# Error on this batch = 0.48106200359873874
# Cost on val dataset after 92 epochs is = 0.4811173564229097
# Initial Cost on Val dataset for this epoch 92 = 0.4811173564229097
# Error on this batch = 0.4810030585196938
# Error on this batch = 0.48105023324479157
# Cost on val dataset after 93 epochs is = 0.4811061370657456
# Initial Cost on Val dataset for this epoch 93 = 0.4811061370657456
# Error on this batch = 0.48099146663254344
# Error on this batch = 0.48103894154477206
# Cost on val dataset after 94 epochs is = 0.4810953816842421
# Initial Cost on Val dataset for this epoch 94 = 0.4810953816842421
# Error on this batch = 0.48098034097933323
# Error on this batch = 0.48102810643346916
# Cost on val dataset after 95 epochs is = 0.48108506886557595
# Initial Cost on Val dataset for this epoch 95 = 0.48108506886557595
# Error on this batch = 0.48096966014530157
# Error on this batch = 0.4810177070108831
# Cost on val dataset after 96 epochs is = 0.4810751783244838
# Initial Cost on Val dataset for this epoch 96 = 0.4810751783244838
# Error on this batch = 0.4809594038429505
# Error on this batch = 0.4810077234716125
# Cost on val dataset after 97 epochs is = 0.48106569083518874
# Initial Cost on Val dataset for this epoch 97 = 0.48106569083518874
# Error on this batch = 0.4809495528439881
# Error on this batch = 0.4809981370391188
# Cost on val dataset after 98 epochs is = 0.48105658816800856
# Initial Cost on Val dataset for this epoch 98 = 0.48105658816800856
# Error on this batch = 0.4809400889159535
# Error on this batch = 0.48098892990448805
# Cost on val dataset after 99 epochs is = 0.4810478530302855
# Initial Cost on Val dataset for this epoch 99 = 0.4810478530302855
# Error on this batch = 0.48093099476316087
# Error on this batch = 0.4809800851693452
# Cost on val dataset after 100 epochs is = 0.48103946901130384
# Initial Cost on Val dataset for this epoch 100 = 0.48103946901130384
# Error on this batch = 0.4809222539716306
# Error on this batch = 0.4809715867926013
# Cost on val dataset after 101 epochs is = 0.48103142053089154
# Initial Cost on Val dataset for this epoch 101 = 0.48103142053089154
# Error on this batch = 0.48091385095770345
# Error on this batch = 0.48096341954074545
# Cost on val dataset after 102 epochs is = 0.48102369279143065
# Initial Cost on Val dataset for this epoch 102 = 0.48102369279143065
# Error on this batch = 0.4809057709200625
# Error on this batch = 0.4809555689414143
# Cost on val dataset after 103 epochs is = 0.4810162717330199
# Initial Cost on Val dataset for this epoch 103 = 0.4810162717330199
# Error on this batch = 0.48089799979490616
# Error on this batch = 0.4809480212399967
# Cost on val dataset after 104 epochs is = 0.4810091439915563
# Initial Cost on Val dataset for this epoch 104 = 0.4810091439915563
# Error on this batch = 0.4808905242140405
# Error on this batch = 0.4809407633590507
# Cost on val dataset after 105 epochs is = 0.48100229685952406
# Initial Cost on Val dataset for this epoch 105 = 0.48100229685952406
# Error on this batch = 0.480883331465676
# Error on this batch = 0.4809337828603256
# Cost on val dataset after 106 epochs is = 0.4809957182492908
# Initial Cost on Val dataset for this epoch 106 = 0.4809957182492908
# Error on this batch = 0.48087640945773374
# Error on this batch = 0.4809270679092022
# Cost on val dataset after 107 epochs is = 0.48098939665873386
# Initial Cost on Val dataset for this epoch 107 = 0.48098939665873386
# Error on this batch = 0.4808697466834783
# Error on this batch = 0.4809206072413797
# Cost on val dataset after 108 epochs is = 0.48098332113902703
# Initial Cost on Val dataset for this epoch 108 = 0.48098332113902703
# Error on this batch = 0.48086333218931276
# Error on this batch = 0.480914390131645
# Cost on val dataset after 109 epochs is = 0.4809774812644386
# Initial Cost on Val dataset for this epoch 109 = 0.4809774812644386
# Error on this batch = 0.4808571555445832
# Error on this batch = 0.4809084063645836
# Cost on val dataset after 110 epochs is = 0.48097186710399625
# Initial Cost on Val dataset for this epoch 110 = 0.48097186710399625
# Error on this batch = 0.48085120681324983
# Error on this batch = 0.48090264620709156
# Cost on val dataset after 111 epochs is = 0.4809664691948906
# Initial Cost on Val dataset for this epoch 111 = 0.4809664691948906
# Error on this batch = 0.4808454765272968
# Error on this batch = 0.480897100382567
# Cost on val dataset after 112 epochs is = 0.4809612785174982
# Initial Cost on Val dataset for this epoch 112 = 0.4809612785174982
# Error on this batch = 0.4808399556617605
# Error on this batch = 0.48089176004666423
# Cost on val dataset after 113 epochs is = 0.4809562864719113
# Initial Cost on Val dataset for this epoch 113 = 0.4809562864719113
# Error on this batch = 0.48083463561126444
# Error on this batch = 0.4808866167645057
# Cost on val dataset after 114 epochs is = 0.48095148485587336
# Initial Cost on Val dataset for this epoch 114 = 0.48095148485587336
# Error on this batch = 0.48082950816796
# Error on this batch = 0.4808816624892516
# Cost on val dataset after 115 epochs is = 0.4809468658440266
# Initial Cost on Val dataset for this epoch 115 = 0.4809468658440266
# Error on this batch = 0.4808245655007778
# Error on this batch = 0.4808768895419372
# Cost on val dataset after 116 epochs is = 0.480942421968382
# Initial Cost on Val dataset for this epoch 116 = 0.480942421968382
# Error on this batch = 0.48081980013590253
# Error on this batch = 0.4808722905924937
# Cost on val dataset after 117 epochs is = 0.4809381460999321
# Initial Cost on Val dataset for this epoch 117 = 0.4809381460999321
# Error on this batch = 0.48081520493838986
# Error on this batch = 0.48086785864187503
# Cost on val dataset after 118 epochs is = 0.48093403143133207
# Initial Cost on Val dataset for this epoch 118 = 0.48093403143133207
# Error on this batch = 0.4808107730948504
# Error on this batch = 0.48086358700521675
# Cost on val dataset after 119 epochs is = 0.4809300714605781
# Initial Cost on Val dataset for this epoch 119 = 0.4809300714605781
# Error on this batch = 0.48080649809713266
# Error on this batch = 0.48085946929596207
# Cost on val dataset after 120 epochs is = 0.48092625997561933
# Initial Cost on Val dataset for this epoch 120 = 0.48092625997561933
# Error on this batch = 0.4808023737269376
# Error on this batch = 0.4808554994108911
# Cost on val dataset after 121 epochs is = 0.48092259103984464
# Initial Cost on Val dataset for this epoch 121 = 0.48092259103984464
# Error on this batch = 0.48079839404130836
# Error on this batch = 0.4808516715159978
# Cost on val dataset after 122 epochs is = 0.48091905897838494
# Initial Cost on Val dataset for this epoch 122 = 0.48091905897838494
# Error on this batch = 0.4807945533589367
# Error on this batch = 0.48084798003315715
# Cost on val dataset after 123 epochs is = 0.48091565836518485
# Initial Cost on Val dataset for this epoch 123 = 0.48091565836518485
# Error on this batch = 0.4807908462472363
# Error on this batch = 0.480844419627538
# Cost on val dataset after 124 epochs is = 0.48091238401079045
# Initial Cost on Val dataset for this epoch 124 = 0.48091238401079045
# Error on this batch = 0.4807872675101336
# Error on this batch = 0.48084098519571017
# Cost on val dataset after 125 epochs is = 0.4809092309508122
# Initial Cost on Val dataset for this epoch 125 = 0.4809092309508122
# Error on this batch = 0.48078381217653304
# Error on this batch = 0.4808376718544058
# Cost on val dataset after 126 epochs is = 0.48090619443501836
# Initial Cost on Val dataset for this epoch 126 = 0.48090619443501836
# Error on this batch = 0.48078047548941355
# Error on this batch = 0.48083447492989373
# Cost on val dataset after 127 epochs is = 0.4809032699170234
# Initial Cost on Val dataset for this epoch 127 = 0.4809032699170234
# Error on this batch = 0.48077725289551837
# Error on this batch = 0.4808313899479296
# Cost on val dataset after 128 epochs is = 0.4809004530445322
# Initial Cost on Val dataset for this epoch 128 = 0.4809004530445322
# Error on this batch = 0.48077414003560204
# Error on this batch = 0.4808284126242465
# Cost on val dataset after 129 epochs is = 0.48089773965010824
# Initial Cost on Val dataset for this epoch 129 = 0.48089773965010824
# Error on this batch = 0.4807711327352007
# Error on this batch = 0.48082553885555407
# Cost on val dataset after 130 epochs is = 0.4808951257424345
# Initial Cost on Val dataset for this epoch 130 = 0.4808951257424345
# Error on this batch = 0.4807682269958944
# Error on this batch = 0.4808227647110154
# Cost on val dataset after 131 epochs is = 0.48089260749803553
# Initial Cost on Val dataset for this epoch 131 = 0.48089260749803553
# Error on this batch = 0.48076541898703185
# Error on this batch = 0.48082008642417345
# Cost on val dataset after 132 epochs is = 0.480890181253437
# Initial Cost on Val dataset for this epoch 132 = 0.480890181253437
# Error on this batch = 0.4807627050378915
# Error on this batch = 0.48081750038530047
# Cost on val dataset after 133 epochs is = 0.48088784349773334
# Initial Cost on Val dataset for this epoch 133 = 0.48088784349773334
# Error on this batch = 0.48076008163025047
# Error on this batch = 0.48081500313414566
# Cost on val dataset after 134 epochs is = 0.48088559086554156
# Initial Cost on Val dataset for this epoch 134 = 0.48088559086554156
# Error on this batch = 0.48075754539134147
# Error on this batch = 0.4808125913530585
# Cost on val dataset after 135 epochs is = 0.48088342013031965
# Initial Cost on Val dataset for this epoch 135 = 0.48088342013031965
# Error on this batch = 0.4807550930871713
# Error on this batch = 0.48081026186046416
# Cost on val dataset after 136 epochs is = 0.48088132819802626
# Initial Cost on Val dataset for this epoch 136 = 0.48088132819802626
# Error on this batch = 0.4807527216161832
# Error on this batch = 0.4808080116046737
# Cost on val dataset after 137 epochs is = 0.4808793121011043
# Initial Cost on Val dataset for this epoch 137 = 0.4808793121011043
# Error on this batch = 0.4807504280032414
# Error on this batch = 0.4808058376580074
# Cost on val dataset after 138 epochs is = 0.4808773689927686
# Initial Cost on Val dataset for this epoch 138 = 0.4808773689927686
# Error on this batch = 0.4807482093939207
# Error on this batch = 0.48080373721121517
# Cost on val dataset after 139 epochs is = 0.4808754961415812
# Initial Cost on Val dataset for this epoch 139 = 0.4808754961415812
# Error on this batch = 0.480746063049083
# Error on this batch = 0.4808017075681763
# Cost on val dataset after 140 epochs is = 0.4808736909262978
# Initial Cost on Val dataset for this epoch 140 = 0.4808736909262978
# Error on this batch = 0.48074398633972565
# Error on this batch = 0.4807997461408634
# Cost on val dataset after 141 epochs is = 0.48087195083097145
# Initial Cost on Val dataset for this epoch 141 = 0.48087195083097145
# Error on this batch = 0.4807419767420859
# Error on this batch = 0.4807978504445559
# Cost on val dataset after 142 epochs is = 0.48087027344029665
# Initial Cost on Val dataset for this epoch 142 = 0.48087027344029665
# Error on this batch = 0.48074003183298686
# Error on this batch = 0.4807960180932895
# Cost on val dataset after 143 epochs is = 0.4808686564351833
# Initial Cost on Val dataset for this epoch 143 = 0.4808686564351833
# Error on this batch = 0.4807381492854124
# Error on this batch = 0.4807942467955283
# Cost on val dataset after 144 epochs is = 0.48086709758854645
# Initial Cost on Val dataset for this epoch 144 = 0.48086709758854645
# Error on this batch = 0.4807363268642986
# Error on this batch = 0.4807925343500466
# Cost on val dataset after 145 epochs is = 0.48086559476130053
# Initial Cost on Val dataset for this epoch 145 = 0.48086559476130053
# Error on this batch = 0.4807345624225295
# Error on this batch = 0.4807908786420123
# Cost on val dataset after 146 epochs is = 0.4808641458985478
# Initial Cost on Val dataset for this epoch 146 = 0.4808641458985478
# Error on this batch = 0.4807328538971256
# Error on this batch = 0.480789277639256
# Cost on val dataset after 147 epochs is = 0.48086274902594806
# Initial Cost on Val dataset for this epoch 147 = 0.48086274902594806
# Error on this batch = 0.48073119930561653
# Error on this batch = 0.48078772938872094
# Cost on val dataset after 148 epochs is = 0.4808614022462634
# Initial Cost on Val dataset for this epoch 148 = 0.4808614022462634
# Error on this batch = 0.48072959674258586
# Error on this batch = 0.4807862320130806
# Cost on val dataset after 149 epochs is = 0.48086010373606647
# Initial Cost on Val dataset for this epoch 149 = 0.48086010373606647
# Error on this batch = 0.480728044376381
# Error on this batch = 0.4807847837075167
# Cost on val dataset after 150 epochs is = 0.48085885174260384
# Initial Cost on Val dataset for this epoch 150 = 0.48085885174260384
# Error on this batch = 0.48072654044597757
# Error on this batch = 0.48078338273664883
# Cost on val dataset after 151 epochs is = 0.4808576445808071
# Initial Cost on Val dataset for this epoch 151 = 0.4808576445808071
# Error on this batch = 0.4807250832579918
# Error on this batch = 0.4807820274316081
# Cost on val dataset after 152 epochs is = 0.4808564806304434
# Initial Cost on Val dataset for this epoch 152 = 0.4808564806304434
# Error on this batch = 0.4807236711838326
# Error on this batch = 0.4807807161872464
# Cost on val dataset after 153 epochs is = 0.4808553583333986
# Initial Cost on Val dataset for this epoch 153 = 0.4808553583333986
# Error on this batch = 0.48072230265698507
# Error on this batch = 0.48077944745947593
# Cost on val dataset after 154 epochs is = 0.4808542761910857
# Initial Cost on Val dataset for this epoch 154 = 0.4808542761910857
# Error on this batch = 0.480720976170421
# Error on this batch = 0.48077821976273
# Cost on val dataset after 155 epochs is = 0.48085323276197306
# Initial Cost on Val dataset for this epoch 155 = 0.48085323276197306
# Error on this batch = 0.4807196902741271
# Error on this batch = 0.48077703166754165
# Cost on val dataset after 156 epochs is = 0.4808522266592242
# Initial Cost on Val dataset for this epoch 156 = 0.4808522266592242
# Error on this batch = 0.48071844357274746
# Error on this batch = 0.4807758817982314
# Cost on val dataset after 157 epochs is = 0.4808512565484475
# Initial Cost on Val dataset for this epoch 157 = 0.4808512565484475
# Error on this batch = 0.4807172347233328
# Error on this batch = 0.48077476883070075
# Cost on val dataset after 158 epochs is = 0.4808503211455453
# Initial Cost on Val dataset for this epoch 158 = 0.4808503211455453
# Error on this batch = 0.48071606243319154
# Error on this batch = 0.4807736914903252
# Cost on val dataset after 159 epochs is = 0.4808494192146614
# Initial Cost on Val dataset for this epoch 159 = 0.4808494192146614
# Error on this batch = 0.4807149254578385
# Error on this batch = 0.48077264854994134
# Cost on val dataset after 160 epochs is = 0.48084854956622003
# Initial Cost on Val dataset for this epoch 160 = 0.48084854956622003
# Error on this batch = 0.48071382259903445
# Error on this batch = 0.4807716388279249
# Cost on val dataset after 161 epochs is = 0.48084771105505286
# Initial Cost on Val dataset for this epoch 161 = 0.48084771105505286
# Error on this batch = 0.48071275270291447
# Error on this batch = 0.48077066118635314
# Cost on val dataset after 162 epochs is = 0.4808469025786083
# Initial Cost on Val dataset for this epoch 162 = 0.4808469025786083
# Error on this batch = 0.48071171465819823
# Error on this batch = 0.48076971452924966
# Cost on val dataset after 163 epochs is = 0.48084612307524033
# Initial Cost on Val dataset for this epoch 163 = 0.48084612307524033
# Error on this batch = 0.48071070739448046
# Error on this batch = 0.4807687978009054
# Cost on val dataset after 164 epochs is = 0.48084537152257334
# Initial Cost on Val dataset for this epoch 164 = 0.48084537152257334
# Error on this batch = 0.4807097298805957
# Error on this batch = 0.48076790998427493
# Cost on val dataset after 165 epochs is = 0.48084464693593715
# Initial Cost on Val dataset for this epoch 165 = 0.48084464693593715
# Error on this batch = 0.4807087811230552
# Error on this batch = 0.4807670500994405
# Cost on val dataset after 166 epochs is = 0.480843948366871
# cost initial= 0.48084464693593715 , cost final=0.480843948366871 , change in cost= -6.985690661487354e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 1 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 166.000
# The training time = 16.713sec
# The training accuracy is = 3.946%
# The validation accuracy is = 3.282%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# (785, 5) (5, 26)
# Initial Cost on Val dataset for this epoch 1 = 3.2527576321672274
# Error on this batch = 3.2526781242519567
# Error on this batch = 0.8163696012459292
# Cost on val dataset after 2 epochs is = 0.6097358868367425
# Initial Cost on Val dataset for this epoch 2 = 0.6097358868367425
# Error on this batch = 0.6091687752596529
# Error on this batch = 0.547679381718689
# Cost on val dataset after 3 epochs is = 0.52344431555167
# Initial Cost on Val dataset for this epoch 3 = 0.52344431555167
# Error on this batch = 0.5231617482269117
# Error on this batch = 0.51029832735089
# Cost on val dataset after 4 epochs is = 0.5022654750329919
# Initial Cost on Val dataset for this epoch 4 = 0.5022654750329919
# Error on this batch = 0.5020638164311997
# Error on this batch = 0.4973870975382827
# Cost on val dataset after 5 epochs is = 0.4936064879546227
# Initial Cost on Val dataset for this epoch 5 = 0.4936064879546227
# Error on this batch = 0.49343985104785787
# Error on this batch = 0.4913057918053359
# Cost on val dataset after 6 epochs is = 0.4891831259436014
# Initial Cost on Val dataset for this epoch 6 = 0.4891831259436014
# Error on this batch = 0.4890346487119506
# Error on this batch = 0.48794320097034066
# Cost on val dataset after 7 epochs is = 0.48661948702444996
# Initial Cost on Val dataset for this epoch 7 = 0.48661948702444996
# Error on this batch = 0.4864813064554085
# Error on this batch = 0.485891368002881
# Cost on val dataset after 8 epochs is = 0.485007615989431
# Initial Cost on Val dataset for this epoch 8 = 0.485007615989431
# Error on this batch = 0.48487550765027776
# Error on this batch = 0.4845529147501073
# Cost on val dataset after 9 epochs is = 0.4839348697534369
# Initial Cost on Val dataset for this epoch 9 = 0.4839348697534369
# Error on this batch = 0.48380634184857685
# Error on this batch = 0.48363668430683704
# Cost on val dataset after 10 epochs is = 0.483190397735268
# Initial Cost on Val dataset for this epoch 10 = 0.483190397735268
# Error on this batch = 0.4830638811132485
# Error on this batch = 0.4829862091105128
# Cost on val dataset after 11 epochs is = 0.48265691933987337
# Initial Cost on Val dataset for this epoch 11 = 0.48265691933987337
# Error on this batch = 0.48253137792147727
# Error on this batch = 0.4825110621293752
# Cost on val dataset after 12 epochs is = 0.48226486192154605
# Initial Cost on Val dataset for this epoch 12 = 0.48226486192154605
# Error on this batch = 0.48213958740780527
# Error on this batch = 0.48215595739180034
# Cost on val dataset after 13 epochs is = 0.48197081446228496
# Initial Cost on Val dataset for this epoch 13 = 0.48197081446228496
# Error on this batch = 0.4818453102543854
# Error on this batch = 0.4818855429139402
# Cost on val dataset after 14 epochs is = 0.48174656436277996
# Initial Cost on Val dataset for this epoch 14 = 0.48174656436277996
# Error on this batch = 0.48162047613581055
# Error on this batch = 0.48167637110741895
# Cost on val dataset after 15 epochs is = 0.48157315228070274
# Initial Cost on Val dataset for this epoch 15 = 0.48157315228070274
# Error on this batch = 0.48144622451113445
# Error on this batch = 0.48151241050866445
# Cost on val dataset after 16 epochs is = 0.48143747575380685
# Initial Cost on Val dataset for this epoch 16 = 0.48143747575380685
# Error on this batch = 0.4813095234360531
# Error on this batch = 0.4813824159741863
# Cost on val dataset after 17 epochs is = 0.48133026276081275
# Initial Cost on Val dataset for this epoch 17 = 0.48133026276081275
# Error on this batch = 0.4812011523978552
# Error on this batch = 0.48127832551009053
# Cost on val dataset after 18 epochs is = 0.48124481734504393
# Initial Cost on Val dataset for this epoch 18 = 0.48124481734504393
# Error on this batch = 0.4811144538090993
# Error on this batch = 0.48119424934287597
# Cost on val dataset after 19 epochs is = 0.48117621825360635
# Initial Cost on Val dataset for this epoch 19 = 0.48117621825360635
# Error on this batch = 0.4810445354791745
# Error on this batch = 0.481125813564327
# Cost on val dataset after 20 epochs is = 0.48112079278096853
# Initial Cost on Val dataset for this epoch 20 = 0.48112079278096853
# Error on this batch = 0.48098774702838515
# Error on this batch = 0.48106972300151757
# Cost on val dataset after 21 epochs is = 0.4810757629294796
# Initial Cost on Val dataset for this epoch 21 = 0.4810757629294796
# Error on this batch = 0.4809413278140539
# Error on this batch = 0.48102346350006214
# Cost on val dataset after 22 epochs is = 0.4810390023691148
# Initial Cost on Val dataset for this epoch 22 = 0.4810390023691148
# Error on this batch = 0.4809031651288864
# Error on this batch = 0.4809850950965566
# Cost on val dataset after 23 epochs is = 0.4810088663364944
# Initial Cost on Val dataset for this epoch 23 = 0.4810088663364944
# Error on this batch = 0.4808716249855656
# Error on this batch = 0.48095310576939826
# Cost on val dataset after 24 epochs is = 0.480984070567706
# Initial Cost on Val dataset for this epoch 24 = 0.480984070567706
# Error on this batch = 0.4808454316937079
# Error on this batch = 0.4809263063719614
# Cost on val dataset after 25 epochs is = 0.48096360382050196
# Initial Cost on Val dataset for this epoch 25 = 0.48096360382050196
# Error on this batch = 0.4808235808579994
# Error on this batch = 0.48090375406503066
# Cost on val dataset after 26 epochs is = 0.4809466637999177
# Initial Cost on Val dataset for this epoch 26 = 0.4809466637999177
# Error on this batch = 0.4808052756605999
# Error on this batch = 0.48088469579149595
# Cost on val dataset after 27 epochs is = 0.4809326096429872
# Initial Cost on Val dataset for this epoch 27 = 0.4809326096429872
# Error on this batch = 0.4807898796169484
# Error on this batch = 0.4808685260535441
# Cost on val dataset after 28 epochs is = 0.48092092628502725
# Initial Cost on Val dataset for this epoch 28 = 0.48092092628502725
# Error on this batch = 0.48077688115063494
# Error on this batch = 0.480854755033442
# Cost on val dataset after 29 epochs is = 0.4809111974609791
# Initial Cost on Val dataset for this epoch 29 = 0.4809111974609791
# Error on this batch = 0.48076586675715605
# Error on this batch = 0.4808429842867645
# Cost on val dataset after 30 epochs is = 0.4809030850563804
# Initial Cost on Val dataset for this epoch 30 = 0.4809030850563804
# Error on this batch = 0.4807565004827841
# Error on this batch = 0.4808328880418841
# Cost on val dataset after 31 epochs is = 0.48089631317802645
# Initial Cost on Val dataset for this epoch 31 = 0.48089631317802645
# Error on this batch = 0.48074850809703046
# Error on this batch = 0.480824198693183
# Cost on val dataset after 32 epochs is = 0.48089065576782614
# Initial Cost on Val dataset for this epoch 32 = 0.48089065576782614
# Error on this batch = 0.4807416647883722
# Error on this batch = 0.48081669546142763
# Cost on val dataset after 33 epochs is = 0.4808859269011762
# Initial Cost on Val dataset for this epoch 33 = 0.4808859269011762
# Error on this batch = 0.48073578552911655
# Error on this batch = 0.4808101954672651
# Cost on val dataset after 34 epochs is = 0.48088197313665115
# Initial Cost on Val dataset for this epoch 34 = 0.48088197313665115
# Error on this batch = 0.48073071747960255
# Error on this batch = 0.4808045466584491
# Cost on val dataset after 35 epochs is = 0.4808786674455882
# Initial Cost on Val dataset for this epoch 35 = 0.4808786674455882
# Error on this batch = 0.4807263339628814
# Error on this batch = 0.4807996221719646
# Cost on val dataset after 36 epochs is = 0.48087590436744887
# Initial Cost on Val dataset for this epoch 36 = 0.48087590436744887
# Error on this batch = 0.4807225296577029
# Error on this batch = 0.4807953158147514
# Cost on val dataset after 37 epochs is = 0.4808735961227316
# Initial Cost on Val dataset for this epoch 37 = 0.4808735961227316
# Error on this batch = 0.4807192167430776
# Error on this batch = 0.4807915384222274
# Cost on val dataset after 38 epochs is = 0.4808716694786837
# Initial Cost on Val dataset for this epoch 38 = 0.4808716694786837
# Error on this batch = 0.480716321790812
# Error on this batch = 0.4807882149099143
# Cost on val dataset after 39 epochs is = 0.48087006321036885
# Initial Cost on Val dataset for this epoch 39 = 0.48087006321036885
# Error on this batch = 0.4807137832494726
# Error on this batch = 0.48078528187548425
# Cost on val dataset after 40 epochs is = 0.4808687260351969
# Initial Cost on Val dataset for this epoch 40 = 0.4808687260351969
# Error on this batch = 0.4807115493985887
# Error on this batch = 0.4807826856402851
# Cost on val dataset after 41 epochs is = 0.4808676149259408
# Initial Cost on Val dataset for this epoch 41 = 0.4808676149259408
# Error on this batch = 0.4807095766786691
# Error on this batch = 0.48078038064353323
# Cost on val dataset after 42 epochs is = 0.4808666937277846
# Initial Cost on Val dataset for this epoch 42 = 0.4808666937277846
# Error on this batch = 0.48070782832302356
# Error on this batch = 0.48077832812085136
# Cost on val dataset after 43 epochs is = 0.48086593202071254
# Initial Cost on Val dataset for this epoch 43 = 0.48086593202071254
# Error on this batch = 0.480706273233045
# Error on this batch = 0.4807764950130802
# Cost on val dataset after 44 epochs is = 0.4808653041807165
# Initial Cost on Val dataset for this epoch 44 = 0.4808653041807165
# Error on this batch = 0.4807048850507188
# Error on this batch = 0.4807748530623526
# Cost on val dataset after 45 epochs is = 0.48086478860277004
# Initial Cost on Val dataset for this epoch 45 = 0.48086478860277004
# Error on this batch = 0.48070364139153426
# Error on this batch = 0.4807733780610436
# Cost on val dataset after 46 epochs is = 0.48086436705591123
# Initial Cost on Val dataset for this epoch 46 = 0.48086436705591123
# Error on this batch = 0.48070252320833123
# Error on this batch = 0.4807720492259838
# Cost on val dataset after 47 epochs is = 0.48086402414659396
# Initial Cost on Val dataset for this epoch 47 = 0.48086402414659396
# Error on this batch = 0.48070151426239366
# Error on this batch = 0.480770848675661
# Cost on val dataset after 48 epochs is = 0.48086374687106065
# Initial Cost on Val dataset for this epoch 48 = 0.48086374687106065
# Error on this batch = 0.4807006006826754
# Error on this batch = 0.480769760992371
# Cost on val dataset after 49 epochs is = 0.48086352424113776
# Initial Cost on Val dataset for this epoch 49 = 0.48086352424113776
# Error on this batch = 0.48069977059766233
# Error on this batch = 0.4807687728546516
# Cost on val dataset after 50 epochs is = 0.480863346970761
# Initial Cost on Val dataset for this epoch 50 = 0.480863346970761
# Error on this batch = 0.48069901382727226
# Error on this batch = 0.48076787272802846
# Cost on val dataset after 51 epochs is = 0.4808632072128712
# cost initial= 0.480863346970761 , cost final=0.4808632072128712 , change in cost= -1.397578898165719e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 5 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 51.000
# The training time = 6.763sec
# The training accuracy is = 3.928%
# The validation accuracy is = 3.385%
# The test accuracy is = 3.846%
# ------------------------------------------------------------------------------
#
# (785, 10) (10, 26)
# Initial Cost on Val dataset for this epoch 1 = 3.2595577614450266
# Error on this batch = 3.259445279895967
# Error on this batch = 0.6219933511536576
# Cost on val dataset after 2 epochs is = 0.5285820531180607
# Initial Cost on Val dataset for this epoch 2 = 0.5285820531180607
# Error on this batch = 0.5280778745583176
# Error on this batch = 0.5050883117159273
# Cost on val dataset after 3 epochs is = 0.49481034150338293
# Initial Cost on Val dataset for this epoch 3 = 0.49481034150338293
# Error on this batch = 0.49453386511571323
# Error on this batch = 0.49060531293985166
# Cost on val dataset after 4 epochs is = 0.4871947978408108
# Initial Cost on Val dataset for this epoch 4 = 0.4871947978408108
# Error on this batch = 0.4869840338660052
# Error on this batch = 0.48591164894684746
# Cost on val dataset after 5 epochs is = 0.48430357122541523
# Initial Cost on Val dataset for this epoch 5 = 0.48430357122541523
# Error on this batch = 0.4841201785551957
# Error on this batch = 0.4838319208511444
# Cost on val dataset after 6 epochs is = 0.48293354161904717
# Initial Cost on Val dataset for this epoch 6 = 0.48293354161904717
# Error on this batch = 0.4827631113713777
# Error on this batch = 0.4827500365638693
# Cost on val dataset after 7 epochs is = 0.4821988161088064
# Initial Cost on Val dataset for this epoch 7 = 0.4821988161088064
# Error on this batch = 0.4820346030326107
# Error on this batch = 0.48212892415418007
# Cost on val dataset after 8 epochs is = 0.481772549496311
# ...
# Error on this batch = 0.023547633712746947
# Error on this batch = 0.02139065404420197
# Cost on val dataset after 3414 epochs is = 0.07179253355880333
# Initial Cost on Val dataset for this epoch 3414 = 0.07179253355880333
# Error on this batch = 0.023545495987167105
# Error on this batch = 0.021387788369343134
# Cost on val dataset after 3415 epochs is = 0.07179134338859192
# Initial Cost on Val dataset for this epoch 3415 = 0.07179134338859192
# Error on this batch = 0.023543359254888197
# Error on this batch = 0.02138492363679753
# Cost on val dataset after 3416 epochs is = 0.07179015605919138
# Initial Cost on Val dataset for this epoch 3416 = 0.07179015605919138
# Error on this batch = 0.02354122350273885
# Error on this batch = 0.02138205981061694
# Cost on val dataset after 3417 epochs is = 0.07178897158581926
# Initial Cost on Val dataset for this epoch 3417 = 0.07178897158581926
# Error on this batch = 0.023539088717601617
# Error on this batch = 0.021379196855205073
# Cost on val dataset after 3418 epochs is = 0.07178778998356404
# Initial Cost on Val dataset for this epoch 3418 = 0.07178778998356404
# Error on this batch = 0.023536954886417202
# Error on this batch = 0.021376334735320072
# Cost on val dataset after 3419 epochs is = 0.07178661126738145
# Initial Cost on Val dataset for this epoch 3419 = 0.07178661126738145
# Error on this batch = 0.02353482199618866
# Error on this batch = 0.021373473416076743
# Cost on val dataset after 3420 epochs is = 0.07178543545209115
# Initial Cost on Val dataset for this epoch 3420 = 0.07178543545209115
# Error on this batch = 0.02353269003398547
# Error on this batch = 0.02137061286294852
# Cost on val dataset after 3421 epochs is = 0.07178426255237338
# Initial Cost on Val dataset for this epoch 3421 = 0.07178426255237338
# Error on this batch = 0.023530558986947635
# Error on this batch = 0.021367753041769237
# Cost on val dataset after 3422 epochs is = 0.07178309258276558
# Initial Cost on Val dataset for this epoch 3422 = 0.07178309258276558
# Error on this batch = 0.02352842884228962
# Error on this batch = 0.021364893918734574
# Cost on val dataset after 3423 epochs is = 0.07178192555765901
# Initial Cost on Val dataset for this epoch 3423 = 0.07178192555765901
# Error on this batch = 0.02352629958730425
# Error on this batch = 0.02136203546040325
# Cost on val dataset after 3424 epochs is = 0.07178076149129574
# Initial Cost on Val dataset for this epoch 3424 = 0.07178076149129574
# Error on this batch = 0.023524171209366534
# Error on this batch = 0.021359177633698042
# Cost on val dataset after 3425 epochs is = 0.07177960039776526
# Initial Cost on Val dataset for this epoch 3425 = 0.07177960039776526
# Error on this batch = 0.02352204369593739
# Error on this batch = 0.021356320405906546
# Cost on val dataset after 3426 epochs is = 0.07177844229100142
# Initial Cost on Val dataset for this epoch 3426 = 0.07177844229100142
# Error on this batch = 0.0235199170345673
# Error on this batch = 0.021353463744681615
# Cost on val dataset after 3427 epochs is = 0.07177728718477917
# Initial Cost on Val dataset for this epoch 3427 = 0.07177728718477917
# Error on this batch = 0.02351779121289981
# Error on this batch = 0.021350607618041754
# Cost on val dataset after 3428 epochs is = 0.07177613509271175
# Initial Cost on Val dataset for this epoch 3428 = 0.07177613509271175
# Error on this batch = 0.023515666218675017
# Error on this batch = 0.021347751994371205
# Cost on val dataset after 3429 epochs is = 0.07177498602824726
# Initial Cost on Val dataset for this epoch 3429 = 0.07177498602824726
# Error on this batch = 0.02351354203973293
# Error on this batch = 0.0213448968424198
# Cost on val dataset after 3430 epochs is = 0.07177384000466605
# Initial Cost on Val dataset for this epoch 3430 = 0.07177384000466605
# Error on this batch = 0.02351141866401667
# Error on this batch = 0.02134204213130272
# Cost on val dataset after 3431 epochs is = 0.0717726970350773
# Initial Cost on Val dataset for this epoch 3431 = 0.0717726970350773
# Error on this batch = 0.02350929607957564
# Error on this batch = 0.021339187830499973
# Cost on val dataset after 3432 epochs is = 0.07177155713241627
# Initial Cost on Val dataset for this epoch 3432 = 0.07177155713241627
# Error on this batch = 0.02350717427456851
# Error on this batch = 0.02133633390985577
# Cost on val dataset after 3433 epochs is = 0.07177042030944128
# Initial Cost on Val dataset for this epoch 3433 = 0.07177042030944128
# Error on this batch = 0.023505053237266173
# Error on this batch = 0.021333480339577732
# Cost on val dataset after 3434 epochs is = 0.07176928657873075
# Initial Cost on Val dataset for this epoch 3434 = 0.07176928657873075
# Error on this batch = 0.02350293295605451
# Error on this batch = 0.02133062709023587
# Cost on val dataset after 3435 epochs is = 0.07176815595268017
# Initial Cost on Val dataset for this epoch 3435 = 0.07176815595268017
# Error on this batch = 0.023500813419437067
# Error on this batch = 0.021327774132761483
# Cost on val dataset after 3436 epochs is = 0.07176702844349928
# Initial Cost on Val dataset for this epoch 3436 = 0.07176702844349928
# Error on this batch = 0.02349869461603758
# Error on this batch = 0.021324921438445922
# Cost on val dataset after 3437 epochs is = 0.07176590406320901
# Initial Cost on Val dataset for this epoch 3437 = 0.07176590406320901
# Error on this batch = 0.023496576534602458
# Error on this batch = 0.02132206897893916
# Cost on val dataset after 3438 epochs is = 0.07176478282363868
# Initial Cost on Val dataset for this epoch 3438 = 0.07176478282363868
# Error on this batch = 0.023494459164002977
# Error on this batch = 0.02131921672624831
# Cost on val dataset after 3439 epochs is = 0.07176366473642291
# Initial Cost on Val dataset for this epoch 3439 = 0.07176366473642291
# Error on this batch = 0.02349234249323756
# Error on this batch = 0.02131636465273605
# Cost on val dataset after 3440 epochs is = 0.07176254981299872
# Initial Cost on Val dataset for this epoch 3440 = 0.07176254981299872
# Error on this batch = 0.023490226511433718
# Error on this batch = 0.02131351273111882
# Cost on val dataset after 3441 epochs is = 0.07176143806460261
# Initial Cost on Val dataset for this epoch 3441 = 0.07176143806460261
# Error on this batch = 0.023488111207849986
# Error on this batch = 0.02131066093446506
# Cost on val dataset after 3442 epochs is = 0.07176032950226759
# Initial Cost on Val dataset for this epoch 3442 = 0.07176032950226759
# Error on this batch = 0.02348599657187766
# Error on this batch = 0.021307809236193284
# Cost on val dataset after 3443 epochs is = 0.07175922413682015
# Initial Cost on Val dataset for this epoch 3443 = 0.07175922413682015
# Error on this batch = 0.02348388259304244
# Error on this batch = 0.021304957610070112
# Cost on val dataset after 3444 epochs is = 0.0717581219788773
# Initial Cost on Val dataset for this epoch 3444 = 0.0717581219788773
# Error on this batch = 0.02348176926100588
# Error on this batch = 0.021302106030208236
# Cost on val dataset after 3445 epochs is = 0.07175702303884358
# Initial Cost on Val dataset for this epoch 3445 = 0.07175702303884358
# Error on this batch = 0.023479656565566748
# Error on this batch = 0.02129925447106432
# Cost on val dataset after 3446 epochs is = 0.071755927326908
# Initial Cost on Val dataset for this epoch 3446 = 0.071755927326908
# Error on this batch = 0.023477544496662183
# Error on this batch = 0.021296402907436826
# Cost on val dataset after 3447 epochs is = 0.07175483485304096
# Initial Cost on Val dataset for this epoch 3447 = 0.07175483485304096
# Error on this batch = 0.023475433044368794
# Error on this batch = 0.02129355131446382
# Cost on val dataset after 3448 epochs is = 0.07175374562699123
# Initial Cost on Val dataset for this epoch 3448 = 0.07175374562699123
# Error on this batch = 0.023473322198903503
# Error on this batch = 0.021290699667620733
# Cost on val dataset after 3449 epochs is = 0.07175265965828286
# Initial Cost on Val dataset for this epoch 3449 = 0.07175265965828286
# Error on this batch = 0.02347121195062432
# Error on this batch = 0.02128784794271812
# Cost on val dataset after 3450 epochs is = 0.07175157695621198
# Initial Cost on Val dataset for this epoch 3450 = 0.07175157695621198
# Error on this batch = 0.023469102290030974
# Error on this batch = 0.02128499611589935
# Cost on val dataset after 3451 epochs is = 0.07175049752984383
# Initial Cost on Val dataset for this epoch 3451 = 0.07175049752984383
# Error on this batch = 0.0234669932077653
# Error on this batch = 0.021282144163638286
# Cost on val dataset after 3452 epochs is = 0.07174942138800933
# Initial Cost on Val dataset for this epoch 3452 = 0.07174942138800933
# Error on this batch = 0.023464884694611613
# Error on this batch = 0.021279292062737046
# Cost on val dataset after 3453 epochs is = 0.07174834853930212
# Initial Cost on Val dataset for this epoch 3453 = 0.07174834853930212
# Error on this batch = 0.023462776741496827
# Error on this batch = 0.02127643979032366
# Cost on val dataset after 3454 epochs is = 0.07174727899207525
# Initial Cost on Val dataset for this epoch 3454 = 0.07174727899207525
# Error on this batch = 0.02346066933949044
# Error on this batch = 0.021273587323849697
# Cost on val dataset after 3455 epochs is = 0.07174621275443789
# Initial Cost on Val dataset for this epoch 3455 = 0.07174621275443789
# Error on this batch = 0.02345856247980441
# Error on this batch = 0.021270734641088095
# Cost on val dataset after 3456 epochs is = 0.07174514983425222
# Initial Cost on Val dataset for this epoch 3456 = 0.07174514983425222
# Error on this batch = 0.023456456153792854
# Error on this batch = 0.021267881720130766
# Cost on val dataset after 3457 epochs is = 0.07174409023912985
# Initial Cost on Val dataset for this epoch 3457 = 0.07174409023912985
# Error on this batch = 0.023454350352951573
# Error on this batch = 0.0212650285393864
# Cost on val dataset after 3458 epochs is = 0.07174303397642888
# Initial Cost on Val dataset for this epoch 3458 = 0.07174303397642888
# Error on this batch = 0.023452245068917472
# Error on this batch = 0.02126217507757822
# Cost on val dataset after 3459 epochs is = 0.07174198105325025
# Initial Cost on Val dataset for this epoch 3459 = 0.07174198105325025
# Error on this batch = 0.02345014029346775
# Error on this batch = 0.021259321313741787
# Cost on val dataset after 3460 epochs is = 0.07174093147643461
# Initial Cost on Val dataset for this epoch 3460 = 0.07174093147643461
# Error on this batch = 0.02344803601851908
# Error on this batch = 0.021256467227222766
# Cost on val dataset after 3461 epochs is = 0.0717398852525588
# Initial Cost on Val dataset for this epoch 3461 = 0.0717398852525588
# Error on this batch = 0.02344593223612647
# Error on this batch = 0.021253612797674886
# Cost on val dataset after 3462 epochs is = 0.07173884238793256
# Initial Cost on Val dataset for this epoch 3462 = 0.07173884238793256
# Error on this batch = 0.023443828938482094
# Error on this batch = 0.021250758005057754
# Cost on val dataset after 3463 epochs is = 0.07173780288859508
# Initial Cost on Val dataset for this epoch 3463 = 0.07173780288859508
# Error on this batch = 0.023441726117913876
# Error on this batch = 0.021247902829634877
# Cost on val dataset after 3464 epochs is = 0.07173676676031174
# Initial Cost on Val dataset for this epoch 3464 = 0.07173676676031174
# Error on this batch = 0.023439623766884098
# Error on this batch = 0.021245047251971582
# Cost on val dataset after 3465 epochs is = 0.07173573400857045
# Initial Cost on Val dataset for this epoch 3465 = 0.07173573400857045
# Error on this batch = 0.02343752187798761
# Error on this batch = 0.02124219125293307
# Cost on val dataset after 3466 epochs is = 0.07173470463857858
# Initial Cost on Val dataset for this epoch 3466 = 0.07173470463857858
# Error on this batch = 0.023435420443950097
# Error on this batch = 0.021239334813682616
# Cost on val dataset after 3467 epochs is = 0.07173367865525922
# Initial Cost on Val dataset for this epoch 3467 = 0.07173367865525922
# Error on this batch = 0.023433319457626132
# Error on this batch = 0.021236477915679508
# Cost on val dataset after 3468 epochs is = 0.07173265606324808
# Initial Cost on Val dataset for this epoch 3468 = 0.07173265606324808
# Error on this batch = 0.02343121891199707
# Error on this batch = 0.021233620540677435
# Cost on val dataset after 3469 epochs is = 0.07173163686688994
# Initial Cost on Val dataset for this epoch 3469 = 0.07173163686688994
# Error on this batch = 0.02342911880016878
# Error on this batch = 0.021230762670722526
# Cost on val dataset after 3470 epochs is = 0.07173062107023535
# Initial Cost on Val dataset for this epoch 3470 = 0.07173062107023535
# Error on this batch = 0.02342701911536932
# Error on this batch = 0.021227904288151817
# Cost on val dataset after 3471 epochs is = 0.0717296086770373
# Initial Cost on Val dataset for this epoch 3471 = 0.0717296086770373
# Error on this batch = 0.023424919850946413
# Error on this batch = 0.021225045375591528
# Cost on val dataset after 3472 epochs is = 0.07172859969074781
# Initial Cost on Val dataset for this epoch 3472 = 0.07172859969074781
# Error on this batch = 0.023422821000364743
# Error on this batch = 0.021222185915955386
# Cost on val dataset after 3473 epochs is = 0.0717275941145148
# Initial Cost on Val dataset for this epoch 3473 = 0.0717275941145148
# Error on this batch = 0.02342072255720319
# Error on this batch = 0.021219325892443183
# Cost on val dataset after 3474 epochs is = 0.07172659195117871
# Initial Cost on Val dataset for this epoch 3474 = 0.07172659195117871
# Error on this batch = 0.023418624515151948
# Error on this batch = 0.021216465288539172
# Cost on val dataset after 3475 epochs is = 0.07172559320326947
# Initial Cost on Val dataset for this epoch 3475 = 0.07172559320326947
# Error on this batch = 0.023416526868009397
# Error on this batch = 0.02121360408801067
# Cost on val dataset after 3476 epochs is = 0.07172459787300317
# Initial Cost on Val dataset for this epoch 3476 = 0.07172459787300317
# Error on this batch = 0.023414429609678954
# Error on this batch = 0.0212107422749066
# Cost on val dataset after 3477 epochs is = 0.07172360596227903
# Initial Cost on Val dataset for this epoch 3477 = 0.07172360596227903
# Error on this batch = 0.02341233273416578
# Error on this batch = 0.02120787983355611
# Cost on val dataset after 3478 epochs is = 0.07172261747267643
# Initial Cost on Val dataset for this epoch 3478 = 0.07172261747267643
# Error on this batch = 0.023410236235573284
# Error on this batch = 0.021205016748567243
# Cost on val dataset after 3479 epochs is = 0.07172163240545179
# Initial Cost on Val dataset for this epoch 3479 = 0.07172163240545179
# Error on this batch = 0.023408140108099634
# Error on this batch = 0.021202153004825683
# Cost on val dataset after 3480 epochs is = 0.071720650761536
# Initial Cost on Val dataset for this epoch 3480 = 0.071720650761536
# Error on this batch = 0.02340604434603403
# Error on this batch = 0.02119928858749341
# Cost on val dataset after 3481 epochs is = 0.07171967254153122
# Initial Cost on Val dataset for this epoch 3481 = 0.07171967254153122
# Error on this batch = 0.02340394894375292
# Error on this batch = 0.0211964234820075
# Cost on val dataset after 3482 epochs is = 0.07171869774570842
# Initial Cost on Val dataset for this epoch 3482 = 0.07171869774570842
# Error on this batch = 0.023401853895716095
# Error on this batch = 0.021193557674078937
# Cost on val dataset after 3483 epochs is = 0.07171772637400461
# Initial Cost on Val dataset for this epoch 3483 = 0.07171772637400461
# Error on this batch = 0.023399759196462703
# Error on this batch = 0.021190691149691403
# Cost on val dataset after 3484 epochs is = 0.07171675842602047
# cost initial= 0.07171772637400461 , cost final=0.07171675842602047 , change in cost= -9.679479841401273e-07
#
# ------------------------------------------------------------------------------
# The stats for number of units in the hidden layer = 100 are as below:
# ------------------------------------------------------------------------------
# The number of epochs = 3484.000
# The training time = 1338.063sec
# The training accuracy is = 97.520%
# The validation accuracy is = 92.359%
# The test accuracy is = 90.800%
# ------------------------------------------------------------------------------

# %%
calc_accuracy(X_test, theta, test_actual_class_enc)
epochs
train_accuracy
test_accuracy
valid_accuracy
train_time
# Out:
# [16.71267580986023,
#  6.762736082077026,
#  5.028317451477051,
#  634.4019582271576,
#  1338.062512397766]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Accuracy with Epochs for #HU=100")
#x = np.arange(0,len(costs))
ax.plot(plt_epoch, plt_train_acc, marker='o', label='Train Accuracy')
ax.plot(plt_epoch, plt_val_acc, marker='o', label='Valid Accuracy')
ax.plot(plt_epoch, plt_test_acc, marker='o', label='Test Accuracy')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Accuracy")

plt.legend()
#plt.savefig("plots/val_loss/accuracy_HiddenUnit100_valloss15per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Validation Loss with Epochs for #HU=100")
x = np.arange(0,len(costs))
ax.plot(x, costs, marker='o', label='Validation Loss')
ax.set_xlabel("number of epochs")
ax.set_ylabel("Validation Loss")

plt.legend()
#plt.savefig("plots/val_loss/partb_val_loss15per_100units.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
len(costs)
# Out:
# 17649

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("Accuracy with number of hidden units \n in one hidden layer network")
ax.plot(arch_test, train_accuracy, marker='o', label='Train Accuracy')
ax.plot(arch_test, valid_accuracy, marker='o',label='Validation Accuracy')
ax.plot(arch_test, test_accuracy, marker='o', label='Test Accuracy')
ax.set_xlabel("number of hidden units")
ax.set_ylabel("Accuracy (%)")

plt.legend()
#plt.savefig("accuracy_HiddenUnit_val20per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(211)
plt.title("Epochs/Time with number of hidden units \n in one hidden layer network")
ax.plot(arch_test, epochs, c='b', marker='o', label='#epochs')
ax.set_xlabel("number of hidden units")
ax.set_ylabel("Epochs")
ax.legend()

ax1 = fig.add_subplot(212)
ax1.plot(arch_test, train_time, c='b', marker='o', label='train time')
ax1.set_xlabel("number of hidden units")
ax1.set_ylabel("train time(sec)")
plt.legend()
#plt.savefig("epochs_time_HiddenUnit_val20per.png", dpi=1000, bbox_inches='tight')
plt.show()

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ax.set_title("Accuracy with number of epochs for \n 1 hidden layer of 100 units")
# ax.plot(plt_epoch, plt_train_acc, c='b', label='Train Accuracy')
# ax.plot(plt_epoch, plt_val_acc, c='m',label='Validation Accuracy')
# ax.plot(plt_epoch, plt_test_acc, c='g', label='Test Accuracy')
# ax.set_xlabel("number of epochs")
# ax.set_ylabel("Accuracy (%)")
#
# plt.legend()
# #plt.savefig("accuracy_epoch_100_valloss.png", dpi=1000, bbox_inches='tight')
# plt.show()
